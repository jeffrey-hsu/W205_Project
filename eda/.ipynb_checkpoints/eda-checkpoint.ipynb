# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm
import seaborn as sns
from IPython.display import display

# %%
# Load financial suite from Wharton
df = pd.read_csv('c:/users/sconner/Desktop/W205_Final/financialsuite.csv')

# %%
# Overview of source dataset
return_all_columns(df)
# Out:
#          permno       adate       qdate public_date    CAPEI     bm       evm  \
# 0         10006  04/30/1969  09/30/1969  01/31/1970   11.609  0.795     6.896
# 1         28601  02/28/1969  11/30/1969  01/31/1970   34.805    NaN    19.509
# 2         10014  03/31/1969  09/30/1969  01/31/1970   50.490  0.386    18.112
# 3         15763  12/31/1968  09/30/1969  01/31/1970   13.153  0.366     8.245
# 4         18980  07/31/1969  10/31/1969  01/31/1970   17.768  0.388     8.690
# 5         37591         NaN  09/30/1969  01/31/1970   55.316    NaN       NaN
# 6         21020  12/31/1968  09/30/1969  01/31/1970   11.967  0.728     8.980
# 7         28636  06/30/1969  09/30/1969  01/31/1970    9.433  0.379    10.684
# 8         28652  09/30/1969  09/30/1969  01/31/1970   22.200  0.682     8.181
# 9         21549  12/31/1968  09/30/1969  01/31/1970      NaN  0.773  8875.590
# 10        27991  12/31/1968  09/30/1969  01/31/1970   10.863  0.642    11.653
# ...

# %%
def return_all_rows(x):
    pd.set_option('display.max_rows', len(x))
    return x
    pd.reset_option('display.max_rows')
    
def return_all_columns(x):
    pd.set_option('display.max_columns', len(x))
    return x
    pd.reset_option('display.max_columns')

# %%
# Upload of the financial suite variables and their descriptions
financialsuite_variables = pd.read_csv('c:/users/sconner/Desktop/W205_Final/W205_Project/eda/financialsuite_variables.csv')
return_all_rows(financialsuite_variables)
# Out:
#       Variable Name Data Type                            Variable Description
# 0           Accrual       NUM                         Accruals/Average Assets
# 1          adv_sale       NUM                       Avertising Expenses/Sales
# 2         aftret_eq       NUM       After-tax Return on Average Common Equity
# 3     aftret_equity       NUM   After-tax Return on Total Stockholders Equity
# 4    aftret_invcapx       NUM            After-tax Return on Invested Capital
# 5           at_turn       NUM                                  Asset Turnover
# 6                bm       NUM                                     Book/Market
# 7             capei       NUM          Shillers Cyclically Adjusted P/E Ratio
# 8     capital_ratio       NUM                            Capitalization Ratio
# 9   cash_conversion       NUM                    Cash Conversion Cycle (Days)
# 10        cash_debt       NUM                            Cash Flow/Total Debt
# ...
