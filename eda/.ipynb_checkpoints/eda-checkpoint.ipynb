# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm
import seaborn as sns
from IPython.display import display
import datetime
import numpy as np
from statsmodels import robust
from sklearn import preprocessing
from sklearn.preprocessing import Imputer
from scipy import stats
from scipy.stats import zscore

# %%
def null_ratio(df):
        null_count = df.isnull().sum()
        null_percent = 100 * df.isnull().sum()/len(df)
        null_table = pd.concat([null_count, null_percent], axis=1)
        null_table = null_table.rename(columns = {0 : 'Null Count', 1 : 'Null Percent'})
        return null_table.sort_values('Null Percent', ascending=0)

# %%
def return_all_rows(x):
    pd.set_option('display.max_rows', len(x))
    return x
    pd.reset_option('display.max_rows')
    
def return_all_columns(x):
    pd.set_option('display.max_columns', len(x))
    return x.head(5)
    pd.reset_option('display.max_columns')

# %%
def overview(df):
    print("Number of columns:", len(df.columns))
    print("Number of rows:", len(df.index))
    df.head(5)

# %%
def drop_dups(df):
    # list comprehension of the cols that end with '_y'
    y_drop = [x for x in df if x.endswith('_y')]
    df.drop(y_drop, axis=1, inplace=True)

# %%
def floatToString(inputValue):
    result = ('%.15f' % inputValue).rstrip('0').rstrip('.')
    return '0' if result == '-0' else result

# %%
def mad(array):
    """ 
    Get Median Absolute Deviation and multiple by 1.486 to mimic standard deviation
        https://www.ibm.com/support/knowledgecenter/SSWLVY_1.0.0/com.ibm.spss.analyticcatalyst.help/analytic_catalyst/modified_z.html
    Median Absolute Deviation: a "Robust" version of standard deviation.
        Indices variabililty of the sample.
        https://en.wikipedia.org/wiki/Median_absolute_deviation
    """
    array = np.ma.array(array).compressed()
    median = np.nanmedian(array)
    mad = np.nanmedian(np.abs(array - median))
    return mad

# %%
def meanad(array):
    """ 
    Get Mean Absolute Deviation and multiple by 1.253314 to mimic standard deviation
        https://www.ibm.com/support/knowledgecenter/SSWLVY_1.0.0/com.ibm.spss.analyticcatalyst.help/analytic_catalyst/modified_z.html
    Mean Absolute Deviation: a "Robust" version of standard deviation.
        Indices variabililty of the sample.
        https://en.wikipedia.org/wiki/Mean_absolute_deviation
    """
    array = np.ma.array(array).compressed()
    median = np.nanmedian(array)
    mad = np.nanmean(np.abs(array - median))
    return mad

# %%
def modified_z(array):
    try:
        try:
            
            try:
                median = np.nanmedian(array)
                denominator = mad(array) * 1.486
                array = (array - median) / denominator
                return array
            
            except:
                median = np.nanmedian(array)
                denominator = meanad(array) * 1.253314
                array = (array - median) / denominator
                return array
        
        except:
            mean = np.nanmean(array)
            denominator = np.nanstd(array)
            array = (array - mean) / denominator
            return array
    
    except:
        array = array.fillna(0)

# %%
def fill_null(column):
    try:
        median = np.nanmedian(column)
        column = column.fillna(median)
        return column
    except:
        return column

# %%
def impute_null(column):
    try:
        imp = Imputer(missing_values='NaN', strategy='median', axis=0)
        imp.fit(column)
        column = imp.transform(column)
        return column
    except:
        return column

# %%
def clip_outliers(column):
    
    # Use try in case all null column
    try:
        floor = column.quantile(0.02)
        ceiling = column.quantile(0.98)
        column = column.clip(floor, ceiling)
        return column
    # If error, return as is
    except:
        return column

# %%
# df - Load
df = pd.read_csv('c:/users/shane/Desktop/W205_Final/sample_data/Sample_Financial_Ratios_Firm_Level.csv')

# %%
# Link Table - Load
link_table = pd.read_csv('c:/users/shane/Desktop/W205_Final/sample_data/Sample_CRSP_Compustat_Merged_Linking_Table.csv')

# %%
# Link Table - Clean - LINKENDDT
# Replace 'E' values with future date (current unique ID)
link_table['LINKENDDT'] = link_table['LINKENDDT'].str.replace('E','20200101').astype(int)

# %%
# Link Table - Clean - LPERMNO
# Convert PERMNO from int to object
link_table['LPERMNO'] = link_table['LPERMNO'].astype(object)

# %%
# Link Table - Clean - LINKDT & LINKENDDT
# Get start and end dates for link to determine identification during given time
link_table['LINKDT'] = pd.to_datetime(link_table['LINKDT'], format='%Y%m%d')
link_table['LINKENDDT'] = pd.to_datetime(link_table['LINKENDDT'], format='%Y%m%d')

# %%
# Merge - df & Link Table
# Merge financial ratio suite with link table to build more foreign keys
df = pd.merge(df, link_table, on='gvkey', how='left', suffixes=('', '_y'))
# Release Memory
del link_table

# %%
# df - Enrich - Time Features
# Convert to time
df['public_date'] = pd.to_datetime(df['public_date'])
# Create year
df['year'] = df['public_date'].dt.year
# Create month
df['month'] = df['public_date'].dt.month
# Create year-month
df["year-month"] = df['public_date'].apply(lambda x: x.strftime('%Y-%m'))

# %%
# df - Enrich - Time-based Unique Identifiers
# Create Unique Identifier for links from other databases for specific date-time
df["GVKEY-year-month"] = df["gvkey"].map(str) + "-" + df["year-month"]
df["CUSIP-year-month"] = df["cusip"].map(str) + "-" + df["year-month"]
df["TIC-year-month"] = df["tic"].map(str) + "-" + df["year-month"]
df["PERMNO-year-month"] = df["LPERMNO"].map(str) + "-" + df["year-month"]

# %%
# df - Subset - Correct Unique ID's per public data
# Filter dataframe to rows of unique identifiers during correct link range
df = df[(df.public_date >= df.LINKDT) & (df.public_date <= df.LINKENDDT)]

# %%
# CRSP - Load
# Load CRSP/Compustat Merged Database - Security Monthly from Wharton
CRSP_comp_merge = pd.read_csv('c:/users/shane/desktop/W205_Final/sample_data/Sample_CRSP_Compustat_Merged_Security_Monthly.csv', low_memory=False)

# %%
# CRSP - Enrich - Time Features

# Convert to date-time
CRSP_comp_merge['datadate'] = pd.to_datetime(CRSP_comp_merge['datadate'])
# Create year
CRSP_comp_merge['year'] = CRSP_comp_merge['datadate'].dt.year
# Create month
CRSP_comp_merge['month'] = CRSP_comp_merge['datadate'].dt.month
# Create year-month
CRSP_comp_merge["year-month"] = CRSP_comp_merge['datadate'].apply(lambda x: x.strftime('%Y-%m'))

# %%
# CRSP - Enrich - Time-based Unique Identifiers
# CRSP - Unique ID in time (GVKEY + time-month)
CRSP_comp_merge["GVKEY-year-month"] = CRSP_comp_merge["GVKEY"].map(str) + "-" + CRSP_comp_merge["year-month"]

# %%
# CRSP - Sort - Date and GVKEY
CRSP_comp_merge = CRSP_comp_merge.sort_values(by=['GVKEY','datadate'], ascending=[True,True])

# %%
# CRSP - Enrich - Forward (PRCCM -- Price - Close - Monthly) 1 – 36 months
CRSP_comp_merge['forward_one_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-1)
CRSP_comp_merge['forward_two_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-2)
CRSP_comp_merge['forward_three_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-3)
CRSP_comp_merge['forward_four_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-4)
CRSP_comp_merge['forward_five_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-5)
CRSP_comp_merge['forward_six_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-6)
CRSP_comp_merge['forward_seven_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-7)
CRSP_comp_merge['forward_eight_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-8)
CRSP_comp_merge['forward_nine_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-9)
CRSP_comp_merge['forward_ten_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-10)
CRSP_comp_merge['forward_eleven_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-11)
CRSP_comp_merge['forward_twelve_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-12)
CRSP_comp_merge['forward_thirteen_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-13)
CRSP_comp_merge['forward_fourteen_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-14)
CRSP_comp_merge['forward_fifteen_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-15)
CRSP_comp_merge['forward_sixteen_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-16)
CRSP_comp_merge['forward_seventeen_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-17)
CRSP_comp_merge['forward_eighteen_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-18)
CRSP_comp_merge['forward_nineteen_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-19)
CRSP_comp_merge['forward_twenty_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-20)
CRSP_comp_merge['forward_twentyone_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-21)
CRSP_comp_merge['forward_twentytwo_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-22)
CRSP_comp_merge['forward_twentythree_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-23)
CRSP_comp_merge['forward_twentyfour_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-24)
CRSP_comp_merge['forward_twentyfive_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-25)
CRSP_comp_merge['forward_twentysix_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-26)
CRSP_comp_merge['forward_twentyseven_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-27)
CRSP_comp_merge['forward_twentyeight_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-28)
CRSP_comp_merge['forward_twentynine_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-29)
CRSP_comp_merge['forward_thirty_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-30)
CRSP_comp_merge['forward_thirtyone_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-31)
CRSP_comp_merge['forward_thirtytwo_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-32)
CRSP_comp_merge['forward_thirtythree_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-33)
CRSP_comp_merge['forward_thirtyfour_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-34)
CRSP_comp_merge['forward_thirtyfive_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-35)
CRSP_comp_merge['forward_thirtysix_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-36)

# %%
# CRSP - Enrich - Forward (AJEXM -- Cumulative Adjustment Factor - Ex Date -Monthly) 1 – 36 months
CRSP_comp_merge['forward_one_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-1)
CRSP_comp_merge['forward_two_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-2)
CRSP_comp_merge['forward_three_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-3)
CRSP_comp_merge['forward_four_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-4)
CRSP_comp_merge['forward_five_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-5)
CRSP_comp_merge['forward_six_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-6)
CRSP_comp_merge['forward_seven_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-7)
CRSP_comp_merge['forward_eight_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-8)
CRSP_comp_merge['forward_nine_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-9)
CRSP_comp_merge['forward_ten_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-10)
CRSP_comp_merge['forward_eleven_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-11)
CRSP_comp_merge['forward_twelve_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-12)
CRSP_comp_merge['forward_thirteen_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-13)
CRSP_comp_merge['forward_fourteen_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-14)
CRSP_comp_merge['forward_fifteen_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-15)
CRSP_comp_merge['forward_sixteen_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-16)
CRSP_comp_merge['forward_seventeen_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-17)
CRSP_comp_merge['forward_eighteen_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-18)
CRSP_comp_merge['forward_nineteen_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-19)
CRSP_comp_merge['forward_twenty_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-20)
CRSP_comp_merge['forward_twentyone_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-21)
CRSP_comp_merge['forward_twentytwo_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-22)
CRSP_comp_merge['forward_twentythree_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-23)
CRSP_comp_merge['forward_twentyfour_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-24)
CRSP_comp_merge['forward_twentyfive_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-25)
CRSP_comp_merge['forward_twentysix_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-26)
CRSP_comp_merge['forward_twentyseven_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-27)
CRSP_comp_merge['forward_twentyeight_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-28)
CRSP_comp_merge['forward_twentynine_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-29)
CRSP_comp_merge['forward_thirty_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-30)
CRSP_comp_merge['forward_thirtyone_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-31)
CRSP_comp_merge['forward_thirtytwo_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-32)
CRSP_comp_merge['forward_thirtythree_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-33)
CRSP_comp_merge['forward_thirtyfour_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-34)
CRSP_comp_merge['forward_thirtyfive_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-35)
CRSP_comp_merge['forward_thirtysix_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-36)

# %%
# CRSP - Enrich - Forward (TRFM -- Monthly Total Return Factor) 1 – 36 months
CRSP_comp_merge['forward_one_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-1)
CRSP_comp_merge['forward_two_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-2)
CRSP_comp_merge['forward_three_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-3)
CRSP_comp_merge['forward_four_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-4)
CRSP_comp_merge['forward_five_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-5)
CRSP_comp_merge['forward_six_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-6)
CRSP_comp_merge['forward_seven_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-7)
CRSP_comp_merge['forward_eight_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-8)
CRSP_comp_merge['forward_nine_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-9)
CRSP_comp_merge['forward_ten_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-10)
CRSP_comp_merge['forward_eleven_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-11)
CRSP_comp_merge['forward_twelve_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-12)
CRSP_comp_merge['forward_thirteen_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-13)
CRSP_comp_merge['forward_fourteen_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-14)
CRSP_comp_merge['forward_fifteen_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-15)
CRSP_comp_merge['forward_sixteen_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-16)
CRSP_comp_merge['forward_seventeen_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-17)
CRSP_comp_merge['forward_eighteen_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-18)
CRSP_comp_merge['forward_nineteen_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-19)
CRSP_comp_merge['forward_twenty_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-20)
CRSP_comp_merge['forward_twentyone_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-21)
CRSP_comp_merge['forward_twentytwo_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-22)
CRSP_comp_merge['forward_twentythree_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-23)
CRSP_comp_merge['forward_twentyfour_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-24)
CRSP_comp_merge['forward_twentyfive_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-25)
CRSP_comp_merge['forward_twentysix_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-26)
CRSP_comp_merge['forward_twentyseven_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-27)
CRSP_comp_merge['forward_twentyeight_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-28)
CRSP_comp_merge['forward_twentynine_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-29)
CRSP_comp_merge['forward_thirty_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-30)
CRSP_comp_merge['forward_thirtyone_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-31)
CRSP_comp_merge['forward_thirtytwo_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-32)
CRSP_comp_merge['forward_thirtythree_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-33)
CRSP_comp_merge['forward_thirtyfour_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-34)
CRSP_comp_merge['forward_thirtyfive_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-35)
CRSP_comp_merge['forward_thirtysix_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-36)

# %%
# CRSP - Enrich - Forward Return over number of months (1 - 36)
CRSP_comp_merge['forward_one_month_return'] = ((((CRSP_comp_merge['forward_one_month_prccm']/CRSP_comp_merge['forward_one_month_ajexm'])*CRSP_comp_merge['forward_one_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_two_month_return'] = ((((CRSP_comp_merge['forward_two_month_prccm']/CRSP_comp_merge['forward_two_month_ajexm'])*CRSP_comp_merge['forward_two_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_three_month_return'] = ((((CRSP_comp_merge['forward_three_month_prccm']/CRSP_comp_merge['forward_three_month_ajexm'])*CRSP_comp_merge['forward_three_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_four_month_return'] = ((((CRSP_comp_merge['forward_four_month_prccm']/CRSP_comp_merge['forward_four_month_ajexm'])*CRSP_comp_merge['forward_four_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_five_month_return'] = ((((CRSP_comp_merge['forward_five_month_prccm']/CRSP_comp_merge['forward_five_month_ajexm'])*CRSP_comp_merge['forward_five_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_six_month_return'] = ((((CRSP_comp_merge['forward_six_month_prccm']/CRSP_comp_merge['forward_six_month_ajexm'])*CRSP_comp_merge['forward_six_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_seven_month_return'] = ((((CRSP_comp_merge['forward_seven_month_prccm']/CRSP_comp_merge['forward_seven_month_ajexm'])*CRSP_comp_merge['forward_seven_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_eight_month_return'] = ((((CRSP_comp_merge['forward_eight_month_prccm']/CRSP_comp_merge['forward_eight_month_ajexm'])*CRSP_comp_merge['forward_eight_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_nine_month_return'] = ((((CRSP_comp_merge['forward_nine_month_prccm']/CRSP_comp_merge['forward_nine_month_ajexm'])*CRSP_comp_merge['forward_nine_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_ten_month_return'] = ((((CRSP_comp_merge['forward_ten_month_prccm']/CRSP_comp_merge['forward_ten_month_ajexm'])*CRSP_comp_merge['forward_ten_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_eleven_month_return'] = ((((CRSP_comp_merge['forward_eleven_month_prccm']/CRSP_comp_merge['forward_eleven_month_ajexm'])*CRSP_comp_merge['forward_eleven_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_twelve_month_return'] = ((((CRSP_comp_merge['forward_twelve_month_prccm']/CRSP_comp_merge['forward_twelve_month_ajexm'])*CRSP_comp_merge['forward_twelve_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_thirteen_month_return'] = ((((CRSP_comp_merge['forward_thirteen_month_prccm']/CRSP_comp_merge['forward_thirteen_month_ajexm'])*CRSP_comp_merge['forward_thirteen_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_fourteen_month_return'] = ((((CRSP_comp_merge['forward_fourteen_month_prccm']/CRSP_comp_merge['forward_fourteen_month_ajexm'])*CRSP_comp_merge['forward_fourteen_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_fifteen_month_return'] = ((((CRSP_comp_merge['forward_fifteen_month_prccm']/CRSP_comp_merge['forward_fifteen_month_ajexm'])*CRSP_comp_merge['forward_fifteen_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_sixteen_month_return'] = ((((CRSP_comp_merge['forward_sixteen_month_prccm']/CRSP_comp_merge['forward_sixteen_month_ajexm'])*CRSP_comp_merge['forward_sixteen_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_seventeen_month_return'] = ((((CRSP_comp_merge['forward_seventeen_month_prccm']/CRSP_comp_merge['forward_seventeen_month_ajexm'])*CRSP_comp_merge['forward_seventeen_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_eighteen_month_return'] = ((((CRSP_comp_merge['forward_eighteen_month_prccm']/CRSP_comp_merge['forward_eighteen_month_ajexm'])*CRSP_comp_merge['forward_eighteen_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_nineteen_month_return'] = ((((CRSP_comp_merge['forward_nineteen_month_prccm']/CRSP_comp_merge['forward_nineteen_month_ajexm'])*CRSP_comp_merge['forward_nineteen_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_twenty_month_return'] = ((((CRSP_comp_merge['forward_twenty_month_prccm']/CRSP_comp_merge['forward_twenty_month_ajexm'])*CRSP_comp_merge['forward_twenty_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_twentyone_month_return'] = ((((CRSP_comp_merge['forward_twentyone_month_prccm']/CRSP_comp_merge['forward_twentyone_month_ajexm'])*CRSP_comp_merge['forward_twentyone_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_twentytwo_month_return'] = ((((CRSP_comp_merge['forward_twentytwo_month_prccm']/CRSP_comp_merge['forward_twentytwo_month_ajexm'])*CRSP_comp_merge['forward_twentytwo_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_twentythree_month_return'] = ((((CRSP_comp_merge['forward_twentythree_month_prccm']/CRSP_comp_merge['forward_twentythree_month_ajexm'])*CRSP_comp_merge['forward_twentythree_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_twentyfour_month_return'] = ((((CRSP_comp_merge['forward_twentyfour_month_prccm']/CRSP_comp_merge['forward_twentyfour_month_ajexm'])*CRSP_comp_merge['forward_twentyfour_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_twentyfive_month_return'] = ((((CRSP_comp_merge['forward_twentyfive_month_prccm']/CRSP_comp_merge['forward_twentyfive_month_ajexm'])*CRSP_comp_merge['forward_twentyfive_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_twentysix_month_return'] = ((((CRSP_comp_merge['forward_twentysix_month_prccm']/CRSP_comp_merge['forward_twentysix_month_ajexm'])*CRSP_comp_merge['forward_twentysix_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_twentyseven_month_return'] = ((((CRSP_comp_merge['forward_twentyseven_month_prccm']/CRSP_comp_merge['forward_twentyseven_month_ajexm'])*CRSP_comp_merge['forward_twentyseven_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_twentyeight_month_return'] = ((((CRSP_comp_merge['forward_twentyeight_month_prccm']/CRSP_comp_merge['forward_twentyeight_month_ajexm'])*CRSP_comp_merge['forward_twentyeight_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_twentynine_month_return'] = ((((CRSP_comp_merge['forward_twentynine_month_prccm']/CRSP_comp_merge['forward_twentynine_month_ajexm'])*CRSP_comp_merge['forward_twentynine_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_thirty_month_return'] = ((((CRSP_comp_merge['forward_thirty_month_prccm']/CRSP_comp_merge['forward_thirty_month_ajexm'])*CRSP_comp_merge['forward_thirty_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_thirtyone_month_return'] = ((((CRSP_comp_merge['forward_thirtyone_month_prccm']/CRSP_comp_merge['forward_thirtyone_month_ajexm'])*CRSP_comp_merge['forward_thirtyone_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_thirtytwo_month_return'] = ((((CRSP_comp_merge['forward_thirtytwo_month_prccm']/CRSP_comp_merge['forward_thirtytwo_month_ajexm'])*CRSP_comp_merge['forward_thirtytwo_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_thirtythree_month_return'] = ((((CRSP_comp_merge['forward_thirtythree_month_prccm']/CRSP_comp_merge['forward_thirtythree_month_ajexm'])*CRSP_comp_merge['forward_thirtythree_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_thirtyfour_month_return'] = ((((CRSP_comp_merge['forward_thirtyfour_month_prccm']/CRSP_comp_merge['forward_thirtyfour_month_ajexm'])*CRSP_comp_merge['forward_thirtyfour_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_thirtyfive_month_return'] = ((((CRSP_comp_merge['forward_thirtyfive_month_prccm']/CRSP_comp_merge['forward_thirtyfive_month_ajexm'])*CRSP_comp_merge['forward_thirtyfive_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_thirtysix_month_return'] = ((((CRSP_comp_merge['forward_thirtysix_month_prccm']/CRSP_comp_merge['forward_thirtysix_month_ajexm'])*CRSP_comp_merge['forward_thirtysix_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100

# %%
# CRSP - Enrich - Past (PRCCM -- Price - Close - Monthly) 1 – 36 months
CRSP_comp_merge['past_one_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(1)
CRSP_comp_merge['past_two_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(2)
CRSP_comp_merge['past_three_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(3)
CRSP_comp_merge['past_four_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(4)
CRSP_comp_merge['past_five_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(5)
CRSP_comp_merge['past_six_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(6)
CRSP_comp_merge['past_seven_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(7)
CRSP_comp_merge['past_eight_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(8)
CRSP_comp_merge['past_nine_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(9)
CRSP_comp_merge['past_ten_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(10)
CRSP_comp_merge['past_eleven_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(11)
CRSP_comp_merge['past_twelve_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(12)
CRSP_comp_merge['past_thirteen_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(13)
CRSP_comp_merge['past_fourteen_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(14)
CRSP_comp_merge['past_fifteen_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(15)
CRSP_comp_merge['past_sixteen_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(16)
CRSP_comp_merge['past_seventeen_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(17)
CRSP_comp_merge['past_eighteen_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(18)
CRSP_comp_merge['past_nineteen_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(19)
CRSP_comp_merge['past_twenty_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(20)
CRSP_comp_merge['past_twentyone_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(21)
CRSP_comp_merge['past_twentytwo_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(22)
CRSP_comp_merge['past_twentythree_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(23)
CRSP_comp_merge['past_twentyfour_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(24)
CRSP_comp_merge['past_twentyfive_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(25)
CRSP_comp_merge['past_twentysix_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(26)
CRSP_comp_merge['past_twentyseven_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(27)
CRSP_comp_merge['past_twentyeight_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(28)
CRSP_comp_merge['past_twentynine_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(29)
CRSP_comp_merge['past_thirty_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(30)
CRSP_comp_merge['past_thirtyone_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(31)
CRSP_comp_merge['past_thirtytwo_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(32)
CRSP_comp_merge['past_thirtythree_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(33)
CRSP_comp_merge['past_thirtyfour_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(34)
CRSP_comp_merge['past_thirtyfive_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(35)
CRSP_comp_merge['past_thirtysix_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(36)

# %%
# CRSP - Enrich -  Past (AJEXM -- Cumulative Adjustment Factor - Ex Date -Monthly) 1 – 36 months
CRSP_comp_merge['past_one_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(1)
CRSP_comp_merge['past_two_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(2)
CRSP_comp_merge['past_three_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(3)
CRSP_comp_merge['past_four_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(4)
CRSP_comp_merge['past_five_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(5)
CRSP_comp_merge['past_six_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(6)
CRSP_comp_merge['past_seven_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(7)
CRSP_comp_merge['past_eight_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(8)
CRSP_comp_merge['past_nine_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(9)
CRSP_comp_merge['past_ten_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(10)
CRSP_comp_merge['past_eleven_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(11)
CRSP_comp_merge['past_twelve_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(12)
CRSP_comp_merge['past_thirteen_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(13)
CRSP_comp_merge['past_fourteen_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(14)
CRSP_comp_merge['past_fifteen_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(15)
CRSP_comp_merge['past_sixteen_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(16)
CRSP_comp_merge['past_seventeen_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(17)
CRSP_comp_merge['past_eighteen_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(18)
CRSP_comp_merge['past_nineteen_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(19)
CRSP_comp_merge['past_twenty_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(20)
CRSP_comp_merge['past_twentyone_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(21)
CRSP_comp_merge['past_twentytwo_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(22)
CRSP_comp_merge['past_twentythree_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(23)
CRSP_comp_merge['past_twentyfour_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(24)
CRSP_comp_merge['past_twentyfive_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(25)
CRSP_comp_merge['past_twentysix_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(26)
CRSP_comp_merge['past_twentyseven_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(27)
CRSP_comp_merge['past_twentyeight_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(28)
CRSP_comp_merge['past_twentynine_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(29)
CRSP_comp_merge['past_thirty_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(30)
CRSP_comp_merge['past_thirtyone_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(31)
CRSP_comp_merge['past_thirtytwo_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(32)
CRSP_comp_merge['past_thirtythree_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(33)
CRSP_comp_merge['past_thirtyfour_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(34)
CRSP_comp_merge['past_thirtyfive_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(35)
CRSP_comp_merge['past_thirtysix_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(36)

# %%
# CRSP - Enrich -  Past (TRFM -- Monthly Total Return Factor) 1 – 36 months
CRSP_comp_merge['past_one_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(1)
CRSP_comp_merge['past_two_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(2)
CRSP_comp_merge['past_three_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(3)
CRSP_comp_merge['past_four_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(4)
CRSP_comp_merge['past_five_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(5)
CRSP_comp_merge['past_six_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(6)
CRSP_comp_merge['past_seven_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(7)
CRSP_comp_merge['past_eight_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(8)
CRSP_comp_merge['past_nine_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(9)
CRSP_comp_merge['past_ten_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(10)
CRSP_comp_merge['past_eleven_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(11)
CRSP_comp_merge['past_twelve_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(12)
CRSP_comp_merge['past_thirteen_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(13)
CRSP_comp_merge['past_fourteen_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(14)
CRSP_comp_merge['past_fifteen_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(15)
CRSP_comp_merge['past_sixteen_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(16)
CRSP_comp_merge['past_seventeen_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(17)
CRSP_comp_merge['past_eighteen_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(18)
CRSP_comp_merge['past_nineteen_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(19)
CRSP_comp_merge['past_twenty_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(20)
CRSP_comp_merge['past_twentyone_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(21)
CRSP_comp_merge['past_twentytwo_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(22)
CRSP_comp_merge['past_twentythree_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(23)
CRSP_comp_merge['past_twentyfour_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(24)
CRSP_comp_merge['past_twentyfive_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(25)
CRSP_comp_merge['past_twentysix_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(26)
CRSP_comp_merge['past_twentyseven_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(27)
CRSP_comp_merge['past_twentyeight_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(28)
CRSP_comp_merge['past_twentynine_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(29)
CRSP_comp_merge['past_thirty_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(30)
CRSP_comp_merge['past_thirtyone_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(31)
CRSP_comp_merge['past_thirtytwo_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(32)
CRSP_comp_merge['past_thirtythree_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(33)
CRSP_comp_merge['past_thirtyfour_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(34)
CRSP_comp_merge['past_thirtyfive_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(35)
CRSP_comp_merge['past_thirtysix_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(36)

# %%
# CRSP - Enrich -  Past Return over number of months (1 - 36)
CRSP_comp_merge['past_one_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_one_month_trfm'])/((CRSP_comp_merge['past_one_month_prccm']/CRSP_comp_merge['past_one_month_ajexm'])*CRSP_comp_merge['past_one_month_trfm']))-1)*100
CRSP_comp_merge['past_two_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_two_month_trfm'])/((CRSP_comp_merge['past_two_month_prccm']/CRSP_comp_merge['past_two_month_ajexm'])*CRSP_comp_merge['past_two_month_trfm']))-1)*100
CRSP_comp_merge['past_three_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_three_month_trfm'])/((CRSP_comp_merge['past_three_month_prccm']/CRSP_comp_merge['past_three_month_ajexm'])*CRSP_comp_merge['past_three_month_trfm']))-1)*100
CRSP_comp_merge['past_four_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_four_month_trfm'])/((CRSP_comp_merge['past_four_month_prccm']/CRSP_comp_merge['past_four_month_ajexm'])*CRSP_comp_merge['past_four_month_trfm']))-1)*100
CRSP_comp_merge['past_five_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_five_month_trfm'])/((CRSP_comp_merge['past_five_month_prccm']/CRSP_comp_merge['past_five_month_ajexm'])*CRSP_comp_merge['past_five_month_trfm']))-1)*100
CRSP_comp_merge['past_six_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_six_month_trfm'])/((CRSP_comp_merge['past_six_month_prccm']/CRSP_comp_merge['past_six_month_ajexm'])*CRSP_comp_merge['past_six_month_trfm']))-1)*100
CRSP_comp_merge['past_seven_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_seven_month_trfm'])/((CRSP_comp_merge['past_seven_month_prccm']/CRSP_comp_merge['past_seven_month_ajexm'])*CRSP_comp_merge['past_seven_month_trfm']))-1)*100
CRSP_comp_merge['past_eight_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_eight_month_trfm'])/((CRSP_comp_merge['past_eight_month_prccm']/CRSP_comp_merge['past_eight_month_ajexm'])*CRSP_comp_merge['past_eight_month_trfm']))-1)*100
CRSP_comp_merge['past_nine_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_nine_month_trfm'])/((CRSP_comp_merge['past_nine_month_prccm']/CRSP_comp_merge['past_nine_month_ajexm'])*CRSP_comp_merge['past_nine_month_trfm']))-1)*100
CRSP_comp_merge['past_ten_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_ten_month_trfm'])/((CRSP_comp_merge['past_ten_month_prccm']/CRSP_comp_merge['past_ten_month_ajexm'])*CRSP_comp_merge['past_ten_month_trfm']))-1)*100
CRSP_comp_merge['past_eleven_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_eleven_month_trfm'])/((CRSP_comp_merge['past_eleven_month_prccm']/CRSP_comp_merge['past_eleven_month_ajexm'])*CRSP_comp_merge['past_eleven_month_trfm']))-1)*100
CRSP_comp_merge['past_twelve_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_twelve_month_trfm'])/((CRSP_comp_merge['past_twelve_month_prccm']/CRSP_comp_merge['past_twelve_month_ajexm'])*CRSP_comp_merge['past_twelve_month_trfm']))-1)*100
CRSP_comp_merge['past_thirteen_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_thirteen_month_trfm'])/((CRSP_comp_merge['past_thirteen_month_prccm']/CRSP_comp_merge['past_thirteen_month_ajexm'])*CRSP_comp_merge['past_thirteen_month_trfm']))-1)*100
CRSP_comp_merge['past_fourteen_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_fourteen_month_trfm'])/((CRSP_comp_merge['past_fourteen_month_prccm']/CRSP_comp_merge['past_fourteen_month_ajexm'])*CRSP_comp_merge['past_fourteen_month_trfm']))-1)*100
CRSP_comp_merge['past_fifteen_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_fifteen_month_trfm'])/((CRSP_comp_merge['past_fifteen_month_prccm']/CRSP_comp_merge['past_fifteen_month_ajexm'])*CRSP_comp_merge['past_fifteen_month_trfm']))-1)*100
CRSP_comp_merge['past_sixteen_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_sixteen_month_trfm'])/((CRSP_comp_merge['past_sixteen_month_prccm']/CRSP_comp_merge['past_sixteen_month_ajexm'])*CRSP_comp_merge['past_sixteen_month_trfm']))-1)*100
CRSP_comp_merge['past_seventeen_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_seventeen_month_trfm'])/((CRSP_comp_merge['past_seventeen_month_prccm']/CRSP_comp_merge['past_seventeen_month_ajexm'])*CRSP_comp_merge['past_seventeen_month_trfm']))-1)*100
CRSP_comp_merge['past_eighteen_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_eighteen_month_trfm'])/((CRSP_comp_merge['past_eighteen_month_prccm']/CRSP_comp_merge['past_eighteen_month_ajexm'])*CRSP_comp_merge['past_eighteen_month_trfm']))-1)*100
CRSP_comp_merge['past_nineteen_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_nineteen_month_trfm'])/((CRSP_comp_merge['past_nineteen_month_prccm']/CRSP_comp_merge['past_nineteen_month_ajexm'])*CRSP_comp_merge['past_nineteen_month_trfm']))-1)*100
CRSP_comp_merge['past_twenty_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_twenty_month_trfm'])/((CRSP_comp_merge['past_twenty_month_prccm']/CRSP_comp_merge['past_twenty_month_ajexm'])*CRSP_comp_merge['past_twenty_month_trfm']))-1)*100
CRSP_comp_merge['past_twentyone_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_twentyone_month_trfm'])/((CRSP_comp_merge['past_twentyone_month_prccm']/CRSP_comp_merge['past_twentyone_month_ajexm'])*CRSP_comp_merge['past_twentyone_month_trfm']))-1)*100
CRSP_comp_merge['past_twentytwo_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_twentytwo_month_trfm'])/((CRSP_comp_merge['past_twentytwo_month_prccm']/CRSP_comp_merge['past_twentytwo_month_ajexm'])*CRSP_comp_merge['past_twentytwo_month_trfm']))-1)*100
CRSP_comp_merge['past_twentythree_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_twentythree_month_trfm'])/((CRSP_comp_merge['past_twentythree_month_prccm']/CRSP_comp_merge['past_twentythree_month_ajexm'])*CRSP_comp_merge['past_twentythree_month_trfm']))-1)*100
CRSP_comp_merge['past_twentyfour_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_twentyfour_month_trfm'])/((CRSP_comp_merge['past_twentyfour_month_prccm']/CRSP_comp_merge['past_twentyfour_month_ajexm'])*CRSP_comp_merge['past_twentyfour_month_trfm']))-1)*100
CRSP_comp_merge['past_twentyfive_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_twentyfive_month_trfm'])/((CRSP_comp_merge['past_twentyfive_month_prccm']/CRSP_comp_merge['past_twentyfive_month_ajexm'])*CRSP_comp_merge['past_twentyfive_month_trfm']))-1)*100
CRSP_comp_merge['past_twentysix_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_twentysix_month_trfm'])/((CRSP_comp_merge['past_twentysix_month_prccm']/CRSP_comp_merge['past_twentysix_month_ajexm'])*CRSP_comp_merge['past_twentysix_month_trfm']))-1)*100
CRSP_comp_merge['past_twentyseven_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_twentyseven_month_trfm'])/((CRSP_comp_merge['past_twentyseven_month_prccm']/CRSP_comp_merge['past_twentyseven_month_ajexm'])*CRSP_comp_merge['past_twentyseven_month_trfm']))-1)*100
CRSP_comp_merge['past_twentyeight_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_twentyeight_month_trfm'])/((CRSP_comp_merge['past_twentyeight_month_prccm']/CRSP_comp_merge['past_twentyeight_month_ajexm'])*CRSP_comp_merge['past_twentyeight_month_trfm']))-1)*100
CRSP_comp_merge['past_twentynine_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_twentynine_month_trfm'])/((CRSP_comp_merge['past_twentynine_month_prccm']/CRSP_comp_merge['past_twentynine_month_ajexm'])*CRSP_comp_merge['past_twentynine_month_trfm']))-1)*100
CRSP_comp_merge['past_thirty_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_thirty_month_trfm'])/((CRSP_comp_merge['past_thirty_month_prccm']/CRSP_comp_merge['past_thirty_month_ajexm'])*CRSP_comp_merge['past_thirty_month_trfm']))-1)*100
CRSP_comp_merge['past_thirtyone_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_thirtyone_month_trfm'])/((CRSP_comp_merge['past_thirtyone_month_prccm']/CRSP_comp_merge['past_thirtyone_month_ajexm'])*CRSP_comp_merge['past_thirtyone_month_trfm']))-1)*100
CRSP_comp_merge['past_thirtytwo_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_thirtytwo_month_trfm'])/((CRSP_comp_merge['past_thirtytwo_month_prccm']/CRSP_comp_merge['past_thirtytwo_month_ajexm'])*CRSP_comp_merge['past_thirtytwo_month_trfm']))-1)*100
CRSP_comp_merge['past_thirtythree_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_thirtythree_month_trfm'])/((CRSP_comp_merge['past_thirtythree_month_prccm']/CRSP_comp_merge['past_thirtythree_month_ajexm'])*CRSP_comp_merge['past_thirtythree_month_trfm']))-1)*100
CRSP_comp_merge['past_thirtyfour_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_thirtyfour_month_trfm'])/((CRSP_comp_merge['past_thirtyfour_month_prccm']/CRSP_comp_merge['past_thirtyfour_month_ajexm'])*CRSP_comp_merge['past_thirtyfour_month_trfm']))-1)*100
CRSP_comp_merge['past_thirtyfive_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_thirtyfive_month_trfm'])/((CRSP_comp_merge['past_thirtyfive_month_prccm']/CRSP_comp_merge['past_thirtyfive_month_ajexm'])*CRSP_comp_merge['past_thirtyfive_month_trfm']))-1)*100
CRSP_comp_merge['past_thirtysix_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_thirtysix_month_trfm'])/((CRSP_comp_merge['past_thirtysix_month_prccm']/CRSP_comp_merge['past_thirtysix_month_ajexm'])*CRSP_comp_merge['past_thirtysix_month_trfm']))-1)*100

# %%
# Merge - df & CRSP
df = df.merge(CRSP_comp_merge, on='GVKEY-year-month', how='left', suffixes=('', '_y'))
# Release Memory
del CRSP_comp_merge

# %%
# df - Clean - Remove duplicate features
drop_dups(df)

# %%
# Recommendations - Load
# Summary Statistics (Consensus Recommendations) from Wharton
recommendations = pd.read_csv('c:/users/shane/Desktop/W205_Final/sample_data/Sample_Recommendations_Summary_Statistics.csv', low_memory=False)

# %%
# Recommendations - Enrich - Time Features
recommendations['STATPERS'] = pd.to_datetime(recommendations['STATPERS'])
# Create year
recommendations['year'] = recommendations['STATPERS'].dt.year
# Create month
recommendations['month'] = recommendations['STATPERS'].dt.month
# Creat year-month
recommendations["year-month"] = recommendations['STATPERS'].apply(lambda x: x.strftime('%Y-%m'))

# %%
# Recommendations - Enrich - Analyst Change
recommendations["recup"] = recommendations["NUMUP"] / recommendations["NUMREC"] 
recommendations["recdown"] = recommendations["NUMDOWN"] / recommendations["NUMREC"]

# %%
# Recommendations - Enrich - Time-based Unique Identifiers
recommendations["TIC-year-month"] = recommendations["OFTIC"].map(str) + "-" + recommendations["year-month"]

# %%
# Merge - df & Recommendations
df = df.merge(recommendations, on='TIC-year-month', how='left', suffixes=('', '_y'))
# Release Memory
del recommendations

# %%
# df - Clean - Remove duplicate features
drop_dups(df)

# %%
# Beta Suite - Load
beta_suite = pd.read_csv('c:/users/shane/Desktop/W205_Final/sample_data/Sample_Beta_Suite.csv', low_memory=False)

# %%
# Beta Suite - Enrich - Time Features
# Convert to data-time
beta_suite['DATE'] = pd.to_datetime(beta_suite['DATE'])
# Create year
beta_suite['year'] = beta_suite['DATE'].dt.year
# Create month
beta_suite['month'] = beta_suite['DATE'].dt.month
# Create year-month
beta_suite["year-month"] = beta_suite['DATE'].apply(lambda x: x.strftime('%Y-%m'))

# %%
# Beta Suite - Enrich - Time-based Unique Identifiers
beta_suite["PERMNO-year-month"] = beta_suite["PERMNO"].map(str) + "-" + beta_suite["year-month"]

# %%
# Merge - df & Beta Suite
df = df.merge(beta_suite, on='PERMNO-year-month', how='left', suffixes=('', '_y'))
# Release Memory
del beta_suite

# %%
# df - Clean - Remove duplicate features
drop_dups(df)

# %%
# Sector - Enrich
# https://en.wikipedia.org/wiki/Global_Industry_Classification_Standard

sector = pd.DataFrame()

sector['GSECTOR'] = [10.0, 
                       15.0, 
                       20.0, 
                       25.0, 
                       30.0, 
                       35.0, 
                       40.0, 
                       45.0, 
                       50.0, 
                       55.0, 
                       60.0]

sector['sector'] = ['Energy', 
                        'Materials', 
                        'Industrials', 
                        'Consumer Discretionary', 
                        'Consumer Staples', 
                        'Health Care', 
                        'Financials', 
                        'Information Technology', 
                        'Telecommunication Services', 
                        'Utilities', 
                        'Real Estate']

# %%
# Merge - df & Sector
df = df.merge(sector, on='GSECTOR', how='left', suffixes=('', '_y'))
# Release Memory
del sector

# %%
# df - Clean - Remove duplicate features
drop_dups(df)

# %%
# df - Enrich - Time Features
df['january'] = np.where(df['month'] == 1, int(1), int(0))
df['february'] = np.where(df['month'] == 2, int(1), int(0))
df['march'] = np.where(df['month'] == 3, int(1), int(0))
df['april'] = np.where(df['month'] == 4, int(1), int(0))
df['may'] = np.where(df['month'] == 5, int(1), int(0))
df['june'] = np.where(df['month'] == 6, int(1), int(0))
df['july'] = np.where(df['month'] == 7, int(1), int(0))
df['august'] = np.where(df['month'] == 8, int(1), int(0))
df['september'] = np.where(df['month'] == 9, int(1), int(0))
df['october'] = np.where(df['month'] == 10, int(1), int(0))
df['november'] = np.where(df['month'] == 11, int(1), int(0))
df['december'] = np.where(df['month'] == 12, int(1), int(0))

# %%
# df - Subset - Relevant features with adequate data

df = df[[
        'GVKEY', 
        'sector',
        'year-month', 
        'forward_one_month_return', 
        'forward_two_month_return', 
        'forward_three_month_return', 
        'forward_four_month_return', 
        'forward_five_month_return', 
        'forward_six_month_return', 
        'forward_seven_month_return', 
        'forward_eight_month_return', 
        'forward_nine_month_return', 
        'forward_ten_month_return', 
        'forward_eleven_month_return', 
        'forward_twelve_month_return', 
        'forward_thirteen_month_return', 
        'forward_fourteen_month_return', 
        'forward_fifteen_month_return', 
        'forward_sixteen_month_return', 
        'forward_seventeen_month_return', 
        'forward_eighteen_month_return', 
        'forward_nineteen_month_return', 
        'forward_twenty_month_return', 
        'forward_twentyone_month_return', 
        'forward_twentytwo_month_return', 
        'forward_twentythree_month_return', 
        'forward_twentyfour_month_return', 
        'forward_twentyfive_month_return', 
        'forward_twentysix_month_return', 
        'forward_twentyseven_month_return', 
        'forward_twentyeight_month_return', 
        'forward_twentynine_month_return', 
        'forward_thirty_month_return', 
        'forward_thirtyone_month_return', 
        'forward_thirtytwo_month_return', 
        'forward_thirtythree_month_return', 
        'forward_thirtyfour_month_return', 
        'forward_thirtyfive_month_return', 
        'forward_thirtysix_month_return', 
        'past_one_month_return', 
        'past_two_month_return', 
        'past_three_month_return', 
        'past_four_month_return', 
        'past_five_month_return', 
        'past_six_month_return', 
        'past_seven_month_return', 
        'past_eight_month_return', 
        'past_nine_month_return', 
        'past_ten_month_return', 
        'past_eleven_month_return', 
        'past_twelve_month_return', 
        'past_thirteen_month_return', 
        'past_fourteen_month_return', 
        'past_fifteen_month_return', 
        'past_sixteen_month_return', 
        'past_seventeen_month_return', 
        'past_eighteen_month_return', 
        'past_nineteen_month_return', 
        'past_twenty_month_return', 
        'past_twentyone_month_return', 
        'past_twentytwo_month_return', 
        'past_twentythree_month_return', 
        'past_twentyfour_month_return', 
        'past_twentyfive_month_return', 
        'past_twentysix_month_return', 
        'past_twentyseven_month_return', 
        'past_twentyeight_month_return', 
        'past_twentynine_month_return', 
        'past_thirty_month_return', 
        'past_thirtyone_month_return', 
        'past_thirtytwo_month_return', 
        'past_thirtythree_month_return', 
        'past_thirtyfour_month_return', 
        'past_thirtyfive_month_return', 
        'past_thirtysix_month_return', 
        'accrual', 
        'adv_sale', 
        'aftret_eq', 
        'aftret_equity', 
        'aftret_invcapx', 
        'at_turn', 
        'bm', 
        'CAPEI', 
        'capital_ratio', 
        'cash_conversion', 
        'cash_debt', 
        'cash_lt', 
        'cash_ratio', 
        'cfm', 
        'curr_debt', 
        'curr_ratio', 
        'de_ratio', 
        'debt_assets', 
        'debt_at', 
        'debt_capital', 
        'debt_ebitda', 
        'debt_invcap', 
        'DIVYIELD', 
        'dltt_be', 
        'dpr', 
        'efftax', 
        'equity_invcap', 
        'evm', 
        'fcf_ocf', 
        'gpm', 
        'GProf', 
        'int_debt', 
        'int_totdebt', 
        'intcov', 
        'intcov_ratio', 
        'inv_turn', 
        'invt_act', 
        'lt_debt', 
        'lt_ppent', 
        'npm', 
        'ocf_lct', 
        'opmad', 
        'opmbd', 
        'pay_turn', 
        'pcf', 
        'pe_exi', 
        'pe_inc', 
        'pe_op_basic', 
        'pe_op_dil', 
        'PEG_1yrforward', 
        'PEG_ltgforward', 
        'PEG_trailing', 
        'pretret_earnat', 
        'pretret_noa', 
        'profit_lct', 
        'ps', 
        'ptb', 
        'ptpm', 
        'quick_ratio', 
        'rd_sale', 
        'rect_act', 
        'rect_turn', 
        'roa', 
        'roce', 
        'roe', 
        'sale_equity', 
        'sale_invcap', 
        'sale_nwc', 
        'short_debt', 
        'staff_sale', 
        'totdebt_invcap', 
        'dvpspm', 
        'dvpsxm', 
        'dvrate', 
        'spcsrc', 
        'alpha', 
        'b_hml', 
        'b_mkt', 
        'b_smb', 
        'b_umd', 
        'exret', 
        'ivol', 
        'n', 
        'R2', 
        'tvol', 
        'BUYPCT', 
        'HOLDPCT',
        'SELLPCT', 
        'MEANREC', 
        'MEDREC',
        'recup', 
        'recdown',
        'STDEV', 
        'january', 
        'february', 
        'march', 
        'april', 
        'may', 
        'june', 
        'july', 
        'august', 
        'september', 
        'october', 
        'november', 
        'december'
        ]]

# %%
# # df - Clean - Dividends - DIVYIELD, dvpspm, dvpsxm, & dvrate
# # Companies who do not report dividends are unlikely to have paid dividends, the majority of companies do not pay as well.
df['DIVYIELD'] = df['DIVYIELD'].replace('%','',regex=True).astype('float')/100
df['DIVYIELD'] = pd.to_numeric(df['DIVYIELD'])

# df['dvpspm'] = df['dvpspm'].fillna(0)
# df['dvpsxm'] = df['dvpsxm'].fillna(0)
# df['dvrate'] = df['dvrate'].fillna(0)

# %%
# df - Clean - Ratings - SPCSRC
# Per S&P Quality Rankings information; 
# A+ - 98-100 percentile (Highest, 2%)
# A - 92-98 percentile (High, 6%) 
# A- - 86-92 percentile (Above Average, 6%) 
# B+ - 70-86 percentile (Average, 16%) 
# B - 51-70 percentile (Below Average, 19%)
# B- - 25-51 percentile (Lower, 26%)
# C - 1-25 percentile (Lowest, 24%)
# D - 0-1 percentile (In Reorganization, 1%) 

# Using the average of percentile ranges above

df['spcsrc'] = df['spcsrc'].map({
                                'A+': 99,
                                'A': 95,
                                'A-': 89,
                                'B+': 79.5,
                                'B': 60.5,
                                'B-': 38,
                                'C': 13,
                                'D': 0.5,
                                })

df['spcsrc'] = pd.to_numeric(df['spcsrc'])

# %%
# df - Clean - Beta Suite - exret, ivol, R2, tvol

df['exret'] = df['exret'].replace('%','',regex=True).astype('float')/100
df['exret'] = pd.to_numeric(df['exret'])

df['ivol'] = df['ivol'].replace('%','',regex=True).astype('float')/100
df['ivol'] = pd.to_numeric(df['ivol'])

df['R2'] = df['R2'].replace('%','',regex=True).astype('float')/100
df['R2'] = pd.to_numeric(df['R2'])

df['tvol'] = df['tvol'].replace('%','',regex=True).astype('float')/100
df['tvol'] = pd.to_numeric(df['tvol'])

# %%
# df - Enrich - Market Z-Score
df['forward_one_month_return_zscore'] = df.groupby(['year-month'])[['forward_one_month_return']].apply(modified_z)
df['forward_two_month_return_zscore'] = df.groupby(['year-month'])[['forward_two_month_return']].apply(modified_z)
df['forward_three_month_return_zscore'] = df.groupby(['year-month'])[['forward_three_month_return']].apply(modified_z)
df['forward_four_month_return_zscore'] = df.groupby(['year-month'])[['forward_four_month_return']].apply(modified_z)
df['forward_five_month_return_zscore'] = df.groupby(['year-month'])[['forward_five_month_return']].apply(modified_z)
df['forward_six_month_return_zscore'] = df.groupby(['year-month'])[['forward_six_month_return']].apply(modified_z)
df['forward_seven_month_return_zscore'] = df.groupby(['year-month'])[['forward_seven_month_return']].apply(modified_z)
df['forward_eight_month_return_zscore'] = df.groupby(['year-month'])[['forward_eight_month_return']].apply(modified_z)
df['forward_nine_month_return_zscore'] = df.groupby(['year-month'])[['forward_nine_month_return']].apply(modified_z)
df['forward_ten_month_return_zscore'] = df.groupby(['year-month'])[['forward_ten_month_return']].apply(modified_z)
df['forward_eleven_month_return_zscore'] = df.groupby(['year-month'])[['forward_eleven_month_return']].apply(modified_z)
df['forward_twelve_month_return_zscore'] = df.groupby(['year-month'])[['forward_twelve_month_return']].apply(modified_z)
df['forward_thirteen_month_return_zscore'] = df.groupby(['year-month'])[['forward_thirteen_month_return']].apply(modified_z)
df['forward_fourteen_month_return_zscore'] = df.groupby(['year-month'])[['forward_fourteen_month_return']].apply(modified_z)
df['forward_fifteen_month_return_zscore'] = df.groupby(['year-month'])[['forward_fifteen_month_return']].apply(modified_z)
df['forward_sixteen_month_return_zscore'] = df.groupby(['year-month'])[['forward_sixteen_month_return']].apply(modified_z)
df['forward_seventeen_month_return_zscore'] = df.groupby(['year-month'])[['forward_seventeen_month_return']].apply(modified_z)
df['forward_eighteen_month_return_zscore'] = df.groupby(['year-month'])[['forward_eighteen_month_return']].apply(modified_z)
df['forward_nineteen_month_return_zscore'] = df.groupby(['year-month'])[['forward_nineteen_month_return']].apply(modified_z)
df['forward_twenty_month_return_zscore'] = df.groupby(['year-month'])[['forward_twenty_month_return']].apply(modified_z)
df['forward_twentyone_month_return_zscore'] = df.groupby(['year-month'])[['forward_twentyone_month_return']].apply(modified_z)
df['forward_twentytwo_month_return_zscore'] = df.groupby(['year-month'])[['forward_twentytwo_month_return']].apply(modified_z)
df['forward_twentythree_month_return_zscore'] = df.groupby(['year-month'])[['forward_twentythree_month_return']].apply(modified_z)
df['forward_twentyfour_month_return_zscore'] = df.groupby(['year-month'])[['forward_twentyfour_month_return']].apply(modified_z)
df['forward_twentyfive_month_return_zscore'] = df.groupby(['year-month'])[['forward_twentyfive_month_return']].apply(modified_z)
df['forward_twentysix_month_return_zscore'] = df.groupby(['year-month'])[['forward_twentysix_month_return']].apply(modified_z)
df['forward_twentyseven_month_return_zscore'] = df.groupby(['year-month'])[['forward_twentyseven_month_return']].apply(modified_z)
df['forward_twentyeight_month_return_zscore'] = df.groupby(['year-month'])[['forward_twentyeight_month_return']].apply(modified_z)
df['forward_twentynine_month_return_zscore'] = df.groupby(['year-month'])[['forward_twentynine_month_return']].apply(modified_z)
df['forward_thirty_month_return_zscore'] = df.groupby(['year-month'])[['forward_thirty_month_return']].apply(modified_z)
df['forward_thirtyone_month_return_zscore'] = df.groupby(['year-month'])[['forward_thirtyone_month_return']].apply(modified_z)
df['forward_thirtytwo_month_return_zscore'] = df.groupby(['year-month'])[['forward_thirtytwo_month_return']].apply(modified_z)
df['forward_thirtythree_month_return_zscore'] = df.groupby(['year-month'])[['forward_thirtythree_month_return']].apply(modified_z)
df['forward_thirtyfour_month_return_zscore'] = df.groupby(['year-month'])[['forward_thirtyfour_month_return']].apply(modified_z)
df['forward_thirtyfive_month_return_zscore'] = df.groupby(['year-month'])[['forward_thirtyfive_month_return']].apply(modified_z)
df['forward_thirtysix_month_return_zscore'] = df.groupby(['year-month'])[['forward_thirtysix_month_return']].apply(modified_z)
df['past_one_month_return_zscore'] = df.groupby(['year-month'])[['past_one_month_return']].apply(modified_z)
df['past_two_month_return_zscore'] = df.groupby(['year-month'])[['past_two_month_return']].apply(modified_z)
df['past_three_month_return_zscore'] = df.groupby(['year-month'])[['past_three_month_return']].apply(modified_z)
df['past_four_month_return_zscore'] = df.groupby(['year-month'])[['past_four_month_return']].apply(modified_z)
df['past_five_month_return_zscore'] = df.groupby(['year-month'])[['past_five_month_return']].apply(modified_z)
df['past_six_month_return_zscore'] = df.groupby(['year-month'])[['past_six_month_return']].apply(modified_z)
df['past_seven_month_return_zscore'] = df.groupby(['year-month'])[['past_seven_month_return']].apply(modified_z)
df['past_eight_month_return_zscore'] = df.groupby(['year-month'])[['past_eight_month_return']].apply(modified_z)
df['past_nine_month_return_zscore'] = df.groupby(['year-month'])[['past_nine_month_return']].apply(modified_z)
df['past_ten_month_return_zscore'] = df.groupby(['year-month'])[['past_ten_month_return']].apply(modified_z)
df['past_eleven_month_return_zscore'] = df.groupby(['year-month'])[['past_eleven_month_return']].apply(modified_z)
df['past_twelve_month_return_zscore'] = df.groupby(['year-month'])[['past_twelve_month_return']].apply(modified_z)
df['past_thirteen_month_return_zscore'] = df.groupby(['year-month'])[['past_thirteen_month_return']].apply(modified_z)
df['past_fourteen_month_return_zscore'] = df.groupby(['year-month'])[['past_fourteen_month_return']].apply(modified_z)
df['past_fifteen_month_return_zscore'] = df.groupby(['year-month'])[['past_fifteen_month_return']].apply(modified_z)
df['past_sixteen_month_return_zscore'] = df.groupby(['year-month'])[['past_sixteen_month_return']].apply(modified_z)
df['past_seventeen_month_return_zscore'] = df.groupby(['year-month'])[['past_seventeen_month_return']].apply(modified_z)
df['past_eighteen_month_return_zscore'] = df.groupby(['year-month'])[['past_eighteen_month_return']].apply(modified_z)
df['past_nineteen_month_return_zscore'] = df.groupby(['year-month'])[['past_nineteen_month_return']].apply(modified_z)
df['past_twenty_month_return_zscore'] = df.groupby(['year-month'])[['past_twenty_month_return']].apply(modified_z)
df['past_twentyone_month_return_zscore'] = df.groupby(['year-month'])[['past_twentyone_month_return']].apply(modified_z)
df['past_twentytwo_month_return_zscore'] = df.groupby(['year-month'])[['past_twentytwo_month_return']].apply(modified_z)
df['past_twentythree_month_return_zscore'] = df.groupby(['year-month'])[['past_twentythree_month_return']].apply(modified_z)
df['past_twentyfour_month_return_zscore'] = df.groupby(['year-month'])[['past_twentyfour_month_return']].apply(modified_z)
df['past_twentyfive_month_return_zscore'] = df.groupby(['year-month'])[['past_twentyfive_month_return']].apply(modified_z)
df['past_twentysix_month_return_zscore'] = df.groupby(['year-month'])[['past_twentysix_month_return']].apply(modified_z)
df['past_twentyseven_month_return_zscore'] = df.groupby(['year-month'])[['past_twentyseven_month_return']].apply(modified_z)
df['past_twentyeight_month_return_zscore'] = df.groupby(['year-month'])[['past_twentyeight_month_return']].apply(modified_z)
df['past_twentynine_month_return_zscore'] = df.groupby(['year-month'])[['past_twentynine_month_return']].apply(modified_z)
df['past_thirty_month_return_zscore'] = df.groupby(['year-month'])[['past_thirty_month_return']].apply(modified_z)
df['past_thirtyone_month_return_zscore'] = df.groupby(['year-month'])[['past_thirtyone_month_return']].apply(modified_z)
df['past_thirtytwo_month_return_zscore'] = df.groupby(['year-month'])[['past_thirtytwo_month_return']].apply(modified_z)
df['past_thirtythree_month_return_zscore'] = df.groupby(['year-month'])[['past_thirtythree_month_return']].apply(modified_z)
df['past_thirtyfour_month_return_zscore'] = df.groupby(['year-month'])[['past_thirtyfour_month_return']].apply(modified_z)
df['past_thirtyfive_month_return_zscore'] = df.groupby(['year-month'])[['past_thirtyfive_month_return']].apply(modified_z)
df['past_thirtysix_month_return_zscore'] = df.groupby(['year-month'])[['past_thirtysix_month_return']].apply(modified_z)
df['accrual_zscore'] = df.groupby(['year-month'])[['accrual']].apply(modified_z)
df['adv_sale_zscore'] = df.groupby(['year-month'])[['adv_sale']].apply(modified_z)
df['aftret_eq_zscore'] = df.groupby(['year-month'])[['aftret_eq']].apply(modified_z)
df['aftret_equity_zscore'] = df.groupby(['year-month'])[['aftret_equity']].apply(modified_z)
df['aftret_invcapx_zscore'] = df.groupby(['year-month'])[['aftret_invcapx']].apply(modified_z)
df['at_turn_zscore'] = df.groupby(['year-month'])[['at_turn']].apply(modified_z)
df['bm_zscore'] = df.groupby(['year-month'])[['bm']].apply(modified_z)
df['CAPEI_zscore'] = df.groupby(['year-month'])[['CAPEI']].apply(modified_z)
df['capital_ratio_zscore'] = df.groupby(['year-month'])[['capital_ratio']].apply(modified_z)
df['cash_conversion_zscore'] = df.groupby(['year-month'])[['cash_conversion']].apply(modified_z)
df['cash_debt_zscore'] = df.groupby(['year-month'])[['cash_debt']].apply(modified_z)
df['cash_lt_zscore'] = df.groupby(['year-month'])[['cash_lt']].apply(modified_z)
df['cash_ratio_zscore'] = df.groupby(['year-month'])[['cash_ratio']].apply(modified_z)
df['cfm_zscore'] = df.groupby(['year-month'])[['cfm']].apply(modified_z)
df['curr_debt_zscore'] = df.groupby(['year-month'])[['curr_debt']].apply(modified_z)
df['curr_ratio_zscore'] = df.groupby(['year-month'])[['curr_ratio']].apply(modified_z)
df['de_ratio_zscore'] = df.groupby(['year-month'])[['de_ratio']].apply(modified_z)
df['debt_assets_zscore'] = df.groupby(['year-month'])[['debt_assets']].apply(modified_z)
df['debt_at_zscore'] = df.groupby(['year-month'])[['debt_at']].apply(modified_z)
df['debt_capital_zscore'] = df.groupby(['year-month'])[['debt_capital']].apply(modified_z)
df['debt_ebitda_zscore'] = df.groupby(['year-month'])[['debt_ebitda']].apply(modified_z)
df['debt_invcap_zscore'] = df.groupby(['year-month'])[['debt_invcap']].apply(modified_z)
df['dltt_be_zscore'] = df.groupby(['year-month'])[['dltt_be']].apply(modified_z)
df['dpr_zscore'] = df.groupby(['year-month'])[['dpr']].apply(modified_z)
df['efftax_zscore'] = df.groupby(['year-month'])[['efftax']].apply(modified_z)
df['equity_invcap_zscore'] = df.groupby(['year-month'])[['equity_invcap']].apply(modified_z)
df['evm_zscore'] = df.groupby(['year-month'])[['evm']].apply(modified_z)
df['fcf_ocf_zscore'] = df.groupby(['year-month'])[['fcf_ocf']].apply(modified_z)
df['gpm_zscore'] = df.groupby(['year-month'])[['gpm']].apply(modified_z)
df['GProf_zscore'] = df.groupby(['year-month'])[['GProf']].apply(modified_z)
df['int_debt_zscore'] = df.groupby(['year-month'])[['int_debt']].apply(modified_z)
df['int_totdebt_zscore'] = df.groupby(['year-month'])[['int_totdebt']].apply(modified_z)
df['intcov_zscore'] = df.groupby(['year-month'])[['intcov']].apply(modified_z)
df['intcov_ratio_zscore'] = df.groupby(['year-month'])[['intcov_ratio']].apply(modified_z)
df['inv_turn_zscore'] = df.groupby(['year-month'])[['inv_turn']].apply(modified_z)
df['invt_act_zscore'] = df.groupby(['year-month'])[['invt_act']].apply(modified_z)
df['lt_debt_zscore'] = df.groupby(['year-month'])[['lt_debt']].apply(modified_z)
df['lt_ppent_zscore'] = df.groupby(['year-month'])[['lt_ppent']].apply(modified_z)
df['npm_zscore'] = df.groupby(['year-month'])[['npm']].apply(modified_z)
df['ocf_lct_zscore'] = df.groupby(['year-month'])[['ocf_lct']].apply(modified_z)
df['opmad_zscore'] = df.groupby(['year-month'])[['opmad']].apply(modified_z)
df['opmbd_zscore'] = df.groupby(['year-month'])[['opmbd']].apply(modified_z)
df['pay_turn_zscore'] = df.groupby(['year-month'])[['pay_turn']].apply(modified_z)
df['pcf_zscore'] = df.groupby(['year-month'])[['pcf']].apply(modified_z)
df['pe_exi_zscore'] = df.groupby(['year-month'])[['pe_exi']].apply(modified_z)
df['pe_inc_zscore'] = df.groupby(['year-month'])[['pe_inc']].apply(modified_z)
df['pe_op_basic_zscore'] = df.groupby(['year-month'])[['pe_op_basic']].apply(modified_z)
df['pe_op_dil_zscore'] = df.groupby(['year-month'])[['pe_op_dil']].apply(modified_z)
df['PEG_1yrforward_zscore'] = df.groupby(['year-month'])[['PEG_1yrforward']].apply(modified_z)
df['PEG_ltgforward_zscore'] = df.groupby(['year-month'])[['PEG_ltgforward']].apply(modified_z)
df['PEG_trailing_zscore'] = df.groupby(['year-month'])[['PEG_trailing']].apply(modified_z)
df['pretret_earnat_zscore'] = df.groupby(['year-month'])[['pretret_earnat']].apply(modified_z)
df['pretret_noa_zscore'] = df.groupby(['year-month'])[['pretret_noa']].apply(modified_z)
df['profit_lct_zscore'] = df.groupby(['year-month'])[['profit_lct']].apply(modified_z)
df['ps_zscore'] = df.groupby(['year-month'])[['ps']].apply(modified_z)
df['ptb_zscore'] = df.groupby(['year-month'])[['ptb']].apply(modified_z)
df['ptpm_zscore'] = df.groupby(['year-month'])[['ptpm']].apply(modified_z)
df['quick_ratio_zscore'] = df.groupby(['year-month'])[['quick_ratio']].apply(modified_z)
df['rd_sale_zscore'] = df.groupby(['year-month'])[['rd_sale']].apply(modified_z)
df['rect_act_zscore'] = df.groupby(['year-month'])[['rect_act']].apply(modified_z)
df['rect_turn_zscore'] = df.groupby(['year-month'])[['rect_turn']].apply(modified_z)
df['roa_zscore'] = df.groupby(['year-month'])[['roa']].apply(modified_z)
df['roce_zscore'] = df.groupby(['year-month'])[['roce']].apply(modified_z)
df['roe_zscore'] = df.groupby(['year-month'])[['roe']].apply(modified_z)
df['sale_equity_zscore'] = df.groupby(['year-month'])[['sale_equity']].apply(modified_z)
df['sale_invcap_zscore'] = df.groupby(['year-month'])[['sale_invcap']].apply(modified_z)
df['sale_nwc_zscore'] = df.groupby(['year-month'])[['sale_nwc']].apply(modified_z)
df['short_debt_zscore'] = df.groupby(['year-month'])[['short_debt']].apply(modified_z)
df['staff_sale_zscore'] = df.groupby(['year-month'])[['staff_sale']].apply(modified_z)
df['totdebt_invcap_zscore'] = df.groupby(['year-month'])[['totdebt_invcap']].apply(modified_z)
df['alpha_zscore'] = df.groupby(['year-month'])[['alpha']].apply(modified_z)
df['b_hml_zscore'] = df.groupby(['year-month'])[['b_hml']].apply(modified_z)
df['b_mkt_zscore'] = df.groupby(['year-month'])[['b_mkt']].apply(modified_z)
df['b_smb_zscore'] = df.groupby(['year-month'])[['b_smb']].apply(modified_z)
df['b_umd_zscore'] = df.groupby(['year-month'])[['b_umd']].apply(modified_z)
df['exret_zscore'] = df.groupby(['year-month'])[['exret']].apply(modified_z)
df['ivol_zscore'] = df.groupby(['year-month'])[['ivol']].apply(modified_z)
df['n_zscore'] = df.groupby(['year-month'])[['n']].apply(modified_z)
df['R2_zscore'] = df.groupby(['year-month'])[['R2']].apply(modified_z)
df['tvol_zscore'] = df.groupby(['year-month'])[['tvol']].apply(modified_z)
df['BUYPCT_zscore'] = df.groupby(['year-month'])[['BUYPCT']].apply(modified_z)
df['HOLDPCT_zscore'] = df.groupby(['year-month'])[['HOLDPCT']].apply(modified_z)
df['MEANREC_zscore'] = df.groupby(['year-month'])[['MEANREC']].apply(modified_z)
df['MEDREC_zscore'] = df.groupby(['year-month'])[['MEDREC']].apply(modified_z)
df['recup_zscore'] = df.groupby(['year-month'])[['recup']].apply(modified_z)
df['recdown_zscore'] = df.groupby(['year-month'])[['recdown']].apply(modified_z)
df['SELLPCT_zscore'] = df.groupby(['year-month'])[['SELLPCT']].apply(modified_z)
df['STDEV_zscore'] = df.groupby(['year-month'])[['STDEV']].apply(modified_z)
# Out:
# C:\Users\shane\Anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:717: RuntimeWarning: All-NaN slice encountered
#   warnings.warn("All-NaN slice encountered", RuntimeWarning)

# %%
# df - Enrich - Sector Z-Score
df['forward_one_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['forward_one_month_return']].apply(modified_z)
df['forward_two_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['forward_two_month_return']].apply(modified_z)
df['forward_three_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['forward_three_month_return']].apply(modified_z)
df['forward_four_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['forward_four_month_return']].apply(modified_z)
df['forward_five_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['forward_five_month_return']].apply(modified_z)
df['forward_six_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['forward_six_month_return']].apply(modified_z)
df['forward_seven_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['forward_seven_month_return']].apply(modified_z)
df['forward_eight_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['forward_eight_month_return']].apply(modified_z)
df['forward_nine_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['forward_nine_month_return']].apply(modified_z)
df['forward_ten_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['forward_ten_month_return']].apply(modified_z)
df['forward_eleven_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['forward_eleven_month_return']].apply(modified_z)
df['forward_twelve_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['forward_twelve_month_return']].apply(modified_z)
df['forward_thirteen_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['forward_thirteen_month_return']].apply(modified_z)
df['forward_fourteen_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['forward_fourteen_month_return']].apply(modified_z)
df['forward_fifteen_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['forward_fifteen_month_return']].apply(modified_z)
df['forward_sixteen_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['forward_sixteen_month_return']].apply(modified_z)
df['forward_seventeen_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['forward_seventeen_month_return']].apply(modified_z)
df['forward_eighteen_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['forward_eighteen_month_return']].apply(modified_z)
df['forward_nineteen_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['forward_nineteen_month_return']].apply(modified_z)
df['forward_twenty_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['forward_twenty_month_return']].apply(modified_z)
df['forward_twentyone_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['forward_twentyone_month_return']].apply(modified_z)
df['forward_twentytwo_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['forward_twentytwo_month_return']].apply(modified_z)
df['forward_twentythree_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['forward_twentythree_month_return']].apply(modified_z)
df['forward_twentyfour_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['forward_twentyfour_month_return']].apply(modified_z)
df['forward_twentyfive_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['forward_twentyfive_month_return']].apply(modified_z)
df['forward_twentysix_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['forward_twentysix_month_return']].apply(modified_z)
df['forward_twentyseven_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['forward_twentyseven_month_return']].apply(modified_z)
df['forward_twentyeight_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['forward_twentyeight_month_return']].apply(modified_z)
df['forward_twentynine_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['forward_twentynine_month_return']].apply(modified_z)
df['forward_thirty_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['forward_thirty_month_return']].apply(modified_z)
df['forward_thirtyone_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['forward_thirtyone_month_return']].apply(modified_z)
df['forward_thirtytwo_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['forward_thirtytwo_month_return']].apply(modified_z)
df['forward_thirtythree_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['forward_thirtythree_month_return']].apply(modified_z)
df['forward_thirtyfour_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['forward_thirtyfour_month_return']].apply(modified_z)
df['forward_thirtyfive_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['forward_thirtyfive_month_return']].apply(modified_z)
df['forward_thirtysix_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['forward_thirtysix_month_return']].apply(modified_z)
df['past_one_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_one_month_return']].apply(modified_z)
df['past_two_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_two_month_return']].apply(modified_z)
df['past_three_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_three_month_return']].apply(modified_z)
df['past_four_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_four_month_return']].apply(modified_z)
df['past_five_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_five_month_return']].apply(modified_z)
df['past_six_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_six_month_return']].apply(modified_z)
df['past_seven_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_seven_month_return']].apply(modified_z)
df['past_eight_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_eight_month_return']].apply(modified_z)
df['past_nine_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_nine_month_return']].apply(modified_z)
df['past_ten_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_ten_month_return']].apply(modified_z)
df['past_eleven_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_eleven_month_return']].apply(modified_z)
df['past_twelve_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_twelve_month_return']].apply(modified_z)
df['past_thirteen_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_thirteen_month_return']].apply(modified_z)
df['past_fourteen_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_fourteen_month_return']].apply(modified_z)
df['past_fifteen_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_fifteen_month_return']].apply(modified_z)
df['past_sixteen_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_sixteen_month_return']].apply(modified_z)
df['past_seventeen_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_seventeen_month_return']].apply(modified_z)
df['past_eighteen_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_eighteen_month_return']].apply(modified_z)
df['past_nineteen_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_nineteen_month_return']].apply(modified_z)
df['past_twenty_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_twenty_month_return']].apply(modified_z)
df['past_twentyone_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_twentyone_month_return']].apply(modified_z)
df['past_twentytwo_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_twentytwo_month_return']].apply(modified_z)
df['past_twentythree_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_twentythree_month_return']].apply(modified_z)
df['past_twentyfour_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_twentyfour_month_return']].apply(modified_z)
df['past_twentyfive_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_twentyfive_month_return']].apply(modified_z)
df['past_twentysix_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_twentysix_month_return']].apply(modified_z)
df['past_twentyseven_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_twentyseven_month_return']].apply(modified_z)
df['past_twentyeight_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_twentyeight_month_return']].apply(modified_z)
df['past_twentynine_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_twentynine_month_return']].apply(modified_z)
df['past_thirty_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_thirty_month_return']].apply(modified_z)
df['past_thirtyone_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_thirtyone_month_return']].apply(modified_z)
df['past_thirtytwo_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_thirtytwo_month_return']].apply(modified_z)
df['past_thirtythree_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_thirtythree_month_return']].apply(modified_z)
df['past_thirtyfour_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_thirtyfour_month_return']].apply(modified_z)
df['past_thirtyfive_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_thirtyfive_month_return']].apply(modified_z)
df['past_thirtysix_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_thirtysix_month_return']].apply(modified_z)
df['accrual_sector_zscore'] = df.groupby(['year-month', 'sector'])[['accrual']].apply(modified_z)
df['adv_sale_sector_zscore'] = df.groupby(['year-month', 'sector'])[['adv_sale']].apply(modified_z)
df['aftret_eq_sector_zscore'] = df.groupby(['year-month', 'sector'])[['aftret_eq']].apply(modified_z)
df['aftret_equity_sector_zscore'] = df.groupby(['year-month', 'sector'])[['aftret_equity']].apply(modified_z)
df['aftret_invcapx_sector_zscore'] = df.groupby(['year-month', 'sector'])[['aftret_invcapx']].apply(modified_z)
df['at_turn_sector_zscore'] = df.groupby(['year-month', 'sector'])[['at_turn']].apply(modified_z)
df['bm_sector_zscore'] = df.groupby(['year-month', 'sector'])[['bm']].apply(modified_z)
df['CAPEI_sector_zscore'] = df.groupby(['year-month', 'sector'])[['CAPEI']].apply(modified_z)
df['capital_ratio_sector_zscore'] = df.groupby(['year-month', 'sector'])[['capital_ratio']].apply(modified_z)
df['cash_conversion_sector_zscore'] = df.groupby(['year-month', 'sector'])[['cash_conversion']].apply(modified_z)
df['cash_debt_sector_zscore'] = df.groupby(['year-month', 'sector'])[['cash_debt']].apply(modified_z)
df['cash_lt_sector_zscore'] = df.groupby(['year-month', 'sector'])[['cash_lt']].apply(modified_z)
df['cash_ratio_sector_zscore'] = df.groupby(['year-month', 'sector'])[['cash_ratio']].apply(modified_z)
df['cfm_sector_zscore'] = df.groupby(['year-month', 'sector'])[['cfm']].apply(modified_z)
df['curr_debt_sector_zscore'] = df.groupby(['year-month', 'sector'])[['curr_debt']].apply(modified_z)
df['curr_ratio_sector_zscore'] = df.groupby(['year-month', 'sector'])[['curr_ratio']].apply(modified_z)
df['de_ratio_sector_zscore'] = df.groupby(['year-month', 'sector'])[['de_ratio']].apply(modified_z)
df['debt_assets_sector_zscore'] = df.groupby(['year-month', 'sector'])[['debt_assets']].apply(modified_z)
df['debt_at_sector_zscore'] = df.groupby(['year-month', 'sector'])[['debt_at']].apply(modified_z)
df['debt_capital_sector_zscore'] = df.groupby(['year-month', 'sector'])[['debt_capital']].apply(modified_z)
df['debt_ebitda_sector_zscore'] = df.groupby(['year-month', 'sector'])[['debt_ebitda']].apply(modified_z)
df['debt_invcap_sector_zscore'] = df.groupby(['year-month', 'sector'])[['debt_invcap']].apply(modified_z)
df['dltt_be_sector_zscore'] = df.groupby(['year-month', 'sector'])[['dltt_be']].apply(modified_z)
df['dpr_sector_zscore'] = df.groupby(['year-month', 'sector'])[['dpr']].apply(modified_z)
df['efftax_sector_zscore'] = df.groupby(['year-month', 'sector'])[['efftax']].apply(modified_z)
df['equity_invcap_sector_zscore'] = df.groupby(['year-month', 'sector'])[['equity_invcap']].apply(modified_z)
df['evm_sector_zscore'] = df.groupby(['year-month', 'sector'])[['evm']].apply(modified_z)
df['fcf_ocf_sector_zscore'] = df.groupby(['year-month', 'sector'])[['fcf_ocf']].apply(modified_z)
df['gpm_sector_zscore'] = df.groupby(['year-month', 'sector'])[['gpm']].apply(modified_z)
df['GProf_sector_zscore'] = df.groupby(['year-month', 'sector'])[['GProf']].apply(modified_z)
df['int_debt_sector_zscore'] = df.groupby(['year-month', 'sector'])[['int_debt']].apply(modified_z)
df['int_totdebt_sector_zscore'] = df.groupby(['year-month', 'sector'])[['int_totdebt']].apply(modified_z)
df['intcov_sector_zscore'] = df.groupby(['year-month', 'sector'])[['intcov']].apply(modified_z)
df['intcov_ratio_sector_zscore'] = df.groupby(['year-month', 'sector'])[['intcov_ratio']].apply(modified_z)
df['inv_turn_sector_zscore'] = df.groupby(['year-month', 'sector'])[['inv_turn']].apply(modified_z)
df['invt_act_sector_zscore'] = df.groupby(['year-month', 'sector'])[['invt_act']].apply(modified_z)
df['lt_debt_sector_zscore'] = df.groupby(['year-month', 'sector'])[['lt_debt']].apply(modified_z)
df['lt_ppent_sector_zscore'] = df.groupby(['year-month', 'sector'])[['lt_ppent']].apply(modified_z)
df['npm_sector_zscore'] = df.groupby(['year-month', 'sector'])[['npm']].apply(modified_z)
df['ocf_lct_sector_zscore'] = df.groupby(['year-month', 'sector'])[['ocf_lct']].apply(modified_z)
df['opmad_sector_zscore'] = df.groupby(['year-month', 'sector'])[['opmad']].apply(modified_z)
df['opmbd_sector_zscore'] = df.groupby(['year-month', 'sector'])[['opmbd']].apply(modified_z)
df['pay_turn_sector_zscore'] = df.groupby(['year-month', 'sector'])[['pay_turn']].apply(modified_z)
df['pcf_sector_zscore'] = df.groupby(['year-month', 'sector'])[['pcf']].apply(modified_z)
df['pe_exi_sector_zscore'] = df.groupby(['year-month', 'sector'])[['pe_exi']].apply(modified_z)
df['pe_inc_sector_zscore'] = df.groupby(['year-month', 'sector'])[['pe_inc']].apply(modified_z)
df['pe_op_basic_sector_zscore'] = df.groupby(['year-month', 'sector'])[['pe_op_basic']].apply(modified_z)
df['pe_op_dil_sector_zscore'] = df.groupby(['year-month', 'sector'])[['pe_op_dil']].apply(modified_z)
df['PEG_1yrforward_sector_zscore'] = df.groupby(['year-month', 'sector'])[['PEG_1yrforward']].apply(modified_z)
df['PEG_ltgforward_sector_zscore'] = df.groupby(['year-month', 'sector'])[['PEG_ltgforward']].apply(modified_z)
df['PEG_trailing_sector_zscore'] = df.groupby(['year-month', 'sector'])[['PEG_trailing']].apply(modified_z)
df['pretret_earnat_sector_zscore'] = df.groupby(['year-month', 'sector'])[['pretret_earnat']].apply(modified_z)
df['pretret_noa_sector_zscore'] = df.groupby(['year-month', 'sector'])[['pretret_noa']].apply(modified_z)
df['profit_lct_sector_zscore'] = df.groupby(['year-month', 'sector'])[['profit_lct']].apply(modified_z)
df['ps_sector_zscore'] = df.groupby(['year-month', 'sector'])[['ps']].apply(modified_z)
df['ptb_sector_zscore'] = df.groupby(['year-month', 'sector'])[['ptb']].apply(modified_z)
df['ptpm_sector_zscore'] = df.groupby(['year-month', 'sector'])[['ptpm']].apply(modified_z)
df['quick_ratio_sector_zscore'] = df.groupby(['year-month', 'sector'])[['quick_ratio']].apply(modified_z)
df['rd_sale_sector_zscore'] = df.groupby(['year-month', 'sector'])[['rd_sale']].apply(modified_z)
df['rect_act_sector_zscore'] = df.groupby(['year-month', 'sector'])[['rect_act']].apply(modified_z)
df['rect_turn_sector_zscore'] = df.groupby(['year-month', 'sector'])[['rect_turn']].apply(modified_z)
df['roa_sector_zscore'] = df.groupby(['year-month', 'sector'])[['roa']].apply(modified_z)
df['roce_sector_zscore'] = df.groupby(['year-month', 'sector'])[['roce']].apply(modified_z)
df['roe_sector_zscore'] = df.groupby(['year-month', 'sector'])[['roe']].apply(modified_z)
df['sale_equity_sector_zscore'] = df.groupby(['year-month', 'sector'])[['sale_equity']].apply(modified_z)
df['sale_invcap_sector_zscore'] = df.groupby(['year-month', 'sector'])[['sale_invcap']].apply(modified_z)
df['sale_nwc_sector_zscore'] = df.groupby(['year-month', 'sector'])[['sale_nwc']].apply(modified_z)
df['short_debt_sector_zscore'] = df.groupby(['year-month', 'sector'])[['short_debt']].apply(modified_z)
df['staff_sale_sector_zscore'] = df.groupby(['year-month', 'sector'])[['staff_sale']].apply(modified_z)
df['totdebt_invcap_sector_zscore'] = df.groupby(['year-month', 'sector'])[['totdebt_invcap']].apply(modified_z)
df['alpha_sector_zscore'] = df.groupby(['year-month', 'sector'])[['alpha']].apply(modified_z)
df['b_hml_sector_zscore'] = df.groupby(['year-month', 'sector'])[['b_hml']].apply(modified_z)
df['b_mkt_sector_zscore'] = df.groupby(['year-month', 'sector'])[['b_mkt']].apply(modified_z)
df['b_smb_sector_zscore'] = df.groupby(['year-month', 'sector'])[['b_smb']].apply(modified_z)
df['b_umd_sector_zscore'] = df.groupby(['year-month', 'sector'])[['b_umd']].apply(modified_z)
df['exret_sector_zscore'] = df.groupby(['year-month', 'sector'])[['exret']].apply(modified_z)
df['ivol_sector_zscore'] = df.groupby(['year-month', 'sector'])[['ivol']].apply(modified_z)
df['n_sector_zscore'] = df.groupby(['year-month', 'sector'])[['n']].apply(modified_z)
df['R2_sector_zscore'] = df.groupby(['year-month', 'sector'])[['R2']].apply(modified_z)
df['tvol_sector_zscore'] = df.groupby(['year-month', 'sector'])[['tvol']].apply(modified_z)
df['BUYPCT_sector_zscore'] = df.groupby(['year-month', 'sector'])[['BUYPCT']].apply(modified_z)
df['HOLDPCT_sector_zscore'] = df.groupby(['year-month', 'sector'])[['HOLDPCT']].apply(modified_z)
df['MEANREC_sector_zscore'] = df.groupby(['year-month', 'sector'])[['MEANREC']].apply(modified_z)
df['MEDREC_sector_zscore'] = df.groupby(['year-month', 'sector'])[['MEDREC']].apply(modified_z)
df['recup_sector_zscore'] = df.groupby(['year-month', 'sector'])[['recup']].apply(modified_z)
df['recdown_sector_zscore'] = df.groupby(['year-month', 'sector'])[['recdown']].apply(modified_z)
df['SELLPCT_sector_zscore'] = df.groupby(['year-month', 'sector'])[['SELLPCT']].apply(modified_z)
df['STDEV_sector_zscore'] = df.groupby(['year-month', 'sector'])[['STDEV']].apply(modified_z)
# Out:
# C:\Users\shane\Anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:717: RuntimeWarning: All-NaN slice encountered
#   warnings.warn("All-NaN slice encountered", RuntimeWarning)

# %%
# df - Subset - Relevant features with adequate data

df = df[[
        'GVKEY', 
        'sector', 
        'year-month', 
        'january', 
        'february', 
        'march', 
        'april', 
        'may', 
        'june', 
        'july', 
        'august', 
        'september', 
        'october', 
        'november', 
        'december', 
        'forward_one_month_return_sector_zscore', 
        'forward_one_month_return_zscore', 
        'forward_two_month_return_sector_zscore', 
        'forward_two_month_return_zscore', 
        'forward_three_month_return_sector_zscore', 
        'forward_three_month_return_zscore', 
        'forward_four_month_return_sector_zscore', 
        'forward_four_month_return_zscore', 
        'forward_five_month_return_sector_zscore', 
        'forward_five_month_return_zscore', 
        'forward_six_month_return_sector_zscore', 
        'forward_six_month_return_zscore', 
        'forward_seven_month_return_sector_zscore', 
        'forward_seven_month_return_zscore', 
        'forward_eight_month_return_sector_zscore', 
        'forward_eight_month_return_zscore', 
        'forward_nine_month_return_sector_zscore', 
        'forward_nine_month_return_zscore', 
        'forward_ten_month_return_sector_zscore', 
        'forward_ten_month_return_zscore', 
        'forward_eleven_month_return_sector_zscore', 
        'forward_eleven_month_return_zscore', 
        'forward_twelve_month_return_sector_zscore', 
        'forward_twelve_month_return_zscore', 
        'forward_thirteen_month_return_sector_zscore', 
        'forward_thirteen_month_return_zscore', 
        'forward_fourteen_month_return_sector_zscore', 
        'forward_fourteen_month_return_zscore', 
        'forward_fifteen_month_return_sector_zscore', 
        'forward_fifteen_month_return_zscore', 
        'forward_sixteen_month_return_sector_zscore', 
        'forward_sixteen_month_return_zscore', 
        'forward_seventeen_month_return_sector_zscore', 
        'forward_seventeen_month_return_zscore', 
        'forward_eighteen_month_return_sector_zscore', 
        'forward_eighteen_month_return_zscore', 
        'forward_nineteen_month_return_sector_zscore', 
        'forward_nineteen_month_return_zscore', 
        'forward_twenty_month_return_sector_zscore', 
        'forward_twenty_month_return_zscore', 
        'forward_twentyone_month_return_sector_zscore', 
        'forward_twentyone_month_return_zscore', 
        'forward_twentytwo_month_return_sector_zscore', 
        'forward_twentytwo_month_return_zscore', 
        'forward_twentythree_month_return_sector_zscore', 
        'forward_twentythree_month_return_zscore', 
        'forward_twentyfour_month_return_sector_zscore', 
        'forward_twentyfour_month_return_zscore', 
        'forward_twentyfive_month_return_sector_zscore', 
        'forward_twentyfive_month_return_zscore', 
        'forward_twentysix_month_return_sector_zscore', 
        'forward_twentysix_month_return_zscore', 
        'forward_twentyseven_month_return_sector_zscore', 
        'forward_twentyseven_month_return_zscore', 
        'forward_twentyeight_month_return_sector_zscore', 
        'forward_twentyeight_month_return_zscore', 
        'forward_twentynine_month_return_sector_zscore', 
        'forward_twentynine_month_return_zscore', 
        'forward_thirty_month_return_sector_zscore', 
        'forward_thirty_month_return_zscore', 
        'forward_thirtyone_month_return_sector_zscore', 
        'forward_thirtyone_month_return_zscore', 
        'forward_thirtytwo_month_return_sector_zscore', 
        'forward_thirtytwo_month_return_zscore', 
        'forward_thirtythree_month_return_sector_zscore', 
        'forward_thirtythree_month_return_zscore', 
        'forward_thirtyfour_month_return_sector_zscore', 
        'forward_thirtyfour_month_return_zscore', 
        'forward_thirtyfive_month_return_sector_zscore', 
        'forward_thirtyfive_month_return_zscore', 
        'forward_thirtysix_month_return_sector_zscore', 
        'forward_thirtysix_month_return_zscore', 
        'past_one_month_return_sector_zscore', 
        'past_one_month_return_zscore', 
        'past_two_month_return_sector_zscore', 
        'past_two_month_return_zscore', 
        'past_three_month_return_sector_zscore', 
        'past_three_month_return_zscore', 
        'past_four_month_return_sector_zscore', 
        'past_four_month_return_zscore', 
        'past_five_month_return_sector_zscore', 
        'past_five_month_return_zscore', 
        'past_six_month_return_sector_zscore', 
        'past_six_month_return_zscore', 
        'past_seven_month_return_sector_zscore', 
        'past_seven_month_return_zscore', 
        'past_eight_month_return_sector_zscore', 
        'past_eight_month_return_zscore', 
        'past_nine_month_return_sector_zscore', 
        'past_nine_month_return_zscore', 
        'past_ten_month_return_sector_zscore', 
        'past_ten_month_return_zscore', 
        'past_eleven_month_return_sector_zscore', 
        'past_eleven_month_return_zscore', 
        'past_twelve_month_return_sector_zscore', 
        'past_twelve_month_return_zscore', 
        'past_thirteen_month_return_sector_zscore', 
        'past_thirteen_month_return_zscore', 
        'past_fourteen_month_return_sector_zscore', 
        'past_fourteen_month_return_zscore', 
        'past_fifteen_month_return_sector_zscore', 
        'past_fifteen_month_return_zscore', 
        'past_sixteen_month_return_sector_zscore', 
        'past_sixteen_month_return_zscore', 
        'past_seventeen_month_return_sector_zscore', 
        'past_seventeen_month_return_zscore', 
        'past_eighteen_month_return_sector_zscore', 
        'past_eighteen_month_return_zscore', 
        'past_nineteen_month_return_sector_zscore', 
        'past_nineteen_month_return_zscore', 
        'past_twenty_month_return_sector_zscore', 
        'past_twenty_month_return_zscore', 
        'past_twentyone_month_return_sector_zscore', 
        'past_twentyone_month_return_zscore', 
        'past_twentytwo_month_return_sector_zscore', 
        'past_twentytwo_month_return_zscore', 
        'past_twentythree_month_return_sector_zscore', 
        'past_twentythree_month_return_zscore', 
        'past_twentyfour_month_return_sector_zscore', 
        'past_twentyfour_month_return_zscore', 
        'past_twentyfive_month_return_sector_zscore', 
        'past_twentyfive_month_return_zscore', 
        'past_twentysix_month_return_sector_zscore', 
        'past_twentysix_month_return_zscore', 
        'past_twentyseven_month_return_sector_zscore', 
        'past_twentyseven_month_return_zscore', 
        'past_twentyeight_month_return_sector_zscore', 
        'past_twentyeight_month_return_zscore', 
        'past_twentynine_month_return_sector_zscore', 
        'past_twentynine_month_return_zscore', 
        'past_thirty_month_return_sector_zscore', 
        'past_thirty_month_return_zscore', 
        'past_thirtyone_month_return_sector_zscore', 
        'past_thirtyone_month_return_zscore', 
        'past_thirtytwo_month_return_sector_zscore', 
        'past_thirtytwo_month_return_zscore', 
        'past_thirtythree_month_return_sector_zscore', 
        'past_thirtythree_month_return_zscore', 
        'past_thirtyfour_month_return_sector_zscore', 
        'past_thirtyfour_month_return_zscore', 
        'past_thirtyfive_month_return_sector_zscore', 
        'past_thirtyfive_month_return_zscore', 
        'past_thirtysix_month_return_sector_zscore', 
        'past_thirtysix_month_return_zscore', 
        'accrual_sector_zscore', 
        'accrual_zscore', 
        'adv_sale_sector_zscore', 
        'adv_sale_zscore', 
        'aftret_eq_sector_zscore', 
        'aftret_eq_zscore', 
        'aftret_equity_sector_zscore', 
        'aftret_equity_zscore', 
        'aftret_invcapx_sector_zscore', 
        'aftret_invcapx_zscore', 
        'alpha_sector_zscore', 
        'alpha_zscore', 
        'at_turn_sector_zscore', 
        'at_turn_zscore', 
        'b_hml_sector_zscore', 
        'b_hml_zscore', 
        'b_mkt_sector_zscore', 
        'b_mkt_zscore', 
        'b_smb_sector_zscore', 
        'b_smb_zscore', 
        'b_umd_sector_zscore', 
        'b_umd_zscore', 
        'bm_sector_zscore', 
        'bm_zscore', 
        'BUYPCT_sector_zscore', 
        'BUYPCT_zscore', 
        'CAPEI_sector_zscore', 
        'CAPEI_zscore', 
        'capital_ratio_sector_zscore', 
        'capital_ratio_zscore', 
        'cash_conversion_sector_zscore', 
        'cash_conversion_zscore', 
        'cash_debt_sector_zscore', 
        'cash_debt_zscore', 
        'cash_lt_sector_zscore', 
        'cash_lt_zscore', 
        'cash_ratio_sector_zscore', 
        'cash_ratio_zscore', 
        'cfm_sector_zscore', 
        'cfm_zscore', 
        'curr_debt_sector_zscore', 
        'curr_debt_zscore', 
        'curr_ratio_sector_zscore', 
        'curr_ratio_zscore', 
        'de_ratio_sector_zscore', 
        'de_ratio_zscore', 
        'debt_assets_sector_zscore', 
        'debt_assets_zscore', 
        'debt_at_sector_zscore', 
        'debt_at_zscore', 
        'debt_capital_sector_zscore', 
        'debt_capital_zscore', 
        'debt_ebitda_sector_zscore', 
        'debt_ebitda_zscore', 
        'debt_invcap_sector_zscore', 
        'debt_invcap_zscore', 
        'DIVYIELD', 
        'dltt_be_sector_zscore', 
        'dltt_be_zscore', 
        'dpr_sector_zscore', 
        'dpr_zscore', 
        'dvpspm', 
        'dvpsxm', 
        'dvrate', 
        'efftax_sector_zscore', 
        'efftax_zscore', 
        'equity_invcap_sector_zscore', 
        'equity_invcap_zscore', 
        'evm_sector_zscore', 
        'evm_zscore', 
        'exret_sector_zscore', 
        'exret_zscore', 
        'fcf_ocf_sector_zscore', 
        'fcf_ocf_zscore', 
        'gpm_sector_zscore', 
        'gpm_zscore', 
        'GProf_sector_zscore', 
        'GProf_zscore', 
        'HOLDPCT_sector_zscore', 
        'HOLDPCT_zscore', 
        'int_debt_sector_zscore', 
        'int_debt_zscore', 
        'int_totdebt_sector_zscore', 
        'int_totdebt_zscore', 
        'intcov_ratio_sector_zscore', 
        'intcov_ratio_zscore', 
        'intcov_sector_zscore', 
        'intcov_zscore', 
        'inv_turn_sector_zscore', 
        'inv_turn_zscore', 
        'invt_act_sector_zscore', 
        'invt_act_zscore', 
        'ivol_sector_zscore', 
        'ivol_zscore', 
        'lt_debt_sector_zscore', 
        'lt_debt_zscore', 
        'lt_ppent_sector_zscore', 
        'lt_ppent_zscore', 
        'MEANREC_sector_zscore', 
        'MEANREC_zscore', 
        'MEDREC_sector_zscore', 
        'MEDREC_zscore', 
        'n_sector_zscore', 
        'n_zscore', 
        'npm_sector_zscore', 
        'npm_zscore', 
        'ocf_lct_sector_zscore', 
        'ocf_lct_zscore', 
        'opmad_sector_zscore', 
        'opmad_zscore', 
        'opmbd_sector_zscore', 
        'opmbd_zscore', 
        'pay_turn_sector_zscore', 
        'pay_turn_zscore', 
        'pcf_sector_zscore', 
        'pcf_zscore', 
        'pe_exi_sector_zscore', 
        'pe_exi_zscore', 
        'pe_inc_sector_zscore', 
        'pe_inc_zscore', 
        'pe_op_basic_sector_zscore', 
        'pe_op_basic_zscore', 
        'pe_op_dil_sector_zscore', 
        'pe_op_dil_zscore', 
        'PEG_1yrforward_sector_zscore', 
        'PEG_1yrforward_zscore', 
        'PEG_ltgforward_sector_zscore', 
        'PEG_ltgforward_zscore', 
        'PEG_trailing_sector_zscore', 
        'PEG_trailing_zscore', 
        'pretret_earnat_sector_zscore', 
        'pretret_earnat_zscore', 
        'pretret_noa_sector_zscore', 
        'pretret_noa_zscore', 
        'profit_lct_sector_zscore', 
        'profit_lct_zscore', 
        'ps_sector_zscore', 
        'ps_zscore', 
        'ptb_sector_zscore', 
        'ptb_zscore', 
        'ptpm_sector_zscore', 
        'ptpm_zscore', 
        'quick_ratio_sector_zscore', 
        'quick_ratio_zscore', 
        'R2_sector_zscore', 
        'R2_zscore', 
        'rd_sale_sector_zscore', 
        'rd_sale_zscore', 
        'recdown_sector_zscore', 
        'recdown_zscore', 
        'rect_act_sector_zscore', 
        'rect_act_zscore', 
        'rect_turn_sector_zscore', 
        'rect_turn_zscore', 
        'recup_sector_zscore', 
        'recup_zscore', 
        'roa_sector_zscore', 
        'roa_zscore', 
        'roce_sector_zscore', 
        'roce_zscore', 
        'roe_sector_zscore', 
        'roe_zscore', 
        'sale_equity_sector_zscore', 
        'sale_equity_zscore', 
        'sale_invcap_sector_zscore', 
        'sale_invcap_zscore', 
        'sale_nwc_sector_zscore', 
        'sale_nwc_zscore', 
        'SELLPCT_sector_zscore', 
        'SELLPCT_zscore', 
        'short_debt_sector_zscore', 
        'short_debt_zscore', 
        'spcsrc', 
        'staff_sale_sector_zscore', 
        'staff_sale_zscore', 
        'STDEV_sector_zscore', 
        'STDEV_zscore', 
        'totdebt_invcap_sector_zscore', 
        'totdebt_invcap_zscore', 
        'tvol_sector_zscore', 
        'tvol_zscore'
        ]]

# %%
return_all_rows(df.describe().transpose())
# Out:
# C:\Users\shane\Anaconda3\lib\site-packages\numpy\lib\function_base.py:3817: RuntimeWarning: invalid value encountered in multiply
#   x2 = take(ap, indices_above, axis=axis) * weights_above
#                                                   count          mean  \
# GVKEY                                           47539.0  7.069949e+04
# january                                         47539.0  8.348935e-02
# february                                        47539.0  8.344727e-02
# march                                           47539.0  8.332106e-02
# april                                           47539.0  8.319485e-02
# may                                             47539.0  8.327899e-02
# june                                            47539.0  8.325796e-02
# july                                            47539.0  8.306864e-02
# august                                          47539.0  8.336313e-02
# september                                       47539.0  8.365763e-02
# october                                         47539.0  8.346831e-02
# november                                        47539.0  8.334210e-02
# december                                        47539.0  8.311071e-02
# forward_one_month_return_sector_zscore          43413.0  1.454676e+01
# forward_one_month_return_zscore                 43526.0  8.955157e+00
# forward_two_month_return_sector_zscore          39425.0  2.264632e+00
# forward_two_month_return_zscore                 39515.0  1.307213e+00
# forward_three_month_return_sector_zscore        35426.0  7.726413e+00
# forward_three_month_return_zscore               35510.0  4.881070e+00
# forward_four_month_return_sector_zscore         31473.0  2.178398e+00
# forward_four_month_return_zscore                31535.0  1.056549e+00
# forward_five_month_return_sector_zscore         27556.0  5.192327e+00
# forward_five_month_return_zscore                27612.0  3.682865e+00
# forward_six_month_return_sector_zscore          23689.0  1.983846e+00
# forward_six_month_return_zscore                 23724.0  1.045741e+00
# forward_seven_month_return_sector_zscore        19848.0  5.250899e+00
# forward_seven_month_return_zscore               19881.0  3.635380e+00
# forward_eight_month_return_sector_zscore        16055.0  2.982473e+00
# forward_eight_month_return_zscore               16072.0  1.847115e+00
# forward_nine_month_return_sector_zscore         12269.0  5.797109e+00
# forward_nine_month_return_zscore                12289.0  4.960711e+00
# forward_ten_month_return_sector_zscore           8545.0  4.782044e+00
# forward_ten_month_return_zscore                  8553.0  3.524725e+00
# forward_eleven_month_return_sector_zscore        4821.0  7.119480e+00
# forward_eleven_month_return_zscore               4834.0  7.854263e+00
# forward_twelve_month_return_sector_zscore        1146.0  2.243947e+01
# forward_twelve_month_return_zscore               1150.0  1.523915e+01
# forward_thirteen_month_return_sector_zscore      1044.0  3.630851e+01
# forward_thirteen_month_return_zscore             1056.0  3.598749e+01
# forward_fourteen_month_return_sector_zscore       959.0  5.717942e-01
# forward_fourteen_month_return_zscore              963.0  7.601524e-01
# forward_fifteen_month_return_sector_zscore        858.0  4.197668e+01
# forward_fifteen_month_return_zscore               870.0  4.564989e+01
# forward_sixteen_month_return_sector_zscore        773.0  6.150183e-01
# forward_sixteen_month_return_zscore               777.0  7.884895e-01
# forward_seventeen_month_return_sector_zscore      680.0  3.005538e+01
# forward_seventeen_month_return_zscore             689.0  4.141417e+01
# forward_eighteen_month_return_sector_zscore       600.0  7.823487e-01
# forward_eighteen_month_return_zscore              602.0  9.483503e-01
# forward_nineteen_month_return_sector_zscore       506.0  4.344533e+01
# forward_nineteen_month_return_zscore              513.0  4.813163e+01
# forward_twenty_month_return_sector_zscore         424.0  5.362913e-01
# forward_twenty_month_return_zscore                424.0  6.833341e-01
# forward_twentyone_month_return_sector_zscore      330.0  3.785964e+01
# forward_twentyone_month_return_zscore             336.0  3.609906e+01
# forward_twentytwo_month_return_sector_zscore      248.0  4.599069e-01
# forward_twentytwo_month_return_zscore             248.0  6.705591e-01
# forward_twentythree_month_return_sector_zscore    154.0  6.403783e+01
# forward_twentythree_month_return_zscore           160.0  6.922137e+01
# forward_twentyfour_month_return_sector_zscore      72.0  4.158141e-01
# forward_twentyfour_month_return_zscore             72.0  4.158141e-01
# forward_twentyfive_month_return_sector_zscore      66.0  1.519049e-01
# forward_twentyfive_month_return_zscore             66.0  1.519049e-01
# forward_twentysix_month_return_sector_zscore       60.0  3.465032e-01
# forward_twentysix_month_return_zscore              60.0  3.465032e-01
# forward_twentyseven_month_return_sector_zscore     54.0  6.309100e-01
# forward_twentyseven_month_return_zscore            54.0  6.309100e-01
# forward_twentyeight_month_return_sector_zscore     48.0  9.411615e-01
# forward_twentyeight_month_return_zscore            48.0  9.411615e-01
# forward_twentynine_month_return_sector_zscore      42.0  5.595936e-01
# forward_twentynine_month_return_zscore             42.0  5.595936e-01
# forward_thirty_month_return_sector_zscore          36.0  6.787304e-01
# forward_thirty_month_return_zscore                 36.0  6.787304e-01
# forward_thirtyone_month_return_sector_zscore       30.0  9.669522e-01
# forward_thirtyone_month_return_zscore              30.0  9.669522e-01
# forward_thirtytwo_month_return_sector_zscore       24.0  1.742201e-01
# forward_thirtytwo_month_return_zscore              24.0  1.742201e-01
# forward_thirtythree_month_return_sector_zscore     18.0  8.849326e-01
# forward_thirtythree_month_return_zscore            18.0  8.849326e-01
# forward_thirtyfour_month_return_sector_zscore      12.0  3.891122e+00
# forward_thirtyfour_month_return_zscore             12.0  3.891122e+00
# forward_thirtyfive_month_return_sector_zscore       6.0 -3.700743e-17
# forward_thirtyfive_month_return_zscore              6.0 -3.700743e-17
# forward_thirtysix_month_return_sector_zscore        0.0           NaN
# forward_thirtysix_month_return_zscore               0.0           NaN
# past_one_month_return_sector_zscore             43523.0  1.519774e+01
# past_one_month_return_zscore                    43642.0  9.919912e+00
# past_two_month_return_sector_zscore             39668.0  2.219543e+00
# past_two_month_return_zscore                    39772.0  1.253905e+00
# past_three_month_return_sector_zscore           35634.0  8.581042e+00
# past_three_month_return_zscore                  35729.0  5.811762e+00
# past_four_month_return_sector_zscore            31647.0  2.168068e+00
# past_four_month_return_zscore                   31721.0  1.112430e+00
# past_five_month_return_sector_zscore            27664.0  6.868137e+00
# past_five_month_return_zscore                   27735.0  5.950591e+00
# past_six_month_return_sector_zscore             23732.0  3.857513e+00
# past_six_month_return_zscore                    23782.0  1.736563e+00
# past_seven_month_return_sector_zscore           19853.0  6.711870e+00
# past_seven_month_return_zscore                  19899.0  5.999471e+00
# past_eight_month_return_sector_zscore           16035.0  3.462995e+00
# past_eight_month_return_zscore                  16062.0  2.336447e+00
# past_nine_month_return_sector_zscore            12245.0  1.042490e+01
# past_nine_month_return_zscore                   12269.0  8.453513e+00
# past_ten_month_return_sector_zscore              8516.0  4.037229e+00
# past_ten_month_return_zscore                     8524.0  3.140013e+00
# past_eleven_month_return_sector_zscore           4797.0  1.297702e+01
# past_eleven_month_return_zscore                  4807.0  1.559203e+01
# past_twelve_month_return_sector_zscore           1140.0  1.288231e+01
# past_twelve_month_return_zscore                  1140.0  1.605107e+01
# past_thirteen_month_return_sector_zscore         1037.0  6.044836e+01
# past_thirteen_month_return_zscore                1045.0  7.304441e+01
# past_fourteen_month_return_sector_zscore          952.0  4.366094e-02
# past_fourteen_month_return_zscore                 952.0  6.578572e-02
# past_fifteen_month_return_sector_zscore           853.0  5.387519e+01
# past_fifteen_month_return_zscore                  861.0  8.278007e+01
# past_sixteen_month_return_sector_zscore           770.0  8.562661e-02
# past_sixteen_month_return_zscore                  770.0  1.052153e-01
# past_seventeen_month_return_sector_zscore         672.0  5.735109e+01
# past_seventeen_month_return_zscore                680.0  8.048568e+01
# past_eighteen_month_return_sector_zscore          592.0  1.534902e-01
# past_eighteen_month_return_zscore                 592.0  1.054594e-01
# past_nineteen_month_return_sector_zscore          496.0  5.680252e+01
# past_nineteen_month_return_zscore                 504.0  7.733830e+01
# past_twenty_month_return_sector_zscore            416.0  1.734083e-01
# past_twenty_month_return_zscore                   416.0  1.558603e-01
# past_twentyone_month_return_sector_zscore         324.0  7.309243e+01
# past_twentyone_month_return_zscore                330.0  7.572224e+01
# past_twentytwo_month_return_sector_zscore         244.0  1.164418e-01
# past_twentytwo_month_return_zscore                244.0  1.297384e-01
# past_twentythree_month_return_sector_zscore       152.0  3.128615e+02
# past_twentythree_month_return_zscore              158.0  7.998673e+01
# past_twentyfour_month_return_sector_zscore         72.0 -1.371826e-02
# past_twentyfour_month_return_zscore                72.0 -1.371826e-02
# past_twentyfive_month_return_sector_zscore         66.0 -1.160713e-02
# past_twentyfive_month_return_zscore                66.0 -1.160713e-02
# past_twentysix_month_return_sector_zscore          60.0 -4.127784e-02
# past_twentysix_month_return_zscore                 60.0 -4.127784e-02
# past_twentyseven_month_return_sector_zscore        54.0 -2.966729e-02
# past_twentyseven_month_return_zscore               54.0 -2.966729e-02
# past_twentyeight_month_return_sector_zscore        48.0 -1.105534e-01
# past_twentyeight_month_return_zscore               48.0 -1.105534e-01
# past_twentynine_month_return_sector_zscore         42.0  8.772801e-02
# past_twentynine_month_return_zscore                42.0  8.772801e-02
# past_thirty_month_return_sector_zscore             36.0 -9.488444e-02
# past_thirty_month_return_zscore                    36.0 -9.488444e-02
# past_thirtyone_month_return_sector_zscore          30.0  3.155290e-01
# past_thirtyone_month_return_zscore                 30.0  3.155290e-01
# past_thirtytwo_month_return_sector_zscore          24.0 -4.564862e-02
# past_thirtytwo_month_return_zscore                 24.0 -4.564862e-02
# past_thirtythree_month_return_sector_zscore        18.0  7.502747e-02
# past_thirtythree_month_return_zscore               18.0  7.502747e-02
# past_thirtyfour_month_return_sector_zscore         12.0  2.693845e-02
# past_thirtyfour_month_return_zscore                12.0  2.693845e-02
# past_thirtyfive_month_return_sector_zscore          6.0 -3.700743e-17
# past_thirtyfive_month_return_zscore                 6.0 -3.700743e-17
# past_thirtysix_month_return_sector_zscore           0.0           NaN
# past_thirtysix_month_return_zscore                  0.0           NaN
# accrual_sector_zscore                           47249.0  2.293429e-01
# accrual_zscore                                  47317.0  3.417534e-01
# adv_sale_sector_zscore                          26597.0           inf
# adv_sale_zscore                                 20402.0           inf
# aftret_eq_sector_zscore                         47200.0  5.126727e-01
# aftret_eq_zscore                                47264.0 -5.302946e-02
# aftret_equity_sector_zscore                     47229.0  6.934604e-02
# aftret_equity_zscore                            47293.0 -5.601659e-01
# aftret_invcapx_sector_zscore                    41812.0           NaN
# aftret_invcapx_zscore                           46805.0 -7.259970e+00
# alpha_sector_zscore                             28801.0  4.419830e-02
# alpha_zscore                                    28801.0  1.279906e-01
# at_turn_sector_zscore                           45835.0  2.225452e+00
# at_turn_zscore                                  45837.0  2.824780e-01
# b_hml_sector_zscore                             28801.0 -7.317833e-02
# b_hml_zscore                                    28801.0 -2.108572e-01
# b_mkt_sector_zscore                             28801.0  1.288006e-01
# b_mkt_zscore                                    28801.0  9.728552e-02
# b_smb_sector_zscore                             28801.0  9.212155e-02
# b_smb_zscore                                    28801.0  1.733561e-01
# b_umd_sector_zscore                             28801.0 -1.675959e-01
# b_umd_zscore                                    28801.0 -2.274573e-01
# bm_sector_zscore                                45610.0  7.966883e-01
# bm_zscore                                       45734.0  6.985280e-01
# BUYPCT_sector_zscore                            38659.0 -8.618851e-02
# BUYPCT_zscore                                   38659.0 -4.866764e-02
# CAPEI_sector_zscore                             45317.0  7.051599e-01
# CAPEI_zscore                                    45327.0  4.396185e-01
# capital_ratio_sector_zscore                     47131.0  7.329419e-01
# capital_ratio_zscore                            47234.0  3.114170e-01
# cash_conversion_sector_zscore                   33282.0  2.822343e+01
# cash_conversion_zscore                          33284.0  1.450871e+02
# cash_debt_sector_zscore                         46985.0  1.758044e-01
# cash_debt_zscore                                47037.0 -1.222023e+00
# cash_lt_sector_zscore                           47301.0  1.837693e+00
# cash_lt_zscore                                  47404.0  3.762105e+00
# cash_ratio_sector_zscore                        38418.0  9.577272e-01
# cash_ratio_zscore                               38520.0  1.829357e+00
# cfm_sector_zscore                               45809.0 -6.103803e+01
# cfm_zscore                                      45811.0 -9.372553e+01
# curr_debt_sector_zscore                         38399.0  1.598783e-01
# curr_debt_zscore                                38502.0  1.431108e-01
# curr_ratio_sector_zscore                        38418.0  5.951065e-01
# curr_ratio_zscore                               38520.0  8.914869e-01
# de_ratio_sector_zscore                          47288.0  1.367085e+00
# de_ratio_zscore                                 47391.0  1.540697e+00
# debt_assets_sector_zscore                       47301.0 -2.264640e-01
# debt_assets_zscore                              47404.0  2.275798e-02
# debt_at_sector_zscore                           47122.0  3.859306e-01
# debt_at_zscore                                  47225.0  2.536427e-01
# debt_capital_sector_zscore                      47019.0 -3.038209e-01
# debt_capital_zscore                             47122.0  1.206953e-01
# debt_ebitda_sector_zscore                       46989.0  1.093465e+00
# debt_ebitda_zscore                              47059.0  6.156221e-01
# debt_invcap_sector_zscore                       46895.0  8.456827e-01
# debt_invcap_zscore                              46998.0  3.787629e-01
# DIVYIELD                                        20005.0  2.523225e-02
# dltt_be_sector_zscore                           45526.0  3.082488e+00
# dltt_be_zscore                                  45629.0  1.558098e+00
# dpr_sector_zscore                               27726.0           NaN
# dpr_zscore                                      33227.0  1.275631e+00
# dvpspm                                           6640.0  2.557892e-01
# dvpsxm                                           6595.0  2.572305e-01
# dvrate                                          20084.0  9.206105e-01
# efftax_sector_zscore                            32565.0 -2.139920e+00
# efftax_zscore                                   32565.0 -1.835752e+00
# equity_invcap_sector_zscore                     47066.0 -7.265775e-01
# equity_invcap_zscore                            47169.0 -3.925780e-01
# evm_sector_zscore                               47190.0  2.441631e-01
# evm_zscore                                      47260.0  5.031943e-01
# exret_sector_zscore                             28682.0  1.830940e-02
# exret_zscore                                    28682.0 -2.369213e-03
# fcf_ocf_sector_zscore                           37361.0 -2.878555e+00
# fcf_ocf_zscore                                  37361.0 -2.594373e+00
# gpm_sector_zscore                               45753.0 -2.262630e+01
# gpm_zscore                                      45755.0 -2.377680e+01
# GProf_sector_zscore                             47299.0  4.507347e-01
# GProf_zscore                                    47367.0  9.052950e-02
# HOLDPCT_sector_zscore                           38659.0  8.103354e-02
# HOLDPCT_zscore                                  38659.0  7.955017e-02
# int_debt_sector_zscore                          32893.0  1.224770e+01
# int_debt_zscore                                 32893.0  1.409710e+01
# int_totdebt_sector_zscore                       34387.0  1.671970e+01
# int_totdebt_zscore                              34417.0  2.970502e+01
# intcov_ratio_sector_zscore                      36122.0  5.228938e+00
# intcov_ratio_zscore                             36128.0 -3.690320e+00
# intcov_sector_zscore                            36123.0  1.238411e+00
# intcov_zscore                                   36129.0 -1.083179e+01
# inv_turn_sector_zscore                          34187.0  1.772310e+01
# inv_turn_zscore                                 34187.0  9.357502e+00
# invt_act_sector_zscore                          37455.0           inf
# invt_act_zscore                                 38173.0  3.836733e-01
# ivol_sector_zscore                              28801.0  3.390180e-01
# ivol_zscore                                     28801.0  2.889405e-01
# lt_debt_sector_zscore                           47144.0  3.582753e-01
# lt_debt_zscore                                  47247.0  9.544705e-02
# lt_ppent_sector_zscore                          46401.0  2.762203e+00
# lt_ppent_zscore                                 46401.0  6.081189e+00
# MEANREC_sector_zscore                           38659.0  4.725871e-02
# MEANREC_zscore                                  38659.0  8.597203e-02
# MEDREC_sector_zscore                            32274.0           NaN
# MEDREC_zscore                                   38659.0  3.634811e-01
# n_sector_zscore                                 19172.0          -inf
# n_zscore                                        12950.0          -inf
# npm_sector_zscore                               45910.0 -7.734537e+01
# npm_zscore                                      45912.0 -1.177081e+02
# ocf_lct_sector_zscore                           38351.0 -9.246785e-02
# ocf_lct_zscore                                  38417.0 -6.103501e-01
# opmad_sector_zscore                             45906.0 -4.420909e+01
# opmad_zscore                                    45908.0 -6.602168e+01
# opmbd_sector_zscore                             45906.0 -3.466865e+01
# opmbd_zscore                                    45908.0 -5.245798e+01
# pay_turn_sector_zscore                          46095.0  2.188328e+02
# pay_turn_zscore                                 46135.0  1.077087e+00
# pcf_sector_zscore                               47248.0  2.354557e-02
# pcf_zscore                                      47315.0 -7.095828e-02
# pe_exi_sector_zscore                            46473.0  2.558925e-02
# pe_exi_zscore                                   46540.0 -1.236533e-01
# pe_inc_sector_zscore                            46488.0  3.637457e-02
# pe_inc_zscore                                   46555.0 -1.089408e-01
# pe_op_basic_sector_zscore                       46492.0  5.086376e-02
# pe_op_basic_zscore                              46559.0 -1.267066e-01
# pe_op_dil_sector_zscore                         46460.0  5.927253e-02
# pe_op_dil_zscore                                46527.0 -1.163358e-01
# PEG_1yrforward_sector_zscore                    32573.0 -2.050341e-01
# PEG_1yrforward_zscore                           32573.0  2.756505e-02
# PEG_ltgforward_sector_zscore                    20612.0 -1.323612e-01
# PEG_ltgforward_zscore                           20612.0 -1.522808e-01
# PEG_trailing_sector_zscore                      23369.0  1.832556e+00
# PEG_trailing_zscore                             23369.0  1.692825e+00
# pretret_earnat_sector_zscore                    38317.0 -3.976861e-01
# pretret_earnat_zscore                           38381.0 -7.291754e-01
# pretret_noa_sector_zscore                       38317.0 -2.100549e-01
# pretret_noa_zscore                              38381.0 -2.125667e-01
# profit_lct_sector_zscore                        38409.0 -5.337633e-01
# profit_lct_zscore                               38478.0 -1.205062e+00
# ps_sector_zscore                                45910.0  3.320859e+00
# ps_zscore                                       45912.0  7.421260e+00
# ptb_sector_zscore                               45610.0  9.391723e-01
# ptb_zscore                                      45734.0  1.200708e+00
# ptpm_sector_zscore                              45910.0 -5.860548e+01
# ptpm_zscore                                     45912.0 -8.620908e+01
# quick_ratio_sector_zscore                       38418.0  6.597480e-01
# quick_ratio_zscore                              38520.0  1.213363e+00
# R2_sector_zscore                                28801.0  7.939551e-02
# R2_zscore                                       28801.0  1.044887e-01
# rd_sale_sector_zscore                           24000.0           inf
# rd_sale_zscore                                  19072.0           inf
# recdown_sector_zscore                            3611.0           inf
# recdown_zscore                                   3611.0           inf
# rect_act_sector_zscore                          38329.0  2.195400e-01
# rect_act_zscore                                 38432.0  8.191533e-02
# rect_turn_sector_zscore                         45157.0  1.140447e+01
# rect_turn_zscore                                45159.0  3.321357e+00
# recup_sector_zscore                              3091.0           inf
# recup_zscore                                     3091.0           inf
# roa_sector_zscore                               47218.0  1.668956e-01
# roa_zscore                                      47282.0 -7.088995e-01
# roce_sector_zscore                              46948.0  3.191906e+00
# roce_zscore                                     47012.0  1.194152e+01
# roe_sector_zscore                               44976.0 -7.296177e-01
# roe_zscore                                      45056.0 -2.454474e+00
# sale_equity_sector_zscore                       44305.0  2.435172e+00
# sale_equity_zscore                              44307.0  2.020586e+00
# sale_invcap_sector_zscore                       45705.0  1.159487e+00
# sale_invcap_zscore                              45707.0  7.811249e-01
# sale_nwc_sector_zscore                          32750.0  2.537659e+00
# sale_nwc_zscore                                 32752.0  2.406681e+00
# SELLPCT_sector_zscore                            9243.0           inf
# SELLPCT_zscore                                   9243.0           inf
# short_debt_sector_zscore                        40122.0  1.486812e+00
# short_debt_zscore                               40187.0  1.204170e+00
# spcsrc                                          34963.0  4.971820e+01
# staff_sale_sector_zscore                        10764.0           inf
# staff_sale_zscore                                9088.0           inf
# STDEV_sector_zscore                             38659.0 -2.430087e-01
# STDEV_zscore                                    38659.0 -2.394200e-01
# totdebt_invcap_sector_zscore                    46873.0  7.054293e-01
# totdebt_invcap_zscore                           46976.0  4.183208e-01
# tvol_sector_zscore                              28801.0  3.037403e-01
# tvol_zscore                                     28801.0  2.646368e-01
#
#                                                          std           min  \
# GVKEY                                           71125.349280  1.004000e+03
# january                                             0.276623  0.000000e+00
# february                                            0.276560  0.000000e+00
# march                                               0.276370  0.000000e+00
# april                                               0.276179  0.000000e+00
# may                                                 0.276306  0.000000e+00
# june                                                0.276275  0.000000e+00
# july                                                0.275989  0.000000e+00
# august                                              0.276433  0.000000e+00
# september                                           0.276877  0.000000e+00
# october                                             0.276592  0.000000e+00
# november                                            0.276402  0.000000e+00
# december                                            0.276052  0.000000e+00
# forward_one_month_return_sector_zscore            672.543839 -2.799444e+01
# forward_one_month_return_zscore                   404.746771 -1.450163e+01
# forward_two_month_return_sector_zscore            214.989817 -1.434044e+01
# forward_two_month_return_zscore                   121.636106 -1.000442e+01
# forward_three_month_return_sector_zscore          370.831424 -1.536452e+01
# forward_three_month_return_zscore                 216.709580 -8.011231e+00
# forward_four_month_return_sector_zscore           189.743437 -1.305995e+01
# forward_four_month_return_zscore                   92.772755 -8.878925e+00
# forward_five_month_return_sector_zscore           249.504946 -1.030038e+01
# forward_five_month_return_zscore                  155.905173 -5.341844e+00
# forward_six_month_return_sector_zscore            150.192651 -1.191794e+01
# forward_six_month_return_zscore                    79.249861 -7.124481e+00
# forward_seven_month_return_sector_zscore          221.649262 -9.019906e+00
# forward_seven_month_return_zscore                 138.697414 -4.302649e+00
# forward_eight_month_return_sector_zscore          188.254564 -8.498648e+00
# forward_eight_month_return_zscore                 119.734097 -9.128670e+00
# forward_nine_month_return_sector_zscore           198.445684 -3.410800e+01
# forward_nine_month_return_zscore                  156.266426 -3.410800e+01
# forward_ten_month_return_sector_zscore            221.554617 -1.009844e+01
# forward_ten_month_return_zscore                   168.747212 -6.822815e+00
# forward_eleven_month_return_sector_zscore         161.984123 -1.280141e+01
# forward_eleven_month_return_zscore                170.821419 -2.988107e+00
# forward_twelve_month_return_sector_zscore         520.473113 -1.837941e+01
# forward_twelve_month_return_zscore                348.516114 -1.837941e+01
# forward_thirteen_month_return_sector_zscore       394.333078 -1.606416e+01
# forward_thirteen_month_return_zscore              363.547112 -3.055283e+00
# forward_fourteen_month_return_sector_zscore         3.827448 -7.658674e+00
# forward_fourteen_month_return_zscore                5.224027 -4.977056e+00
# forward_fifteen_month_return_sector_zscore        412.960521 -4.751451e+00
# forward_fifteen_month_return_zscore               417.563146 -3.437792e+00
# forward_sixteen_month_return_sector_zscore          4.532394 -8.550923e+00
# forward_sixteen_month_return_zscore                 5.644651 -8.550923e+00
# forward_seventeen_month_return_sector_zscore      274.016755 -1.187130e+01
# forward_seventeen_month_return_zscore             382.313004 -3.617623e+00
# forward_eighteen_month_return_sector_zscore         5.103713 -9.595987e+00
# forward_eighteen_month_return_zscore                6.222190 -5.709780e+00
# forward_nineteen_month_return_sector_zscore       417.232405 -4.598671e+00
# forward_nineteen_month_return_zscore              445.380793 -3.823685e+00
# forward_twenty_month_return_sector_zscore           3.102292 -7.786197e+00
# forward_twenty_month_return_zscore                  4.395501 -4.236173e+00
# forward_twentyone_month_return_sector_zscore      332.909012 -5.296486e+00
# forward_twentyone_month_return_zscore             320.841265 -2.688797e+00
# forward_twentytwo_month_return_sector_zscore        2.506904 -3.401090e+00
# forward_twentytwo_month_return_zscore               4.978228 -3.401090e+00
# forward_twentythree_month_return_sector_zscore    551.148035 -3.703158e+00
# forward_twentythree_month_return_zscore           606.316964 -3.740464e+00
# forward_twentyfour_month_return_sector_zscore       1.490964 -1.934808e+00
# forward_twentyfour_month_return_zscore              1.490964 -1.934808e+00
# forward_twentyfive_month_return_sector_zscore       1.499636 -3.218051e+00
# forward_twentyfive_month_return_zscore              1.499636 -3.218051e+00
# forward_twentysix_month_return_sector_zscore        1.354785 -1.332253e+00
# forward_twentysix_month_return_zscore               1.354785 -1.332253e+00
# forward_twentyseven_month_return_sector_zscore      2.488826 -2.236236e+00
# forward_twentyseven_month_return_zscore             2.488826 -2.236236e+00
# forward_twentyeight_month_return_sector_zscore      4.497477 -4.724535e+00
# forward_twentyeight_month_return_zscore             4.497477 -4.724535e+00
# forward_twentynine_month_return_sector_zscore       1.527944 -7.399820e-01
# forward_twentynine_month_return_zscore              1.527944 -7.399820e-01
# forward_thirty_month_return_sector_zscore           3.652548 -2.853482e+00
# forward_thirty_month_return_zscore                  3.652548 -2.853482e+00
# forward_thirtyone_month_return_sector_zscore        4.695678 -4.009386e+00
# forward_thirtyone_month_return_zscore               4.695678 -4.009386e+00
# forward_thirtytwo_month_return_sector_zscore        0.840920 -7.220735e-01
# forward_thirtytwo_month_return_zscore               0.840920 -7.220735e-01
# forward_thirtythree_month_return_sector_zscore      3.715814 -2.427659e+00
# forward_thirtythree_month_return_zscore             3.715814 -2.427659e+00
# forward_thirtyfour_month_return_sector_zscore       7.553852 -8.233682e-01
# forward_thirtyfour_month_return_zscore              7.553852 -8.233682e-01
# forward_thirtyfive_month_return_sector_zscore       0.737177 -6.729475e-01
# forward_thirtyfive_month_return_zscore              0.737177 -6.729475e-01
# forward_thirtysix_month_return_sector_zscore             NaN           NaN
# forward_thirtysix_month_return_zscore                    NaN           NaN
# past_one_month_return_sector_zscore               698.367472 -2.849092e+01
# past_one_month_return_zscore                      446.393306 -1.489707e+01
# past_two_month_return_sector_zscore               219.625923 -1.549710e+01
# past_two_month_return_zscore                      125.597034 -1.014728e+01
# past_three_month_return_sector_zscore             390.019484 -1.550650e+01
# past_three_month_return_zscore                    268.888644 -1.231569e+01
# past_four_month_return_sector_zscore              192.805055 -1.230139e+01
# past_four_month_return_zscore                     102.864939 -6.583413e+00
# past_five_month_return_sector_zscore              303.750894 -1.085584e+01
# past_five_month_return_zscore                     271.646482 -1.028817e+01
# past_six_month_return_sector_zscore               327.238250 -2.539650e+01
# past_six_month_return_zscore                      146.468090 -1.009238e+01
# past_seven_month_return_sector_zscore             257.466150 -9.044783e+00
# past_seven_month_return_zscore                    240.859369 -8.231626e+00
# past_eight_month_return_sector_zscore             225.674712 -1.194739e+01
# past_eight_month_return_zscore                    161.465010 -9.353079e+00
# past_nine_month_return_sector_zscore              361.620033 -8.417999e+00
# past_nine_month_return_zscore                     290.561038 -7.425914e+00
# past_ten_month_return_sector_zscore               186.692583 -6.749537e+00
# past_ten_month_return_zscore                      151.813964 -6.177923e+00
# past_eleven_month_return_sector_zscore            286.311703 -9.456822e+00
# past_eleven_month_return_zscore                   351.414097 -6.620303e+00
# past_twelve_month_return_sector_zscore            307.993488 -7.684290e+00
# past_twelve_month_return_zscore                   382.018148 -7.684290e+00
# past_thirteen_month_return_sector_zscore          622.566577 -1.605041e+01
# past_thirteen_month_return_zscore                 752.362079 -6.087827e+00
# past_fourteen_month_return_sector_zscore            1.513561 -8.648301e+00
# past_fourteen_month_return_zscore                   1.566977 -8.648301e+00
# past_fifteen_month_return_sector_zscore           504.266033 -7.495284e+00
# past_fifteen_month_return_zscore                  766.749743 -5.284515e+00
# past_sixteen_month_return_sector_zscore             1.601123 -1.108235e+01
# past_sixteen_month_return_zscore                    1.463517 -5.335980e+00
# past_seventeen_month_return_sector_zscore         523.411468 -1.449968e+01
# past_seventeen_month_return_zscore                743.514366 -5.834929e+00
# past_eighteen_month_return_sector_zscore            1.763027 -5.387694e+00
# past_eighteen_month_return_zscore                   1.395244 -3.895125e+00
# past_nineteen_month_return_sector_zscore          528.743255 -7.351391e+00
# past_nineteen_month_return_zscore                 705.146563 -4.730189e+00
# past_twenty_month_return_sector_zscore              1.404933 -2.253308e+00
# past_twenty_month_return_zscore                     1.201386 -2.775867e+00
# past_twentyone_month_return_sector_zscore         700.875158 -4.677037e+00
# past_twentyone_month_return_zscore                701.404422 -3.581656e+00
# past_twentytwo_month_return_sector_zscore           1.286885 -2.507635e+00
# past_twentytwo_month_return_zscore                  1.378922 -2.507635e+00
# past_twentythree_month_return_sector_zscore      2719.346828 -8.279774e+00
# past_twentythree_month_return_zscore              709.035330 -2.320080e+00
# past_twentyfour_month_return_sector_zscore          0.931987 -1.934808e+00
# past_twentyfour_month_return_zscore                 0.931987 -1.934808e+00
# past_twentyfive_month_return_sector_zscore          1.089616 -2.102447e+00
# past_twentyfive_month_return_zscore                 1.089616 -2.102447e+00
# past_twentysix_month_return_sector_zscore           1.022105 -2.609572e+00
# past_twentysix_month_return_zscore                  1.022105 -2.609572e+00
# past_twentyseven_month_return_sector_zscore         0.877475 -1.715290e+00
# past_twentyseven_month_return_zscore                0.877475 -1.715290e+00
# past_twentyeight_month_return_sector_zscore         1.057968 -2.610568e+00
# past_twentyeight_month_return_zscore                1.057968 -2.610568e+00
# past_twentynine_month_return_sector_zscore          1.042937 -1.616074e+00
# past_twentynine_month_return_zscore                 1.042937 -1.616074e+00
# past_thirty_month_return_sector_zscore              0.800894 -1.258693e+00
# past_thirty_month_return_zscore                     0.800894 -1.258693e+00
# past_thirtyone_month_return_sector_zscore           1.744858 -2.015899e+00
# past_thirtyone_month_return_zscore                  1.744858 -2.015899e+00
# past_thirtytwo_month_return_sector_zscore           0.737512 -9.647823e-01
# past_thirtytwo_month_return_zscore                  0.737512 -9.647823e-01
# past_thirtythree_month_return_sector_zscore         0.723092 -8.168558e-01
# past_thirtythree_month_return_zscore                0.723092 -8.168558e-01
# past_thirtyfour_month_return_sector_zscore          0.762705 -8.525931e-01
# past_thirtyfour_month_return_zscore                 0.762705 -8.525931e-01
# past_thirtyfive_month_return_sector_zscore          0.737177 -6.729475e-01
# past_thirtyfive_month_return_zscore                 0.737177 -6.729475e-01
# past_thirtysix_month_return_sector_zscore                NaN           NaN
# past_thirtysix_month_return_zscore                       NaN           NaN
# accrual_sector_zscore                               6.022525 -1.980473e+02
# accrual_zscore                                      4.840092 -3.040268e+02
# adv_sale_sector_zscore                                   NaN -6.729475e-01
# adv_sale_zscore                                          NaN           inf
# aftret_eq_sector_zscore                            93.855577 -3.014700e+03
# aftret_eq_zscore                                  133.495784 -8.464933e+03
# aftret_equity_sector_zscore                        64.403952 -3.046412e+03
# aftret_equity_zscore                               70.346539 -3.288855e+03
# aftret_invcapx_sector_zscore                             NaN          -inf
# aftret_invcapx_zscore                             552.179493 -6.690056e+04
# alpha_sector_zscore                                 1.308247 -1.037461e+01
# alpha_zscore                                        1.357635 -7.437381e+00
# at_turn_sector_zscore                              22.424548 -3.752976e+00
# at_turn_zscore                                      1.306531 -1.010189e+00
# b_hml_sector_zscore                                 1.256076 -1.032501e+01
# b_hml_zscore                                        1.359084 -1.117758e+01
# b_mkt_sector_zscore                                 1.138709 -3.793872e+00
# b_mkt_zscore                                        1.036406 -2.889989e+00
# b_smb_sector_zscore                                 1.155009 -5.702468e+00
# b_smb_zscore                                        1.256849 -6.101243e+00
# b_umd_sector_zscore                                 1.355633 -1.887576e+01
# b_umd_zscore                                        1.299370 -1.075026e+01
# bm_sector_zscore                                   51.966331 -2.877714e+00
# bm_zscore                                          41.501046 -1.275796e+00
# BUYPCT_sector_zscore                                0.946435 -4.037685e+00
# BUYPCT_zscore                                       0.801005 -1.585946e+00
# CAPEI_sector_zscore                                81.819781 -2.926136e+03
# CAPEI_zscore                                       54.464307 -1.980818e+03
# capital_ratio_sector_zscore                        25.913436 -1.205035e+03
# capital_ratio_zscore                               17.061816 -3.235732e+02
# cash_conversion_sector_zscore                    1930.098231 -2.123290e+00
# cash_conversion_zscore                          10443.142412 -1.216367e+00
# cash_debt_sector_zscore                            18.509505 -6.827533e+02
# cash_debt_zscore                                    7.775732 -2.381364e+02
# cash_lt_sector_zscore                              10.134959 -1.151094e+00
# cash_lt_zscore                                     13.621930 -8.084403e-01
# cash_ratio_sector_zscore                            4.628065 -1.240685e+00
# cash_ratio_zscore                                   5.786846 -8.494362e-01
# cfm_sector_zscore                                2401.484607 -2.289256e+05
# cfm_zscore                                       2210.450664 -1.199136e+05
# curr_debt_sector_zscore                             1.164752 -3.539205e+00
# curr_debt_zscore                                    0.827065 -1.342994e+00
# curr_ratio_sector_zscore                            3.162431 -2.227758e+00
# curr_ratio_zscore                                   3.207510 -1.558563e+00
# de_ratio_sector_zscore                             46.059194 -2.296473e+03
# de_ratio_zscore                                    28.293116 -9.759433e+02
# debt_assets_sector_zscore                           2.207519 -1.786567e+01
# debt_assets_zscore                                  1.082650 -1.815992e+00
# debt_at_sector_zscore                               1.635027 -4.845222e+00
# debt_at_zscore                                      1.071084 -7.778224e-01
# debt_capital_sector_zscore                          7.649206 -3.255062e+02
# debt_capital_zscore                                 4.731243 -1.995380e+02
# debt_ebitda_sector_zscore                          59.433735 -1.402419e+03
# debt_ebitda_zscore                                 34.486368 -1.529080e+03
# debt_invcap_sector_zscore                          25.192872 -1.495718e+02
# debt_invcap_zscore                                 16.895788 -6.149473e+01
# DIVYIELD                                            0.021816  3.000000e-04
# dltt_be_sector_zscore                              45.334829 -2.950273e+00
# dltt_be_zscore                                     15.838250 -6.729475e-01
# dpr_sector_zscore                                        NaN          -inf
# dpr_zscore                                         62.828264 -5.071574e+03
# dvpspm                                              0.510477  0.000000e+00
# dvpsxm                                              0.508186  0.000000e+00
# dvrate                                              0.908450  1.000000e-02
# efftax_sector_zscore                              171.935734 -3.017947e+04
# efftax_zscore                                     125.130861 -2.169114e+04
# equity_invcap_sector_zscore                        24.178567 -3.069403e+03
# equity_invcap_zscore                               17.990547 -2.247290e+03
# evm_sector_zscore                                  57.588421 -2.047739e+03
# evm_zscore                                         76.421295 -1.546988e+03
# exret_sector_zscore                                 1.580239 -1.486791e+01
# exret_zscore                                        1.684111 -1.318875e+01
# fcf_ocf_sector_zscore                              55.816913 -4.305055e+03
# fcf_ocf_zscore                                     45.660285 -3.955102e+03
# gpm_sector_zscore                                 855.616337 -8.220443e+04
# gpm_zscore                                        661.929904 -3.300528e+04
# GProf_sector_zscore                                 5.489997 -7.427658e+02
# GProf_zscore                                        1.353685 -3.486951e+01
# HOLDPCT_sector_zscore                               1.004361 -2.058470e+00
# HOLDPCT_zscore                                      0.838870 -1.052559e+00
# int_debt_sector_zscore                            210.322640 -5.607896e+00
# int_debt_zscore                                   206.591788 -1.985195e+00
# int_totdebt_sector_zscore                        1282.411182 -9.735307e+00
# int_totdebt_zscore                               2510.982880 -8.150142e+00
# intcov_ratio_sector_zscore                        245.201929 -4.818282e+03
# intcov_ratio_zscore                               301.016811 -1.368125e+04
# intcov_sector_zscore                              243.193090 -5.796171e+03
# intcov_zscore                                     364.359586 -1.857037e+04
# inv_turn_sector_zscore                            586.417079 -2.057297e+00
# inv_turn_zscore                                   215.482050 -1.323929e+00
# invt_act_sector_zscore                                   NaN -2.629190e+00
# invt_act_zscore                                     1.166787 -6.729475e-01
# ivol_sector_zscore                                  1.418596 -2.148385e+00
# ivol_zscore                                         1.208002 -1.295364e+00
# lt_debt_sector_zscore                               1.794870 -4.961562e+00
# lt_debt_zscore                                      0.741334 -7.423786e-01
# lt_ppent_sector_zscore                             27.661402 -4.737768e+00
# lt_ppent_zscore                                    40.701577 -8.482930e-01
# MEANREC_sector_zscore                               1.044597 -3.364738e+00
# MEANREC_zscore                                      1.028310 -2.340250e+00
# MEDREC_sector_zscore                                     NaN          -inf
# MEDREC_zscore                                       0.872636 -1.345895e+00
# n_sector_zscore                                          NaN          -inf
# n_zscore                                                 NaN          -inf
# npm_sector_zscore                                3238.618873 -3.301002e+05
# npm_zscore                                       2779.215303 -1.650501e+05
# ocf_lct_sector_zscore                               5.178116 -6.439313e+01
# ocf_lct_zscore                                      7.981093 -4.673498e+01
# opmad_sector_zscore                              1582.653221 -1.639374e+05
# opmad_zscore                                     1427.464417 -7.586475e+04
# opmbd_sector_zscore                              1272.795227 -1.429520e+05
# opmbd_zscore                                     1155.797495 -6.262068e+04
# pay_turn_sector_zscore                          13729.970108 -9.207335e+03
# pay_turn_zscore                                    29.965348 -1.934290e+01
# pcf_sector_zscore                                   4.077406 -9.674635e+01
# pcf_zscore                                          3.496027 -2.059128e+01
# pe_exi_sector_zscore                                3.909495 -6.242987e+01
# pe_exi_zscore                                       2.416444 -1.559655e+01
# pe_inc_sector_zscore                                3.810168 -5.824089e+01
# pe_inc_zscore                                       2.410333 -1.294823e+01
# pe_op_basic_sector_zscore                           4.278097 -6.531728e+01
# pe_op_basic_zscore                                  3.045074 -1.869562e+01
# pe_op_dil_sector_zscore                             4.208818 -6.392451e+01
# pe_op_dil_zscore                                    2.952612 -1.741844e+01
# PEG_1yrforward_sector_zscore                        7.085641 -4.282222e+02
# PEG_1yrforward_zscore                               3.747914 -2.804164e+01
# PEG_ltgforward_sector_zscore                        4.323189 -5.371067e+01
# PEG_ltgforward_zscore                               3.826773 -2.772135e+01
# PEG_trailing_sector_zscore                          8.484102 -3.602308e+01
# PEG_trailing_zscore                                 7.262650 -1.108592e+01
# pretret_earnat_sector_zscore                        8.009164 -5.878689e+02
# pretret_earnat_zscore                               6.893376 -4.123726e+02
# pretret_noa_sector_zscore                          22.278702 -1.113580e+03
# pretret_noa_zscore                                 24.013382 -1.810200e+03
# profit_lct_sector_zscore                           24.205909 -2.135758e+03
# profit_lct_zscore                                  33.591431 -2.960963e+03
# ps_sector_zscore                                   28.049402 -2.098988e+00
# ...
# past_twentyfour_month_return_sector_zscore      6.908989e-01  1.752016e+00
# past_twentyfour_month_return_zscore             6.908989e-01  1.752016e+00
# past_twentyfive_month_return_sector_zscore      6.098094e-01  3.039278e+00
# past_twentyfive_month_return_zscore             6.098094e-01  3.039278e+00
# past_twentysix_month_return_sector_zscore       6.330123e-01  1.976686e+00
# past_twentysix_month_return_zscore              6.330123e-01  1.976686e+00
# past_twentyseven_month_return_sector_zscore     7.018949e-01  1.466660e+00
# past_twentyseven_month_return_zscore            7.018949e-01  1.466660e+00
# past_twentyeight_month_return_sector_zscore     6.602429e-01  1.556835e+00
# past_twentyeight_month_return_zscore            6.602429e-01  1.556835e+00
# past_twentynine_month_return_sector_zscore      6.729475e-01  2.851053e+00
# past_twentynine_month_return_zscore             6.729475e-01  2.851053e+00
# past_thirty_month_return_sector_zscore          6.505900e-01  9.401575e-01
# past_thirty_month_return_zscore                 6.505900e-01  9.401575e-01
# past_thirtyone_month_return_sector_zscore       6.283211e-01  4.530817e+00
# past_thirtyone_month_return_zscore              6.283211e-01  4.530817e+00
# past_thirtytwo_month_return_sector_zscore       4.797185e-01  1.114871e+00
# past_thirtytwo_month_return_zscore              4.797185e-01  1.114871e+00
# past_thirtythree_month_return_sector_zscore     7.813587e-01  1.050198e+00
# past_thirtythree_month_return_zscore            7.813587e-01  1.050198e+00
# past_thirtyfour_month_return_sector_zscore      6.100632e-01  9.603469e-01
# past_thirtyfour_month_return_zscore             6.100632e-01  9.603469e-01
# past_thirtyfive_month_return_sector_zscore      6.729475e-01  6.729475e-01
# past_thirtyfive_month_return_zscore             6.729475e-01  6.729475e-01
# past_thirtysix_month_return_sector_zscore                NaN           NaN
# past_thirtysix_month_return_zscore                       NaN           NaN
# accrual_sector_zscore                           7.851054e-01  2.072052e+02
# accrual_zscore                                  8.411844e-01  2.410971e+02
# adv_sale_sector_zscore                                   NaN           inf
# adv_sale_zscore                                          inf           inf
# aftret_eq_sector_zscore                         5.722703e-01  1.240774e+04
# aftret_eq_zscore                                5.397600e-01  1.330339e+04
# aftret_equity_sector_zscore                     6.033323e-01  1.265102e+04
# aftret_equity_zscore                            5.272578e-01  1.330341e+04
# aftret_invcapx_sector_zscore                    7.516549e-01           inf
# aftret_invcapx_zscore                           7.491302e-01  2.522518e+02
# alpha_sector_zscore                             7.057742e-01  1.065949e+01
# alpha_zscore                                    7.592228e-01  1.028901e+01
# at_turn_sector_zscore                           9.083810e-01  1.305922e+03
# at_turn_zscore                                  7.591833e-01  2.876086e+01
# b_hml_sector_zscore                             6.729475e-01  7.367598e+00
# b_hml_zscore                                    6.047728e-01  6.745517e+00
# b_mkt_sector_zscore                             7.334448e-01  8.220751e+00
# b_mkt_zscore                                    7.057440e-01  4.408366e+00
# b_smb_sector_zscore                             7.012226e-01  1.422438e+01
# b_smb_zscore                                    7.500324e-01  1.686581e+01
# b_umd_sector_zscore                             6.324474e-01  4.816972e+00
# b_umd_zscore                                    6.029905e-01  3.908918e+00
# bm_sector_zscore                                8.411844e-01  1.050017e+04
# bm_zscore                                       8.708732e-01  8.013238e+03
# BUYPCT_sector_zscore                            6.729475e-01  1.794616e+00
# BUYPCT_zscore                                   6.938904e-01  1.009295e+00
# CAPEI_sector_zscore                             7.080042e-01  9.613884e+03
# CAPEI_zscore                                    4.974084e-01  4.027867e+03
# capital_ratio_sector_zscore                     9.784574e-01  2.941087e+03
# capital_ratio_zscore                            6.641316e-01  2.092055e+03
# cash_conversion_sector_zscore                   9.581330e-01  1.983175e+05
# cash_conversion_zscore                          1.004860e+00  1.079253e+06
# cash_debt_sector_zscore                         6.729475e-01  4.968275e+02
# cash_debt_zscore                                8.101504e-01  5.458062e+01
# cash_lt_sector_zscore                           1.322946e+00  8.622905e+02
# cash_lt_zscore                                  2.411395e+00  3.334297e+02
# cash_ratio_sector_zscore                        1.070958e+00  2.140234e+02
# cash_ratio_zscore                               1.565716e+00  1.518623e+02
# cfm_sector_zscore                               5.974648e-01  2.203945e+03
# cfm_zscore                                      7.303942e-01  1.769495e+03
# curr_debt_sector_zscore                         7.608703e-01  2.068690e+01
# curr_debt_zscore                                8.643895e-01  1.709807e+00
# curr_ratio_sector_zscore                        9.269503e-01  2.185267e+02
# curr_ratio_zscore                               1.002653e+00  8.264894e+01
# de_ratio_sector_zscore                          8.715076e-01  2.925953e+03
# de_ratio_zscore                                 1.302395e+00  1.906204e+03
# debt_assets_sector_zscore                       6.331281e-01  8.662026e+01
# debt_assets_zscore                              6.792663e-01  8.645434e+01
# debt_at_sector_zscore                           8.541257e-01  5.273818e+01
# debt_at_zscore                                  8.057059e-01  3.812973e+01
# debt_capital_sector_zscore                      6.709175e-01  9.729328e+02
# debt_capital_zscore                             7.226985e-01  6.412345e+02
# debt_ebitda_sector_zscore                       9.511854e-01  5.222297e+03
# debt_ebitda_zscore                              9.110810e-01  2.450919e+03
# debt_invcap_sector_zscore                       9.435763e-01  3.091017e+03
# debt_invcap_zscore                              6.729475e-01  2.101117e+03
# DIVYIELD                                        3.160000e-02  9.520000e-01
# dltt_be_sector_zscore                           1.387634e+00  8.191582e+03
# dltt_be_zscore                                  1.026478e+00  2.347960e+03
# dpr_sector_zscore                               2.203718e+00           inf
# dpr_zscore                                      1.014822e+00  4.010689e+03
# dvpspm                                          3.000000e-01  2.500000e+01
# dvpsxm                                          3.100000e-01  2.500000e+01
# dvrate                                          1.200000e+00  1.400000e+01
# efftax_sector_zscore                            5.673871e-01  1.183816e+03
# efftax_zscore                                   5.677995e-01  9.806843e+02
# equity_invcap_sector_zscore                     6.729475e-01  8.279294e+01
# equity_invcap_zscore                            6.925751e-01  5.998049e+01
# evm_sector_zscore                               7.470758e-01  4.664281e+03
# evm_zscore                                      6.723790e-01  7.230187e+03
# exret_sector_zscore                             6.682110e-01  4.633599e+01
# exret_zscore                                    6.504986e-01  6.563377e+01
# fcf_ocf_sector_zscore                           5.414520e-01  3.489497e+00
# fcf_ocf_zscore                                  5.414880e-01  1.540776e+00
# gpm_sector_zscore                               6.146115e-01  1.123979e+01
# gpm_zscore                                      8.704794e-01  7.476079e+00
# GProf_sector_zscore                             7.570659e-01  1.382066e+02
# GProf_zscore                                    6.965597e-01  1.422803e+01
# HOLDPCT_sector_zscore                           6.729475e-01  4.712518e+00
# HOLDPCT_zscore                                  6.571731e-01  1.884310e+00
# int_debt_sector_zscore                          9.228994e-01  1.671669e+04
# int_debt_zscore                                 9.757739e-01  1.170188e+04
# int_totdebt_sector_zscore                       7.969115e-01  1.365494e+05
# int_totdebt_zscore                              8.224914e-01  2.655132e+05
# intcov_ratio_sector_zscore                      8.156711e-01  1.107259e+04
# intcov_ratio_zscore                             9.478436e-01  7.614548e+03
# intcov_sector_zscore                            7.220902e-01  1.043519e+04
# intcov_zscore                                   7.983398e-01  6.878598e+03
# inv_turn_sector_zscore                          1.676314e+00  5.388019e+04
# inv_turn_zscore                                 1.420118e+00  1.759992e+04
# invt_act_sector_zscore                          1.330245e+00           inf
# invt_act_zscore                                 1.121579e+00  8.367606e+00
# ivol_sector_zscore                              8.451944e-01  1.315271e+01
# ivol_zscore                                     8.572062e-01  1.062725e+01
# lt_debt_sector_zscore                           8.356746e-01  1.536290e+01
# lt_debt_zscore                                  6.924937e-01  3.160401e+00
# lt_ppent_sector_zscore                          1.194538e+00  1.311242e+03
# lt_ppent_zscore                                 2.608361e+00  2.072428e+03
# MEANREC_sector_zscore                           7.537012e-01  1.028648e+01
# MEANREC_zscore                                  7.917030e-01  5.601298e+00
# MEDREC_sector_zscore                            1.345895e+00           inf
# MEDREC_zscore                                   1.345895e+00  4.037685e+00
# n_sector_zscore                                 6.729475e-01  6.729475e-01
# n_zscore                                                -inf          -inf
# npm_sector_zscore                               5.447670e-01  2.263774e+03
# npm_zscore                                      6.542545e-01  2.035179e+03
# ocf_lct_sector_zscore                           6.564156e-01  3.791327e+02
# ocf_lct_zscore                                  6.676626e-01  5.988481e+02
# opmad_sector_zscore                             5.670906e-01  1.405915e+01
# opmad_zscore                                    7.874918e-01  1.508748e+01
# opmbd_sector_zscore                             5.924864e-01  1.575849e+01
# opmbd_zscore                                    8.754273e-01  1.455907e+01
# pay_turn_sector_zscore                          1.200982e+00  1.651251e+06
# pay_turn_zscore                                 8.160812e-01  3.454129e+03
# pcf_sector_zscore                               7.365735e-01  7.543425e+01
# pcf_zscore                                      6.655691e-01  2.344475e+01
# pe_exi_sector_zscore                            7.087986e-01  6.308041e+01
# pe_exi_zscore                                   4.365090e-01  1.434253e+01
# pe_inc_sector_zscore                            7.087328e-01  5.206171e+01
# pe_inc_zscore                                   4.463868e-01  1.403267e+01
# pe_op_basic_sector_zscore                       7.317951e-01  5.599387e+01
# pe_op_basic_zscore                              4.929071e-01  1.969210e+01
# pe_op_dil_sector_zscore                         7.376392e-01  5.883351e+01
# pe_op_dil_zscore                                4.886682e-01  1.962279e+01
# PEG_1yrforward_sector_zscore                    7.134909e-01  1.846021e+02
# PEG_1yrforward_zscore                           8.834325e-01  1.775173e+01
# PEG_ltgforward_sector_zscore                    6.179737e-01  5.515728e+01
# PEG_ltgforward_zscore                           6.525220e-01  2.490388e+01
# PEG_trailing_sector_zscore                      1.163700e+00  2.214603e+02
# PEG_trailing_zscore                             1.228307e+00  7.904872e+01
# pretret_earnat_sector_zscore                    6.729475e-01  1.372813e+01
# pretret_earnat_zscore                           5.811819e-01  1.132641e+01
# pretret_noa_sector_zscore                       6.793872e-01  1.397406e+03
# pretret_noa_zscore                              6.370797e-01  1.503593e+03
# profit_lct_sector_zscore                        6.576328e-01  3.812782e+01
# profit_lct_zscore                               6.505626e-01  4.616854e+01
# ps_sector_zscore                                9.281670e-01  1.132484e+03
# ps_zscore                                       1.063770e+00  5.534047e+02
# ptb_sector_zscore                               9.652732e-01  1.179732e+02
# ptb_zscore                                      1.217739e+00  3.182695e+01
# ptpm_sector_zscore                              5.673871e-01  1.989496e+03
# ptpm_zscore                                     6.801835e-01  1.927775e+03
# quick_ratio_sector_zscore                       9.495475e-01  1.357903e+02
# quick_ratio_zscore                              1.157318e+00  1.112931e+02
# R2_sector_zscore                                7.180448e-01  4.073844e+00
# R2_zscore                                       7.193707e-01  3.540794e+00
# rd_sale_sector_zscore                           1.876838e+03           inf
# rd_sale_zscore                                           inf           inf
# recdown_sector_zscore                                    inf           inf
# recdown_zscore                                           inf           inf
# rect_act_sector_zscore                          8.295818e-01  1.038808e+01
# rect_act_zscore                                 6.547597e-01  1.624495e+01
# rect_turn_sector_zscore                         1.199602e+00  3.873136e+03
# rect_turn_zscore                                8.043449e-01  4.585310e+03
# recup_sector_zscore                                      inf           inf
# recup_zscore                                             inf           inf
# roa_sector_zscore                               6.610369e-01  1.170929e+02
# roa_zscore                                      6.624327e-01  1.704110e+01
# roce_sector_zscore                              6.021109e-01  1.357496e+05
# roce_zscore                                     6.075221e-01  5.599662e+05
# roe_sector_zscore                               6.006716e-01  7.604307e+02
# roe_zscore                                      5.308808e-01  3.161542e+02
# sale_equity_sector_zscore                       1.077063e+00  2.235116e+03
# sale_equity_zscore                              1.040836e+00  2.261670e+03
# sale_invcap_sector_zscore                       8.833738e-01  3.475068e+03
# sale_invcap_zscore                              9.621866e-01  1.306347e+03
# sale_nwc_sector_zscore                          1.303725e+00  4.464463e+03
# sale_nwc_zscore                                 1.091902e+00  5.893669e+03
# SELLPCT_sector_zscore                                    inf           inf
# SELLPCT_zscore                                           inf           inf
# short_debt_sector_zscore                        1.552602e+00  3.927259e+02
# short_debt_zscore                               1.978304e+00  6.495923e+02
# spcsrc                                          7.950000e+01  9.900000e+01
# staff_sale_sector_zscore                        1.421602e+00           inf
# staff_sale_zscore                                        inf           inf
# STDEV_sector_zscore                             6.308883e-01  6.235980e+00
# STDEV_zscore                                    6.355615e-01  5.271422e+00
# totdebt_invcap_sector_zscore                    8.292125e-01  3.204609e+03
# totdebt_invcap_zscore                           6.563996e-01  2.012797e+03
# tvol_sector_zscore                              8.399547e-01  1.213558e+01
# tvol_zscore                                     8.391592e-01  1.102074e+01

# %%
# df - Subset - Numeric Columns
numeric_cols = df.select_dtypes(include=[np.float]).columns

# %%
df = df[numeric_cols].apply(clip_outliers)

# %%
df = df[numeric_cols].apply(fill_null)
# Out:
# C:\Users\shane\Anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:717: RuntimeWarning: All-NaN slice encountered
#   warnings.warn("All-NaN slice encountered", RuntimeWarning)

# %%
return_all_rows(df.describe().transpose())
# Out:
# C:\Users\shane\Anaconda3\lib\site-packages\numpy\lib\function_base.py:3817: RuntimeWarning: invalid value encountered in multiply
#   x2 = take(ap, indices_above, axis=axis) * weights_above
#                                                   count          mean  \
# forward_one_month_return_sector_zscore          47539.0  7.720099e-03
# forward_one_month_return_zscore                 47539.0 -5.187623e-03
# forward_two_month_return_sector_zscore          47539.0 -1.321320e-02
# forward_two_month_return_zscore                 47539.0 -4.201955e-02
# forward_three_month_return_sector_zscore        47539.0 -3.619667e-03
# forward_three_month_return_zscore               47539.0 -3.068638e-02
# forward_four_month_return_sector_zscore         47539.0 -1.288105e-02
# forward_four_month_return_zscore                47539.0 -5.056448e-02
# forward_five_month_return_sector_zscore         47539.0 -7.370185e-03
# forward_five_month_return_zscore                47539.0 -3.294270e-02
# forward_six_month_return_sector_zscore          47539.0 -1.347846e-02
# forward_six_month_return_zscore                 47539.0 -3.773714e-02
# forward_seven_month_return_sector_zscore        47539.0 -2.731923e-03
# forward_seven_month_return_zscore               47539.0 -2.232294e-02
# forward_eight_month_return_sector_zscore        47539.0 -7.407526e-03
# forward_eight_month_return_zscore               47539.0 -2.160631e-02
# forward_nine_month_return_sector_zscore         47539.0  2.338849e-03
# forward_nine_month_return_zscore                47539.0 -7.748479e-03
# forward_ten_month_return_sector_zscore          47539.0 -1.240314e-05
# forward_ten_month_return_zscore                 47539.0 -6.621584e-03
# forward_eleven_month_return_sector_zscore       47539.0  1.093881e-02
# forward_eleven_month_return_zscore              47539.0  8.016055e-03
# forward_twelve_month_return_sector_zscore       47539.0  1.039006e-02
# forward_twelve_month_return_zscore              47539.0  1.163172e-02
# forward_thirteen_month_return_sector_zscore     47539.0  1.623169e-02
# forward_thirteen_month_return_zscore            47539.0  2.081240e-02
# forward_fourteen_month_return_sector_zscore     47539.0  9.185207e-03
# forward_fourteen_month_return_zscore            47539.0  9.278204e-03
# forward_fifteen_month_return_sector_zscore      47539.0  2.333227e-02
# forward_fifteen_month_return_zscore             47539.0  2.139378e-02
# forward_sixteen_month_return_sector_zscore      47539.0  7.042939e-03
# forward_sixteen_month_return_zscore             47539.0  8.140919e-03
# forward_seventeen_month_return_sector_zscore    47539.0  1.130624e-02
# forward_seventeen_month_return_zscore           47539.0  1.458327e-02
# forward_eighteen_month_return_sector_zscore     47539.0  7.424027e-03
# forward_eighteen_month_return_zscore            47539.0  7.145531e-03
# forward_nineteen_month_return_sector_zscore     47539.0  1.438493e-02
# forward_nineteen_month_return_zscore            47539.0  1.236259e-02
# forward_twenty_month_return_sector_zscore       47539.0  4.337139e-03
# forward_twenty_month_return_zscore              47539.0  3.943933e-03
# forward_twentyone_month_return_sector_zscore    47539.0  9.481176e-03
# forward_twentyone_month_return_zscore           47539.0  8.408732e-03
# forward_twentytwo_month_return_sector_zscore    47539.0  1.990608e-03
# forward_twentytwo_month_return_zscore           47539.0  1.601333e-03
# forward_twentythree_month_return_sector_zscore  47539.0  4.920030e-03
# forward_twentythree_month_return_zscore         47539.0  5.384266e-03
# forward_twentyfour_month_return_sector_zscore   47539.0  6.297696e-04
# forward_twentyfour_month_return_zscore          47539.0  6.297696e-04
# forward_twentyfive_month_return_sector_zscore   47539.0  2.108947e-04
# forward_twentyfive_month_return_zscore          47539.0  2.108947e-04
# forward_twentysix_month_return_sector_zscore    47539.0  4.373291e-04
# forward_twentysix_month_return_zscore           47539.0  4.373291e-04
# forward_twentyseven_month_return_sector_zscore  47539.0  7.166566e-04
# forward_twentyseven_month_return_zscore         47539.0  7.166566e-04
# forward_twentyeight_month_return_sector_zscore  47539.0  9.502882e-04
# forward_twentyeight_month_return_zscore         47539.0  9.502882e-04
# forward_twentynine_month_return_sector_zscore   47539.0  4.943926e-04
# forward_twentynine_month_return_zscore          47539.0  4.943926e-04
# forward_thirty_month_return_sector_zscore       47539.0  5.139842e-04
# forward_thirty_month_return_zscore              47539.0  5.139842e-04
# forward_thirtyone_month_return_sector_zscore    47539.0  6.102056e-04
# forward_thirtyone_month_return_zscore           47539.0  6.102056e-04
# forward_thirtytwo_month_return_sector_zscore    47539.0  8.795480e-05
# forward_thirtytwo_month_return_zscore           47539.0  8.795480e-05
# forward_thirtythree_month_return_sector_zscore  47539.0  3.350678e-04
# forward_thirtythree_month_return_zscore         47539.0  3.350678e-04
# forward_thirtyfour_month_return_sector_zscore   47539.0  9.822139e-04
# forward_thirtyfour_month_return_zscore          47539.0  9.822139e-04
# forward_thirtyfive_month_return_sector_zscore   47539.0 -4.670788e-21
# forward_thirtyfive_month_return_zscore          47539.0 -4.670788e-21
# forward_thirtysix_month_return_sector_zscore        0.0           NaN
# forward_thirtysix_month_return_zscore               0.0           NaN
# past_one_month_return_sector_zscore             47539.0 -6.863980e-03
# past_one_month_return_zscore                    47539.0 -2.493207e-02
# past_two_month_return_sector_zscore             47539.0 -1.512690e-02
# past_two_month_return_zscore                    47539.0 -3.846697e-02
# past_three_month_return_sector_zscore           47539.0 -1.240842e-02
# past_three_month_return_zscore                  47539.0 -4.381877e-02
# past_four_month_return_sector_zscore            47539.0 -1.531376e-02
# past_four_month_return_zscore                   47539.0 -5.226301e-02
# past_five_month_return_sector_zscore            47539.0 -1.494354e-02
# past_five_month_return_zscore                   47539.0 -4.454786e-02
# past_six_month_return_sector_zscore             47539.0 -1.554835e-02
# past_six_month_return_zscore                    47539.0 -3.836914e-02
# past_seven_month_return_sector_zscore           47539.0 -1.366437e-02
# past_seven_month_return_zscore                  47539.0 -3.116693e-02
# past_eight_month_return_sector_zscore           47539.0 -1.015358e-02
# past_eight_month_return_zscore                  47539.0 -2.510564e-02
# past_nine_month_return_sector_zscore            47539.0 -5.378377e-03
# past_nine_month_return_zscore                   47539.0 -1.540701e-02
# past_ten_month_return_sector_zscore             47539.0 -2.972006e-03
# past_ten_month_return_zscore                    47539.0 -9.768278e-03
# past_eleven_month_return_sector_zscore          47539.0  1.221985e-03
# past_eleven_month_return_zscore                 47539.0 -1.504065e-03
# past_twelve_month_return_sector_zscore          47539.0 -3.982886e-04
# past_twelve_month_return_zscore                 47539.0  9.273479e-04
# past_thirteen_month_return_sector_zscore        47539.0  3.508062e-03
# past_thirteen_month_return_zscore               47539.0  2.045166e-03
# past_fourteen_month_return_sector_zscore        47539.0  6.003638e-04
# past_fourteen_month_return_zscore               47539.0  1.050934e-03
# past_fifteen_month_return_sector_zscore         47539.0  3.935855e-03
# past_fifteen_month_return_zscore                47539.0  2.463136e-03
# past_sixteen_month_return_sector_zscore         47539.0  9.920726e-04
# past_sixteen_month_return_zscore                47539.0  1.536143e-03
# past_seventeen_month_return_sector_zscore       47539.0  3.783430e-03
# past_seventeen_month_return_zscore              47539.0  1.691174e-03
# past_eighteen_month_return_sector_zscore        47539.0  1.510040e-03
# past_eighteen_month_return_zscore               47539.0  1.125743e-03
# past_nineteen_month_return_sector_zscore        47539.0  2.714802e-03
# past_nineteen_month_return_zscore               47539.0  1.759810e-03
# past_twenty_month_return_sector_zscore          47539.0  1.264820e-03
# past_twenty_month_return_zscore                 47539.0  1.205766e-03
# past_twentyone_month_return_sector_zscore       47539.0  1.991751e-03
# past_twentyone_month_return_zscore              47539.0  7.421464e-04
# past_twentytwo_month_return_sector_zscore       47539.0  5.988218e-04
# past_twentytwo_month_return_zscore              47539.0  5.099793e-04
# past_twentythree_month_return_sector_zscore     47539.0  3.852461e-05
# past_twentythree_month_return_zscore            47539.0 -2.982833e-05
# past_twentyfour_month_return_sector_zscore      47539.0 -2.077694e-05
# past_twentyfour_month_return_zscore             47539.0 -2.077694e-05
# past_twentyfive_month_return_sector_zscore      47539.0 -1.611457e-05
# past_twentyfive_month_return_zscore             47539.0 -1.611457e-05
# past_twentysix_month_return_sector_zscore       47539.0 -5.209765e-05
# past_twentysix_month_return_zscore              47539.0 -5.209765e-05
# past_twentyseven_month_return_sector_zscore     47539.0 -3.369936e-05
# past_twentyseven_month_return_zscore            47539.0 -3.369936e-05
# past_twentyeight_month_return_sector_zscore     47539.0 -1.116254e-04
# past_twentyeight_month_return_zscore            47539.0 -1.116254e-04
# past_twentynine_month_return_sector_zscore      47539.0  7.750639e-05
# past_twentynine_month_return_zscore             47539.0  7.750639e-05
# past_thirty_month_return_sector_zscore          47539.0 -7.185343e-05
# past_thirty_month_return_zscore                 47539.0 -7.185343e-05
# past_thirtyone_month_return_sector_zscore       47539.0  1.991180e-04
# past_thirtyone_month_return_zscore              47539.0  1.991180e-04
# past_thirtytwo_month_return_sector_zscore       47539.0 -2.304565e-05
# past_thirtytwo_month_return_zscore              47539.0 -2.304565e-05
# past_thirtythree_month_return_sector_zscore     47539.0  2.840814e-05
# past_thirtythree_month_return_zscore            47539.0  2.840814e-05
# past_thirtyfour_month_return_sector_zscore      47539.0  6.799921e-06
# past_thirtyfour_month_return_zscore             47539.0  6.799921e-06
# past_thirtyfive_month_return_sector_zscore      47539.0 -4.670788e-21
# past_thirtyfive_month_return_zscore             47539.0 -4.670788e-21
# past_thirtysix_month_return_sector_zscore           0.0           NaN
# past_thirtysix_month_return_zscore                  0.0           NaN
# accrual_sector_zscore                           47539.0  2.497437e-01
# accrual_zscore                                  47539.0  3.055258e-01
# adv_sale_sector_zscore                          47539.0           inf
# adv_sale_zscore                                 47539.0           inf
# aftret_eq_sector_zscore                         47539.0 -3.131315e-01
# aftret_eq_zscore                                47539.0 -7.775568e-01
# aftret_equity_sector_zscore                     47539.0 -3.017311e-01
# aftret_equity_zscore                            47539.0 -8.449486e-01
# aftret_invcapx_sector_zscore                    47539.0           inf
# aftret_invcapx_zscore                           47539.0 -8.815510e-01
# alpha_sector_zscore                             47539.0  2.175315e-02
# alpha_zscore                                    47539.0  7.710008e-02
# at_turn_sector_zscore                           47539.0  1.241347e+00
# at_turn_zscore                                  47539.0  2.375301e-01
# b_hml_sector_zscore                             47539.0 -4.008496e-02
# b_hml_zscore                                    47539.0 -1.242146e-01
# b_mkt_sector_zscore                             47539.0  7.338263e-02
# b_mkt_zscore                                    47539.0  5.739737e-02
# b_smb_sector_zscore                             47539.0  4.406689e-02
# b_smb_zscore                                    47539.0  9.231234e-02
# b_umd_sector_zscore                             47539.0 -8.652543e-02
# b_umd_zscore                                    47539.0 -1.274531e-01
# bm_sector_zscore                                47539.0  3.105128e-01
# bm_zscore                                       47539.0  2.803222e-01
# BUYPCT_sector_zscore                            47539.0 -5.858212e-02
# BUYPCT_zscore                                   47539.0 -3.904245e-02
# CAPEI_sector_zscore                             47539.0  2.801924e-02
# CAPEI_zscore                                    47539.0 -1.108117e-01
# capital_ratio_sector_zscore                     47539.0  5.045972e-01
# capital_ratio_zscore                            47539.0  1.499788e-01
# cash_conversion_sector_zscore                   47539.0  4.097720e-01
# cash_conversion_zscore                          47539.0  6.715584e-01
# cash_debt_sector_zscore                         47539.0  7.593327e-03
# cash_debt_zscore                                47539.0 -1.035710e+00
# cash_lt_sector_zscore                           47539.0  1.301250e+00
# cash_lt_zscore                                  47539.0  3.000729e+00
# cash_ratio_sector_zscore                        47539.0  5.700102e-01
# cash_ratio_zscore                               47539.0  1.285198e+00
# cfm_sector_zscore                               47539.0 -2.325364e+00
# cfm_zscore                                      47539.0 -5.057422e+00
# curr_debt_sector_zscore                         47539.0  9.837132e-02
# curr_debt_zscore                                47539.0  1.163945e-01
# curr_ratio_sector_zscore                        47539.0  3.726584e-01
# curr_ratio_zscore                               47539.0  6.116323e-01
# de_ratio_sector_zscore                          47539.0  5.054931e-01
# de_ratio_zscore                                 47539.0  9.495579e-01
# debt_assets_sector_zscore                       47539.0 -1.878418e-01
# debt_assets_zscore                              47539.0 -5.936083e-03
# debt_at_sector_zscore                           47539.0  3.325682e-01
# debt_at_zscore                                  47539.0  2.283306e-01
# debt_capital_sector_zscore                      47539.0 -3.412384e-01
# debt_capital_zscore                             47539.0  7.220561e-02
# debt_ebitda_sector_zscore                       47539.0  5.539528e-01
# debt_ebitda_zscore                              47539.0  3.689852e-01
# debt_invcap_sector_zscore                       47539.0  4.594680e-01
# debt_invcap_zscore                              47539.0  1.559648e-01
# DIVYIELD                                        47539.0  2.225436e-02
# dltt_be_sector_zscore                           47539.0  1.630727e+00
# dltt_be_zscore                                  47539.0  7.953832e-01
# dpr_sector_zscore                               47539.0           inf
# dpr_zscore                                      47539.0  4.579046e-01
# dvpspm                                          47539.0  1.784015e-01
# dvpsxm                                          47539.0  1.827777e-01
# dvrate                                          47539.0  7.702378e-01
# efftax_sector_zscore                            47539.0 -3.830527e-01
# efftax_zscore                                   47539.0 -3.939408e-01
# equity_invcap_sector_zscore                     47539.0 -3.745159e-01
# equity_invcap_zscore                            47539.0 -1.531888e-01
# evm_sector_zscore                               47539.0  3.553533e-02
# evm_zscore                                      47539.0 -2.978052e-01
# exret_sector_zscore                             47539.0 -2.275451e-04
# exret_zscore                                    47539.0 -1.388282e-02
# fcf_ocf_sector_zscore                           47539.0 -7.924414e-01
# fcf_ocf_zscore                                  47539.0 -7.781933e-01
# gpm_sector_zscore                               47539.0 -8.135326e-01
# gpm_zscore                                      47539.0 -7.347573e-01
# GProf_sector_zscore                             47539.0  2.239272e-01
# GProf_zscore                                    47539.0  1.059030e-01
# HOLDPCT_sector_zscore                           47539.0  5.508974e-02
# HOLDPCT_zscore                                  47539.0  6.462573e-02
# int_debt_sector_zscore                          47539.0  1.434379e+00
# int_debt_zscore                                 47539.0  1.842562e+00
# int_totdebt_sector_zscore                       47539.0  4.772550e-01
# int_totdebt_zscore                              47539.0  6.116632e-01
# intcov_ratio_sector_zscore                      47539.0  5.261413e-01
# intcov_ratio_zscore                             47539.0 -2.767364e-01
# intcov_sector_zscore                            47539.0 -1.372182e-01
# intcov_zscore                                   47539.0 -1.474103e+00
# inv_turn_sector_zscore                          47539.0  2.451721e+00
# inv_turn_zscore                                 47539.0  2.025454e+00
# invt_act_sector_zscore                          47539.0  9.230780e-01
# invt_act_zscore                                 47539.0  3.005910e-01
# ivol_sector_zscore                              47539.0  1.815478e-01
# ivol_zscore                                     47539.0  1.611911e-01
# lt_debt_sector_zscore                           47539.0  2.874077e-01
# lt_debt_zscore                                  47539.0  9.170637e-02
# lt_ppent_sector_zscore                          47539.0  1.364484e+00
# lt_ppent_zscore                                 47539.0  3.766663e+00
# MEANREC_sector_zscore                           47539.0  3.258159e-02
# MEANREC_zscore                                  47539.0  6.168147e-02
# MEDREC_sector_zscore                            47539.0           NaN
# MEDREC_zscore                                   47539.0  2.877994e-01
# n_sector_zscore                                 47539.0          -inf
# n_zscore                                        47539.0          -inf
# npm_sector_zscore                               47539.0 -2.790848e+00
# npm_zscore                                      47539.0 -6.425230e+00
# ocf_lct_sector_zscore                           47539.0 -6.074381e-02
# ocf_lct_zscore                                  47539.0 -5.401915e-01
# opmad_sector_zscore                             47539.0 -2.214191e+00
# opmad_zscore                                    47539.0 -4.260236e+00
# opmbd_sector_zscore                             47539.0 -1.891449e+00
# opmbd_zscore                                    47539.0 -3.451974e+00
# pay_turn_sector_zscore                          47539.0  2.935993e+01
# pay_turn_zscore                                 47539.0  4.795834e-01
# pcf_sector_zscore                               47539.0  4.371620e-02
# pcf_zscore                                      47539.0 -5.842022e-02
# pe_exi_sector_zscore                            47539.0  3.238707e-02
# pe_exi_zscore                                   47539.0 -1.312510e-01
# pe_inc_sector_zscore                            47539.0  3.627014e-02
# pe_inc_zscore                                   47539.0 -1.180543e-01
# pe_op_basic_sector_zscore                       47539.0  6.976184e-02
# pe_op_basic_zscore                              47539.0 -1.261836e-01
# pe_op_dil_sector_zscore                         47539.0  7.270549e-02
# pe_op_dil_zscore                                47539.0 -1.213580e-01
# PEG_1yrforward_sector_zscore                    47539.0 -7.090471e-02
# PEG_1yrforward_zscore                           47539.0  4.763608e-02
# PEG_ltgforward_sector_zscore                    47539.0 -2.011080e-02
# PEG_ltgforward_zscore                           47539.0 -3.880912e-02
# PEG_trailing_sector_zscore                      47539.0  6.955113e-01
# PEG_trailing_zscore                             47539.0  6.529960e-01
# pretret_earnat_sector_zscore                    47539.0 -1.352725e-01
# pretret_earnat_zscore                           47539.0 -3.932658e-01
# pretret_noa_sector_zscore                       47539.0 -3.556029e-02
# pretret_noa_zscore                              47539.0 -1.674512e-01
# profit_lct_sector_zscore                        47539.0 -6.496440e-02
# profit_lct_zscore                               47539.0 -5.334116e-01
# ps_sector_zscore                                47539.0  1.444989e+00
# ps_zscore                                       47539.0  2.943646e+00
# ptb_sector_zscore                               47539.0  7.128495e-01
# ptb_zscore                                      47539.0  9.938236e-01
# ptpm_sector_zscore                              47539.0 -2.307709e+00
# ptpm_zscore                                     47539.0 -4.878018e+00
# quick_ratio_sector_zscore                       47539.0  4.143543e-01
# quick_ratio_zscore                              47539.0  8.356690e-01
# R2_sector_zscore                                47539.0  4.548548e-02
# R2_zscore                                       47539.0  5.978014e-02
# rd_sale_sector_zscore                           47539.0           inf
# rd_sale_zscore                                  47539.0           inf
# recdown_sector_zscore                           47539.0           inf
# recdown_zscore                                  47539.0           inf
# rect_act_sector_zscore                          47539.0  1.669808e-01
# rect_act_zscore                                 47539.0  6.107929e-02
# rect_turn_sector_zscore                         47539.0  6.495710e+00
# rect_turn_zscore                                47539.0  1.190949e+00
# recup_sector_zscore                             47539.0           inf
# recup_zscore                                    47539.0           inf
# roa_sector_zscore                               47539.0  1.047681e-02
# roa_zscore                                      47539.0 -5.824533e-01
# roce_sector_zscore                              47539.0 -1.876835e-01
# roce_zscore                                     47539.0 -7.120250e-01
# roe_sector_zscore                               47539.0 -3.420843e-01
# roe_zscore                                      47539.0 -8.964798e-01
# sale_equity_sector_zscore                       47539.0  9.000417e-01
# sale_equity_zscore                              47539.0  7.412894e-01
# sale_invcap_sector_zscore                       47539.0  5.584734e-01
# sale_invcap_zscore                              47539.0  4.998389e-01
# sale_nwc_sector_zscore                          47539.0  9.138306e-01
# sale_nwc_zscore                                 47539.0  8.376252e-01
# SELLPCT_sector_zscore                           47539.0           inf
# SELLPCT_zscore                                  47539.0           inf
# short_debt_sector_zscore                        47539.0  9.669634e-01
# short_debt_zscore                               47539.0  9.954552e-01
# spcsrc                                          47539.0  5.253635e+01
# staff_sale_sector_zscore                        47539.0           inf
# staff_sale_zscore                               47539.0           inf
# STDEV_sector_zscore                             47539.0 -2.012888e-01
# STDEV_zscore                                    47539.0 -2.006466e-01
# totdebt_invcap_sector_zscore                    47539.0  3.082265e-01
# totdebt_invcap_zscore                           47539.0  1.680545e-01
# tvol_sector_zscore                              47539.0  1.628169e-01
# tvol_zscore                                     47539.0  1.491004e-01
#
#                                                        std         min  \
# forward_one_month_return_sector_zscore            1.467499   -4.232918
# forward_one_month_return_zscore                   1.550222   -4.416518
# forward_two_month_return_sector_zscore            1.215267   -3.508131
# forward_two_month_return_zscore                   1.282880   -3.787618
# forward_three_month_return_sector_zscore          1.147917   -3.326866
# forward_three_month_return_zscore                 1.204128   -3.547409
# forward_four_month_return_sector_zscore           1.031508   -3.199241
# forward_four_month_return_zscore                  1.063058   -3.369184
# forward_five_month_return_sector_zscore           0.961735   -3.000603
# forward_five_month_return_zscore                  0.971752   -3.066175
# forward_six_month_return_sector_zscore            0.853932   -2.954106
# forward_six_month_return_zscore                   0.857794   -2.978730
# forward_seven_month_return_sector_zscore          0.796270   -2.824094
# forward_seven_month_return_zscore                 0.792629   -2.776073
# forward_eight_month_return_sector_zscore          0.702782   -2.824737
# forward_eight_month_return_zscore                 0.696222   -2.788112
# forward_nine_month_return_sector_zscore           0.620316   -2.657485
# forward_nine_month_return_zscore                  0.621963   -2.637419
# forward_ten_month_return_sector_zscore            0.532646   -2.772682
# forward_ten_month_return_zscore                   0.524739   -2.737899
# forward_eleven_month_return_sector_zscore         0.457544   -2.479880
# forward_eleven_month_return_zscore                0.448264   -2.392935
# forward_twelve_month_return_sector_zscore         0.507988   -4.584835
# forward_twelve_month_return_zscore                0.498966   -3.602244
# forward_thirteen_month_return_sector_zscore       0.535048   -3.411806
# forward_thirteen_month_return_zscore              0.649938   -2.295808
# forward_fourteen_month_return_sector_zscore       0.402672   -3.672568
# forward_fourteen_month_return_zscore              0.420131   -3.616219
# forward_fifteen_month_return_sector_zscore        0.837710   -2.739079
# forward_fifteen_month_return_zscore               0.675104   -2.275422
# forward_sixteen_month_return_sector_zscore        0.367788   -4.798246
# forward_sixteen_month_return_zscore               0.355529   -3.655726
# forward_seventeen_month_return_sector_zscore      0.424009   -2.232755
# forward_seventeen_month_return_zscore             0.517621   -2.440420
# forward_eighteen_month_return_sector_zscore       0.418926   -5.709780
# forward_eighteen_month_return_zscore              0.354275   -3.465901
# forward_nineteen_month_return_sector_zscore       0.679646   -2.709413
# forward_nineteen_month_return_zscore              0.526332   -2.382005
# forward_twenty_month_return_sector_zscore         0.261285   -4.193727
# forward_twenty_month_return_zscore                0.229419   -3.522714
# forward_twentyone_month_return_sector_zscore      0.502236   -2.577448
# forward_twentyone_month_return_zscore             0.380650   -1.856854
# forward_twentytwo_month_return_sector_zscore      0.148557   -2.675424
# forward_twentytwo_month_return_zscore             0.134894   -2.680752
# forward_twentythree_month_return_sector_zscore    0.389949   -3.392304
# forward_twentythree_month_return_zscore           0.369924   -3.424155
# forward_twentyfour_month_return_sector_zscore     0.059846   -1.934808
# forward_twentyfour_month_return_zscore            0.059846   -1.934808
# forward_twentyfive_month_return_sector_zscore     0.055740   -3.218051
# forward_twentyfive_month_return_zscore            0.055740   -3.218051
# forward_twentysix_month_return_sector_zscore      0.049288   -1.332253
# forward_twentysix_month_return_zscore             0.049288   -1.332253
# forward_twentyseven_month_return_sector_zscore    0.085776   -2.236236
# forward_twentyseven_month_return_zscore           0.085776   -2.236236
# forward_twentyeight_month_return_sector_zscore    0.144540   -4.724535
# forward_twentyeight_month_return_zscore           0.144540   -4.724535
# forward_twentynine_month_return_sector_zscore     0.047853   -0.739982
# forward_twentynine_month_return_zscore            0.047853   -0.739982
# forward_thirty_month_return_sector_zscore         0.100852   -2.853482
# forward_thirty_month_return_zscore                0.100852   -2.853482
# forward_thirtyone_month_return_sector_zscore      0.118493   -4.009386
# forward_thirtyone_month_return_zscore             0.118493   -4.009386
# forward_thirtytwo_month_return_sector_zscore      0.018906   -0.722074
# forward_thirtytwo_month_return_zscore             0.018906   -0.722074
# forward_thirtythree_month_return_sector_zscore    0.072346   -2.427659
# forward_thirtythree_month_return_zscore           0.072346   -2.427659
# forward_thirtyfour_month_return_sector_zscore     0.130478   -0.823368
# forward_thirtyfour_month_return_zscore            0.130478   -0.823368
# forward_thirtyfive_month_return_sector_zscore     0.007560   -0.672948
# forward_thirtyfive_month_return_zscore            0.007560   -0.672948
# forward_thirtysix_month_return_sector_zscore           NaN         NaN
# forward_thirtysix_month_return_zscore                  NaN         NaN
# past_one_month_return_sector_zscore               1.289898   -3.553792
# past_one_month_return_zscore                      1.373160   -3.852940
# past_two_month_return_sector_zscore               1.166168   -3.286335
# past_two_month_return_zscore                      1.230613   -3.574951
# past_three_month_return_sector_zscore             1.088022   -3.157455
# past_three_month_return_zscore                    1.138594   -3.426288
# past_four_month_return_sector_zscore              1.002951   -3.060532
# past_four_month_return_zscore                     1.023777   -3.185989
# past_five_month_return_sector_zscore              0.917776   -2.939238
# past_five_month_return_zscore                     0.927263   -3.026707
# past_six_month_return_sector_zscore               0.830966   -2.862417
# past_six_month_return_zscore                      0.832057   -2.884583
# past_seven_month_return_sector_zscore             0.756645   -2.843728
# past_seven_month_return_zscore                    0.751535   -2.765398
# past_eight_month_return_sector_zscore             0.671898   -2.709441
# past_eight_month_return_zscore                    0.661990   -2.682293
# past_nine_month_return_sector_zscore              0.589551   -2.621498
# past_nine_month_return_zscore                     0.579921   -2.635526
# past_ten_month_return_sector_zscore               0.490360   -2.532110
# past_ten_month_return_zscore                      0.485986   -2.562334
# past_eleven_month_return_sector_zscore            0.381189   -2.660051
# past_eleven_month_return_zscore                   0.367474   -2.517379
# past_twelve_month_return_sector_zscore            0.217856   -3.868327
# past_twelve_month_return_zscore                   0.199936   -3.793793
# past_thirteen_month_return_sector_zscore          0.267241   -3.588994
# past_thirteen_month_return_zscore                 0.238621   -3.512515
# past_fourteen_month_return_sector_zscore          0.176416   -3.020038
# past_fourteen_month_return_zscore                 0.183519   -3.583782
# past_fifteen_month_return_sector_zscore           0.241236   -3.064539
# past_fifteen_month_return_zscore                  0.212999   -3.338823
# past_sixteen_month_return_sector_zscore           0.161179   -3.069461
# past_sixteen_month_return_zscore                  0.159339   -2.976823
# past_seventeen_month_return_sector_zscore         0.201924   -2.631844
# past_seventeen_month_return_zscore                0.178328   -2.912775
# past_eighteen_month_return_sector_zscore          0.160187   -3.097487
# past_eighteen_month_return_zscore                 0.138671   -2.454210
# past_nineteen_month_return_sector_zscore          0.187046   -2.738617
# past_nineteen_month_return_zscore                 0.148543   -2.285616
# past_twenty_month_return_sector_zscore            0.117457   -1.898129
# past_twenty_month_return_zscore                   0.101394   -1.903492
# past_twentyone_month_return_sector_zscore         0.141823   -2.498018
# past_twentyone_month_return_zscore                0.099018   -2.139128
# past_twentytwo_month_return_sector_zscore         0.090422   -2.085702
# past_twentytwo_month_return_zscore                0.089197   -2.241950
# past_twentythree_month_return_sector_zscore       0.063403   -2.423224
# past_twentythree_month_return_zscore              0.060368   -2.086694
# past_twentyfour_month_return_sector_zscore        0.036022   -1.934808
# past_twentyfour_month_return_zscore               0.036022   -1.934808
# past_twentyfive_month_return_sector_zscore        0.040293   -2.102447
# past_twentyfive_month_return_zscore               0.040293   -2.102447
# past_twentysix_month_return_sector_zscore         0.036038   -2.609572
# past_twentysix_month_return_zscore                0.036038   -2.609572
# past_twentyseven_month_return_sector_zscore       0.029316   -1.715290
# past_twentyseven_month_return_zscore              0.029316   -1.715290
# past_twentyeight_month_return_sector_zscore       0.033451   -2.610568
# past_twentyeight_month_return_zscore              0.033451   -2.610568
# past_twentynine_month_return_sector_zscore        0.030739   -1.616074
# past_twentynine_month_return_zscore               0.030739   -1.616074
# past_thirty_month_return_sector_zscore            0.021888   -1.258693
# past_thirty_month_return_zscore                   0.021888   -1.258693
# past_thirtyone_month_return_sector_zscore         0.043819   -2.015899
# past_thirtyone_month_return_zscore                0.043819   -2.015899
# past_thirtytwo_month_return_sector_zscore         0.016255   -0.964782
# past_thirtytwo_month_return_zscore                0.016255   -0.964782
# past_thirtythree_month_return_sector_zscore       0.013752   -0.816856
# past_thirtythree_month_return_zscore              0.013752   -0.816856
# past_thirtyfour_month_return_sector_zscore        0.011610   -0.852593
# past_thirtyfour_month_return_zscore               0.011610   -0.852593
# past_thirtyfive_month_return_sector_zscore        0.007560   -0.672948
# past_thirtyfive_month_return_zscore               0.007560   -0.672948
# past_thirtysix_month_return_sector_zscore              NaN         NaN
# past_thirtysix_month_return_zscore                     NaN         NaN
# accrual_sector_zscore                             2.107222   -5.518328
# accrual_zscore                                    1.665822   -3.291986
# adv_sale_sector_zscore                                 NaN   -0.672948
# adv_sale_zscore                                        NaN         inf
# aftret_eq_sector_zscore                           2.611355  -10.641147
# aftret_eq_zscore                                  3.830946  -16.777425
# aftret_equity_sector_zscore                       2.452946   -9.838184
# aftret_equity_zscore                              3.498279  -15.338915
# aftret_invcapx_sector_zscore                           NaN  -13.151735
# aftret_invcapx_zscore                             3.637237  -16.836150
# alpha_sector_zscore                               0.888096   -2.790270
# alpha_zscore                                      0.963577   -2.725437
# at_turn_sector_zscore                             4.833716   -1.522752
# at_turn_zscore                                    1.071429   -0.956415
# b_hml_sector_zscore                               0.883440   -3.099700
# b_hml_zscore                                      0.994943   -3.736494
# b_mkt_sector_zscore                               0.834088   -1.905163
# b_mkt_zscore                                      0.780623   -1.643348
# b_smb_sector_zscore                               0.796652   -1.904831
# b_smb_zscore                                      0.873242   -1.817791
# b_umd_sector_zscore                               0.907377   -3.624959
# b_umd_zscore                                      0.913923   -3.633619
# bm_sector_zscore                                  1.323337   -1.525271
# bm_zscore                                         1.167494   -1.125901
# BUYPCT_sector_zscore                              0.806705   -2.210594
# BUYPCT_zscore                                     0.721456   -1.529335
# CAPEI_sector_zscore                               2.501342   -8.915577
# CAPEI_zscore                                      2.124501   -8.012959
# capital_ratio_sector_zscore                       1.737655   -1.405782
# capital_ratio_zscore                              0.852427   -0.769898
# cash_conversion_sector_zscore                     1.653813   -1.195599
# cash_conversion_zscore                            2.852818   -1.112764
# cash_debt_sector_zscore                           3.046588  -10.671025
# cash_debt_zscore                                  5.418855  -27.338636
# cash_lt_sector_zscore                             3.613458   -0.878570
# cash_lt_zscore                                    7.928954   -0.775723
# cash_ratio_sector_zscore                          1.852114   -0.940210
# cash_ratio_zscore                                 3.748157   -0.810714
# cfm_sector_zscore                                11.289882  -72.170811
# cfm_zscore                                       24.564011 -159.148655
# curr_debt_sector_zscore                           0.846911   -1.465247
# curr_debt_zscore                                  0.743360   -1.083209
# curr_ratio_sector_zscore                          1.416317   -1.252732
# curr_ratio_zscore                                 2.071808   -1.142336
# de_ratio_sector_zscore                            2.891236   -7.830748
# de_ratio_zscore                                   2.800764   -5.168941
# debt_assets_sector_zscore                         1.616469   -7.696837
# debt_assets_zscore                                0.862142   -1.595486
# debt_at_sector_zscore                             1.315301   -1.290895
# debt_at_zscore                                    0.951050   -0.773453
# debt_capital_sector_zscore                        2.550050  -12.660122
# debt_capital_zscore                               0.817319   -1.088784
# debt_ebitda_sector_zscore                         2.498210   -5.652093
# debt_ebitda_zscore                                1.728951   -3.265461
# debt_invcap_sector_zscore                         1.614178   -1.316647
# debt_invcap_zscore                                0.859477   -0.776922
# DIVYIELD                                          0.011204    0.002800
# dltt_be_sector_zscore                             4.899909   -0.902942
# dltt_be_zscore                                    2.493757   -0.672948
# dpr_sector_zscore                                      NaN   -1.030451
# dpr_zscore                                        1.869819   -0.672948
# dvpspm                                            0.075694    0.015000
# dvpsxm                                            0.075472    0.020000
# dvrate                                            0.496771    0.080000
# efftax_sector_zscore                              2.364275  -14.154424
# efftax_zscore                                     2.348639  -14.644620
# equity_invcap_sector_zscore                       1.481569   -5.992870
# equity_invcap_zscore                              0.909184   -3.131445
# evm_sector_zscore                                 2.840058  -10.519895
# evm_zscore                                        3.873222  -15.868791
# exret_sector_zscore                               0.986102   -3.322560
# exret_zscore                                      1.030881   -3.597376
# fcf_ocf_sector_zscore                             2.853249  -16.822160
# fcf_ocf_zscore                                    2.542881  -14.296900
# gpm_sector_zscore                                 3.973807  -24.745159
# gpm_zscore                                        5.039345  -32.260336
# GProf_sector_zscore                               1.568992   -2.862586
# GProf_zscore                                      1.055971   -2.666970
# HOLDPCT_sector_zscore                             0.856103   -1.441351
# HOLDPCT_zscore                                    0.755329   -1.025498
# int_debt_sector_zscore                            6.814536   -1.634301
# int_debt_zscore                                   8.880269   -1.514132
# int_totdebt_sector_zscore                         2.328490   -1.671515
# int_totdebt_zscore                                2.855489   -1.644983
# intcov_ratio_sector_zscore                        9.891821  -45.407043
# intcov_ratio_zscore                              13.364234  -79.900379
# intcov_sector_zscore                             10.521282  -58.438538
# intcov_zscore                                    17.514250 -117.177973
# inv_turn_sector_zscore                            8.837837   -1.072866
# inv_turn_zscore                                   7.302212   -0.981556
# invt_act_sector_zscore                            2.884774   -1.044634
# invt_act_zscore                                   1.030706   -0.672948
# ivol_sector_zscore                                0.962068   -1.300677
# ivol_zscore                                       0.871550   -1.122676
# lt_debt_sector_zscore                             1.357378   -1.718898
# lt_debt_zscore                                    0.731739   -0.738335
# lt_ppent_sector_zscore                            4.338059   -1.148143
# lt_ppent_zscore                                   9.692235   -0.765499
# MEANREC_sector_zscore                             0.897945   -2.226301
# MEANREC_zscore                                    0.898904   -2.224465
# MEDREC_sector_zscore                                   NaN        -inf
# MEDREC_zscore                                     0.782903   -1.345895
# n_sector_zscore                                        NaN        -inf
# n_zscore                                               NaN        -inf
# npm_sector_zscore                                12.836821  -82.420570
# npm_zscore                                       30.026859 -193.284380
# ocf_lct_sector_zscore                             1.331669   -4.959918
# ocf_lct_zscore                                    2.628024  -11.916629
# opmad_sector_zscore                              10.585555  -68.283223
# opmad_zscore                                     21.147940 -135.974485
# opmbd_sector_zscore                               9.363910  -60.293736
# opmbd_zscore                                     17.623663 -113.656666
# pay_turn_sector_zscore                          138.668238   -1.389100
# pay_turn_zscore                                   1.781640   -1.094261
# pcf_sector_zscore                                 2.225665   -7.940330
# pcf_zscore                                        2.345927   -8.619318
# pe_exi_sector_zscore                              2.392422   -8.129726
# pe_exi_zscore                                     1.781124   -6.426498
# pe_inc_sector_zscore                              2.342900   -7.994254
# pe_inc_zscore                                     1.774827   -6.288589
# pe_op_basic_sector_zscore                         2.513020   -8.305084
# pe_op_basic_zscore                                2.146100   -7.496959
# pe_op_dil_sector_zscore                           2.481041   -8.152568
# pe_op_dil_zscore                                  2.094393   -7.270283
# PEG_1yrforward_sector_zscore                      2.736365  -13.159009
# PEG_1yrforward_zscore                             2.334565  -10.964859
# PEG_ltgforward_sector_zscore                      1.699470   -9.658607
# PEG_ltgforward_zscore                             1.727878   -9.833888
# PEG_trailing_sector_zscore                        3.433565   -3.086418
# PEG_trailing_zscore                               3.224449   -2.793322
# pretret_earnat_sector_zscore                      1.346446   -5.993696
# pretret_earnat_zscore                             1.825847   -7.728053
# pretret_noa_sector_zscore                         1.778791   -7.086511
# pretret_noa_zscore                                2.063143   -8.238852
# profit_lct_sector_zscore                          1.294137   -4.878188
# profit_lct_zscore                                 2.493784  -11.369392
# ps_sector_zscore                                  6.001563   -1.150706
# ps_zscore                                        13.060723   -0.950877
# ptb_sector_zscore                                 2.353410   -1.191997
# ptb_zscore                                        2.979372   -1.104067
# ptpm_sector_zscore                               10.769936  -68.858232
# ptpm_zscore                                      23.190534 -149.909166
# quick_ratio_sector_zscore                         1.526540   -1.281028
# quick_ratio_zscore                                2.688356   -1.203984
# R2_sector_zscore                                  0.717089   -1.553225
# R2_zscore                                         0.719281   -1.392751
# rd_sale_sector_zscore                                  NaN   -0.895936
# rd_sale_zscore                                         NaN         inf
# recdown_sector_zscore                                  NaN         inf
# recdown_zscore                                         NaN         inf
# rect_act_sector_zscore                            0.985766   -1.720110
# rect_act_zscore                                   0.833387   -1.234870
# rect_turn_sector_zscore                          26.559973   -1.725200
# rect_turn_zscore                                  4.477278   -1.553397
# recup_sector_zscore                                    NaN         inf
# recup_zscore                                           NaN         inf
# roa_sector_zscore                                 1.909599   -5.762375
# roa_zscore                                        2.414335   -9.717789
# roce_sector_zscore                                1.752405   -6.810955
# roce_zscore                                       3.052330  -13.206095
# roe_sector_zscore                                 2.103324   -9.062425
# roe_zscore                                        3.277371  -15.356557
# sale_equity_sector_zscore                         2.885177   -1.317167
# sale_equity_zscore                                2.363060   -1.008075
# sale_invcap_sector_zscore                         1.946209   -1.416088
# sale_invcap_zscore                                1.603361   -1.030604
# sale_nwc_sector_zscore                            3.251952   -1.143273
# sale_nwc_zscore                                   3.179698   -1.026956
# SELLPCT_sector_zscore                                  NaN         inf
# SELLPCT_zscore                                         NaN         inf
# short_debt_sector_zscore                          2.627023   -0.743905
# short_debt_zscore                                 2.311441   -0.672948
# spcsrc                                           24.531283    0.500000
# staff_sale_sector_zscore                               NaN   -2.726300
# staff_sale_zscore                                      NaN         inf
# STDEV_sector_zscore                               1.181257   -3.275011
# STDEV_zscore                                      1.182086   -2.729176
# totdebt_invcap_sector_zscore                      1.339850   -1.376484
# totdebt_invcap_zscore                             1.027878   -0.917900
# ...
# past_twentyone_month_return_sector_zscore       0.000000e+00    7.070419
# past_twentyone_month_return_zscore              0.000000e+00    4.296558
# past_twentytwo_month_return_sector_zscore       8.673617e-18    4.167489
# past_twentytwo_month_return_zscore              0.000000e+00    3.672263
# past_twentythree_month_return_sector_zscore     0.000000e+00    3.077834
# past_twentythree_month_return_zscore            0.000000e+00    2.294734
# past_twentyfour_month_return_sector_zscore      2.775558e-17    1.752016
# past_twentyfour_month_return_zscore             2.775558e-17    1.752016
# past_twentyfive_month_return_sector_zscore      0.000000e+00    3.039278
# past_twentyfive_month_return_zscore             0.000000e+00    3.039278
# past_twentysix_month_return_sector_zscore       0.000000e+00    1.976686
# past_twentysix_month_return_zscore              0.000000e+00    1.976686
# past_twentyseven_month_return_sector_zscore     0.000000e+00    1.466660
# past_twentyseven_month_return_zscore            0.000000e+00    1.466660
# past_twentyeight_month_return_sector_zscore    -8.326673e-17    1.556835
# past_twentyeight_month_return_zscore           -8.326673e-17    1.556835
# past_twentynine_month_return_sector_zscore      0.000000e+00    2.851053
# past_twentynine_month_return_zscore             0.000000e+00    2.851053
# past_thirty_month_return_sector_zscore          1.387779e-16    0.940158
# past_thirty_month_return_zscore                 1.387779e-16    0.940158
# past_thirtyone_month_return_sector_zscore       0.000000e+00    4.530817
# past_thirtyone_month_return_zscore              0.000000e+00    4.530817
# past_thirtytwo_month_return_sector_zscore       0.000000e+00    1.114871
# past_thirtytwo_month_return_zscore              0.000000e+00    1.114871
# past_thirtythree_month_return_sector_zscore     0.000000e+00    1.050198
# past_thirtythree_month_return_zscore            0.000000e+00    1.050198
# past_thirtyfour_month_return_sector_zscore      0.000000e+00    0.960347
# past_thirtyfour_month_return_zscore             0.000000e+00    0.960347
# past_thirtyfive_month_return_sector_zscore      0.000000e+00    0.672948
# past_thirtyfive_month_return_zscore             0.000000e+00    0.672948
# past_thirtysix_month_return_sector_zscore                NaN         NaN
# past_thirtysix_month_return_zscore                       NaN         NaN
# accrual_sector_zscore                           7.764779e-01    8.293701
# accrual_zscore                                  8.366374e-01    6.325707
# adv_sale_sector_zscore                          1.261777e+00         inf
# adv_sale_zscore                                          inf         inf
# aftret_eq_sector_zscore                         5.677407e-01    7.413820
# aftret_eq_zscore                                5.341954e-01    9.142706
# aftret_equity_sector_zscore                     5.992233e-01    6.778881
# aftret_equity_zscore                            5.248991e-01    7.012511
# aftret_invcapx_sector_zscore                    6.412794e-01         inf
# aftret_invcapx_zscore                           7.364331e-01    4.089297
# alpha_sector_zscore                             2.223653e-01    2.823741
# alpha_zscore                                    2.187079e-01    3.452133
# at_turn_sector_zscore                           8.568173e-01   27.835801
# at_turn_zscore                                  7.258712e-01    3.603418
# b_hml_sector_zscore                             2.238018e-01    2.273005
# b_hml_zscore                                    1.833150e-01    2.078706
# b_mkt_sector_zscore                             2.075025e-01    2.953387
# b_mkt_zscore                                    2.127739e-01    2.646635
# b_smb_sector_zscore                             2.209632e-01    2.769106
# b_smb_zscore                                    2.236230e-01    3.322569
# b_umd_sector_zscore                             2.256651e-01    2.034526
# b_umd_zscore                                    2.176160e-01    1.890168
# bm_sector_zscore                                7.931748e-01    5.362943
# bm_zscore                                       8.226325e-01    4.682593
# BUYPCT_sector_zscore                            5.754309e-01    1.363150
# BUYPCT_zscore                                   5.046476e-01    1.009295
# CAPEI_sector_zscore                             6.626248e-01    8.950637
# CAPEI_zscore                                    4.604345e-01    7.327061
# capital_ratio_sector_zscore                     9.640076e-01    7.130362
# capital_ratio_zscore                            6.584755e-01    2.738139
# cash_conversion_sector_zscore                   4.484550e-01    9.071255
# cash_conversion_zscore                          4.668318e-01   19.560137
# cash_debt_sector_zscore                         6.658451e-01   11.440108
# cash_debt_zscore                                7.970835e-01    6.878705
# cash_lt_sector_zscore                           1.312248e+00   18.012084
# cash_lt_zscore                                  2.397799e+00   42.182593
# cash_ratio_sector_zscore                        6.983675e-01    9.058271
# cash_ratio_zscore                               1.000895e+00   19.952182
# cfm_sector_zscore                               5.682668e-01    3.561996
# cfm_zscore                                      6.969813e-01    3.599864
# curr_debt_sector_zscore                         5.829813e-01    2.664691
# curr_debt_zscore                                6.286746e-01    1.611532
# curr_ratio_sector_zscore                        6.253402e-01    6.191862
# curr_ratio_zscore                               6.778321e-01   10.421874
# de_ratio_sector_zscore                          8.652384e-01   12.975415
# de_ratio_zscore                                 1.292454e+00   11.349056
# debt_assets_sector_zscore                       6.308883e-01    2.726061
# debt_assets_zscore                              6.737392e-01    1.966930
# debt_at_sector_zscore                           8.448819e-01    4.943231
# debt_at_zscore                                  7.994074e-01    2.975674
# debt_capital_sector_zscore                      6.608586e-01    3.234785
# debt_capital_zscore                             7.121485e-01    1.995626
# debt_ebitda_sector_zscore                       9.339431e-01   11.112306
# debt_ebitda_zscore                              8.968966e-01    7.475951
# debt_invcap_sector_zscore                       9.276601e-01    6.479460
# debt_invcap_zscore                              6.640735e-01    2.844943
# DIVYIELD                                        2.060000e-02    0.086984
# dltt_be_sector_zscore                           1.281787e+00   26.714451
# dltt_be_zscore                                  9.619191e-01   13.301251
# dpr_sector_zscore                               5.525351e-01         inf
# dpr_zscore                                      5.631893e-01   11.438538
# dvpspm                                          1.702000e-01    0.900000
# dvpsxm                                          1.750000e-01    0.901200
# dvrate                                          6.800000e-01    3.350000
# efftax_sector_zscore                            3.267669e-01    5.914291
# efftax_zscore                                   3.311329e-01    5.415485
# equity_invcap_sector_zscore                     6.729475e-01    1.349720
# equity_invcap_zscore                            6.847021e-01    0.838380
# evm_sector_zscore                               7.398866e-01   10.362668
# evm_zscore                                      6.668928e-01   13.365761
# exret_sector_zscore                             2.066759e-01    3.442132
# exret_zscore                                    2.022429e-01    3.626052
# fcf_ocf_sector_zscore                           4.133820e-01    1.097652
# fcf_ocf_zscore                                  4.259943e-01    0.932248
# gpm_sector_zscore                               5.842645e-01    2.257989
# gpm_zscore                                      8.303034e-01    1.871472
# GProf_sector_zscore                             7.570659e-01    6.729475
# GProf_zscore                                    6.961526e-01    2.879589
# HOLDPCT_sector_zscore                           5.099447e-01    2.355709
# HOLDPCT_zscore                                  4.711480e-01    1.834236
# int_debt_sector_zscore                          3.958515e-01   48.372011
# int_debt_zscore                                 4.037685e-01   65.376851
# int_totdebt_sector_zscore                       4.326091e-01   14.847669
# int_totdebt_zscore                              4.354366e-01   18.992074
# intcov_ratio_sector_zscore                      4.459898e-01   50.651232
# intcov_ratio_zscore                             5.177482e-01   49.645023
# intcov_sector_zscore                            3.942752e-01   42.647444
# intcov_zscore                                   4.266133e-01   45.073402
# inv_turn_sector_zscore                          6.646916e-01   56.719480
# inv_turn_zscore                                 5.762730e-01   45.305298
# invt_act_sector_zscore                          8.466114e-01   14.947606
# invt_act_zscore                                 8.391074e-01    3.478703
# ivol_sector_zscore                              2.596012e-01    4.181980
# ivol_zscore                                     2.579756e-01    3.516184
# lt_debt_sector_zscore                           8.253130e-01    5.242873
# lt_debt_zscore                                  6.892944e-01    1.617248
# lt_ppent_sector_zscore                          1.148515e+00   23.823260
# lt_ppent_zscore                                 2.466052e+00   50.764153
# MEANREC_sector_zscore                           5.541921e-01    2.083704
# MEANREC_zscore                                  6.152663e-01    2.018843
# MEDREC_sector_zscore                            6.729475e-01         inf
# MEDREC_zscore                                   1.345895e+00    1.345895
# n_sector_zscore                                -1.752303e+00    0.672948
# n_zscore                                                -inf        -inf
# npm_sector_zscore                               5.203950e-01    2.934799
# npm_zscore                                      6.227275e-01    2.841334
# ocf_lct_sector_zscore                           4.978916e-01    3.489539
# ocf_lct_zscore                                  4.730268e-01    3.460464
# opmad_sector_zscore                             5.444070e-01    2.757765
# opmad_zscore                                    7.416156e-01    3.273475
# opmbd_sector_zscore                             5.672768e-01    2.860027
# opmbd_zscore                                    8.218297e-01    2.930002
# pay_turn_sector_zscore                          1.138678e+00  851.156246
# pay_turn_zscore                                 7.800939e-01    7.793167
# pcf_sector_zscore                               7.317200e-01    7.685710
# pcf_zscore                                      6.617178e-01    8.044614
# pe_exi_sector_zscore                            6.804599e-01    8.116090
# pe_exi_zscore                                   4.199984e-01    5.843805
# pe_inc_sector_zscore                            6.792812e-01    7.906066
# pe_inc_zscore                                   4.299218e-01    5.926626
# pe_op_basic_sector_zscore                       7.042519e-01    8.975805
# pe_op_basic_zscore                              4.749561e-01    7.570713
# pe_op_dil_sector_zscore                         7.096390e-01    8.765890
# pe_op_dil_zscore                                4.715274e-01    7.321266
# PEG_1yrforward_sector_zscore                    2.714614e-01    9.903641
# PEG_1yrforward_zscore                           4.241056e-01    8.663909
# PEG_ltgforward_sector_zscore                    0.000000e+00    8.363901
# PEG_ltgforward_zscore                           0.000000e+00    8.387744
# PEG_trailing_sector_zscore                      0.000000e+00   26.515269
# PEG_trailing_zscore                             0.000000e+00   24.773513
# pretret_earnat_sector_zscore                    5.272137e-01    2.742792
# pretret_earnat_zscore                           4.085753e-01    2.833404
# pretret_noa_sector_zscore                       5.117804e-01    6.253675
# pretret_noa_zscore                              4.187830e-01    6.787400
# profit_lct_sector_zscore                        4.991517e-01    3.252580
# profit_lct_zscore                               4.791966e-01    3.238635
# ps_sector_zscore                                8.810981e-01   38.096356
# ps_zscore                                       1.010803e+00   85.081457
# ptb_sector_zscore                               9.036661e-01   11.709022
# ptb_zscore                                      1.138756e+00   15.450662
# ptpm_sector_zscore                              5.440852e-01    2.644284
# ptpm_zscore                                     6.440035e-01    2.796938
# quick_ratio_sector_zscore                       6.420024e-01    6.952928
# quick_ratio_zscore                              7.375809e-01   13.968347
# R2_sector_zscore                                2.180380e-01    2.196851
# R2_zscore                                       2.157417e-01    2.319992
# rd_sale_sector_zscore                           6.935565e-01         inf
# rd_sale_zscore                                           inf         inf
# recdown_sector_zscore                                    inf         inf
# recdown_zscore                                           inf         inf
# rect_act_sector_zscore                          5.882239e-01    3.126457
# rect_act_zscore                                 4.800359e-01    2.348934
# rect_turn_sector_zscore                         1.061370e+00  158.899731
# rect_turn_zscore                                7.389536e-01   23.559234
# recup_sector_zscore                                      inf         inf
# recup_zscore                                             inf         inf
# roa_sector_zscore                               6.572976e-01    7.290265
# roa_zscore                                      6.624327e-01    2.862697
# roce_sector_zscore                              5.958338e-01    4.310502
# roce_zscore                                     5.981756e-01    4.858128
# roe_sector_zscore                               5.670906e-01    4.481915
# roe_zscore                                      4.870015e-01    3.976902
# sale_equity_sector_zscore                       9.355196e-01   15.027947
# sale_equity_zscore                              9.164198e-01   12.245700
# sale_invcap_sector_zscore                       8.318449e-01    8.801417
# sale_invcap_zscore                              9.052746e-01    6.815430
# sale_nwc_sector_zscore                          5.221797e-01   20.303361
# sale_nwc_zscore                                 4.442219e-01   19.875682
# SELLPCT_sector_zscore                                    inf         inf
# SELLPCT_zscore                                           inf         inf
# short_debt_sector_zscore                        1.143640e+00   13.013706
# short_debt_zscore                               1.329679e+00    7.738896
# spcsrc                                          6.050000e+01   95.000000
# staff_sale_sector_zscore                        2.470314e-01         inf
# staff_sale_zscore                                        inf         inf
# STDEV_sector_zscore                             4.710633e-01    2.281910
# STDEV_zscore                                    4.604378e-01    2.430088
# totdebt_invcap_sector_zscore                    8.135188e-01    5.240694
# totdebt_invcap_zscore                           6.483275e-01    3.879576
# tvol_sector_zscore                              2.589364e-01    3.942988
# tvol_zscore                                     2.466842e-01    3.280858

# %%
from scipy.stats.stats import pearsonr

# %%
feature = []
correlation = []
significance = []

for column in df:
    pair = pearsonr(df['forward_one_month_return_sector_zscore'], df[column])
    feature.append(column)
    correlation.append(abs(pair[0]))
    significance.append(pair[1])
    
review = pd.DataFrame()
review['feature'] = feature
review['correlation'] = correlation
review['significance'] = significance

# review - Sort - Correlation
review = review.sort_values(by=['correlation'], ascending=0)
# Out:
# C:\Users\shane\Anaconda3\lib\site-packages\scipy\stats\stats.py:5084: RuntimeWarning: invalid value encountered in less
#   x = np.where(x < 1.0, x, 1.0)  # if x > 1 then return 1.0
# C:\Users\shane\Anaconda3\lib\site-packages\scipy\stats\stats.py:3026: RuntimeWarning: invalid value encountered in subtract
#   xm, ym = x - mx, y - my

# %%
review
# Out:
#                                             feature  correlation  significance
# 0            forward_one_month_return_sector_zscore     1.000000  0.000000e+00
# 1                   forward_one_month_return_zscore     0.950835  0.000000e+00
# 2            forward_two_month_return_sector_zscore     0.594806  0.000000e+00
# 3                   forward_two_month_return_zscore     0.568935  0.000000e+00
# 4          forward_three_month_return_sector_zscore     0.535254  0.000000e+00
# 5                 forward_three_month_return_zscore     0.518751  0.000000e+00
# 8           forward_five_month_return_sector_zscore     0.405415  0.000000e+00
# 6           forward_four_month_return_sector_zscore     0.404030  0.000000e+00
# 9                  forward_five_month_return_zscore     0.387086  0.000000e+00
# 7                  forward_four_month_return_zscore     0.385913  0.000000e+00
# 274                    pretret_earnat_sector_zscore     0.071362  1.013581e-54
# 316                                          spcsrc     0.062562  1.920148e-42
# 304                               roe_sector_zscore     0.062041  9.104352e-42
# 275                           pretret_earnat_zscore     0.061663  2.794614e-41
# 305                                      roe_zscore     0.060042  3.181727e-39
# 302                              roce_sector_zscore     0.057215  9.033118e-36
# 303                                     roce_zscore     0.052427  2.683991e-30
# 278                        profit_lct_sector_zscore     0.051743  1.486916e-29
# 276                       pretret_noa_sector_zscore     0.051465  2.959237e-29
# 153                           aftret_invcapx_zscore     0.050790  1.554004e-28
# 301                                      roa_zscore     0.049480  3.645587e-27
# 277                              pretret_noa_zscore     0.047375  4.901486e-25
# 151                            aftret_equity_zscore     0.046887  1.481599e-24
# 149                                aftret_eq_zscore     0.043224  4.160385e-21
# 148                         aftret_eq_sector_zscore     0.041696  9.471678e-20
# 150                     aftret_equity_sector_zscore     0.041241  2.352876e-19
# 250                           ocf_lct_sector_zscore     0.041020  3.645090e-19
# 279                               profit_lct_zscore     0.040722  6.552583e-19
# 323                              tvol_sector_zscore     0.038894  2.190835e-17
# 145                                  accrual_zscore     0.037725  1.903477e-16
# 236                              ivol_sector_zscore     0.036716  1.168155e-15
# 248                               npm_sector_zscore     0.035093  1.954989e-14
# 252                             opmad_sector_zscore     0.034340  6.922557e-14
# 284                              ptpm_sector_zscore     0.034178  9.063042e-14
# 300                               roa_sector_zscore     0.033408  3.194855e-13
# 79                    past_four_month_return_zscore     0.032993  6.226823e-13
# 78             past_four_month_return_sector_zscore     0.032943  6.750809e-13
# 251                                  ocf_lct_zscore     0.032933  6.852879e-13
# 324                                     tvol_zscore     0.032881  7.451423e-13
# 144                           accrual_sector_zscore     0.032793  8.573246e-13
# 237                                     ivol_zscore     0.032683  1.020586e-12
# 226                       int_totdebt_sector_zscore     0.032462  1.445550e-12
# 254                             opmbd_sector_zscore     0.032224  2.102995e-12
# 177                                cash_debt_zscore     0.031820  3.937941e-12
# 182                               cfm_sector_zscore     0.031489  6.551327e-12
# 218                               gpm_sector_zscore     0.030178  4.665784e-11
# 256                          pay_turn_sector_zscore     0.029419  1.403847e-10
# 227                              int_totdebt_zscore     0.028395  5.933899e-10
# 253                                    opmad_zscore     0.027499  2.014426e-09
# 192                           debt_at_sector_zscore     0.027406  2.281880e-09
# 249                                      npm_zscore     0.026995  3.937366e-09
# 77                   past_three_month_return_zscore     0.026821  4.952778e-09
# 285                                     ptpm_zscore     0.026553  7.028718e-09
# 255                                    opmbd_zscore     0.026475  7.775287e-09
# 296                         rect_turn_sector_zscore     0.026377  8.825729e-09
# 262                            pe_inc_sector_zscore     0.025809  1.821969e-08
# 76            past_three_month_return_sector_zscore     0.025402  3.037194e-08
# 167                                       bm_zscore     0.025148  4.161273e-08
# 224                          int_debt_sector_zscore     0.025127  4.273196e-08
# 183                                      cfm_zscore     0.025113  4.344572e-08
# 160                             b_mkt_sector_zscore     0.024946  5.331240e-08
# 260                            pe_exi_sector_zscore     0.024667  7.491185e-08
# 263                                   pe_inc_zscore     0.024336  1.115534e-07
# 161                                    b_mkt_zscore     0.023970  1.723113e-07
# 225                                 int_debt_zscore     0.023910  1.850214e-07
# 266                         pe_op_dil_sector_zscore     0.023720  2.311520e-07
# 261                                   pe_exi_zscore     0.023685  2.408720e-07
# 166                                bm_sector_zscore     0.023405  3.331577e-07
# 264                       pe_op_basic_sector_zscore     0.023398  3.356606e-07
# 221                                    GProf_zscore     0.023173  4.349171e-07
# 265                              pe_op_basic_zscore     0.023100  4.727069e-07
# 175                          cash_conversion_zscore     0.022936  5.694837e-07
# 267                                pe_op_dil_zscore     0.022871  6.123150e-07
# 314                        short_debt_sector_zscore     0.022836  6.376476e-07
# 176                         cash_debt_sector_zscore     0.022475  9.546312e-07
# 178                           cash_lt_sector_zscore     0.022175  1.329108e-06
# 81                    past_five_month_return_zscore     0.022153  1.361723e-06
# 259                                      pcf_zscore     0.022084  1.467416e-06
# 219                                      gpm_zscore     0.021832  1.929576e-06
# 258                               pcf_sector_zscore     0.021813  1.970058e-06
# 80             past_five_month_return_sector_zscore     0.021792  2.014803e-06
# 294                          rect_act_sector_zscore     0.020677  6.521743e-06
# 193                                  debt_at_zscore     0.020381  8.829440e-06
# 170                             CAPEI_sector_zscore     0.020253  1.004875e-05
# 230                            intcov_sector_zscore     0.019430  2.268558e-05
# 229                             intcov_ratio_zscore     0.018356  6.268353e-05
# 321                    totdebt_invcap_sector_zscore     0.018078  8.084926e-05
# 162                             b_smb_sector_zscore     0.017950  9.076541e-05
# 228                      intcov_ratio_sector_zscore     0.017946  9.110279e-05
# 220                             GProf_sector_zscore     0.017493  1.365695e-04
# 202                                  dltt_be_zscore     0.017417  1.460665e-04
# 171                                    CAPEI_zscore     0.017164  1.821605e-04
# 190                       debt_assets_sector_zscore     0.017065  1.985590e-04
# 231                                   intcov_zscore     0.017026  2.052266e-04
# 322                           totdebt_invcap_zscore     0.016675  2.770108e-04
# 295                                 rect_act_zscore     0.016157  4.267190e-04
# 156                           at_turn_sector_zscore     0.016092  4.501790e-04
# 155                                    alpha_zscore     0.015904  5.246730e-04
# 163                                    b_smb_zscore     0.015844  5.510952e-04
# 72              past_one_month_return_sector_zscore     0.015661  6.384797e-04
# 210                     equity_invcap_sector_zscore     0.015310  8.432769e-04
# 238                           lt_debt_sector_zscore     0.015024  1.053794e-03
# 194                      debt_capital_sector_zscore     0.014679  1.370865e-03
# 315                               short_debt_zscore     0.014653  1.399068e-03
# 154                             alpha_sector_zscore     0.014591  1.465706e-03
# 281                                       ps_zscore     0.014472  1.602165e-03
# 211                            equity_invcap_zscore     0.014277  1.852007e-03
# 280                                ps_sector_zscore     0.014257  1.879983e-03
# 174                   cash_conversion_sector_zscore     0.012867  5.023561e-03
# 213                                      evm_zscore     0.012587  6.061647e-03
# 222                           HOLDPCT_sector_zscore     0.012403  6.842337e-03
# 73                     past_one_month_return_zscore     0.012270  7.463843e-03
# 201                           dltt_be_sector_zscore     0.012169  7.971048e-03
# 306                       sale_equity_sector_zscore     0.011363  1.323135e-02
# 165                                    b_umd_zscore     0.010225  2.579051e-02
# 269                           PEG_1yrforward_zscore     0.010038  2.862608e-02
# 212                               evm_sector_zscore     0.009561  3.710858e-02
# 233                                 inv_turn_zscore     0.009537  3.758259e-02
# 74              past_two_month_return_sector_zscore     0.009283  4.296537e-02
# 282                               ptb_sector_zscore     0.009246  4.380717e-02
# 223                                  HOLDPCT_zscore     0.009134  4.643563e-02
# 232                          inv_turn_sector_zscore     0.009100  4.724278e-02
# 185                                curr_debt_zscore     0.008942  5.120861e-02
# 164                             b_umd_sector_zscore     0.008754  5.631935e-02
# 288                                R2_sector_zscore     0.008436  6.587546e-02
# 173                            capital_ratio_zscore     0.008409  6.675251e-02
# 179                                  cash_lt_zscore     0.007923  8.407683e-02
# 310                          sale_nwc_sector_zscore     0.007899  8.504660e-02
# 268                    PEG_1yrforward_sector_zscore     0.007754  9.091776e-02
# 75                     past_two_month_return_zscore     0.007557  9.942468e-02
# 180                        cash_ratio_sector_zscore     0.007436  1.049436e-01
# 184                         curr_debt_sector_zscore     0.007425  1.054910e-01
# 189                                 de_ratio_zscore     0.007146  1.192105e-01
# 196                       debt_ebitda_sector_zscore     0.007108  1.211749e-01
# 172                     capital_ratio_sector_zscore     0.006953  1.295097e-01
# 198                       debt_invcap_sector_zscore     0.006401  1.628212e-01
# 311                                 sale_nwc_zscore     0.006245  1.733256e-01
# 204                                      dpr_zscore     0.006234  1.741132e-01
# 157                                  at_turn_zscore     0.006202  1.762718e-01
# 199                              debt_invcap_zscore     0.006139  1.807273e-01
# 297                                rect_turn_zscore     0.005881  1.997797e-01
# 289                                       R2_zscore     0.005685  2.151906e-01
# 217                                  fcf_ocf_zscore     0.005420  2.373211e-01
# 168                            BUYPCT_sector_zscore     0.005204  2.565037e-01
# 209                                   efftax_zscore     0.005062  2.697754e-01
# 208                            efftax_sector_zscore     0.004954  2.800451e-01
# 257                                 pay_turn_zscore     0.004766  2.987825e-01
# 319                             STDEV_sector_zscore     0.004529  3.234512e-01
# 181                               cash_ratio_zscore     0.004354  3.424292e-01
# 283                                      ptb_zscore     0.004319  3.464081e-01
# 239                                  lt_debt_zscore     0.004309  3.474872e-01
# 243                                  MEANREC_zscore     0.004231  3.562838e-01
# 320                                    STDEV_zscore     0.004119  3.691795e-01
# 235                                 invt_act_zscore     0.003624  4.294150e-01
# 242                           MEANREC_sector_zscore     0.003577  4.354494e-01
# 159                                    b_hml_zscore     0.003310  4.704981e-01
# 158                             b_hml_sector_zscore     0.003294  4.725752e-01
# 187                               curr_ratio_zscore     0.003146  4.928124e-01
# 186                        curr_ratio_sector_zscore     0.002400  6.008066e-01
# 195                             debt_capital_zscore     0.002362  6.065617e-01
# 169                                   BUYPCT_zscore     0.002166  6.366963e-01
# 287                              quick_ratio_zscore     0.002061  6.531819e-01
# 214                             exret_sector_zscore     0.001741  7.042182e-01
# 234                          invt_act_sector_zscore     0.001711  7.091282e-01
# 215                                    exret_zscore     0.001172  7.983281e-01
# 188                          de_ratio_sector_zscore     0.001109  8.090052e-01
# 197                              debt_ebitda_zscore     0.000933  8.388258e-01
# 308                       sale_invcap_sector_zscore     0.000781  8.648311e-01
# 307                              sale_equity_zscore     0.000755  8.692148e-01
# 286                       quick_ratio_sector_zscore     0.000754  8.694824e-01
# 191                              debt_assets_zscore     0.000634  8.899970e-01
# 241                                 lt_ppent_zscore     0.000558  9.031489e-01
# 240                          lt_ppent_sector_zscore     0.000442  9.231815e-01
# 216                           fcf_ocf_sector_zscore     0.000330  9.426518e-01
# 309                              sale_invcap_zscore     0.000192  9.665336e-01
# 10           forward_six_month_return_sector_zscore          NaN  1.000000e+00
# 11                  forward_six_month_return_zscore          NaN  1.000000e+00
# 12         forward_seven_month_return_sector_zscore          NaN  1.000000e+00
# 13                forward_seven_month_return_zscore          NaN  1.000000e+00
# 14         forward_eight_month_return_sector_zscore          NaN  1.000000e+00
# 15                forward_eight_month_return_zscore          NaN  1.000000e+00
# 16          forward_nine_month_return_sector_zscore          NaN  1.000000e+00
# 17                 forward_nine_month_return_zscore          NaN  1.000000e+00
# 18           forward_ten_month_return_sector_zscore          NaN  1.000000e+00
# 19                  forward_ten_month_return_zscore          NaN  1.000000e+00
# 20        forward_eleven_month_return_sector_zscore          NaN  1.000000e+00
# 21               forward_eleven_month_return_zscore          NaN  1.000000e+00
# 22        forward_twelve_month_return_sector_zscore          NaN  1.000000e+00
# 23               forward_twelve_month_return_zscore          NaN  1.000000e+00
# 24      forward_thirteen_month_return_sector_zscore          NaN  1.000000e+00
# 25             forward_thirteen_month_return_zscore          NaN  1.000000e+00
# 26      forward_fourteen_month_return_sector_zscore          NaN  1.000000e+00
# 27             forward_fourteen_month_return_zscore          NaN  1.000000e+00
# 28       forward_fifteen_month_return_sector_zscore          NaN  1.000000e+00
# 29              forward_fifteen_month_return_zscore          NaN  1.000000e+00
# 30       forward_sixteen_month_return_sector_zscore          NaN  1.000000e+00
# 31              forward_sixteen_month_return_zscore          NaN  1.000000e+00
# 32     forward_seventeen_month_return_sector_zscore          NaN  1.000000e+00
# 33            forward_seventeen_month_return_zscore          NaN  1.000000e+00
# 34      forward_eighteen_month_return_sector_zscore          NaN  1.000000e+00
# 35             forward_eighteen_month_return_zscore          NaN  1.000000e+00
# 36      forward_nineteen_month_return_sector_zscore          NaN  1.000000e+00
# 37             forward_nineteen_month_return_zscore          NaN  1.000000e+00
# 38        forward_twenty_month_return_sector_zscore          NaN  1.000000e+00
# 39               forward_twenty_month_return_zscore          NaN  1.000000e+00
# 40     forward_twentyone_month_return_sector_zscore          NaN  1.000000e+00
# 41            forward_twentyone_month_return_zscore          NaN  1.000000e+00
# 42     forward_twentytwo_month_return_sector_zscore          NaN  1.000000e+00
# 43            forward_twentytwo_month_return_zscore          NaN  1.000000e+00
# 44   forward_twentythree_month_return_sector_zscore          NaN  1.000000e+00
# 45          forward_twentythree_month_return_zscore          NaN  1.000000e+00
# 46    forward_twentyfour_month_return_sector_zscore          NaN  1.000000e+00
# 47           forward_twentyfour_month_return_zscore          NaN  1.000000e+00
# 48    forward_twentyfive_month_return_sector_zscore          NaN  1.000000e+00
# 49           forward_twentyfive_month_return_zscore          NaN  1.000000e+00
# 50     forward_twentysix_month_return_sector_zscore          NaN  1.000000e+00
# 51            forward_twentysix_month_return_zscore          NaN  1.000000e+00
# 52   forward_twentyseven_month_return_sector_zscore          NaN  1.000000e+00
# 53          forward_twentyseven_month_return_zscore          NaN  1.000000e+00
# 54   forward_twentyeight_month_return_sector_zscore          NaN  1.000000e+00
# 55          forward_twentyeight_month_return_zscore          NaN  1.000000e+00
# 56    forward_twentynine_month_return_sector_zscore          NaN  1.000000e+00
# 57           forward_twentynine_month_return_zscore          NaN  1.000000e+00
# 58        forward_thirty_month_return_sector_zscore          NaN  1.000000e+00
# 59               forward_thirty_month_return_zscore          NaN  1.000000e+00
# 60     forward_thirtyone_month_return_sector_zscore          NaN  1.000000e+00
# 61            forward_thirtyone_month_return_zscore          NaN  1.000000e+00
# 62     forward_thirtytwo_month_return_sector_zscore          NaN  1.000000e+00
# 63            forward_thirtytwo_month_return_zscore          NaN  1.000000e+00
# 64   forward_thirtythree_month_return_sector_zscore          NaN  1.000000e+00
# 65          forward_thirtythree_month_return_zscore          NaN  1.000000e+00
# 66    forward_thirtyfour_month_return_sector_zscore          NaN  1.000000e+00
# 67           forward_thirtyfour_month_return_zscore          NaN  1.000000e+00
# 68    forward_thirtyfive_month_return_sector_zscore          NaN  1.000000e+00
# 69           forward_thirtyfive_month_return_zscore          NaN  1.000000e+00
# 70     forward_thirtysix_month_return_sector_zscore          NaN  1.000000e+00
# 71            forward_thirtysix_month_return_zscore          NaN  1.000000e+00
# 82              past_six_month_return_sector_zscore          NaN  1.000000e+00
# 83                     past_six_month_return_zscore          NaN  1.000000e+00
# 84            past_seven_month_return_sector_zscore          NaN  1.000000e+00
# 85                   past_seven_month_return_zscore          NaN  1.000000e+00
# 86            past_eight_month_return_sector_zscore          NaN  1.000000e+00
# 87                   past_eight_month_return_zscore          NaN  1.000000e+00
# 88             past_nine_month_return_sector_zscore          NaN  1.000000e+00
# 89                    past_nine_month_return_zscore          NaN  1.000000e+00
# 90              past_ten_month_return_sector_zscore          NaN  1.000000e+00
# 91                     past_ten_month_return_zscore          NaN  1.000000e+00
# 92           past_eleven_month_return_sector_zscore          NaN  1.000000e+00
# 93                  past_eleven_month_return_zscore          NaN  1.000000e+00
# 94           past_twelve_month_return_sector_zscore          NaN  1.000000e+00
# 95                  past_twelve_month_return_zscore          NaN  1.000000e+00
# 96         past_thirteen_month_return_sector_zscore          NaN  1.000000e+00
# 97                past_thirteen_month_return_zscore          NaN  1.000000e+00
# 98         past_fourteen_month_return_sector_zscore          NaN  1.000000e+00
# 99                past_fourteen_month_return_zscore          NaN  1.000000e+00
# 100         past_fifteen_month_return_sector_zscore          NaN  1.000000e+00
# 101                past_fifteen_month_return_zscore          NaN  1.000000e+00
# 102         past_sixteen_month_return_sector_zscore          NaN  1.000000e+00
# 103                past_sixteen_month_return_zscore          NaN  1.000000e+00
# 104       past_seventeen_month_return_sector_zscore          NaN  1.000000e+00
# 105              past_seventeen_month_return_zscore          NaN  1.000000e+00
# 106        past_eighteen_month_return_sector_zscore          NaN  1.000000e+00
# 107               past_eighteen_month_return_zscore          NaN  1.000000e+00
# 108        past_nineteen_month_return_sector_zscore          NaN  1.000000e+00
# 109               past_nineteen_month_return_zscore          NaN  1.000000e+00
# 110          past_twenty_month_return_sector_zscore          NaN  1.000000e+00
# 111                 past_twenty_month_return_zscore          NaN  1.000000e+00
# 112       past_twentyone_month_return_sector_zscore          NaN  1.000000e+00
# 113              past_twentyone_month_return_zscore          NaN  1.000000e+00
# 114       past_twentytwo_month_return_sector_zscore          NaN  1.000000e+00
# 115              past_twentytwo_month_return_zscore          NaN  1.000000e+00
# 116     past_twentythree_month_return_sector_zscore          NaN  1.000000e+00
# 117            past_twentythree_month_return_zscore          NaN  1.000000e+00
# 118      past_twentyfour_month_return_sector_zscore          NaN  1.000000e+00
# 119             past_twentyfour_month_return_zscore          NaN  1.000000e+00
# 120      past_twentyfive_month_return_sector_zscore          NaN  1.000000e+00
# 121             past_twentyfive_month_return_zscore          NaN  1.000000e+00
# 122       past_twentysix_month_return_sector_zscore          NaN  1.000000e+00
# 123              past_twentysix_month_return_zscore          NaN  1.000000e+00
# 124     past_twentyseven_month_return_sector_zscore          NaN  1.000000e+00
# 125            past_twentyseven_month_return_zscore          NaN  1.000000e+00
# 126     past_twentyeight_month_return_sector_zscore          NaN  1.000000e+00
# 127            past_twentyeight_month_return_zscore          NaN  1.000000e+00
# 128      past_twentynine_month_return_sector_zscore          NaN  1.000000e+00
# 129             past_twentynine_month_return_zscore          NaN  1.000000e+00
# 130          past_thirty_month_return_sector_zscore          NaN  1.000000e+00
# 131                 past_thirty_month_return_zscore          NaN  1.000000e+00
# 132       past_thirtyone_month_return_sector_zscore          NaN  1.000000e+00
# 133              past_thirtyone_month_return_zscore          NaN  1.000000e+00
# 134       past_thirtytwo_month_return_sector_zscore          NaN  1.000000e+00
# 135              past_thirtytwo_month_return_zscore          NaN  1.000000e+00
# 136     past_thirtythree_month_return_sector_zscore          NaN  1.000000e+00
# 137            past_thirtythree_month_return_zscore          NaN  1.000000e+00
# 138      past_thirtyfour_month_return_sector_zscore          NaN  1.000000e+00
# 139             past_thirtyfour_month_return_zscore          NaN  1.000000e+00
# 140      past_thirtyfive_month_return_sector_zscore          NaN  1.000000e+00
# 141             past_thirtyfive_month_return_zscore          NaN  1.000000e+00
# 142       past_thirtysix_month_return_sector_zscore          NaN  1.000000e+00
# 143              past_thirtysix_month_return_zscore          NaN  1.000000e+00
# 146                          adv_sale_sector_zscore          NaN  1.000000e+00
# 147                                 adv_sale_zscore          NaN  1.000000e+00
# 152                    aftret_invcapx_sector_zscore          NaN  1.000000e+00
# 200                                        DIVYIELD          NaN  1.000000e+00
# 203                               dpr_sector_zscore          NaN  1.000000e+00
# 205                                          dvpspm          NaN  1.000000e+00
# 206                                          dvpsxm          NaN  1.000000e+00
# 207                                          dvrate          NaN  1.000000e+00
# 244                            MEDREC_sector_zscore          NaN  1.000000e+00
# 245                                   MEDREC_zscore          NaN  1.000000e+00
# 246                                 n_sector_zscore          NaN  1.000000e+00
# 247                                        n_zscore          NaN  1.000000e+00
# 270                    PEG_ltgforward_sector_zscore          NaN  1.000000e+00
# 271                           PEG_ltgforward_zscore          NaN  1.000000e+00
# 272                      PEG_trailing_sector_zscore          NaN  1.000000e+00
# 273                             PEG_trailing_zscore          NaN  1.000000e+00
# 290                           rd_sale_sector_zscore          NaN  1.000000e+00
# 291                                  rd_sale_zscore          NaN  1.000000e+00
# 292                           recdown_sector_zscore          NaN  1.000000e+00
# 293                                  recdown_zscore          NaN  1.000000e+00
# 298                             recup_sector_zscore          NaN  1.000000e+00
# 299                                    recup_zscore          NaN  1.000000e+00
# 312                           SELLPCT_sector_zscore          NaN  1.000000e+00
# 313                                  SELLPCT_zscore          NaN  1.000000e+00
# 317                        staff_sale_sector_zscore          NaN  1.000000e+00
# 318                               staff_sale_zscore          NaN  1.000000e+00
