# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm
import seaborn as sns
from IPython.display import display
import datetime
import numpy as np
from statsmodels import robust
from sklearn import preprocessing
from sklearn.preprocessing import Imputer
from scipy import stats
from scipy.stats import zscore
from scipy.stats.stats import pearsonr
pd.options.mode.chained_assignment = None  # default='warn'

# %%
def null_ratio(df):
        null_count = df.isnull().sum()
        null_percent = 100 * df.isnull().sum()/len(df)
        null_table = pd.concat([null_count, null_percent], axis=1)
        null_table = null_table.rename(columns = {0 : 'Null Count', 1 : 'Null Percent'})
        return null_table.sort_values('Null Percent', ascending=0)

# %%
def return_all_rows(x):
    pd.set_option('display.max_rows', len(x))
    return x
    pd.reset_option('display.max_rows')
    
def return_all_columns(x):
    pd.set_option('display.max_columns', len(x))
    return x.head(5)
    pd.reset_option('display.max_columns')

# %%
def drop_dups(df):
    # list comprehension of the cols that end with '_y'
    y_drop = [x for x in df if x.endswith('_y')]
    df.drop(y_drop, axis=1, inplace=True)

# %%
def floatToString(inputValue):
    result = ('%.15f' % inputValue).rstrip('0').rstrip('.')
    return '0' if result == '-0' else result

# %%
def mad(array):
    # https://en.wikipedia.org/wiki/Median_absolute_deviation
    array = np.ma.array(array).compressed()
    median = np.nanmedian(array)
    mad = np.nanmedian(np.abs(array - median))
    return mad

# %%
def meanad(array):
    # https://en.wikipedia.org/wiki/Mean_absolute_deviation
    array = np.ma.array(array).compressed()
    median = np.nanmedian(array)
    mad = np.nanmean(np.abs(array - median))
    return mad

# %%
def modified_z(array):

    median = np.nanmedian(array)
    median_absolute_deviation = mad(array)

    if median_absolute_deviation == 0:
        mean_absolute_deviation = meanad(array)
        array = (array - median) / (mean_absolute_deviation * 1.253314)
        return array

    else:  
        array = (array - median) / (median_absolute_deviation * 1.486)
        return array

# %%
def clip_outliers(column):
    
    # Use try in case all null column
    try:
        floor = column.quantile(0.05)
        ceiling = column.quantile(0.95)
        column = column.clip(floor, ceiling)
        return column
    # If error, return as is
    except:
        return column

# %%
# df - Load
df = pd.read_csv('c:/users/shane/Desktop/W205_Final/sample_data/Financial_Ratios_Firm_Level.csv')

# %%
# Link Table - Load
link_table = pd.read_csv('c:/users/shane/Desktop/W205_Final/sample_data/CRSP_Compustat_Merged_Linking_Table.csv')

# %%
# Link Table - Clean - LINKENDDT
# Replace 'E' values with future date (current unique ID)
link_table['LINKENDDT'] = link_table['LINKENDDT'].str.replace('E','20200101').astype(int)

# %%
# Link Table - Clean - LPERMNO
# Convert PERMNO from int to object
link_table['LPERMNO'] = link_table['LPERMNO'].astype(object)

# %%
# Link Table - Clean - LINKDT & LINKENDDT
# Get start and end dates for link to determine identification during given time
link_table['LINKDT'] = pd.to_datetime(link_table['LINKDT'], format='%Y%m%d')
link_table['LINKENDDT'] = pd.to_datetime(link_table['LINKENDDT'], format='%Y%m%d')

# %%
# Merge - df & Link Table
# Merge financial ratio suite with link table to build more foreign keys
df = pd.merge(df, link_table, on='gvkey', how='left', suffixes=('', '_y'))
# Release Memory
del link_table

# %%
# df - Enrich - Time Features
# Convert to time
df['public_date'] = pd.to_datetime(df['public_date'], infer_datetime_format=True)
# Create year
df['year'] = df['public_date'].dt.year
# Create month
df['month'] = df['public_date'].dt.month
# Create year-month
df["year-month"] = df['public_date'].apply(lambda x: x.strftime('%Y-%m'))

# %%
# df - Enrich - Time-based Unique Identifiers
# Create Unique Identifier for links from other databases for specific date-time
df["GVKEY-year-month"] = df["gvkey"].map(str) + "-" + df["year-month"]
df["CUSIP-year-month"] = df["cusip"].map(str) + "-" + df["year-month"]
df["TIC-year-month"] = df["tic"].map(str) + "-" + df["year-month"]
df["PERMNO-year-month"] = df["LPERMNO"].map(str) + "-" + df["year-month"]

# %%
# df - Subset - Correct Unique ID's per public data
# Filter dataframe to rows of unique identifiers during correct link range
df = df[(df.public_date >= df.LINKDT) & (df.public_date <= df.LINKENDDT)]

# %%
# df - Clean - Remove duplicate Time-based Unique Identifiers
df = df.drop_duplicates(['GVKEY-year-month'], keep='last')

# %%
# CRSP - Load
# Load CRSP/Compustat Merged Database - Security Monthly from Wharton
CRSP_comp_merge = pd.read_csv('c:/users/shane/desktop/W205_Final/sample_data/CRSP_Compustat_Merged_Security_Monthly.csv')
# Out:
# C:\Users\shane\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (36,37,40,42,43,50,51,52,58,72,73,78,83) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# CRSP - Enrich - Time Features

# Convert to date-time
CRSP_comp_merge['datadate'] = pd.to_datetime(CRSP_comp_merge['datadate'], infer_datetime_format=True)
# Create year
CRSP_comp_merge['year'] = CRSP_comp_merge['datadate'].dt.year
# Create month
CRSP_comp_merge['month'] = CRSP_comp_merge['datadate'].dt.month
# Create year-month
CRSP_comp_merge["year-month"] = CRSP_comp_merge['datadate'].apply(lambda x: x.strftime('%Y-%m'))

# %%
# CRSP - Enrich - Time-based Unique Identifiers
# CRSP - Unique ID in time (GVKEY + time-month)
CRSP_comp_merge["GVKEY-year-month"] = CRSP_comp_merge["GVKEY"].map(str) + "-" + CRSP_comp_merge["year-month"]

# %%
# CRSP - Sort - Date and GVKEY
CRSP_comp_merge = CRSP_comp_merge.sort_values(by=['GVKEY','datadate'], ascending=[True,True])

# %%
# CRSP - Enrich - Forward (PRCCM -- Price - Close - Monthly) 1 – 36 months
CRSP_comp_merge['forward_one_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-1)
CRSP_comp_merge['forward_two_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-2)
CRSP_comp_merge['forward_three_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-3)
CRSP_comp_merge['forward_four_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-4)
CRSP_comp_merge['forward_five_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-5)
CRSP_comp_merge['forward_six_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-6)
CRSP_comp_merge['forward_seven_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-7)
CRSP_comp_merge['forward_eight_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-8)
CRSP_comp_merge['forward_nine_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-9)
CRSP_comp_merge['forward_ten_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-10)
CRSP_comp_merge['forward_eleven_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-11)
CRSP_comp_merge['forward_twelve_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-12)
CRSP_comp_merge['forward_thirteen_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-13)
CRSP_comp_merge['forward_fourteen_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-14)
CRSP_comp_merge['forward_fifteen_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-15)
CRSP_comp_merge['forward_sixteen_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-16)
CRSP_comp_merge['forward_seventeen_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-17)
CRSP_comp_merge['forward_eighteen_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-18)
CRSP_comp_merge['forward_nineteen_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-19)
CRSP_comp_merge['forward_twenty_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-20)
CRSP_comp_merge['forward_twentyone_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-21)
CRSP_comp_merge['forward_twentytwo_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-22)
CRSP_comp_merge['forward_twentythree_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-23)
CRSP_comp_merge['forward_twentyfour_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-24)
CRSP_comp_merge['forward_twentyfive_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-25)
CRSP_comp_merge['forward_twentysix_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-26)
CRSP_comp_merge['forward_twentyseven_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-27)
CRSP_comp_merge['forward_twentyeight_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-28)
CRSP_comp_merge['forward_twentynine_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-29)
CRSP_comp_merge['forward_thirty_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-30)
CRSP_comp_merge['forward_thirtyone_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-31)
CRSP_comp_merge['forward_thirtytwo_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-32)
CRSP_comp_merge['forward_thirtythree_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-33)
CRSP_comp_merge['forward_thirtyfour_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-34)
CRSP_comp_merge['forward_thirtyfive_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-35)
CRSP_comp_merge['forward_thirtysix_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(-36)

# %%
# CRSP - Enrich - Forward (AJEXM -- Cumulative Adjustment Factor - Ex Date -Monthly) 1 – 36 months
CRSP_comp_merge['forward_one_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-1)
CRSP_comp_merge['forward_two_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-2)
CRSP_comp_merge['forward_three_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-3)
CRSP_comp_merge['forward_four_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-4)
CRSP_comp_merge['forward_five_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-5)
CRSP_comp_merge['forward_six_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-6)
CRSP_comp_merge['forward_seven_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-7)
CRSP_comp_merge['forward_eight_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-8)
CRSP_comp_merge['forward_nine_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-9)
CRSP_comp_merge['forward_ten_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-10)
CRSP_comp_merge['forward_eleven_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-11)
CRSP_comp_merge['forward_twelve_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-12)
CRSP_comp_merge['forward_thirteen_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-13)
CRSP_comp_merge['forward_fourteen_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-14)
CRSP_comp_merge['forward_fifteen_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-15)
CRSP_comp_merge['forward_sixteen_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-16)
CRSP_comp_merge['forward_seventeen_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-17)
CRSP_comp_merge['forward_eighteen_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-18)
CRSP_comp_merge['forward_nineteen_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-19)
CRSP_comp_merge['forward_twenty_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-20)
CRSP_comp_merge['forward_twentyone_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-21)
CRSP_comp_merge['forward_twentytwo_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-22)
CRSP_comp_merge['forward_twentythree_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-23)
CRSP_comp_merge['forward_twentyfour_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-24)
CRSP_comp_merge['forward_twentyfive_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-25)
CRSP_comp_merge['forward_twentysix_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-26)
CRSP_comp_merge['forward_twentyseven_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-27)
CRSP_comp_merge['forward_twentyeight_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-28)
CRSP_comp_merge['forward_twentynine_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-29)
CRSP_comp_merge['forward_thirty_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-30)
CRSP_comp_merge['forward_thirtyone_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-31)
CRSP_comp_merge['forward_thirtytwo_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-32)
CRSP_comp_merge['forward_thirtythree_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-33)
CRSP_comp_merge['forward_thirtyfour_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-34)
CRSP_comp_merge['forward_thirtyfive_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-35)
CRSP_comp_merge['forward_thirtysix_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(-36)

# %%
# CRSP - Enrich - Forward (TRFM -- Monthly Total Return Factor) 1 – 36 months
CRSP_comp_merge['forward_one_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-1)
CRSP_comp_merge['forward_two_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-2)
CRSP_comp_merge['forward_three_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-3)
CRSP_comp_merge['forward_four_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-4)
CRSP_comp_merge['forward_five_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-5)
CRSP_comp_merge['forward_six_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-6)
CRSP_comp_merge['forward_seven_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-7)
CRSP_comp_merge['forward_eight_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-8)
CRSP_comp_merge['forward_nine_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-9)
CRSP_comp_merge['forward_ten_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-10)
CRSP_comp_merge['forward_eleven_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-11)
CRSP_comp_merge['forward_twelve_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-12)
CRSP_comp_merge['forward_thirteen_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-13)
CRSP_comp_merge['forward_fourteen_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-14)
CRSP_comp_merge['forward_fifteen_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-15)
CRSP_comp_merge['forward_sixteen_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-16)
CRSP_comp_merge['forward_seventeen_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-17)
CRSP_comp_merge['forward_eighteen_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-18)
CRSP_comp_merge['forward_nineteen_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-19)
CRSP_comp_merge['forward_twenty_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-20)
CRSP_comp_merge['forward_twentyone_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-21)
CRSP_comp_merge['forward_twentytwo_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-22)
CRSP_comp_merge['forward_twentythree_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-23)
CRSP_comp_merge['forward_twentyfour_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-24)
CRSP_comp_merge['forward_twentyfive_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-25)
CRSP_comp_merge['forward_twentysix_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-26)
CRSP_comp_merge['forward_twentyseven_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-27)
CRSP_comp_merge['forward_twentyeight_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-28)
CRSP_comp_merge['forward_twentynine_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-29)
CRSP_comp_merge['forward_thirty_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-30)
CRSP_comp_merge['forward_thirtyone_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-31)
CRSP_comp_merge['forward_thirtytwo_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-32)
CRSP_comp_merge['forward_thirtythree_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-33)
CRSP_comp_merge['forward_thirtyfour_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-34)
CRSP_comp_merge['forward_thirtyfive_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-35)
CRSP_comp_merge['forward_thirtysix_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(-36)

# %%
# CRSP - Enrich - Forward Return over number of months (1 - 36)
CRSP_comp_merge['forward_one_month_return'] = ((((CRSP_comp_merge['forward_one_month_prccm']/CRSP_comp_merge['forward_one_month_ajexm'])*CRSP_comp_merge['forward_one_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_two_month_return'] = ((((CRSP_comp_merge['forward_two_month_prccm']/CRSP_comp_merge['forward_two_month_ajexm'])*CRSP_comp_merge['forward_two_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_three_month_return'] = ((((CRSP_comp_merge['forward_three_month_prccm']/CRSP_comp_merge['forward_three_month_ajexm'])*CRSP_comp_merge['forward_three_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_four_month_return'] = ((((CRSP_comp_merge['forward_four_month_prccm']/CRSP_comp_merge['forward_four_month_ajexm'])*CRSP_comp_merge['forward_four_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_five_month_return'] = ((((CRSP_comp_merge['forward_five_month_prccm']/CRSP_comp_merge['forward_five_month_ajexm'])*CRSP_comp_merge['forward_five_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_six_month_return'] = ((((CRSP_comp_merge['forward_six_month_prccm']/CRSP_comp_merge['forward_six_month_ajexm'])*CRSP_comp_merge['forward_six_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_seven_month_return'] = ((((CRSP_comp_merge['forward_seven_month_prccm']/CRSP_comp_merge['forward_seven_month_ajexm'])*CRSP_comp_merge['forward_seven_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_eight_month_return'] = ((((CRSP_comp_merge['forward_eight_month_prccm']/CRSP_comp_merge['forward_eight_month_ajexm'])*CRSP_comp_merge['forward_eight_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_nine_month_return'] = ((((CRSP_comp_merge['forward_nine_month_prccm']/CRSP_comp_merge['forward_nine_month_ajexm'])*CRSP_comp_merge['forward_nine_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_ten_month_return'] = ((((CRSP_comp_merge['forward_ten_month_prccm']/CRSP_comp_merge['forward_ten_month_ajexm'])*CRSP_comp_merge['forward_ten_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_eleven_month_return'] = ((((CRSP_comp_merge['forward_eleven_month_prccm']/CRSP_comp_merge['forward_eleven_month_ajexm'])*CRSP_comp_merge['forward_eleven_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_twelve_month_return'] = ((((CRSP_comp_merge['forward_twelve_month_prccm']/CRSP_comp_merge['forward_twelve_month_ajexm'])*CRSP_comp_merge['forward_twelve_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_thirteen_month_return'] = ((((CRSP_comp_merge['forward_thirteen_month_prccm']/CRSP_comp_merge['forward_thirteen_month_ajexm'])*CRSP_comp_merge['forward_thirteen_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_fourteen_month_return'] = ((((CRSP_comp_merge['forward_fourteen_month_prccm']/CRSP_comp_merge['forward_fourteen_month_ajexm'])*CRSP_comp_merge['forward_fourteen_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_fifteen_month_return'] = ((((CRSP_comp_merge['forward_fifteen_month_prccm']/CRSP_comp_merge['forward_fifteen_month_ajexm'])*CRSP_comp_merge['forward_fifteen_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_sixteen_month_return'] = ((((CRSP_comp_merge['forward_sixteen_month_prccm']/CRSP_comp_merge['forward_sixteen_month_ajexm'])*CRSP_comp_merge['forward_sixteen_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_seventeen_month_return'] = ((((CRSP_comp_merge['forward_seventeen_month_prccm']/CRSP_comp_merge['forward_seventeen_month_ajexm'])*CRSP_comp_merge['forward_seventeen_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_eighteen_month_return'] = ((((CRSP_comp_merge['forward_eighteen_month_prccm']/CRSP_comp_merge['forward_eighteen_month_ajexm'])*CRSP_comp_merge['forward_eighteen_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_nineteen_month_return'] = ((((CRSP_comp_merge['forward_nineteen_month_prccm']/CRSP_comp_merge['forward_nineteen_month_ajexm'])*CRSP_comp_merge['forward_nineteen_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_twenty_month_return'] = ((((CRSP_comp_merge['forward_twenty_month_prccm']/CRSP_comp_merge['forward_twenty_month_ajexm'])*CRSP_comp_merge['forward_twenty_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_twentyone_month_return'] = ((((CRSP_comp_merge['forward_twentyone_month_prccm']/CRSP_comp_merge['forward_twentyone_month_ajexm'])*CRSP_comp_merge['forward_twentyone_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_twentytwo_month_return'] = ((((CRSP_comp_merge['forward_twentytwo_month_prccm']/CRSP_comp_merge['forward_twentytwo_month_ajexm'])*CRSP_comp_merge['forward_twentytwo_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_twentythree_month_return'] = ((((CRSP_comp_merge['forward_twentythree_month_prccm']/CRSP_comp_merge['forward_twentythree_month_ajexm'])*CRSP_comp_merge['forward_twentythree_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_twentyfour_month_return'] = ((((CRSP_comp_merge['forward_twentyfour_month_prccm']/CRSP_comp_merge['forward_twentyfour_month_ajexm'])*CRSP_comp_merge['forward_twentyfour_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_twentyfive_month_return'] = ((((CRSP_comp_merge['forward_twentyfive_month_prccm']/CRSP_comp_merge['forward_twentyfive_month_ajexm'])*CRSP_comp_merge['forward_twentyfive_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_twentysix_month_return'] = ((((CRSP_comp_merge['forward_twentysix_month_prccm']/CRSP_comp_merge['forward_twentysix_month_ajexm'])*CRSP_comp_merge['forward_twentysix_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_twentyseven_month_return'] = ((((CRSP_comp_merge['forward_twentyseven_month_prccm']/CRSP_comp_merge['forward_twentyseven_month_ajexm'])*CRSP_comp_merge['forward_twentyseven_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_twentyeight_month_return'] = ((((CRSP_comp_merge['forward_twentyeight_month_prccm']/CRSP_comp_merge['forward_twentyeight_month_ajexm'])*CRSP_comp_merge['forward_twentyeight_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_twentynine_month_return'] = ((((CRSP_comp_merge['forward_twentynine_month_prccm']/CRSP_comp_merge['forward_twentynine_month_ajexm'])*CRSP_comp_merge['forward_twentynine_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_thirty_month_return'] = ((((CRSP_comp_merge['forward_thirty_month_prccm']/CRSP_comp_merge['forward_thirty_month_ajexm'])*CRSP_comp_merge['forward_thirty_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_thirtyone_month_return'] = ((((CRSP_comp_merge['forward_thirtyone_month_prccm']/CRSP_comp_merge['forward_thirtyone_month_ajexm'])*CRSP_comp_merge['forward_thirtyone_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_thirtytwo_month_return'] = ((((CRSP_comp_merge['forward_thirtytwo_month_prccm']/CRSP_comp_merge['forward_thirtytwo_month_ajexm'])*CRSP_comp_merge['forward_thirtytwo_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_thirtythree_month_return'] = ((((CRSP_comp_merge['forward_thirtythree_month_prccm']/CRSP_comp_merge['forward_thirtythree_month_ajexm'])*CRSP_comp_merge['forward_thirtythree_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_thirtyfour_month_return'] = ((((CRSP_comp_merge['forward_thirtyfour_month_prccm']/CRSP_comp_merge['forward_thirtyfour_month_ajexm'])*CRSP_comp_merge['forward_thirtyfour_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_thirtyfive_month_return'] = ((((CRSP_comp_merge['forward_thirtyfive_month_prccm']/CRSP_comp_merge['forward_thirtyfive_month_ajexm'])*CRSP_comp_merge['forward_thirtyfive_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100
CRSP_comp_merge['forward_thirtysix_month_return'] = ((((CRSP_comp_merge['forward_thirtysix_month_prccm']/CRSP_comp_merge['forward_thirtysix_month_ajexm'])*CRSP_comp_merge['forward_thirtysix_month_trfm'])/((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['trfm']))-1)*100

# %%
# CRSP - Enrich - Past (PRCCM -- Price - Close - Monthly) 1 – 36 months
CRSP_comp_merge['past_one_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(1)
CRSP_comp_merge['past_two_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(2)
CRSP_comp_merge['past_three_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(3)
CRSP_comp_merge['past_four_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(4)
CRSP_comp_merge['past_five_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(5)
CRSP_comp_merge['past_six_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(6)
CRSP_comp_merge['past_seven_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(7)
CRSP_comp_merge['past_eight_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(8)
CRSP_comp_merge['past_nine_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(9)
CRSP_comp_merge['past_ten_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(10)
CRSP_comp_merge['past_eleven_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(11)
CRSP_comp_merge['past_twelve_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(12)
CRSP_comp_merge['past_thirteen_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(13)
CRSP_comp_merge['past_fourteen_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(14)
CRSP_comp_merge['past_fifteen_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(15)
CRSP_comp_merge['past_sixteen_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(16)
CRSP_comp_merge['past_seventeen_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(17)
CRSP_comp_merge['past_eighteen_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(18)
CRSP_comp_merge['past_nineteen_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(19)
CRSP_comp_merge['past_twenty_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(20)
CRSP_comp_merge['past_twentyone_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(21)
CRSP_comp_merge['past_twentytwo_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(22)
CRSP_comp_merge['past_twentythree_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(23)
CRSP_comp_merge['past_twentyfour_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(24)
CRSP_comp_merge['past_twentyfive_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(25)
CRSP_comp_merge['past_twentysix_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(26)
CRSP_comp_merge['past_twentyseven_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(27)
CRSP_comp_merge['past_twentyeight_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(28)
CRSP_comp_merge['past_twentynine_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(29)
CRSP_comp_merge['past_thirty_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(30)
CRSP_comp_merge['past_thirtyone_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(31)
CRSP_comp_merge['past_thirtytwo_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(32)
CRSP_comp_merge['past_thirtythree_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(33)
CRSP_comp_merge['past_thirtyfour_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(34)
CRSP_comp_merge['past_thirtyfive_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(35)
CRSP_comp_merge['past_thirtysix_month_prccm'] = CRSP_comp_merge.groupby('GVKEY')['prccm'].shift(36)

# %%
# CRSP - Enrich -  Past (AJEXM -- Cumulative Adjustment Factor - Ex Date -Monthly) 1 – 36 months
CRSP_comp_merge['past_one_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(1)
CRSP_comp_merge['past_two_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(2)
CRSP_comp_merge['past_three_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(3)
CRSP_comp_merge['past_four_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(4)
CRSP_comp_merge['past_five_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(5)
CRSP_comp_merge['past_six_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(6)
CRSP_comp_merge['past_seven_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(7)
CRSP_comp_merge['past_eight_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(8)
CRSP_comp_merge['past_nine_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(9)
CRSP_comp_merge['past_ten_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(10)
CRSP_comp_merge['past_eleven_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(11)
CRSP_comp_merge['past_twelve_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(12)
CRSP_comp_merge['past_thirteen_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(13)
CRSP_comp_merge['past_fourteen_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(14)
CRSP_comp_merge['past_fifteen_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(15)
CRSP_comp_merge['past_sixteen_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(16)
CRSP_comp_merge['past_seventeen_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(17)
CRSP_comp_merge['past_eighteen_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(18)
CRSP_comp_merge['past_nineteen_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(19)
CRSP_comp_merge['past_twenty_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(20)
CRSP_comp_merge['past_twentyone_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(21)
CRSP_comp_merge['past_twentytwo_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(22)
CRSP_comp_merge['past_twentythree_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(23)
CRSP_comp_merge['past_twentyfour_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(24)
CRSP_comp_merge['past_twentyfive_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(25)
CRSP_comp_merge['past_twentysix_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(26)
CRSP_comp_merge['past_twentyseven_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(27)
CRSP_comp_merge['past_twentyeight_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(28)
CRSP_comp_merge['past_twentynine_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(29)
CRSP_comp_merge['past_thirty_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(30)
CRSP_comp_merge['past_thirtyone_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(31)
CRSP_comp_merge['past_thirtytwo_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(32)
CRSP_comp_merge['past_thirtythree_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(33)
CRSP_comp_merge['past_thirtyfour_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(34)
CRSP_comp_merge['past_thirtyfive_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(35)
CRSP_comp_merge['past_thirtysix_month_ajexm'] = CRSP_comp_merge.groupby('GVKEY')['ajexm'].shift(36)

# %%
# CRSP - Enrich -  Past (TRFM -- Monthly Total Return Factor) 1 – 36 months
CRSP_comp_merge['past_one_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(1)
CRSP_comp_merge['past_two_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(2)
CRSP_comp_merge['past_three_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(3)
CRSP_comp_merge['past_four_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(4)
CRSP_comp_merge['past_five_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(5)
CRSP_comp_merge['past_six_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(6)
CRSP_comp_merge['past_seven_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(7)
CRSP_comp_merge['past_eight_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(8)
CRSP_comp_merge['past_nine_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(9)
CRSP_comp_merge['past_ten_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(10)
CRSP_comp_merge['past_eleven_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(11)
CRSP_comp_merge['past_twelve_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(12)
CRSP_comp_merge['past_thirteen_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(13)
CRSP_comp_merge['past_fourteen_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(14)
CRSP_comp_merge['past_fifteen_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(15)
CRSP_comp_merge['past_sixteen_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(16)
CRSP_comp_merge['past_seventeen_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(17)
CRSP_comp_merge['past_eighteen_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(18)
CRSP_comp_merge['past_nineteen_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(19)
CRSP_comp_merge['past_twenty_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(20)
CRSP_comp_merge['past_twentyone_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(21)
CRSP_comp_merge['past_twentytwo_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(22)
CRSP_comp_merge['past_twentythree_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(23)
CRSP_comp_merge['past_twentyfour_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(24)
CRSP_comp_merge['past_twentyfive_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(25)
CRSP_comp_merge['past_twentysix_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(26)
CRSP_comp_merge['past_twentyseven_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(27)
CRSP_comp_merge['past_twentyeight_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(28)
CRSP_comp_merge['past_twentynine_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(29)
CRSP_comp_merge['past_thirty_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(30)
CRSP_comp_merge['past_thirtyone_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(31)
CRSP_comp_merge['past_thirtytwo_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(32)
CRSP_comp_merge['past_thirtythree_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(33)
CRSP_comp_merge['past_thirtyfour_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(34)
CRSP_comp_merge['past_thirtyfive_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(35)
CRSP_comp_merge['past_thirtysix_month_trfm'] = CRSP_comp_merge.groupby('GVKEY')['trfm'].shift(36)

# %%
# CRSP - Enrich -  Past Return over number of months (1 - 36)
CRSP_comp_merge['past_one_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_one_month_trfm'])/((CRSP_comp_merge['past_one_month_prccm']/CRSP_comp_merge['past_one_month_ajexm'])*CRSP_comp_merge['past_one_month_trfm']))-1)*100
CRSP_comp_merge['past_two_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_two_month_trfm'])/((CRSP_comp_merge['past_two_month_prccm']/CRSP_comp_merge['past_two_month_ajexm'])*CRSP_comp_merge['past_two_month_trfm']))-1)*100
CRSP_comp_merge['past_three_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_three_month_trfm'])/((CRSP_comp_merge['past_three_month_prccm']/CRSP_comp_merge['past_three_month_ajexm'])*CRSP_comp_merge['past_three_month_trfm']))-1)*100
CRSP_comp_merge['past_four_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_four_month_trfm'])/((CRSP_comp_merge['past_four_month_prccm']/CRSP_comp_merge['past_four_month_ajexm'])*CRSP_comp_merge['past_four_month_trfm']))-1)*100
CRSP_comp_merge['past_five_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_five_month_trfm'])/((CRSP_comp_merge['past_five_month_prccm']/CRSP_comp_merge['past_five_month_ajexm'])*CRSP_comp_merge['past_five_month_trfm']))-1)*100
CRSP_comp_merge['past_six_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_six_month_trfm'])/((CRSP_comp_merge['past_six_month_prccm']/CRSP_comp_merge['past_six_month_ajexm'])*CRSP_comp_merge['past_six_month_trfm']))-1)*100
CRSP_comp_merge['past_seven_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_seven_month_trfm'])/((CRSP_comp_merge['past_seven_month_prccm']/CRSP_comp_merge['past_seven_month_ajexm'])*CRSP_comp_merge['past_seven_month_trfm']))-1)*100
CRSP_comp_merge['past_eight_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_eight_month_trfm'])/((CRSP_comp_merge['past_eight_month_prccm']/CRSP_comp_merge['past_eight_month_ajexm'])*CRSP_comp_merge['past_eight_month_trfm']))-1)*100
CRSP_comp_merge['past_nine_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_nine_month_trfm'])/((CRSP_comp_merge['past_nine_month_prccm']/CRSP_comp_merge['past_nine_month_ajexm'])*CRSP_comp_merge['past_nine_month_trfm']))-1)*100
CRSP_comp_merge['past_ten_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_ten_month_trfm'])/((CRSP_comp_merge['past_ten_month_prccm']/CRSP_comp_merge['past_ten_month_ajexm'])*CRSP_comp_merge['past_ten_month_trfm']))-1)*100
CRSP_comp_merge['past_eleven_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_eleven_month_trfm'])/((CRSP_comp_merge['past_eleven_month_prccm']/CRSP_comp_merge['past_eleven_month_ajexm'])*CRSP_comp_merge['past_eleven_month_trfm']))-1)*100
CRSP_comp_merge['past_twelve_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_twelve_month_trfm'])/((CRSP_comp_merge['past_twelve_month_prccm']/CRSP_comp_merge['past_twelve_month_ajexm'])*CRSP_comp_merge['past_twelve_month_trfm']))-1)*100
CRSP_comp_merge['past_thirteen_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_thirteen_month_trfm'])/((CRSP_comp_merge['past_thirteen_month_prccm']/CRSP_comp_merge['past_thirteen_month_ajexm'])*CRSP_comp_merge['past_thirteen_month_trfm']))-1)*100
CRSP_comp_merge['past_fourteen_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_fourteen_month_trfm'])/((CRSP_comp_merge['past_fourteen_month_prccm']/CRSP_comp_merge['past_fourteen_month_ajexm'])*CRSP_comp_merge['past_fourteen_month_trfm']))-1)*100
CRSP_comp_merge['past_fifteen_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_fifteen_month_trfm'])/((CRSP_comp_merge['past_fifteen_month_prccm']/CRSP_comp_merge['past_fifteen_month_ajexm'])*CRSP_comp_merge['past_fifteen_month_trfm']))-1)*100
CRSP_comp_merge['past_sixteen_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_sixteen_month_trfm'])/((CRSP_comp_merge['past_sixteen_month_prccm']/CRSP_comp_merge['past_sixteen_month_ajexm'])*CRSP_comp_merge['past_sixteen_month_trfm']))-1)*100
CRSP_comp_merge['past_seventeen_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_seventeen_month_trfm'])/((CRSP_comp_merge['past_seventeen_month_prccm']/CRSP_comp_merge['past_seventeen_month_ajexm'])*CRSP_comp_merge['past_seventeen_month_trfm']))-1)*100
CRSP_comp_merge['past_eighteen_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_eighteen_month_trfm'])/((CRSP_comp_merge['past_eighteen_month_prccm']/CRSP_comp_merge['past_eighteen_month_ajexm'])*CRSP_comp_merge['past_eighteen_month_trfm']))-1)*100
CRSP_comp_merge['past_nineteen_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_nineteen_month_trfm'])/((CRSP_comp_merge['past_nineteen_month_prccm']/CRSP_comp_merge['past_nineteen_month_ajexm'])*CRSP_comp_merge['past_nineteen_month_trfm']))-1)*100
CRSP_comp_merge['past_twenty_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_twenty_month_trfm'])/((CRSP_comp_merge['past_twenty_month_prccm']/CRSP_comp_merge['past_twenty_month_ajexm'])*CRSP_comp_merge['past_twenty_month_trfm']))-1)*100
CRSP_comp_merge['past_twentyone_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_twentyone_month_trfm'])/((CRSP_comp_merge['past_twentyone_month_prccm']/CRSP_comp_merge['past_twentyone_month_ajexm'])*CRSP_comp_merge['past_twentyone_month_trfm']))-1)*100
CRSP_comp_merge['past_twentytwo_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_twentytwo_month_trfm'])/((CRSP_comp_merge['past_twentytwo_month_prccm']/CRSP_comp_merge['past_twentytwo_month_ajexm'])*CRSP_comp_merge['past_twentytwo_month_trfm']))-1)*100
CRSP_comp_merge['past_twentythree_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_twentythree_month_trfm'])/((CRSP_comp_merge['past_twentythree_month_prccm']/CRSP_comp_merge['past_twentythree_month_ajexm'])*CRSP_comp_merge['past_twentythree_month_trfm']))-1)*100
CRSP_comp_merge['past_twentyfour_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_twentyfour_month_trfm'])/((CRSP_comp_merge['past_twentyfour_month_prccm']/CRSP_comp_merge['past_twentyfour_month_ajexm'])*CRSP_comp_merge['past_twentyfour_month_trfm']))-1)*100
CRSP_comp_merge['past_twentyfive_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_twentyfive_month_trfm'])/((CRSP_comp_merge['past_twentyfive_month_prccm']/CRSP_comp_merge['past_twentyfive_month_ajexm'])*CRSP_comp_merge['past_twentyfive_month_trfm']))-1)*100
CRSP_comp_merge['past_twentysix_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_twentysix_month_trfm'])/((CRSP_comp_merge['past_twentysix_month_prccm']/CRSP_comp_merge['past_twentysix_month_ajexm'])*CRSP_comp_merge['past_twentysix_month_trfm']))-1)*100
CRSP_comp_merge['past_twentyseven_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_twentyseven_month_trfm'])/((CRSP_comp_merge['past_twentyseven_month_prccm']/CRSP_comp_merge['past_twentyseven_month_ajexm'])*CRSP_comp_merge['past_twentyseven_month_trfm']))-1)*100
CRSP_comp_merge['past_twentyeight_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_twentyeight_month_trfm'])/((CRSP_comp_merge['past_twentyeight_month_prccm']/CRSP_comp_merge['past_twentyeight_month_ajexm'])*CRSP_comp_merge['past_twentyeight_month_trfm']))-1)*100
CRSP_comp_merge['past_twentynine_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_twentynine_month_trfm'])/((CRSP_comp_merge['past_twentynine_month_prccm']/CRSP_comp_merge['past_twentynine_month_ajexm'])*CRSP_comp_merge['past_twentynine_month_trfm']))-1)*100
CRSP_comp_merge['past_thirty_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_thirty_month_trfm'])/((CRSP_comp_merge['past_thirty_month_prccm']/CRSP_comp_merge['past_thirty_month_ajexm'])*CRSP_comp_merge['past_thirty_month_trfm']))-1)*100
CRSP_comp_merge['past_thirtyone_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_thirtyone_month_trfm'])/((CRSP_comp_merge['past_thirtyone_month_prccm']/CRSP_comp_merge['past_thirtyone_month_ajexm'])*CRSP_comp_merge['past_thirtyone_month_trfm']))-1)*100
CRSP_comp_merge['past_thirtytwo_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_thirtytwo_month_trfm'])/((CRSP_comp_merge['past_thirtytwo_month_prccm']/CRSP_comp_merge['past_thirtytwo_month_ajexm'])*CRSP_comp_merge['past_thirtytwo_month_trfm']))-1)*100
CRSP_comp_merge['past_thirtythree_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_thirtythree_month_trfm'])/((CRSP_comp_merge['past_thirtythree_month_prccm']/CRSP_comp_merge['past_thirtythree_month_ajexm'])*CRSP_comp_merge['past_thirtythree_month_trfm']))-1)*100
CRSP_comp_merge['past_thirtyfour_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_thirtyfour_month_trfm'])/((CRSP_comp_merge['past_thirtyfour_month_prccm']/CRSP_comp_merge['past_thirtyfour_month_ajexm'])*CRSP_comp_merge['past_thirtyfour_month_trfm']))-1)*100
CRSP_comp_merge['past_thirtyfive_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_thirtyfive_month_trfm'])/((CRSP_comp_merge['past_thirtyfive_month_prccm']/CRSP_comp_merge['past_thirtyfive_month_ajexm'])*CRSP_comp_merge['past_thirtyfive_month_trfm']))-1)*100
CRSP_comp_merge['past_thirtysix_month_return'] = ((((CRSP_comp_merge['prccm']/CRSP_comp_merge['ajexm'])*CRSP_comp_merge['past_thirtysix_month_trfm'])/((CRSP_comp_merge['past_thirtysix_month_prccm']/CRSP_comp_merge['past_thirtysix_month_ajexm'])*CRSP_comp_merge['past_thirtysix_month_trfm']))-1)*100

# %%
# CRSP_comp_merge - Clean - Remove duplicate Time-based Unique Identifiers
CRSP_comp_merge = CRSP_comp_merge.drop_duplicates(['GVKEY-year-month'], keep='last')

# %%
# Merge - df & CRSP
df = pd.merge(df, CRSP_comp_merge, on='GVKEY-year-month', how='left', suffixes=('', '_y'))
del CRSP_comp_merge

# %%
# df - Clean - Remove duplicate features
drop_dups(df)

# %%
# Recommendations - Load
# Summary Statistics (Consensus Recommendations) from Wharton
recommendations = pd.read_csv('c:/users/shane/Desktop/W205_Final/sample_data/Recommendations_Summary_Statistics.csv', low_memory=False)

# %%
# Recommendations - Enrich - Time Features
recommendations['STATPERS'] = pd.to_datetime(recommendations['STATPERS'], infer_datetime_format=True)
# Create year
recommendations['year'] = recommendations['STATPERS'].dt.year
# Create month
recommendations['month'] = recommendations['STATPERS'].dt.month
# Creat year-month
recommendations["year-month"] = recommendations['STATPERS'].apply(lambda x: x.strftime('%Y-%m'))

# %%
# Recommendations - Enrich - Analyst Change
recommendations["recup"] = recommendations["NUMUP"] / recommendations["NUMREC"] 
recommendations["recdown"] = recommendations["NUMDOWN"] / recommendations["NUMREC"]

# %%
# Recommendations - Clean - Strip @ in Ticker
recommendations['TICKER'] = recommendations['TICKER'].replace('@','',regex=True).astype('object')

# %%
# Recommendations - Enrich - Time-based Unique Identifiers
recommendations["TIC-year-month"] = recommendations["TICKER"].map(str) + "-" + recommendations["year-month"]

# %%
# recommendations - Clean - Remove duplicate Time-based Unique Identifiers
recommendations = recommendations.drop_duplicates(['TIC-year-month'], keep='last')

# %%
# Merge - df & Recommendations
df = pd.merge(df, recommendations, on='TIC-year-month', how='left', suffixes=('', '_y'))
# Release Memory
del recommendations

# %%
# df - Clean - Remove duplicate features
drop_dups(df)

# %%
# Beta Suite - Load
beta_suite = pd.read_csv('c:/users/shane/Desktop/W205_Final/sample_data/Beta_Suite.csv')

# %%
# Beta Suite - Enrich - Time Features
# Convert to data-time
beta_suite['DATE'] = pd.to_datetime(beta_suite['DATE'], infer_datetime_format=True)
# Create year
beta_suite['year'] = beta_suite['DATE'].dt.year
# Create month
beta_suite['month'] = beta_suite['DATE'].dt.month
# Create year-month
beta_suite["year-month"] = beta_suite['DATE'].apply(lambda x: x.strftime('%Y-%m'))

# %%
# Beta Suite - Enrich - Time-based Unique Identifiers
beta_suite["PERMNO-year-month"] = beta_suite["PERMNO"].map(str) + "-" + beta_suite["year-month"]

# %%
# Merge - df & Beta Suite
df = pd.merge(df, beta_suite, on='PERMNO-year-month', how='left', suffixes=('', '_y'))
# Release Memory
del beta_suite

# %%
# df - Clean - Remove duplicate features
drop_dups(df)

# %%
# Sector - Enrich
# https://en.wikipedia.org/wiki/Global_Industry_Classification_Standard

sector = pd.DataFrame()

sector['GSECTOR'] = [10.0, 
                       15.0, 
                       20.0, 
                       25.0, 
                       30.0, 
                       35.0, 
                       40.0, 
                       45.0, 
                       50.0, 
                       55.0, 
                       60.0]

sector['sector'] = ['Energy', 
                        'Materials', 
                        'Industrials', 
                        'Consumer Discretionary', 
                        'Consumer Staples', 
                        'Health Care', 
                        'Financials', 
                        'Information Technology', 
                        'Telecommunication Services', 
                        'Utilities', 
                        'Real Estate']

# %%
# Merge - df & Sector
df = pd.merge(df, sector, on='GSECTOR', how='left', suffixes=('', '_y'))
# Release Memory
del sector

# %%
# df - Clean - Remove duplicate features
drop_dups(df)

# %%
# df - Enrich - Month Features
df['january'] = np.where(df['month'] == 1, int(1), int(0))
df['february'] = np.where(df['month'] == 2, int(1), int(0))
df['march'] = np.where(df['month'] == 3, int(1), int(0))
df['april'] = np.where(df['month'] == 4, int(1), int(0))
df['may'] = np.where(df['month'] == 5, int(1), int(0))
df['june'] = np.where(df['month'] == 6, int(1), int(0))
df['july'] = np.where(df['month'] == 7, int(1), int(0))
df['august'] = np.where(df['month'] == 8, int(1), int(0))
df['september'] = np.where(df['month'] == 9, int(1), int(0))
df['october'] = np.where(df['month'] == 10, int(1), int(0))
df['november'] = np.where(df['month'] == 11, int(1), int(0))
df['december'] = np.where(df['month'] == 12, int(1), int(0))

# %%
# df - Subset - Relevant features with adequate data

df = df[[
        'GVKEY',
        'GVKEY-year-month',
        'sector',
        'year-month', 
        'forward_one_month_return', 
        'forward_two_month_return', 
        'forward_three_month_return', 
        'forward_four_month_return', 
        'forward_five_month_return', 
        'forward_six_month_return', 
        'forward_seven_month_return', 
        'forward_eight_month_return', 
        'forward_nine_month_return', 
        'forward_ten_month_return', 
        'forward_eleven_month_return', 
        'forward_twelve_month_return', 
        'forward_thirteen_month_return', 
        'forward_fourteen_month_return', 
        'forward_fifteen_month_return', 
        'forward_sixteen_month_return', 
        'forward_seventeen_month_return', 
        'forward_eighteen_month_return', 
        'forward_nineteen_month_return', 
        'forward_twenty_month_return', 
        'forward_twentyone_month_return', 
        'forward_twentytwo_month_return', 
        'forward_twentythree_month_return', 
        'forward_twentyfour_month_return', 
        'forward_twentyfive_month_return', 
        'forward_twentysix_month_return', 
        'forward_twentyseven_month_return', 
        'forward_twentyeight_month_return', 
        'forward_twentynine_month_return', 
        'forward_thirty_month_return', 
        'forward_thirtyone_month_return', 
        'forward_thirtytwo_month_return', 
        'forward_thirtythree_month_return', 
        'forward_thirtyfour_month_return', 
        'forward_thirtyfive_month_return', 
        'forward_thirtysix_month_return', 
        'past_one_month_return', 
        'past_two_month_return', 
        'past_three_month_return', 
        'past_four_month_return', 
        'past_five_month_return', 
        'past_six_month_return', 
        'past_seven_month_return', 
        'past_eight_month_return', 
        'past_nine_month_return', 
        'past_ten_month_return', 
        'past_eleven_month_return', 
        'past_twelve_month_return', 
        'past_thirteen_month_return', 
        'past_fourteen_month_return', 
        'past_fifteen_month_return', 
        'past_sixteen_month_return', 
        'past_seventeen_month_return', 
        'past_eighteen_month_return', 
        'past_nineteen_month_return', 
        'past_twenty_month_return', 
        'past_twentyone_month_return', 
        'past_twentytwo_month_return', 
        'past_twentythree_month_return', 
        'past_twentyfour_month_return', 
        'past_twentyfive_month_return', 
        'past_twentysix_month_return', 
        'past_twentyseven_month_return', 
        'past_twentyeight_month_return', 
        'past_twentynine_month_return', 
        'past_thirty_month_return', 
        'past_thirtyone_month_return', 
        'past_thirtytwo_month_return', 
        'past_thirtythree_month_return', 
        'past_thirtyfour_month_return', 
        'past_thirtyfive_month_return', 
        'past_thirtysix_month_return', 
        'accrual', 
        'adv_sale', 
        'aftret_eq', 
        'aftret_equity', 
        'aftret_invcapx', 
        'at_turn', 
        'bm', 
        'CAPEI', 
        'capital_ratio', 
        'cash_conversion', 
        'cash_debt', 
        'cash_lt', 
        'cash_ratio', 
        'cfm', 
        'curr_debt', 
        'curr_ratio', 
        'de_ratio', 
        'debt_assets', 
        'debt_at', 
        'debt_capital', 
        'debt_ebitda', 
        'debt_invcap', 
        'DIVYIELD', 
        'dltt_be', 
        'dpr', 
        'efftax', 
        'equity_invcap', 
        'evm', 
        'fcf_ocf', 
        'gpm', 
        'GProf', 
        'int_debt', 
        'int_totdebt', 
        'intcov', 
        'intcov_ratio', 
        'inv_turn', 
        'invt_act', 
        'lt_debt', 
        'lt_ppent', 
        'npm', 
        'ocf_lct', 
        'opmad', 
        'opmbd', 
        'pay_turn', 
        'pcf', 
        'pe_exi', 
        'pe_inc', 
        'pe_op_basic', 
        'pe_op_dil', 
        'PEG_1yrforward', 
        'PEG_ltgforward', 
        'PEG_trailing', 
        'pretret_earnat', 
        'pretret_noa', 
        'profit_lct', 
        'ps', 
        'ptb', 
        'ptpm', 
        'quick_ratio', 
        'rd_sale', 
        'rect_act', 
        'rect_turn', 
        'roa', 
        'roce', 
        'roe', 
        'sale_equity', 
        'sale_invcap', 
        'sale_nwc', 
        'short_debt', 
        'staff_sale', 
        'totdebt_invcap', 
        'dvpspm', 
        'dvpsxm', 
        'dvrate', 
        'spcsrc', 
        'alpha', 
        'b_hml', 
        'b_mkt', 
        'b_smb', 
        'b_umd', 
        'exret', 
        'ivol', 
        'n', 
        'R2', 
        'tvol', 
        'BUYPCT', 
        'HOLDPCT',
        'SELLPCT', 
        'MEANREC', 
        'MEDREC',
        'recup', 
        'recdown',
        'STDEV', 
        'january', 
        'february', 
        'march', 
        'april', 
        'may', 
        'june', 
        'july', 
        'august', 
        'september', 
        'october', 
        'november', 
        'december'
        ]]

# %%
# df - Clean - Dividends - DIVYIELD, dvpspm, dvpsxm, & dvrate
# # Companies who do not report dividends are unlikely to have paid dividends, the majority of companies do not pay as well.
df['DIVYIELD'] = df['DIVYIELD'].replace('%','',regex=True).astype('float')/100
df['DIVYIELD'] = pd.to_numeric(df['DIVYIELD'])
df['DIVYIELD'] = df['DIVYIELD'].fillna(0)

df['dvpspm'] = df['dvpspm'].fillna(0)
df['dvpspm'] = pd.to_numeric(df['dvpspm'])
df['dvpsxm'] = df['dvpsxm'].fillna(0)
df['dvpsxm'] = pd.to_numeric(df['dvpsxm'])
df['dvrate'] = df['dvrate'].fillna(0)
df['dvrate'] = pd.to_numeric(df['dvrate'])

# %%
# df - Clean - Ratings - SPCSRC
# Per S&P Quality Rankings information; 
# A+ - 98-100 percentile (Highest, 2%)
# A - 92-98 percentile (High, 6%) 
# A- - 86-92 percentile (Above Average, 6%) 
# B+ - 70-86 percentile (Average, 16%) 
# B - 51-70 percentile (Below Average, 19%)
# B- - 25-51 percentile (Lower, 26%)
# C - 1-25 percentile (Lowest, 24%)
# D - 0-1 percentile (In Reorganization, 1%) 

# Using the average of percentile ranges above

df['spcsrc'] = df['spcsrc'].map({
                                'A+': 99,
                                'A': 95,
                                'A-': 89,
                                'B+': 79.5,
                                'B': 60.5,
                                'B-': 38,
                                'C': 13,
                                'D': 0.5,
                                })

df['spcsrc'] = pd.to_numeric(df['spcsrc'])

# %%
# df - Clean - Beta Suite - exret, ivol, R2, tvol

df['exret'] = df['exret'].replace('%','',regex=True).astype('float')/100
df['exret'] = pd.to_numeric(df['exret'])

df['ivol'] = df['ivol'].replace('%','',regex=True).astype('float')/100
df['ivol'] = pd.to_numeric(df['ivol'])

df['R2'] = df['R2'].replace('%','',regex=True).astype('float')/100
df['R2'] = pd.to_numeric(df['R2'])

df['tvol'] = df['tvol'].replace('%','',regex=True).astype('float')/100
df['tvol'] = pd.to_numeric(df['tvol'])

# %%
# df - Sort - Date and GVKEY
df = df.sort_values(by=['year-month','GVKEY'], ascending=[True,True])

# %%
# df - Clean - All - Fill N/A's
df = df.groupby(['GVKEY'], as_index=False).apply(lambda group: group.ffill())
df = df.groupby(['GVKEY'], as_index=False).apply(lambda group: group.bfill())
df = df.groupby(['sector'], as_index=False).apply(lambda group: group.ffill())
df = df.groupby(['sector'], as_index=False).apply(lambda group: group.bfill())
df = df.fillna(method='ffill')
df = df.fillna(method='bfill')

# %%
# df - Clean - Remove duplicate Time-based Unique Identifiers
df["GVKEY-year-month"] = df["GVKEY"].map(str) + "-" + df["year-month"]
df = df.drop_duplicates(['GVKEY-year-month'], keep='last')

# %%
# df - Clean - Clip outliers
# Trims back 5.91% of data

# Clip when grouped by sector (3%)

# Dependent Variable

df['forward_one_month_return'] = df.groupby(['year-month', 'sector'])[['forward_one_month_return']].apply(clip_outliers)
df['forward_two_month_return'] = df.groupby(['year-month', 'sector'])[['forward_two_month_return']].apply(clip_outliers)
df['forward_three_month_return'] = df.groupby(['year-month', 'sector'])[['forward_three_month_return']].apply(clip_outliers)
df['forward_four_month_return'] = df.groupby(['year-month', 'sector'])[['forward_four_month_return']].apply(clip_outliers)
df['forward_five_month_return'] = df.groupby(['year-month', 'sector'])[['forward_five_month_return']].apply(clip_outliers)
df['forward_six_month_return'] = df.groupby(['year-month', 'sector'])[['forward_six_month_return']].apply(clip_outliers)
df['forward_seven_month_return'] = df.groupby(['year-month', 'sector'])[['forward_seven_month_return']].apply(clip_outliers)
df['forward_eight_month_return'] = df.groupby(['year-month', 'sector'])[['forward_eight_month_return']].apply(clip_outliers)
df['forward_nine_month_return'] = df.groupby(['year-month', 'sector'])[['forward_nine_month_return']].apply(clip_outliers)
df['forward_ten_month_return'] = df.groupby(['year-month', 'sector'])[['forward_ten_month_return']].apply(clip_outliers)
df['forward_eleven_month_return'] = df.groupby(['year-month', 'sector'])[['forward_eleven_month_return']].apply(clip_outliers)
df['forward_twelve_month_return'] = df.groupby(['year-month', 'sector'])[['forward_twelve_month_return']].apply(clip_outliers)
df['forward_thirteen_month_return'] = df.groupby(['year-month', 'sector'])[['forward_thirteen_month_return']].apply(clip_outliers)
df['forward_fourteen_month_return'] = df.groupby(['year-month', 'sector'])[['forward_fourteen_month_return']].apply(clip_outliers)
df['forward_fifteen_month_return'] = df.groupby(['year-month', 'sector'])[['forward_fifteen_month_return']].apply(clip_outliers)
df['forward_sixteen_month_return'] = df.groupby(['year-month', 'sector'])[['forward_sixteen_month_return']].apply(clip_outliers)
df['forward_seventeen_month_return'] = df.groupby(['year-month', 'sector'])[['forward_seventeen_month_return']].apply(clip_outliers)
df['forward_eighteen_month_return'] = df.groupby(['year-month', 'sector'])[['forward_eighteen_month_return']].apply(clip_outliers)
df['forward_nineteen_month_return'] = df.groupby(['year-month', 'sector'])[['forward_nineteen_month_return']].apply(clip_outliers)
df['forward_twenty_month_return'] = df.groupby(['year-month', 'sector'])[['forward_twenty_month_return']].apply(clip_outliers)
df['forward_twentyone_month_return'] = df.groupby(['year-month', 'sector'])[['forward_twentyone_month_return']].apply(clip_outliers)
df['forward_twentytwo_month_return'] = df.groupby(['year-month', 'sector'])[['forward_twentytwo_month_return']].apply(clip_outliers)
df['forward_twentythree_month_return'] = df.groupby(['year-month', 'sector'])[['forward_twentythree_month_return']].apply(clip_outliers)
df['forward_twentyfour_month_return'] = df.groupby(['year-month', 'sector'])[['forward_twentyfour_month_return']].apply(clip_outliers)
df['forward_twentyfive_month_return'] = df.groupby(['year-month', 'sector'])[['forward_twentyfive_month_return']].apply(clip_outliers)
df['forward_twentysix_month_return'] = df.groupby(['year-month', 'sector'])[['forward_twentysix_month_return']].apply(clip_outliers)
df['forward_twentyseven_month_return'] = df.groupby(['year-month', 'sector'])[['forward_twentyseven_month_return']].apply(clip_outliers)
df['forward_twentyeight_month_return'] = df.groupby(['year-month', 'sector'])[['forward_twentyeight_month_return']].apply(clip_outliers)
df['forward_twentynine_month_return'] = df.groupby(['year-month', 'sector'])[['forward_twentynine_month_return']].apply(clip_outliers)
df['forward_thirty_month_return'] = df.groupby(['year-month', 'sector'])[['forward_thirty_month_return']].apply(clip_outliers)
df['forward_thirtyone_month_return'] = df.groupby(['year-month', 'sector'])[['forward_thirtyone_month_return']].apply(clip_outliers)
df['forward_thirtytwo_month_return'] = df.groupby(['year-month', 'sector'])[['forward_thirtytwo_month_return']].apply(clip_outliers)
df['forward_thirtythree_month_return'] = df.groupby(['year-month', 'sector'])[['forward_thirtythree_month_return']].apply(clip_outliers)
df['forward_thirtyfour_month_return'] = df.groupby(['year-month', 'sector'])[['forward_thirtyfour_month_return']].apply(clip_outliers)
df['forward_thirtyfive_month_return'] = df.groupby(['year-month', 'sector'])[['forward_thirtyfive_month_return']].apply(clip_outliers)
df['forward_thirtysix_month_return'] = df.groupby(['year-month', 'sector'])[['forward_thirtysix_month_return']].apply(clip_outliers)

# Independent Variable

df['past_one_month_return'] = df.groupby(['year-month', 'sector'])[['past_one_month_return']].apply(clip_outliers)
df['past_two_month_return'] = df.groupby(['year-month', 'sector'])[['past_two_month_return']].apply(clip_outliers)
df['past_three_month_return'] = df.groupby(['year-month', 'sector'])[['past_three_month_return']].apply(clip_outliers)
df['past_four_month_return'] = df.groupby(['year-month', 'sector'])[['past_four_month_return']].apply(clip_outliers)
df['past_five_month_return'] = df.groupby(['year-month', 'sector'])[['past_five_month_return']].apply(clip_outliers)
df['past_six_month_return'] = df.groupby(['year-month', 'sector'])[['past_six_month_return']].apply(clip_outliers)
df['past_seven_month_return'] = df.groupby(['year-month', 'sector'])[['past_seven_month_return']].apply(clip_outliers)
df['past_eight_month_return'] = df.groupby(['year-month', 'sector'])[['past_eight_month_return']].apply(clip_outliers)
df['past_nine_month_return'] = df.groupby(['year-month', 'sector'])[['past_nine_month_return']].apply(clip_outliers)
df['past_ten_month_return'] = df.groupby(['year-month', 'sector'])[['past_ten_month_return']].apply(clip_outliers)
df['past_eleven_month_return'] = df.groupby(['year-month', 'sector'])[['past_eleven_month_return']].apply(clip_outliers)
df['past_twelve_month_return'] = df.groupby(['year-month', 'sector'])[['past_twelve_month_return']].apply(clip_outliers)
df['past_thirteen_month_return'] = df.groupby(['year-month', 'sector'])[['past_thirteen_month_return']].apply(clip_outliers)
df['past_fourteen_month_return'] = df.groupby(['year-month', 'sector'])[['past_fourteen_month_return']].apply(clip_outliers)
df['past_fifteen_month_return'] = df.groupby(['year-month', 'sector'])[['past_fifteen_month_return']].apply(clip_outliers)
df['past_sixteen_month_return'] = df.groupby(['year-month', 'sector'])[['past_sixteen_month_return']].apply(clip_outliers)
df['past_seventeen_month_return'] = df.groupby(['year-month', 'sector'])[['past_seventeen_month_return']].apply(clip_outliers)
df['past_eighteen_month_return'] = df.groupby(['year-month', 'sector'])[['past_eighteen_month_return']].apply(clip_outliers)
df['past_nineteen_month_return'] = df.groupby(['year-month', 'sector'])[['past_nineteen_month_return']].apply(clip_outliers)
df['past_twenty_month_return'] = df.groupby(['year-month', 'sector'])[['past_twenty_month_return']].apply(clip_outliers)
df['past_twentyone_month_return'] = df.groupby(['year-month', 'sector'])[['past_twentyone_month_return']].apply(clip_outliers)
df['past_twentytwo_month_return'] = df.groupby(['year-month', 'sector'])[['past_twentytwo_month_return']].apply(clip_outliers)
df['past_twentythree_month_return'] = df.groupby(['year-month', 'sector'])[['past_twentythree_month_return']].apply(clip_outliers)
df['past_twentyfour_month_return'] = df.groupby(['year-month', 'sector'])[['past_twentyfour_month_return']].apply(clip_outliers)
df['past_twentyfive_month_return'] = df.groupby(['year-month', 'sector'])[['past_twentyfive_month_return']].apply(clip_outliers)
df['past_twentysix_month_return'] = df.groupby(['year-month', 'sector'])[['past_twentysix_month_return']].apply(clip_outliers)
df['past_twentyseven_month_return'] = df.groupby(['year-month', 'sector'])[['past_twentyseven_month_return']].apply(clip_outliers)
df['past_twentyeight_month_return'] = df.groupby(['year-month', 'sector'])[['past_twentyeight_month_return']].apply(clip_outliers)
df['past_twentynine_month_return'] = df.groupby(['year-month', 'sector'])[['past_twentynine_month_return']].apply(clip_outliers)
df['past_thirty_month_return'] = df.groupby(['year-month', 'sector'])[['past_thirty_month_return']].apply(clip_outliers)
df['past_thirtyone_month_return'] = df.groupby(['year-month', 'sector'])[['past_thirtyone_month_return']].apply(clip_outliers)
df['past_thirtytwo_month_return'] = df.groupby(['year-month', 'sector'])[['past_thirtytwo_month_return']].apply(clip_outliers)
df['past_thirtythree_month_return'] = df.groupby(['year-month', 'sector'])[['past_thirtythree_month_return']].apply(clip_outliers)
df['past_thirtyfour_month_return'] = df.groupby(['year-month', 'sector'])[['past_thirtyfour_month_return']].apply(clip_outliers)
df['past_thirtyfive_month_return'] = df.groupby(['year-month', 'sector'])[['past_thirtyfive_month_return']].apply(clip_outliers)
df['past_thirtysix_month_return'] = df.groupby(['year-month', 'sector'])[['past_thirtysix_month_return']].apply(clip_outliers)
df['accrual'] = df.groupby(['year-month', 'sector'])[['accrual']].apply(clip_outliers)
df['adv_sale'] = df.groupby(['year-month', 'sector'])[['adv_sale']].apply(clip_outliers)
df['aftret_eq'] = df.groupby(['year-month', 'sector'])[['aftret_eq']].apply(clip_outliers)
df['aftret_equity'] = df.groupby(['year-month', 'sector'])[['aftret_equity']].apply(clip_outliers)
df['aftret_invcapx'] = df.groupby(['year-month', 'sector'])[['aftret_invcapx']].apply(clip_outliers)
df['at_turn'] = df.groupby(['year-month', 'sector'])[['at_turn']].apply(clip_outliers)
df['bm'] = df.groupby(['year-month', 'sector'])[['bm']].apply(clip_outliers)
df['CAPEI'] = df.groupby(['year-month', 'sector'])[['CAPEI']].apply(clip_outliers)
df['capital_ratio'] = df.groupby(['year-month', 'sector'])[['capital_ratio']].apply(clip_outliers)
df['cash_conversion'] = df.groupby(['year-month', 'sector'])[['cash_conversion']].apply(clip_outliers)
df['cash_debt'] = df.groupby(['year-month', 'sector'])[['cash_debt']].apply(clip_outliers)
df['cash_lt'] = df.groupby(['year-month', 'sector'])[['cash_lt']].apply(clip_outliers)
df['cash_ratio'] = df.groupby(['year-month', 'sector'])[['cash_ratio']].apply(clip_outliers)
df['cfm'] = df.groupby(['year-month', 'sector'])[['cfm']].apply(clip_outliers)
df['curr_debt'] = df.groupby(['year-month', 'sector'])[['curr_debt']].apply(clip_outliers)
df['curr_ratio'] = df.groupby(['year-month', 'sector'])[['curr_ratio']].apply(clip_outliers)
df['de_ratio'] = df.groupby(['year-month', 'sector'])[['de_ratio']].apply(clip_outliers)
df['debt_assets'] = df.groupby(['year-month', 'sector'])[['debt_assets']].apply(clip_outliers)
df['debt_at'] = df.groupby(['year-month', 'sector'])[['debt_at']].apply(clip_outliers)
df['debt_capital'] = df.groupby(['year-month', 'sector'])[['debt_capital']].apply(clip_outliers)
df['debt_ebitda'] = df.groupby(['year-month', 'sector'])[['debt_ebitda']].apply(clip_outliers)
df['debt_invcap'] = df.groupby(['year-month', 'sector'])[['debt_invcap']].apply(clip_outliers)
df['DIVYIELD'] = df.groupby(['year-month', 'sector'])[['DIVYIELD']].apply(clip_outliers)
df['dltt_be'] = df.groupby(['year-month', 'sector'])[['dltt_be']].apply(clip_outliers)
df['dpr'] = df.groupby(['year-month', 'sector'])[['dpr']].apply(clip_outliers)
df['efftax'] = df.groupby(['year-month', 'sector'])[['efftax']].apply(clip_outliers)
df['equity_invcap'] = df.groupby(['year-month', 'sector'])[['equity_invcap']].apply(clip_outliers)
df['evm'] = df.groupby(['year-month', 'sector'])[['evm']].apply(clip_outliers)
df['fcf_ocf'] = df.groupby(['year-month', 'sector'])[['fcf_ocf']].apply(clip_outliers)
df['gpm'] = df.groupby(['year-month', 'sector'])[['gpm']].apply(clip_outliers)
df['GProf'] = df.groupby(['year-month', 'sector'])[['GProf']].apply(clip_outliers)
df['int_debt'] = df.groupby(['year-month', 'sector'])[['int_debt']].apply(clip_outliers)
df['int_totdebt'] = df.groupby(['year-month', 'sector'])[['int_totdebt']].apply(clip_outliers)
df['intcov'] = df.groupby(['year-month', 'sector'])[['intcov']].apply(clip_outliers)
df['intcov_ratio'] = df.groupby(['year-month', 'sector'])[['intcov_ratio']].apply(clip_outliers)
df['inv_turn'] = df.groupby(['year-month', 'sector'])[['inv_turn']].apply(clip_outliers)
df['invt_act'] = df.groupby(['year-month', 'sector'])[['invt_act']].apply(clip_outliers)
df['lt_debt'] = df.groupby(['year-month', 'sector'])[['lt_debt']].apply(clip_outliers)
df['lt_ppent'] = df.groupby(['year-month', 'sector'])[['lt_ppent']].apply(clip_outliers)
df['npm'] = df.groupby(['year-month', 'sector'])[['npm']].apply(clip_outliers)
df['ocf_lct'] = df.groupby(['year-month', 'sector'])[['ocf_lct']].apply(clip_outliers)
df['opmad'] = df.groupby(['year-month', 'sector'])[['opmad']].apply(clip_outliers)
df['opmbd'] = df.groupby(['year-month', 'sector'])[['opmbd']].apply(clip_outliers)
df['pay_turn'] = df.groupby(['year-month', 'sector'])[['pay_turn']].apply(clip_outliers)
df['pcf'] = df.groupby(['year-month', 'sector'])[['pcf']].apply(clip_outliers)
df['pe_exi'] = df.groupby(['year-month', 'sector'])[['pe_exi']].apply(clip_outliers)
df['pe_inc'] = df.groupby(['year-month', 'sector'])[['pe_inc']].apply(clip_outliers)
df['pe_op_basic'] = df.groupby(['year-month', 'sector'])[['pe_op_basic']].apply(clip_outliers)
df['pe_op_dil'] = df.groupby(['year-month', 'sector'])[['pe_op_dil']].apply(clip_outliers)
df['PEG_1yrforward'] = df.groupby(['year-month', 'sector'])[['PEG_1yrforward']].apply(clip_outliers)
df['PEG_ltgforward'] = df.groupby(['year-month', 'sector'])[['PEG_ltgforward']].apply(clip_outliers)
df['PEG_trailing'] = df.groupby(['year-month', 'sector'])[['PEG_trailing']].apply(clip_outliers)
df['pretret_earnat'] = df.groupby(['year-month', 'sector'])[['pretret_earnat']].apply(clip_outliers)
df['pretret_noa'] = df.groupby(['year-month', 'sector'])[['pretret_noa']].apply(clip_outliers)
df['profit_lct'] = df.groupby(['year-month', 'sector'])[['profit_lct']].apply(clip_outliers)
df['ps'] = df.groupby(['year-month', 'sector'])[['ps']].apply(clip_outliers)
df['ptb'] = df.groupby(['year-month', 'sector'])[['ptb']].apply(clip_outliers)
df['ptpm'] = df.groupby(['year-month', 'sector'])[['ptpm']].apply(clip_outliers)
df['quick_ratio'] = df.groupby(['year-month', 'sector'])[['quick_ratio']].apply(clip_outliers)
df['rd_sale'] = df.groupby(['year-month', 'sector'])[['rd_sale']].apply(clip_outliers)
df['rect_act'] = df.groupby(['year-month', 'sector'])[['rect_act']].apply(clip_outliers)
df['rect_turn'] = df.groupby(['year-month', 'sector'])[['rect_turn']].apply(clip_outliers)
df['roa'] = df.groupby(['year-month', 'sector'])[['roa']].apply(clip_outliers)
df['roce'] = df.groupby(['year-month', 'sector'])[['roce']].apply(clip_outliers)
df['roe'] = df.groupby(['year-month', 'sector'])[['roe']].apply(clip_outliers)
df['sale_equity'] = df.groupby(['year-month', 'sector'])[['sale_equity']].apply(clip_outliers)
df['sale_invcap'] = df.groupby(['year-month', 'sector'])[['sale_invcap']].apply(clip_outliers)
df['sale_nwc'] = df.groupby(['year-month', 'sector'])[['sale_nwc']].apply(clip_outliers)
df['short_debt'] = df.groupby(['year-month', 'sector'])[['short_debt']].apply(clip_outliers)
df['staff_sale'] = df.groupby(['year-month', 'sector'])[['staff_sale']].apply(clip_outliers)
df['totdebt_invcap'] = df.groupby(['year-month', 'sector'])[['totdebt_invcap']].apply(clip_outliers)
df['dvpspm'] = df.groupby(['year-month', 'sector'])[['dvpspm']].apply(clip_outliers)
df['dvpsxm'] = df.groupby(['year-month', 'sector'])[['dvpsxm']].apply(clip_outliers)
df['dvrate'] = df.groupby(['year-month', 'sector'])[['dvrate']].apply(clip_outliers)
df['spcsrc'] = df.groupby(['year-month', 'sector'])[['spcsrc']].apply(clip_outliers)
df['alpha'] = df.groupby(['year-month', 'sector'])[['alpha']].apply(clip_outliers)
df['b_hml'] = df.groupby(['year-month', 'sector'])[['b_hml']].apply(clip_outliers)
df['b_mkt'] = df.groupby(['year-month', 'sector'])[['b_mkt']].apply(clip_outliers)
df['b_smb'] = df.groupby(['year-month', 'sector'])[['b_smb']].apply(clip_outliers)
df['b_umd'] = df.groupby(['year-month', 'sector'])[['b_umd']].apply(clip_outliers)
df['exret'] = df.groupby(['year-month', 'sector'])[['exret']].apply(clip_outliers)
df['ivol'] = df.groupby(['year-month', 'sector'])[['ivol']].apply(clip_outliers)
df['n'] = df.groupby(['year-month', 'sector'])[['n']].apply(clip_outliers)
df['R2'] = df.groupby(['year-month', 'sector'])[['R2']].apply(clip_outliers)
df['tvol'] = df.groupby(['year-month', 'sector'])[['tvol']].apply(clip_outliers)
df['BUYPCT'] = df.groupby(['year-month', 'sector'])[['BUYPCT']].apply(clip_outliers)
df['HOLDPCT'] = df.groupby(['year-month', 'sector'])[['HOLDPCT']].apply(clip_outliers)
df['SELLPCT'] = df.groupby(['year-month', 'sector'])[['SELLPCT']].apply(clip_outliers)
df['MEANREC'] = df.groupby(['year-month', 'sector'])[['MEANREC']].apply(clip_outliers)
df['MEDREC'] = df.groupby(['year-month', 'sector'])[['MEDREC']].apply(clip_outliers)
df['recup'] = df.groupby(['year-month', 'sector'])[['recup']].apply(clip_outliers)
df['recdown'] = df.groupby(['year-month', 'sector'])[['recdown']].apply(clip_outliers)
df['STDEV'] = df.groupby(['year-month', 'sector'])[['STDEV']].apply(clip_outliers)

# Clip by month for whole market (2.91% of total data)

# Dependent Variable

df['forward_one_month_return'] = df.groupby(['year-month'])[['forward_one_month_return']].apply(clip_outliers)
df['forward_two_month_return'] = df.groupby(['year-month'])[['forward_two_month_return']].apply(clip_outliers)
df['forward_three_month_return'] = df.groupby(['year-month'])[['forward_three_month_return']].apply(clip_outliers)
df['forward_four_month_return'] = df.groupby(['year-month'])[['forward_four_month_return']].apply(clip_outliers)
df['forward_five_month_return'] = df.groupby(['year-month'])[['forward_five_month_return']].apply(clip_outliers)
df['forward_six_month_return'] = df.groupby(['year-month'])[['forward_six_month_return']].apply(clip_outliers)
df['forward_seven_month_return'] = df.groupby(['year-month'])[['forward_seven_month_return']].apply(clip_outliers)
df['forward_eight_month_return'] = df.groupby(['year-month'])[['forward_eight_month_return']].apply(clip_outliers)
df['forward_nine_month_return'] = df.groupby(['year-month'])[['forward_nine_month_return']].apply(clip_outliers)
df['forward_ten_month_return'] = df.groupby(['year-month'])[['forward_ten_month_return']].apply(clip_outliers)
df['forward_eleven_month_return'] = df.groupby(['year-month'])[['forward_eleven_month_return']].apply(clip_outliers)
df['forward_twelve_month_return'] = df.groupby(['year-month'])[['forward_twelve_month_return']].apply(clip_outliers)
df['forward_thirteen_month_return'] = df.groupby(['year-month'])[['forward_thirteen_month_return']].apply(clip_outliers)
df['forward_fourteen_month_return'] = df.groupby(['year-month'])[['forward_fourteen_month_return']].apply(clip_outliers)
df['forward_fifteen_month_return'] = df.groupby(['year-month'])[['forward_fifteen_month_return']].apply(clip_outliers)
df['forward_sixteen_month_return'] = df.groupby(['year-month'])[['forward_sixteen_month_return']].apply(clip_outliers)
df['forward_seventeen_month_return'] = df.groupby(['year-month'])[['forward_seventeen_month_return']].apply(clip_outliers)
df['forward_eighteen_month_return'] = df.groupby(['year-month'])[['forward_eighteen_month_return']].apply(clip_outliers)
df['forward_nineteen_month_return'] = df.groupby(['year-month'])[['forward_nineteen_month_return']].apply(clip_outliers)
df['forward_twenty_month_return'] = df.groupby(['year-month'])[['forward_twenty_month_return']].apply(clip_outliers)
df['forward_twentyone_month_return'] = df.groupby(['year-month'])[['forward_twentyone_month_return']].apply(clip_outliers)
df['forward_twentytwo_month_return'] = df.groupby(['year-month'])[['forward_twentytwo_month_return']].apply(clip_outliers)
df['forward_twentythree_month_return'] = df.groupby(['year-month'])[['forward_twentythree_month_return']].apply(clip_outliers)
df['forward_twentyfour_month_return'] = df.groupby(['year-month'])[['forward_twentyfour_month_return']].apply(clip_outliers)
df['forward_twentyfive_month_return'] = df.groupby(['year-month'])[['forward_twentyfive_month_return']].apply(clip_outliers)
df['forward_twentysix_month_return'] = df.groupby(['year-month'])[['forward_twentysix_month_return']].apply(clip_outliers)
df['forward_twentyseven_month_return'] = df.groupby(['year-month'])[['forward_twentyseven_month_return']].apply(clip_outliers)
df['forward_twentyeight_month_return'] = df.groupby(['year-month'])[['forward_twentyeight_month_return']].apply(clip_outliers)
df['forward_twentynine_month_return'] = df.groupby(['year-month'])[['forward_twentynine_month_return']].apply(clip_outliers)
df['forward_thirty_month_return'] = df.groupby(['year-month'])[['forward_thirty_month_return']].apply(clip_outliers)
df['forward_thirtyone_month_return'] = df.groupby(['year-month'])[['forward_thirtyone_month_return']].apply(clip_outliers)
df['forward_thirtytwo_month_return'] = df.groupby(['year-month'])[['forward_thirtytwo_month_return']].apply(clip_outliers)
df['forward_thirtythree_month_return'] = df.groupby(['year-month'])[['forward_thirtythree_month_return']].apply(clip_outliers)
df['forward_thirtyfour_month_return'] = df.groupby(['year-month'])[['forward_thirtyfour_month_return']].apply(clip_outliers)
df['forward_thirtyfive_month_return'] = df.groupby(['year-month'])[['forward_thirtyfive_month_return']].apply(clip_outliers)
df['forward_thirtysix_month_return'] = df.groupby(['year-month'])[['forward_thirtysix_month_return']].apply(clip_outliers)

# Independent Variable

df['past_one_month_return'] = df.groupby(['year-month'])[['past_one_month_return']].apply(clip_outliers)
df['past_two_month_return'] = df.groupby(['year-month'])[['past_two_month_return']].apply(clip_outliers)
df['past_three_month_return'] = df.groupby(['year-month'])[['past_three_month_return']].apply(clip_outliers)
df['past_four_month_return'] = df.groupby(['year-month'])[['past_four_month_return']].apply(clip_outliers)
df['past_five_month_return'] = df.groupby(['year-month'])[['past_five_month_return']].apply(clip_outliers)
df['past_six_month_return'] = df.groupby(['year-month'])[['past_six_month_return']].apply(clip_outliers)
df['past_seven_month_return'] = df.groupby(['year-month'])[['past_seven_month_return']].apply(clip_outliers)
df['past_eight_month_return'] = df.groupby(['year-month'])[['past_eight_month_return']].apply(clip_outliers)
df['past_nine_month_return'] = df.groupby(['year-month'])[['past_nine_month_return']].apply(clip_outliers)
df['past_ten_month_return'] = df.groupby(['year-month'])[['past_ten_month_return']].apply(clip_outliers)
df['past_eleven_month_return'] = df.groupby(['year-month'])[['past_eleven_month_return']].apply(clip_outliers)
df['past_twelve_month_return'] = df.groupby(['year-month'])[['past_twelve_month_return']].apply(clip_outliers)
df['past_thirteen_month_return'] = df.groupby(['year-month'])[['past_thirteen_month_return']].apply(clip_outliers)
df['past_fourteen_month_return'] = df.groupby(['year-month'])[['past_fourteen_month_return']].apply(clip_outliers)
df['past_fifteen_month_return'] = df.groupby(['year-month'])[['past_fifteen_month_return']].apply(clip_outliers)
df['past_sixteen_month_return'] = df.groupby(['year-month'])[['past_sixteen_month_return']].apply(clip_outliers)
df['past_seventeen_month_return'] = df.groupby(['year-month'])[['past_seventeen_month_return']].apply(clip_outliers)
df['past_eighteen_month_return'] = df.groupby(['year-month'])[['past_eighteen_month_return']].apply(clip_outliers)
df['past_nineteen_month_return'] = df.groupby(['year-month'])[['past_nineteen_month_return']].apply(clip_outliers)
df['past_twenty_month_return'] = df.groupby(['year-month'])[['past_twenty_month_return']].apply(clip_outliers)
df['past_twentyone_month_return'] = df.groupby(['year-month'])[['past_twentyone_month_return']].apply(clip_outliers)
df['past_twentytwo_month_return'] = df.groupby(['year-month'])[['past_twentytwo_month_return']].apply(clip_outliers)
df['past_twentythree_month_return'] = df.groupby(['year-month'])[['past_twentythree_month_return']].apply(clip_outliers)
df['past_twentyfour_month_return'] = df.groupby(['year-month'])[['past_twentyfour_month_return']].apply(clip_outliers)
df['past_twentyfive_month_return'] = df.groupby(['year-month'])[['past_twentyfive_month_return']].apply(clip_outliers)
df['past_twentysix_month_return'] = df.groupby(['year-month'])[['past_twentysix_month_return']].apply(clip_outliers)
df['past_twentyseven_month_return'] = df.groupby(['year-month'])[['past_twentyseven_month_return']].apply(clip_outliers)
df['past_twentyeight_month_return'] = df.groupby(['year-month'])[['past_twentyeight_month_return']].apply(clip_outliers)
df['past_twentynine_month_return'] = df.groupby(['year-month'])[['past_twentynine_month_return']].apply(clip_outliers)
df['past_thirty_month_return'] = df.groupby(['year-month'])[['past_thirty_month_return']].apply(clip_outliers)
df['past_thirtyone_month_return'] = df.groupby(['year-month'])[['past_thirtyone_month_return']].apply(clip_outliers)
df['past_thirtytwo_month_return'] = df.groupby(['year-month'])[['past_thirtytwo_month_return']].apply(clip_outliers)
df['past_thirtythree_month_return'] = df.groupby(['year-month'])[['past_thirtythree_month_return']].apply(clip_outliers)
df['past_thirtyfour_month_return'] = df.groupby(['year-month'])[['past_thirtyfour_month_return']].apply(clip_outliers)
df['past_thirtyfive_month_return'] = df.groupby(['year-month'])[['past_thirtyfive_month_return']].apply(clip_outliers)
df['past_thirtysix_month_return'] = df.groupby(['year-month'])[['past_thirtysix_month_return']].apply(clip_outliers)
df['accrual'] = df.groupby(['year-month'])[['accrual']].apply(clip_outliers)
df['adv_sale'] = df.groupby(['year-month'])[['adv_sale']].apply(clip_outliers)
df['aftret_eq'] = df.groupby(['year-month'])[['aftret_eq']].apply(clip_outliers)
df['aftret_equity'] = df.groupby(['year-month'])[['aftret_equity']].apply(clip_outliers)
df['aftret_invcapx'] = df.groupby(['year-month'])[['aftret_invcapx']].apply(clip_outliers)
df['at_turn'] = df.groupby(['year-month'])[['at_turn']].apply(clip_outliers)
df['bm'] = df.groupby(['year-month'])[['bm']].apply(clip_outliers)
df['CAPEI'] = df.groupby(['year-month'])[['CAPEI']].apply(clip_outliers)
df['capital_ratio'] = df.groupby(['year-month'])[['capital_ratio']].apply(clip_outliers)
df['cash_conversion'] = df.groupby(['year-month'])[['cash_conversion']].apply(clip_outliers)
df['cash_debt'] = df.groupby(['year-month'])[['cash_debt']].apply(clip_outliers)
df['cash_lt'] = df.groupby(['year-month'])[['cash_lt']].apply(clip_outliers)
df['cash_ratio'] = df.groupby(['year-month'])[['cash_ratio']].apply(clip_outliers)
df['cfm'] = df.groupby(['year-month'])[['cfm']].apply(clip_outliers)
df['curr_debt'] = df.groupby(['year-month'])[['curr_debt']].apply(clip_outliers)
df['curr_ratio'] = df.groupby(['year-month'])[['curr_ratio']].apply(clip_outliers)
df['de_ratio'] = df.groupby(['year-month'])[['de_ratio']].apply(clip_outliers)
df['debt_assets'] = df.groupby(['year-month'])[['debt_assets']].apply(clip_outliers)
df['debt_at'] = df.groupby(['year-month'])[['debt_at']].apply(clip_outliers)
df['debt_capital'] = df.groupby(['year-month'])[['debt_capital']].apply(clip_outliers)
df['debt_ebitda'] = df.groupby(['year-month'])[['debt_ebitda']].apply(clip_outliers)
df['debt_invcap'] = df.groupby(['year-month'])[['debt_invcap']].apply(clip_outliers)
df['DIVYIELD'] = df.groupby(['year-month'])[['DIVYIELD']].apply(clip_outliers)
df['dltt_be'] = df.groupby(['year-month'])[['dltt_be']].apply(clip_outliers)
df['dpr'] = df.groupby(['year-month'])[['dpr']].apply(clip_outliers)
df['efftax'] = df.groupby(['year-month'])[['efftax']].apply(clip_outliers)
df['equity_invcap'] = df.groupby(['year-month'])[['equity_invcap']].apply(clip_outliers)
df['evm'] = df.groupby(['year-month'])[['evm']].apply(clip_outliers)
df['fcf_ocf'] = df.groupby(['year-month'])[['fcf_ocf']].apply(clip_outliers)
df['gpm'] = df.groupby(['year-month'])[['gpm']].apply(clip_outliers)
df['GProf'] = df.groupby(['year-month'])[['GProf']].apply(clip_outliers)
df['int_debt'] = df.groupby(['year-month'])[['int_debt']].apply(clip_outliers)
df['int_totdebt'] = df.groupby(['year-month'])[['int_totdebt']].apply(clip_outliers)
df['intcov'] = df.groupby(['year-month'])[['intcov']].apply(clip_outliers)
df['intcov_ratio'] = df.groupby(['year-month'])[['intcov_ratio']].apply(clip_outliers)
df['inv_turn'] = df.groupby(['year-month'])[['inv_turn']].apply(clip_outliers)
df['invt_act'] = df.groupby(['year-month'])[['invt_act']].apply(clip_outliers)
df['lt_debt'] = df.groupby(['year-month'])[['lt_debt']].apply(clip_outliers)
df['lt_ppent'] = df.groupby(['year-month'])[['lt_ppent']].apply(clip_outliers)
df['npm'] = df.groupby(['year-month'])[['npm']].apply(clip_outliers)
df['ocf_lct'] = df.groupby(['year-month'])[['ocf_lct']].apply(clip_outliers)
df['opmad'] = df.groupby(['year-month'])[['opmad']].apply(clip_outliers)
df['opmbd'] = df.groupby(['year-month'])[['opmbd']].apply(clip_outliers)
df['pay_turn'] = df.groupby(['year-month'])[['pay_turn']].apply(clip_outliers)
df['pcf'] = df.groupby(['year-month'])[['pcf']].apply(clip_outliers)
df['pe_exi'] = df.groupby(['year-month'])[['pe_exi']].apply(clip_outliers)
df['pe_inc'] = df.groupby(['year-month'])[['pe_inc']].apply(clip_outliers)
df['pe_op_basic'] = df.groupby(['year-month'])[['pe_op_basic']].apply(clip_outliers)
df['pe_op_dil'] = df.groupby(['year-month'])[['pe_op_dil']].apply(clip_outliers)
df['PEG_1yrforward'] = df.groupby(['year-month'])[['PEG_1yrforward']].apply(clip_outliers)
df['PEG_ltgforward'] = df.groupby(['year-month'])[['PEG_ltgforward']].apply(clip_outliers)
df['PEG_trailing'] = df.groupby(['year-month'])[['PEG_trailing']].apply(clip_outliers)
df['pretret_earnat'] = df.groupby(['year-month'])[['pretret_earnat']].apply(clip_outliers)
df['pretret_noa'] = df.groupby(['year-month'])[['pretret_noa']].apply(clip_outliers)
df['profit_lct'] = df.groupby(['year-month'])[['profit_lct']].apply(clip_outliers)
df['ps'] = df.groupby(['year-month'])[['ps']].apply(clip_outliers)
df['ptb'] = df.groupby(['year-month'])[['ptb']].apply(clip_outliers)
df['ptpm'] = df.groupby(['year-month'])[['ptpm']].apply(clip_outliers)
df['quick_ratio'] = df.groupby(['year-month'])[['quick_ratio']].apply(clip_outliers)
df['rd_sale'] = df.groupby(['year-month'])[['rd_sale']].apply(clip_outliers)
df['rect_act'] = df.groupby(['year-month'])[['rect_act']].apply(clip_outliers)
df['rect_turn'] = df.groupby(['year-month'])[['rect_turn']].apply(clip_outliers)
df['roa'] = df.groupby(['year-month'])[['roa']].apply(clip_outliers)
df['roce'] = df.groupby(['year-month'])[['roce']].apply(clip_outliers)
df['roe'] = df.groupby(['year-month'])[['roe']].apply(clip_outliers)
df['sale_equity'] = df.groupby(['year-month'])[['sale_equity']].apply(clip_outliers)
df['sale_invcap'] = df.groupby(['year-month'])[['sale_invcap']].apply(clip_outliers)
df['sale_nwc'] = df.groupby(['year-month'])[['sale_nwc']].apply(clip_outliers)
df['short_debt'] = df.groupby(['year-month'])[['short_debt']].apply(clip_outliers)
df['staff_sale'] = df.groupby(['year-month'])[['staff_sale']].apply(clip_outliers)
df['totdebt_invcap'] = df.groupby(['year-month'])[['totdebt_invcap']].apply(clip_outliers)
df['dvpspm'] = df.groupby(['year-month'])[['dvpspm']].apply(clip_outliers)
df['dvpsxm'] = df.groupby(['year-month'])[['dvpsxm']].apply(clip_outliers)
df['dvrate'] = df.groupby(['year-month'])[['dvrate']].apply(clip_outliers)
df['spcsrc'] = df.groupby(['year-month'])[['spcsrc']].apply(clip_outliers)
df['alpha'] = df.groupby(['year-month'])[['alpha']].apply(clip_outliers)
df['b_hml'] = df.groupby(['year-month'])[['b_hml']].apply(clip_outliers)
df['b_mkt'] = df.groupby(['year-month'])[['b_mkt']].apply(clip_outliers)
df['b_smb'] = df.groupby(['year-month'])[['b_smb']].apply(clip_outliers)
df['b_umd'] = df.groupby(['year-month'])[['b_umd']].apply(clip_outliers)
df['exret'] = df.groupby(['year-month'])[['exret']].apply(clip_outliers)
df['ivol'] = df.groupby(['year-month'])[['ivol']].apply(clip_outliers)
df['n'] = df.groupby(['year-month'])[['n']].apply(clip_outliers)
df['R2'] = df.groupby(['year-month'])[['R2']].apply(clip_outliers)
df['tvol'] = df.groupby(['year-month'])[['tvol']].apply(clip_outliers)
df['BUYPCT'] = df.groupby(['year-month'])[['BUYPCT']].apply(clip_outliers)
df['HOLDPCT'] = df.groupby(['year-month'])[['HOLDPCT']].apply(clip_outliers)
df['SELLPCT'] = df.groupby(['year-month'])[['SELLPCT']].apply(clip_outliers)
df['MEANREC'] = df.groupby(['year-month'])[['MEANREC']].apply(clip_outliers)
df['MEDREC'] = df.groupby(['year-month'])[['MEDREC']].apply(clip_outliers)
df['recup'] = df.groupby(['year-month'])[['recup']].apply(clip_outliers)
df['recdown'] = df.groupby(['year-month'])[['recdown']].apply(clip_outliers)
df['STDEV'] = df.groupby(['year-month'])[['STDEV']].apply(clip_outliers)

# %%
# df - Enrich - Market Z-Score
df['past_one_month_return_zscore'] = df.groupby(['year-month'])[['past_one_month_return']].apply(modified_z)
df['past_two_month_return_zscore'] = df.groupby(['year-month'])[['past_two_month_return']].apply(modified_z)
df['past_three_month_return_zscore'] = df.groupby(['year-month'])[['past_three_month_return']].apply(modified_z)
df['past_four_month_return_zscore'] = df.groupby(['year-month'])[['past_four_month_return']].apply(modified_z)
df['past_five_month_return_zscore'] = df.groupby(['year-month'])[['past_five_month_return']].apply(modified_z)
df['past_six_month_return_zscore'] = df.groupby(['year-month'])[['past_six_month_return']].apply(modified_z)
df['past_seven_month_return_zscore'] = df.groupby(['year-month'])[['past_seven_month_return']].apply(modified_z)
df['past_eight_month_return_zscore'] = df.groupby(['year-month'])[['past_eight_month_return']].apply(modified_z)
df['past_nine_month_return_zscore'] = df.groupby(['year-month'])[['past_nine_month_return']].apply(modified_z)
df['past_ten_month_return_zscore'] = df.groupby(['year-month'])[['past_ten_month_return']].apply(modified_z)
df['past_eleven_month_return_zscore'] = df.groupby(['year-month'])[['past_eleven_month_return']].apply(modified_z)
df['past_twelve_month_return_zscore'] = df.groupby(['year-month'])[['past_twelve_month_return']].apply(modified_z)
df['past_thirteen_month_return_zscore'] = df.groupby(['year-month'])[['past_thirteen_month_return']].apply(modified_z)
df['past_fourteen_month_return_zscore'] = df.groupby(['year-month'])[['past_fourteen_month_return']].apply(modified_z)
df['past_fifteen_month_return_zscore'] = df.groupby(['year-month'])[['past_fifteen_month_return']].apply(modified_z)
df['past_sixteen_month_return_zscore'] = df.groupby(['year-month'])[['past_sixteen_month_return']].apply(modified_z)
df['past_seventeen_month_return_zscore'] = df.groupby(['year-month'])[['past_seventeen_month_return']].apply(modified_z)
df['past_eighteen_month_return_zscore'] = df.groupby(['year-month'])[['past_eighteen_month_return']].apply(modified_z)
df['past_nineteen_month_return_zscore'] = df.groupby(['year-month'])[['past_nineteen_month_return']].apply(modified_z)
df['past_twenty_month_return_zscore'] = df.groupby(['year-month'])[['past_twenty_month_return']].apply(modified_z)
df['past_twentyone_month_return_zscore'] = df.groupby(['year-month'])[['past_twentyone_month_return']].apply(modified_z)
df['past_twentytwo_month_return_zscore'] = df.groupby(['year-month'])[['past_twentytwo_month_return']].apply(modified_z)
df['past_twentythree_month_return_zscore'] = df.groupby(['year-month'])[['past_twentythree_month_return']].apply(modified_z)
df['past_twentyfour_month_return_zscore'] = df.groupby(['year-month'])[['past_twentyfour_month_return']].apply(modified_z)
df['past_twentyfive_month_return_zscore'] = df.groupby(['year-month'])[['past_twentyfive_month_return']].apply(modified_z)
df['past_twentysix_month_return_zscore'] = df.groupby(['year-month'])[['past_twentysix_month_return']].apply(modified_z)
df['past_twentyseven_month_return_zscore'] = df.groupby(['year-month'])[['past_twentyseven_month_return']].apply(modified_z)
df['past_twentyeight_month_return_zscore'] = df.groupby(['year-month'])[['past_twentyeight_month_return']].apply(modified_z)
df['past_twentynine_month_return_zscore'] = df.groupby(['year-month'])[['past_twentynine_month_return']].apply(modified_z)
df['past_thirty_month_return_zscore'] = df.groupby(['year-month'])[['past_thirty_month_return']].apply(modified_z)
df['past_thirtyone_month_return_zscore'] = df.groupby(['year-month'])[['past_thirtyone_month_return']].apply(modified_z)
df['past_thirtytwo_month_return_zscore'] = df.groupby(['year-month'])[['past_thirtytwo_month_return']].apply(modified_z)
df['past_thirtythree_month_return_zscore'] = df.groupby(['year-month'])[['past_thirtythree_month_return']].apply(modified_z)
df['past_thirtyfour_month_return_zscore'] = df.groupby(['year-month'])[['past_thirtyfour_month_return']].apply(modified_z)
df['past_thirtyfive_month_return_zscore'] = df.groupby(['year-month'])[['past_thirtyfive_month_return']].apply(modified_z)
df['past_thirtysix_month_return_zscore'] = df.groupby(['year-month'])[['past_thirtysix_month_return']].apply(modified_z)
df['accrual_zscore'] = df.groupby(['year-month'])[['accrual']].apply(modified_z)
df['adv_sale_zscore'] = df.groupby(['year-month'])[['adv_sale']].apply(modified_z)
df['aftret_eq_zscore'] = df.groupby(['year-month'])[['aftret_eq']].apply(modified_z)
df['aftret_equity_zscore'] = df.groupby(['year-month'])[['aftret_equity']].apply(modified_z)
df['aftret_invcapx_zscore'] = df.groupby(['year-month'])[['aftret_invcapx']].apply(modified_z)
df['at_turn_zscore'] = df.groupby(['year-month'])[['at_turn']].apply(modified_z)
df['bm_zscore'] = df.groupby(['year-month'])[['bm']].apply(modified_z)
df['CAPEI_zscore'] = df.groupby(['year-month'])[['CAPEI']].apply(modified_z)
df['capital_ratio_zscore'] = df.groupby(['year-month'])[['capital_ratio']].apply(modified_z)
df['cash_conversion_zscore'] = df.groupby(['year-month'])[['cash_conversion']].apply(modified_z)
df['cash_debt_zscore'] = df.groupby(['year-month'])[['cash_debt']].apply(modified_z)
df['cash_lt_zscore'] = df.groupby(['year-month'])[['cash_lt']].apply(modified_z)
df['cash_ratio_zscore'] = df.groupby(['year-month'])[['cash_ratio']].apply(modified_z)
df['cfm_zscore'] = df.groupby(['year-month'])[['cfm']].apply(modified_z)
df['curr_debt_zscore'] = df.groupby(['year-month'])[['curr_debt']].apply(modified_z)
df['curr_ratio_zscore'] = df.groupby(['year-month'])[['curr_ratio']].apply(modified_z)
df['de_ratio_zscore'] = df.groupby(['year-month'])[['de_ratio']].apply(modified_z)
df['debt_assets_zscore'] = df.groupby(['year-month'])[['debt_assets']].apply(modified_z)
df['debt_at_zscore'] = df.groupby(['year-month'])[['debt_at']].apply(modified_z)
df['debt_capital_zscore'] = df.groupby(['year-month'])[['debt_capital']].apply(modified_z)
df['debt_ebitda_zscore'] = df.groupby(['year-month'])[['debt_ebitda']].apply(modified_z)
df['debt_invcap_zscore'] = df.groupby(['year-month'])[['debt_invcap']].apply(modified_z)
df['DIVYIELD_zscore'] = df.groupby(['year-month'])[['DIVYIELD']].apply(modified_z)
df['dltt_be_zscore'] = df.groupby(['year-month'])[['dltt_be']].apply(modified_z)
df['dpr_zscore'] = df.groupby(['year-month'])[['dpr']].apply(modified_z)
df['efftax_zscore'] = df.groupby(['year-month'])[['efftax']].apply(modified_z)
df['equity_invcap_zscore'] = df.groupby(['year-month'])[['equity_invcap']].apply(modified_z)
df['evm_zscore'] = df.groupby(['year-month'])[['evm']].apply(modified_z)
df['fcf_ocf_zscore'] = df.groupby(['year-month'])[['fcf_ocf']].apply(modified_z)
df['gpm_zscore'] = df.groupby(['year-month'])[['gpm']].apply(modified_z)
df['GProf_zscore'] = df.groupby(['year-month'])[['GProf']].apply(modified_z)
df['int_debt_zscore'] = df.groupby(['year-month'])[['int_debt']].apply(modified_z)
df['int_totdebt_zscore'] = df.groupby(['year-month'])[['int_totdebt']].apply(modified_z)
df['intcov_zscore'] = df.groupby(['year-month'])[['intcov']].apply(modified_z)
df['intcov_ratio_zscore'] = df.groupby(['year-month'])[['intcov_ratio']].apply(modified_z)
df['inv_turn_zscore'] = df.groupby(['year-month'])[['inv_turn']].apply(modified_z)
df['invt_act_zscore'] = df.groupby(['year-month'])[['invt_act']].apply(modified_z)
df['lt_debt_zscore'] = df.groupby(['year-month'])[['lt_debt']].apply(modified_z)
df['lt_ppent_zscore'] = df.groupby(['year-month'])[['lt_ppent']].apply(modified_z)
df['npm_zscore'] = df.groupby(['year-month'])[['npm']].apply(modified_z)
df['ocf_lct_zscore'] = df.groupby(['year-month'])[['ocf_lct']].apply(modified_z)
df['opmad_zscore'] = df.groupby(['year-month'])[['opmad']].apply(modified_z)
df['opmbd_zscore'] = df.groupby(['year-month'])[['opmbd']].apply(modified_z)
df['pay_turn_zscore'] = df.groupby(['year-month'])[['pay_turn']].apply(modified_z)
df['pcf_zscore'] = df.groupby(['year-month'])[['pcf']].apply(modified_z)
df['pe_exi_zscore'] = df.groupby(['year-month'])[['pe_exi']].apply(modified_z)
df['pe_inc_zscore'] = df.groupby(['year-month'])[['pe_inc']].apply(modified_z)
df['pe_op_basic_zscore'] = df.groupby(['year-month'])[['pe_op_basic']].apply(modified_z)
df['pe_op_dil_zscore'] = df.groupby(['year-month'])[['pe_op_dil']].apply(modified_z)
df['PEG_1yrforward_zscore'] = df.groupby(['year-month'])[['PEG_1yrforward']].apply(modified_z)
df['PEG_ltgforward_zscore'] = df.groupby(['year-month'])[['PEG_ltgforward']].apply(modified_z)
df['PEG_trailing_zscore'] = df.groupby(['year-month'])[['PEG_trailing']].apply(modified_z)
df['pretret_earnat_zscore'] = df.groupby(['year-month'])[['pretret_earnat']].apply(modified_z)
df['pretret_noa_zscore'] = df.groupby(['year-month'])[['pretret_noa']].apply(modified_z)
df['profit_lct_zscore'] = df.groupby(['year-month'])[['profit_lct']].apply(modified_z)
df['ps_zscore'] = df.groupby(['year-month'])[['ps']].apply(modified_z)
df['ptb_zscore'] = df.groupby(['year-month'])[['ptb']].apply(modified_z)
df['ptpm_zscore'] = df.groupby(['year-month'])[['ptpm']].apply(modified_z)
df['quick_ratio_zscore'] = df.groupby(['year-month'])[['quick_ratio']].apply(modified_z)
df['rd_sale_zscore'] = df.groupby(['year-month'])[['rd_sale']].apply(modified_z)
df['rect_act_zscore'] = df.groupby(['year-month'])[['rect_act']].apply(modified_z)
df['rect_turn_zscore'] = df.groupby(['year-month'])[['rect_turn']].apply(modified_z)
df['roa_zscore'] = df.groupby(['year-month'])[['roa']].apply(modified_z)
df['roce_zscore'] = df.groupby(['year-month'])[['roce']].apply(modified_z)
df['roe_zscore'] = df.groupby(['year-month'])[['roe']].apply(modified_z)
df['sale_equity_zscore'] = df.groupby(['year-month'])[['sale_equity']].apply(modified_z)
df['sale_invcap_zscore'] = df.groupby(['year-month'])[['sale_invcap']].apply(modified_z)
df['sale_nwc_zscore'] = df.groupby(['year-month'])[['sale_nwc']].apply(modified_z)
df['short_debt_zscore'] = df.groupby(['year-month'])[['short_debt']].apply(modified_z)
df['staff_sale_zscore'] = df.groupby(['year-month'])[['staff_sale']].apply(modified_z)
df['totdebt_invcap_zscore'] = df.groupby(['year-month'])[['totdebt_invcap']].apply(modified_z)
df['dvpspm_zscore'] = df.groupby(['year-month'])[['dvpspm']].apply(modified_z)
df['dvpsxm_zscore'] = df.groupby(['year-month'])[['dvpsxm']].apply(modified_z)
df['dvrate_zscore'] = df.groupby(['year-month'])[['dvrate']].apply(modified_z)
df['spcsrc_zscore'] = df.groupby(['year-month'])[['spcsrc']].apply(modified_z)
df['alpha_zscore'] = df.groupby(['year-month'])[['alpha']].apply(modified_z)
df['b_hml_zscore'] = df.groupby(['year-month'])[['b_hml']].apply(modified_z)
df['b_mkt_zscore'] = df.groupby(['year-month'])[['b_mkt']].apply(modified_z)
df['b_smb_zscore'] = df.groupby(['year-month'])[['b_smb']].apply(modified_z)
df['b_umd_zscore'] = df.groupby(['year-month'])[['b_umd']].apply(modified_z)
df['exret_zscore'] = df.groupby(['year-month'])[['exret']].apply(modified_z)
df['ivol_zscore'] = df.groupby(['year-month'])[['ivol']].apply(modified_z)
df['n_zscore'] = df.groupby(['year-month'])[['n']].apply(modified_z)
df['R2_zscore'] = df.groupby(['year-month'])[['R2']].apply(modified_z)
df['tvol_zscore'] = df.groupby(['year-month'])[['tvol']].apply(modified_z)
df['BUYPCT_zscore'] = df.groupby(['year-month'])[['BUYPCT']].apply(modified_z)
df['HOLDPCT_zscore'] = df.groupby(['year-month'])[['HOLDPCT']].apply(modified_z)
df['MEANREC_zscore'] = df.groupby(['year-month'])[['MEANREC']].apply(modified_z)
df['MEDREC_zscore'] = df.groupby(['year-month'])[['MEDREC']].apply(modified_z)
df['recup_zscore'] = df.groupby(['year-month'])[['recup']].apply(modified_z)
df['recdown_zscore'] = df.groupby(['year-month'])[['recdown']].apply(modified_z)
df['SELLPCT_zscore'] = df.groupby(['year-month'])[['SELLPCT']].apply(modified_z)
df['STDEV_zscore'] = df.groupby(['year-month'])[['STDEV']].apply(modified_z)

# %%
# df - Enrich - Sector Z-Score
df['past_one_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_one_month_return']].apply(modified_z)
df['past_two_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_two_month_return']].apply(modified_z)
df['past_three_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_three_month_return']].apply(modified_z)
df['past_four_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_four_month_return']].apply(modified_z)
df['past_five_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_five_month_return']].apply(modified_z)
df['past_six_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_six_month_return']].apply(modified_z)
df['past_seven_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_seven_month_return']].apply(modified_z)
df['past_eight_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_eight_month_return']].apply(modified_z)
df['past_nine_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_nine_month_return']].apply(modified_z)
df['past_ten_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_ten_month_return']].apply(modified_z)
df['past_eleven_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_eleven_month_return']].apply(modified_z)
df['past_twelve_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_twelve_month_return']].apply(modified_z)
df['past_thirteen_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_thirteen_month_return']].apply(modified_z)
df['past_fourteen_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_fourteen_month_return']].apply(modified_z)
df['past_fifteen_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_fifteen_month_return']].apply(modified_z)
df['past_sixteen_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_sixteen_month_return']].apply(modified_z)
df['past_seventeen_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_seventeen_month_return']].apply(modified_z)
df['past_eighteen_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_eighteen_month_return']].apply(modified_z)
df['past_nineteen_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_nineteen_month_return']].apply(modified_z)
df['past_twenty_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_twenty_month_return']].apply(modified_z)
df['past_twentyone_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_twentyone_month_return']].apply(modified_z)
df['past_twentytwo_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_twentytwo_month_return']].apply(modified_z)
df['past_twentythree_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_twentythree_month_return']].apply(modified_z)
df['past_twentyfour_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_twentyfour_month_return']].apply(modified_z)
df['past_twentyfive_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_twentyfive_month_return']].apply(modified_z)
df['past_twentysix_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_twentysix_month_return']].apply(modified_z)
df['past_twentyseven_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_twentyseven_month_return']].apply(modified_z)
df['past_twentyeight_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_twentyeight_month_return']].apply(modified_z)
df['past_twentynine_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_twentynine_month_return']].apply(modified_z)
df['past_thirty_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_thirty_month_return']].apply(modified_z)
df['past_thirtyone_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_thirtyone_month_return']].apply(modified_z)
df['past_thirtytwo_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_thirtytwo_month_return']].apply(modified_z)
df['past_thirtythree_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_thirtythree_month_return']].apply(modified_z)
df['past_thirtyfour_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_thirtyfour_month_return']].apply(modified_z)
df['past_thirtyfive_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_thirtyfive_month_return']].apply(modified_z)
df['past_thirtysix_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_thirtysix_month_return']].apply(modified_z)
df['accrual_sector_zscore'] = df.groupby(['year-month', 'sector'])[['accrual']].apply(modified_z)
df['adv_sale_sector_zscore'] = df.groupby(['year-month', 'sector'])[['adv_sale']].apply(modified_z)
df['aftret_eq_sector_zscore'] = df.groupby(['year-month', 'sector'])[['aftret_eq']].apply(modified_z)
df['aftret_equity_sector_zscore'] = df.groupby(['year-month', 'sector'])[['aftret_equity']].apply(modified_z)
df['aftret_invcapx_sector_zscore'] = df.groupby(['year-month', 'sector'])[['aftret_invcapx']].apply(modified_z)
df['at_turn_sector_zscore'] = df.groupby(['year-month', 'sector'])[['at_turn']].apply(modified_z)
df['bm_sector_zscore'] = df.groupby(['year-month', 'sector'])[['bm']].apply(modified_z)
df['CAPEI_sector_zscore'] = df.groupby(['year-month', 'sector'])[['CAPEI']].apply(modified_z)
df['capital_ratio_sector_zscore'] = df.groupby(['year-month', 'sector'])[['capital_ratio']].apply(modified_z)
df['cash_conversion_sector_zscore'] = df.groupby(['year-month', 'sector'])[['cash_conversion']].apply(modified_z)
df['cash_debt_sector_zscore'] = df.groupby(['year-month', 'sector'])[['cash_debt']].apply(modified_z)
df['cash_lt_sector_zscore'] = df.groupby(['year-month', 'sector'])[['cash_lt']].apply(modified_z)
df['cash_ratio_sector_zscore'] = df.groupby(['year-month', 'sector'])[['cash_ratio']].apply(modified_z)
df['cfm_sector_zscore'] = df.groupby(['year-month', 'sector'])[['cfm']].apply(modified_z)
df['curr_debt_sector_zscore'] = df.groupby(['year-month', 'sector'])[['curr_debt']].apply(modified_z)
df['curr_ratio_sector_zscore'] = df.groupby(['year-month', 'sector'])[['curr_ratio']].apply(modified_z)
df['de_ratio_sector_zscore'] = df.groupby(['year-month', 'sector'])[['de_ratio']].apply(modified_z)
df['debt_assets_sector_zscore'] = df.groupby(['year-month', 'sector'])[['debt_assets']].apply(modified_z)
df['debt_at_sector_zscore'] = df.groupby(['year-month', 'sector'])[['debt_at']].apply(modified_z)
df['debt_capital_sector_zscore'] = df.groupby(['year-month', 'sector'])[['debt_capital']].apply(modified_z)
df['debt_ebitda_sector_zscore'] = df.groupby(['year-month', 'sector'])[['debt_ebitda']].apply(modified_z)
df['debt_invcap_sector_zscore'] = df.groupby(['year-month', 'sector'])[['debt_invcap']].apply(modified_z)
df['DIVYIELD_sector_zscore'] = df.groupby(['year-month', 'sector'])[['DIVYIELD']].apply(modified_z)
df['dltt_be_sector_zscore'] = df.groupby(['year-month', 'sector'])[['dltt_be']].apply(modified_z)
df['dpr_sector_zscore'] = df.groupby(['year-month', 'sector'])[['dpr']].apply(modified_z)
df['efftax_sector_zscore'] = df.groupby(['year-month', 'sector'])[['efftax']].apply(modified_z)
df['equity_invcap_sector_zscore'] = df.groupby(['year-month', 'sector'])[['equity_invcap']].apply(modified_z)
df['evm_sector_zscore'] = df.groupby(['year-month', 'sector'])[['evm']].apply(modified_z)
df['fcf_ocf_sector_zscore'] = df.groupby(['year-month', 'sector'])[['fcf_ocf']].apply(modified_z)
df['gpm_sector_zscore'] = df.groupby(['year-month', 'sector'])[['gpm']].apply(modified_z)
df['GProf_sector_zscore'] = df.groupby(['year-month', 'sector'])[['GProf']].apply(modified_z)
df['int_debt_sector_zscore'] = df.groupby(['year-month', 'sector'])[['int_debt']].apply(modified_z)
df['int_totdebt_sector_zscore'] = df.groupby(['year-month', 'sector'])[['int_totdebt']].apply(modified_z)
df['intcov_sector_zscore'] = df.groupby(['year-month', 'sector'])[['intcov']].apply(modified_z)
df['intcov_ratio_sector_zscore'] = df.groupby(['year-month', 'sector'])[['intcov_ratio']].apply(modified_z)
df['inv_turn_sector_zscore'] = df.groupby(['year-month', 'sector'])[['inv_turn']].apply(modified_z)
df['invt_act_sector_zscore'] = df.groupby(['year-month', 'sector'])[['invt_act']].apply(modified_z)
df['lt_debt_sector_zscore'] = df.groupby(['year-month', 'sector'])[['lt_debt']].apply(modified_z)
df['lt_ppent_sector_zscore'] = df.groupby(['year-month', 'sector'])[['lt_ppent']].apply(modified_z)
df['npm_sector_zscore'] = df.groupby(['year-month', 'sector'])[['npm']].apply(modified_z)
df['ocf_lct_sector_zscore'] = df.groupby(['year-month', 'sector'])[['ocf_lct']].apply(modified_z)
df['opmad_sector_zscore'] = df.groupby(['year-month', 'sector'])[['opmad']].apply(modified_z)
df['opmbd_sector_zscore'] = df.groupby(['year-month', 'sector'])[['opmbd']].apply(modified_z)
df['pay_turn_sector_zscore'] = df.groupby(['year-month', 'sector'])[['pay_turn']].apply(modified_z)
df['pcf_sector_zscore'] = df.groupby(['year-month', 'sector'])[['pcf']].apply(modified_z)
df['pe_exi_sector_zscore'] = df.groupby(['year-month', 'sector'])[['pe_exi']].apply(modified_z)
df['pe_inc_sector_zscore'] = df.groupby(['year-month', 'sector'])[['pe_inc']].apply(modified_z)
df['pe_op_basic_sector_zscore'] = df.groupby(['year-month', 'sector'])[['pe_op_basic']].apply(modified_z)
df['pe_op_dil_sector_zscore'] = df.groupby(['year-month', 'sector'])[['pe_op_dil']].apply(modified_z)
df['PEG_1yrforward_sector_zscore'] = df.groupby(['year-month', 'sector'])[['PEG_1yrforward']].apply(modified_z)
df['PEG_ltgforward_sector_zscore'] = df.groupby(['year-month', 'sector'])[['PEG_ltgforward']].apply(modified_z)
df['PEG_trailing_sector_zscore'] = df.groupby(['year-month', 'sector'])[['PEG_trailing']].apply(modified_z)
df['pretret_earnat_sector_zscore'] = df.groupby(['year-month', 'sector'])[['pretret_earnat']].apply(modified_z)
df['pretret_noa_sector_zscore'] = df.groupby(['year-month', 'sector'])[['pretret_noa']].apply(modified_z)
df['profit_lct_sector_zscore'] = df.groupby(['year-month', 'sector'])[['profit_lct']].apply(modified_z)
df['ps_sector_zscore'] = df.groupby(['year-month', 'sector'])[['ps']].apply(modified_z)
df['ptb_sector_zscore'] = df.groupby(['year-month', 'sector'])[['ptb']].apply(modified_z)
df['ptpm_sector_zscore'] = df.groupby(['year-month', 'sector'])[['ptpm']].apply(modified_z)
df['quick_ratio_sector_zscore'] = df.groupby(['year-month', 'sector'])[['quick_ratio']].apply(modified_z)
df['rd_sale_sector_zscore'] = df.groupby(['year-month', 'sector'])[['rd_sale']].apply(modified_z)
df['rect_act_sector_zscore'] = df.groupby(['year-month', 'sector'])[['rect_act']].apply(modified_z)
df['rect_turn_sector_zscore'] = df.groupby(['year-month', 'sector'])[['rect_turn']].apply(modified_z)
df['roa_sector_zscore'] = df.groupby(['year-month', 'sector'])[['roa']].apply(modified_z)
df['roce_sector_zscore'] = df.groupby(['year-month', 'sector'])[['roce']].apply(modified_z)
df['roe_sector_zscore'] = df.groupby(['year-month', 'sector'])[['roe']].apply(modified_z)
df['sale_equity_sector_zscore'] = df.groupby(['year-month', 'sector'])[['sale_equity']].apply(modified_z)
df['sale_invcap_sector_zscore'] = df.groupby(['year-month', 'sector'])[['sale_invcap']].apply(modified_z)
df['sale_nwc_sector_zscore'] = df.groupby(['year-month', 'sector'])[['sale_nwc']].apply(modified_z)
df['short_debt_sector_zscore'] = df.groupby(['year-month', 'sector'])[['short_debt']].apply(modified_z)
df['staff_sale_sector_zscore'] = df.groupby(['year-month', 'sector'])[['staff_sale']].apply(modified_z)
df['totdebt_invcap_sector_zscore'] = df.groupby(['year-month', 'sector'])[['totdebt_invcap']].apply(modified_z)
df['dvpspm_sector_zscore'] = df.groupby(['year-month', 'sector'])[['dvpspm']].apply(modified_z)
df['dvpsxm_sector_zscore'] = df.groupby(['year-month', 'sector'])[['dvpsxm']].apply(modified_z)
df['dvrate_sector_zscore'] = df.groupby(['year-month', 'sector'])[['dvrate']].apply(modified_z)
df['spcsrc_sector_zscore'] = df.groupby(['year-month', 'sector'])[['spcsrc']].apply(modified_z)
df['alpha_sector_zscore'] = df.groupby(['year-month', 'sector'])[['alpha']].apply(modified_z)
df['b_hml_sector_zscore'] = df.groupby(['year-month', 'sector'])[['b_hml']].apply(modified_z)
df['b_mkt_sector_zscore'] = df.groupby(['year-month', 'sector'])[['b_mkt']].apply(modified_z)
df['b_smb_sector_zscore'] = df.groupby(['year-month', 'sector'])[['b_smb']].apply(modified_z)
df['b_umd_sector_zscore'] = df.groupby(['year-month', 'sector'])[['b_umd']].apply(modified_z)
df['exret_sector_zscore'] = df.groupby(['year-month', 'sector'])[['exret']].apply(modified_z)
df['ivol_sector_zscore'] = df.groupby(['year-month', 'sector'])[['ivol']].apply(modified_z)
df['n_sector_zscore'] = df.groupby(['year-month', 'sector'])[['n']].apply(modified_z)
df['R2_sector_zscore'] = df.groupby(['year-month', 'sector'])[['R2']].apply(modified_z)
df['tvol_sector_zscore'] = df.groupby(['year-month', 'sector'])[['tvol']].apply(modified_z)
df['BUYPCT_sector_zscore'] = df.groupby(['year-month', 'sector'])[['BUYPCT']].apply(modified_z)
df['HOLDPCT_sector_zscore'] = df.groupby(['year-month', 'sector'])[['HOLDPCT']].apply(modified_z)
df['MEANREC_sector_zscore'] = df.groupby(['year-month', 'sector'])[['MEANREC']].apply(modified_z)
df['MEDREC_sector_zscore'] = df.groupby(['year-month', 'sector'])[['MEDREC']].apply(modified_z)
df['recup_sector_zscore'] = df.groupby(['year-month', 'sector'])[['recup']].apply(modified_z)
df['recdown_sector_zscore'] = df.groupby(['year-month', 'sector'])[['recdown']].apply(modified_z)
df['SELLPCT_sector_zscore'] = df.groupby(['year-month', 'sector'])[['SELLPCT']].apply(modified_z)
df['STDEV_sector_zscore'] = df.groupby(['year-month', 'sector'])[['STDEV']].apply(modified_z)

# %%
# df - Clean - All - Fill N/A's
df = df.groupby(['GVKEY'], as_index=False).apply(lambda group: group.ffill())
df = df.groupby(['GVKEY'], as_index=False).apply(lambda group: group.bfill())
df = df.groupby(['sector'], as_index=False).apply(lambda group: group.ffill())
df = df.groupby(['sector'], as_index=False).apply(lambda group: group.bfill())
df = df.fillna(method='ffill')
df = df.fillna(method='bfill')

# %%
# df - Clean - Clip outliers

# By Sector

# Dependent Variables

df['forward_one_month_return'] = df.groupby(['year-month', 'sector'])[['forward_one_month_return']].apply(clip_outliers)
df['forward_two_month_return'] = df.groupby(['year-month', 'sector'])[['forward_two_month_return']].apply(clip_outliers)
df['forward_three_month_return'] = df.groupby(['year-month', 'sector'])[['forward_three_month_return']].apply(clip_outliers)
df['forward_four_month_return'] = df.groupby(['year-month', 'sector'])[['forward_four_month_return']].apply(clip_outliers)
df['forward_five_month_return'] = df.groupby(['year-month', 'sector'])[['forward_five_month_return']].apply(clip_outliers)
df['forward_six_month_return'] = df.groupby(['year-month', 'sector'])[['forward_six_month_return']].apply(clip_outliers)
df['forward_seven_month_return'] = df.groupby(['year-month', 'sector'])[['forward_seven_month_return']].apply(clip_outliers)
df['forward_eight_month_return'] = df.groupby(['year-month', 'sector'])[['forward_eight_month_return']].apply(clip_outliers)
df['forward_nine_month_return'] = df.groupby(['year-month', 'sector'])[['forward_nine_month_return']].apply(clip_outliers)
df['forward_ten_month_return'] = df.groupby(['year-month', 'sector'])[['forward_ten_month_return']].apply(clip_outliers)
df['forward_eleven_month_return'] = df.groupby(['year-month', 'sector'])[['forward_eleven_month_return']].apply(clip_outliers)
df['forward_twelve_month_return'] = df.groupby(['year-month', 'sector'])[['forward_twelve_month_return']].apply(clip_outliers)
df['forward_thirteen_month_return'] = df.groupby(['year-month', 'sector'])[['forward_thirteen_month_return']].apply(clip_outliers)
df['forward_fourteen_month_return'] = df.groupby(['year-month', 'sector'])[['forward_fourteen_month_return']].apply(clip_outliers)
df['forward_fifteen_month_return'] = df.groupby(['year-month', 'sector'])[['forward_fifteen_month_return']].apply(clip_outliers)
df['forward_sixteen_month_return'] = df.groupby(['year-month', 'sector'])[['forward_sixteen_month_return']].apply(clip_outliers)
df['forward_seventeen_month_return'] = df.groupby(['year-month', 'sector'])[['forward_seventeen_month_return']].apply(clip_outliers)
df['forward_eighteen_month_return'] = df.groupby(['year-month', 'sector'])[['forward_eighteen_month_return']].apply(clip_outliers)
df['forward_nineteen_month_return'] = df.groupby(['year-month', 'sector'])[['forward_nineteen_month_return']].apply(clip_outliers)
df['forward_twenty_month_return'] = df.groupby(['year-month', 'sector'])[['forward_twenty_month_return']].apply(clip_outliers)
df['forward_twentyone_month_return'] = df.groupby(['year-month', 'sector'])[['forward_twentyone_month_return']].apply(clip_outliers)
df['forward_twentytwo_month_return'] = df.groupby(['year-month', 'sector'])[['forward_twentytwo_month_return']].apply(clip_outliers)
df['forward_twentythree_month_return'] = df.groupby(['year-month', 'sector'])[['forward_twentythree_month_return']].apply(clip_outliers)
df['forward_twentyfour_month_return'] = df.groupby(['year-month', 'sector'])[['forward_twentyfour_month_return']].apply(clip_outliers)
df['forward_twentyfive_month_return'] = df.groupby(['year-month', 'sector'])[['forward_twentyfive_month_return']].apply(clip_outliers)
df['forward_twentysix_month_return'] = df.groupby(['year-month', 'sector'])[['forward_twentysix_month_return']].apply(clip_outliers)
df['forward_twentyseven_month_return'] = df.groupby(['year-month', 'sector'])[['forward_twentyseven_month_return']].apply(clip_outliers)
df['forward_twentyeight_month_return'] = df.groupby(['year-month', 'sector'])[['forward_twentyeight_month_return']].apply(clip_outliers)
df['forward_twentynine_month_return'] = df.groupby(['year-month', 'sector'])[['forward_twentynine_month_return']].apply(clip_outliers)
df['forward_thirty_month_return'] = df.groupby(['year-month', 'sector'])[['forward_thirty_month_return']].apply(clip_outliers)
df['forward_thirtyone_month_return'] = df.groupby(['year-month', 'sector'])[['forward_thirtyone_month_return']].apply(clip_outliers)
df['forward_thirtytwo_month_return'] = df.groupby(['year-month', 'sector'])[['forward_thirtytwo_month_return']].apply(clip_outliers)
df['forward_thirtythree_month_return'] = df.groupby(['year-month', 'sector'])[['forward_thirtythree_month_return']].apply(clip_outliers)
df['forward_thirtyfour_month_return'] = df.groupby(['year-month', 'sector'])[['forward_thirtyfour_month_return']].apply(clip_outliers)
df['forward_thirtyfive_month_return'] = df.groupby(['year-month', 'sector'])[['forward_thirtyfive_month_return']].apply(clip_outliers)
df['forward_thirtysix_month_return'] = df.groupby(['year-month', 'sector'])[['forward_thirtysix_month_return']].apply(clip_outliers)

# Independent Variables
df['past_one_month_return'] = df.groupby(['year-month', 'sector'])[['past_one_month_return']].apply(clip_outliers)
df['past_two_month_return'] = df.groupby(['year-month', 'sector'])[['past_two_month_return']].apply(clip_outliers)
df['past_three_month_return'] = df.groupby(['year-month', 'sector'])[['past_three_month_return']].apply(clip_outliers)
df['past_four_month_return'] = df.groupby(['year-month', 'sector'])[['past_four_month_return']].apply(clip_outliers)
df['past_five_month_return'] = df.groupby(['year-month', 'sector'])[['past_five_month_return']].apply(clip_outliers)
df['past_six_month_return'] = df.groupby(['year-month', 'sector'])[['past_six_month_return']].apply(clip_outliers)
df['past_seven_month_return'] = df.groupby(['year-month', 'sector'])[['past_seven_month_return']].apply(clip_outliers)
df['past_eight_month_return'] = df.groupby(['year-month', 'sector'])[['past_eight_month_return']].apply(clip_outliers)
df['past_nine_month_return'] = df.groupby(['year-month', 'sector'])[['past_nine_month_return']].apply(clip_outliers)
df['past_ten_month_return'] = df.groupby(['year-month', 'sector'])[['past_ten_month_return']].apply(clip_outliers)
df['past_eleven_month_return'] = df.groupby(['year-month', 'sector'])[['past_eleven_month_return']].apply(clip_outliers)
df['past_twelve_month_return'] = df.groupby(['year-month', 'sector'])[['past_twelve_month_return']].apply(clip_outliers)
df['past_thirteen_month_return'] = df.groupby(['year-month', 'sector'])[['past_thirteen_month_return']].apply(clip_outliers)
df['past_fourteen_month_return'] = df.groupby(['year-month', 'sector'])[['past_fourteen_month_return']].apply(clip_outliers)
df['past_fifteen_month_return'] = df.groupby(['year-month', 'sector'])[['past_fifteen_month_return']].apply(clip_outliers)
df['past_sixteen_month_return'] = df.groupby(['year-month', 'sector'])[['past_sixteen_month_return']].apply(clip_outliers)
df['past_seventeen_month_return'] = df.groupby(['year-month', 'sector'])[['past_seventeen_month_return']].apply(clip_outliers)
df['past_eighteen_month_return'] = df.groupby(['year-month', 'sector'])[['past_eighteen_month_return']].apply(clip_outliers)
df['past_nineteen_month_return'] = df.groupby(['year-month', 'sector'])[['past_nineteen_month_return']].apply(clip_outliers)
df['past_twenty_month_return'] = df.groupby(['year-month', 'sector'])[['past_twenty_month_return']].apply(clip_outliers)
df['past_twentyone_month_return'] = df.groupby(['year-month', 'sector'])[['past_twentyone_month_return']].apply(clip_outliers)
df['past_twentytwo_month_return'] = df.groupby(['year-month', 'sector'])[['past_twentytwo_month_return']].apply(clip_outliers)
df['past_twentythree_month_return'] = df.groupby(['year-month', 'sector'])[['past_twentythree_month_return']].apply(clip_outliers)
df['past_twentyfour_month_return'] = df.groupby(['year-month', 'sector'])[['past_twentyfour_month_return']].apply(clip_outliers)
df['past_twentyfive_month_return'] = df.groupby(['year-month', 'sector'])[['past_twentyfive_month_return']].apply(clip_outliers)
df['past_twentysix_month_return'] = df.groupby(['year-month', 'sector'])[['past_twentysix_month_return']].apply(clip_outliers)
df['past_twentyseven_month_return'] = df.groupby(['year-month', 'sector'])[['past_twentyseven_month_return']].apply(clip_outliers)
df['past_twentyeight_month_return'] = df.groupby(['year-month', 'sector'])[['past_twentyeight_month_return']].apply(clip_outliers)
df['past_twentynine_month_return'] = df.groupby(['year-month', 'sector'])[['past_twentynine_month_return']].apply(clip_outliers)
df['past_thirty_month_return'] = df.groupby(['year-month', 'sector'])[['past_thirty_month_return']].apply(clip_outliers)
df['past_thirtyone_month_return'] = df.groupby(['year-month', 'sector'])[['past_thirtyone_month_return']].apply(clip_outliers)
df['past_thirtytwo_month_return'] = df.groupby(['year-month', 'sector'])[['past_thirtytwo_month_return']].apply(clip_outliers)
df['past_thirtythree_month_return'] = df.groupby(['year-month', 'sector'])[['past_thirtythree_month_return']].apply(clip_outliers)
df['past_thirtyfour_month_return'] = df.groupby(['year-month', 'sector'])[['past_thirtyfour_month_return']].apply(clip_outliers)
df['past_thirtyfive_month_return'] = df.groupby(['year-month', 'sector'])[['past_thirtyfive_month_return']].apply(clip_outliers)
df['past_thirtysix_month_return'] = df.groupby(['year-month', 'sector'])[['past_thirtysix_month_return']].apply(clip_outliers)
df['accrual'] = df.groupby(['year-month', 'sector'])[['accrual']].apply(clip_outliers)
df['adv_sale'] = df.groupby(['year-month', 'sector'])[['adv_sale']].apply(clip_outliers)
df['aftret_eq'] = df.groupby(['year-month', 'sector'])[['aftret_eq']].apply(clip_outliers)
df['aftret_equity'] = df.groupby(['year-month', 'sector'])[['aftret_equity']].apply(clip_outliers)
df['aftret_invcapx'] = df.groupby(['year-month', 'sector'])[['aftret_invcapx']].apply(clip_outliers)
df['at_turn'] = df.groupby(['year-month', 'sector'])[['at_turn']].apply(clip_outliers)
df['bm'] = df.groupby(['year-month', 'sector'])[['bm']].apply(clip_outliers)
df['CAPEI'] = df.groupby(['year-month', 'sector'])[['CAPEI']].apply(clip_outliers)
df['capital_ratio'] = df.groupby(['year-month', 'sector'])[['capital_ratio']].apply(clip_outliers)
df['cash_conversion'] = df.groupby(['year-month', 'sector'])[['cash_conversion']].apply(clip_outliers)
df['cash_debt'] = df.groupby(['year-month', 'sector'])[['cash_debt']].apply(clip_outliers)
df['cash_lt'] = df.groupby(['year-month', 'sector'])[['cash_lt']].apply(clip_outliers)
df['cash_ratio'] = df.groupby(['year-month', 'sector'])[['cash_ratio']].apply(clip_outliers)
df['cfm'] = df.groupby(['year-month', 'sector'])[['cfm']].apply(clip_outliers)
df['curr_debt'] = df.groupby(['year-month', 'sector'])[['curr_debt']].apply(clip_outliers)
df['curr_ratio'] = df.groupby(['year-month', 'sector'])[['curr_ratio']].apply(clip_outliers)
df['de_ratio'] = df.groupby(['year-month', 'sector'])[['de_ratio']].apply(clip_outliers)
df['debt_assets'] = df.groupby(['year-month', 'sector'])[['debt_assets']].apply(clip_outliers)
df['debt_at'] = df.groupby(['year-month', 'sector'])[['debt_at']].apply(clip_outliers)
df['debt_capital'] = df.groupby(['year-month', 'sector'])[['debt_capital']].apply(clip_outliers)
df['debt_ebitda'] = df.groupby(['year-month', 'sector'])[['debt_ebitda']].apply(clip_outliers)
df['debt_invcap'] = df.groupby(['year-month', 'sector'])[['debt_invcap']].apply(clip_outliers)
df['DIVYIELD'] = df.groupby(['year-month', 'sector'])[['DIVYIELD']].apply(clip_outliers)
df['dltt_be'] = df.groupby(['year-month', 'sector'])[['dltt_be']].apply(clip_outliers)
df['dpr'] = df.groupby(['year-month', 'sector'])[['dpr']].apply(clip_outliers)
df['efftax'] = df.groupby(['year-month', 'sector'])[['efftax']].apply(clip_outliers)
df['equity_invcap'] = df.groupby(['year-month', 'sector'])[['equity_invcap']].apply(clip_outliers)
df['evm'] = df.groupby(['year-month', 'sector'])[['evm']].apply(clip_outliers)
df['fcf_ocf'] = df.groupby(['year-month', 'sector'])[['fcf_ocf']].apply(clip_outliers)
df['gpm'] = df.groupby(['year-month', 'sector'])[['gpm']].apply(clip_outliers)
df['GProf'] = df.groupby(['year-month', 'sector'])[['GProf']].apply(clip_outliers)
df['int_debt'] = df.groupby(['year-month', 'sector'])[['int_debt']].apply(clip_outliers)
df['int_totdebt'] = df.groupby(['year-month', 'sector'])[['int_totdebt']].apply(clip_outliers)
df['intcov'] = df.groupby(['year-month', 'sector'])[['intcov']].apply(clip_outliers)
df['intcov_ratio'] = df.groupby(['year-month', 'sector'])[['intcov_ratio']].apply(clip_outliers)
df['inv_turn'] = df.groupby(['year-month', 'sector'])[['inv_turn']].apply(clip_outliers)
df['invt_act'] = df.groupby(['year-month', 'sector'])[['invt_act']].apply(clip_outliers)
df['lt_debt'] = df.groupby(['year-month', 'sector'])[['lt_debt']].apply(clip_outliers)
df['lt_ppent'] = df.groupby(['year-month', 'sector'])[['lt_ppent']].apply(clip_outliers)
df['npm'] = df.groupby(['year-month', 'sector'])[['npm']].apply(clip_outliers)
df['ocf_lct'] = df.groupby(['year-month', 'sector'])[['ocf_lct']].apply(clip_outliers)
df['opmad'] = df.groupby(['year-month', 'sector'])[['opmad']].apply(clip_outliers)
df['opmbd'] = df.groupby(['year-month', 'sector'])[['opmbd']].apply(clip_outliers)
df['pay_turn'] = df.groupby(['year-month', 'sector'])[['pay_turn']].apply(clip_outliers)
df['pcf'] = df.groupby(['year-month', 'sector'])[['pcf']].apply(clip_outliers)
df['pe_exi'] = df.groupby(['year-month', 'sector'])[['pe_exi']].apply(clip_outliers)
df['pe_inc'] = df.groupby(['year-month', 'sector'])[['pe_inc']].apply(clip_outliers)
df['pe_op_basic'] = df.groupby(['year-month', 'sector'])[['pe_op_basic']].apply(clip_outliers)
df['pe_op_dil'] = df.groupby(['year-month', 'sector'])[['pe_op_dil']].apply(clip_outliers)
df['PEG_1yrforward'] = df.groupby(['year-month', 'sector'])[['PEG_1yrforward']].apply(clip_outliers)
df['PEG_ltgforward'] = df.groupby(['year-month', 'sector'])[['PEG_ltgforward']].apply(clip_outliers)
df['PEG_trailing'] = df.groupby(['year-month', 'sector'])[['PEG_trailing']].apply(clip_outliers)
df['pretret_earnat'] = df.groupby(['year-month', 'sector'])[['pretret_earnat']].apply(clip_outliers)
df['pretret_noa'] = df.groupby(['year-month', 'sector'])[['pretret_noa']].apply(clip_outliers)
df['profit_lct'] = df.groupby(['year-month', 'sector'])[['profit_lct']].apply(clip_outliers)
df['ps'] = df.groupby(['year-month', 'sector'])[['ps']].apply(clip_outliers)
df['ptb'] = df.groupby(['year-month', 'sector'])[['ptb']].apply(clip_outliers)
df['ptpm'] = df.groupby(['year-month', 'sector'])[['ptpm']].apply(clip_outliers)
df['quick_ratio'] = df.groupby(['year-month', 'sector'])[['quick_ratio']].apply(clip_outliers)
df['rd_sale'] = df.groupby(['year-month', 'sector'])[['rd_sale']].apply(clip_outliers)
df['rect_act'] = df.groupby(['year-month', 'sector'])[['rect_act']].apply(clip_outliers)
df['rect_turn'] = df.groupby(['year-month', 'sector'])[['rect_turn']].apply(clip_outliers)
df['roa'] = df.groupby(['year-month', 'sector'])[['roa']].apply(clip_outliers)
df['roce'] = df.groupby(['year-month', 'sector'])[['roce']].apply(clip_outliers)
df['roe'] = df.groupby(['year-month', 'sector'])[['roe']].apply(clip_outliers)
df['sale_equity'] = df.groupby(['year-month', 'sector'])[['sale_equity']].apply(clip_outliers)
df['sale_invcap'] = df.groupby(['year-month', 'sector'])[['sale_invcap']].apply(clip_outliers)
df['sale_nwc'] = df.groupby(['year-month', 'sector'])[['sale_nwc']].apply(clip_outliers)
df['short_debt'] = df.groupby(['year-month', 'sector'])[['short_debt']].apply(clip_outliers)
df['staff_sale'] = df.groupby(['year-month', 'sector'])[['staff_sale']].apply(clip_outliers)
df['totdebt_invcap'] = df.groupby(['year-month', 'sector'])[['totdebt_invcap']].apply(clip_outliers)
df['dvpspm'] = df.groupby(['year-month', 'sector'])[['dvpspm']].apply(clip_outliers)
df['dvpsxm'] = df.groupby(['year-month', 'sector'])[['dvpsxm']].apply(clip_outliers)
df['dvrate'] = df.groupby(['year-month', 'sector'])[['dvrate']].apply(clip_outliers)
df['spcsrc'] = df.groupby(['year-month', 'sector'])[['spcsrc']].apply(clip_outliers)
df['alpha'] = df.groupby(['year-month', 'sector'])[['alpha']].apply(clip_outliers)
df['b_hml'] = df.groupby(['year-month', 'sector'])[['b_hml']].apply(clip_outliers)
df['b_mkt'] = df.groupby(['year-month', 'sector'])[['b_mkt']].apply(clip_outliers)
df['b_smb'] = df.groupby(['year-month', 'sector'])[['b_smb']].apply(clip_outliers)
df['b_umd'] = df.groupby(['year-month', 'sector'])[['b_umd']].apply(clip_outliers)
df['exret'] = df.groupby(['year-month', 'sector'])[['exret']].apply(clip_outliers)
df['ivol'] = df.groupby(['year-month', 'sector'])[['ivol']].apply(clip_outliers)
df['n'] = df.groupby(['year-month', 'sector'])[['n']].apply(clip_outliers)
df['R2'] = df.groupby(['year-month', 'sector'])[['R2']].apply(clip_outliers)
df['tvol'] = df.groupby(['year-month', 'sector'])[['tvol']].apply(clip_outliers)
df['BUYPCT'] = df.groupby(['year-month', 'sector'])[['BUYPCT']].apply(clip_outliers)
df['HOLDPCT'] = df.groupby(['year-month', 'sector'])[['HOLDPCT']].apply(clip_outliers)
df['SELLPCT'] = df.groupby(['year-month', 'sector'])[['SELLPCT']].apply(clip_outliers)
df['MEANREC'] = df.groupby(['year-month', 'sector'])[['MEANREC']].apply(clip_outliers)
df['MEDREC'] = df.groupby(['year-month', 'sector'])[['MEDREC']].apply(clip_outliers)
df['recup'] = df.groupby(['year-month', 'sector'])[['recup']].apply(clip_outliers)
df['recdown'] = df.groupby(['year-month', 'sector'])[['recdown']].apply(clip_outliers)
df['STDEV'] = df.groupby(['year-month', 'sector'])[['STDEV']].apply(clip_outliers)
df['past_one_month_return_zscore'] = df.groupby(['year-month', 'sector'])[['past_one_month_return_zscore']].apply(clip_outliers)
df['past_two_month_return_zscore'] = df.groupby(['year-month', 'sector'])[['past_two_month_return_zscore']].apply(clip_outliers)
df['past_three_month_return_zscore'] = df.groupby(['year-month', 'sector'])[['past_three_month_return_zscore']].apply(clip_outliers)
df['past_four_month_return_zscore'] = df.groupby(['year-month', 'sector'])[['past_four_month_return_zscore']].apply(clip_outliers)
df['past_five_month_return_zscore'] = df.groupby(['year-month', 'sector'])[['past_five_month_return_zscore']].apply(clip_outliers)
df['past_six_month_return_zscore'] = df.groupby(['year-month', 'sector'])[['past_six_month_return_zscore']].apply(clip_outliers)
df['past_seven_month_return_zscore'] = df.groupby(['year-month', 'sector'])[['past_seven_month_return_zscore']].apply(clip_outliers)
df['past_eight_month_return_zscore'] = df.groupby(['year-month', 'sector'])[['past_eight_month_return_zscore']].apply(clip_outliers)
df['past_nine_month_return_zscore'] = df.groupby(['year-month', 'sector'])[['past_nine_month_return_zscore']].apply(clip_outliers)
df['past_ten_month_return_zscore'] = df.groupby(['year-month', 'sector'])[['past_ten_month_return_zscore']].apply(clip_outliers)
df['past_eleven_month_return_zscore'] = df.groupby(['year-month', 'sector'])[['past_eleven_month_return_zscore']].apply(clip_outliers)
df['past_twelve_month_return_zscore'] = df.groupby(['year-month', 'sector'])[['past_twelve_month_return_zscore']].apply(clip_outliers)
df['past_thirteen_month_return_zscore'] = df.groupby(['year-month', 'sector'])[['past_thirteen_month_return_zscore']].apply(clip_outliers)
df['past_fourteen_month_return_zscore'] = df.groupby(['year-month', 'sector'])[['past_fourteen_month_return_zscore']].apply(clip_outliers)
df['past_fifteen_month_return_zscore'] = df.groupby(['year-month', 'sector'])[['past_fifteen_month_return_zscore']].apply(clip_outliers)
df['past_sixteen_month_return_zscore'] = df.groupby(['year-month', 'sector'])[['past_sixteen_month_return_zscore']].apply(clip_outliers)
df['past_seventeen_month_return_zscore'] = df.groupby(['year-month', 'sector'])[['past_seventeen_month_return_zscore']].apply(clip_outliers)
df['past_eighteen_month_return_zscore'] = df.groupby(['year-month', 'sector'])[['past_eighteen_month_return_zscore']].apply(clip_outliers)
df['past_nineteen_month_return_zscore'] = df.groupby(['year-month', 'sector'])[['past_nineteen_month_return_zscore']].apply(clip_outliers)
df['past_twenty_month_return_zscore'] = df.groupby(['year-month', 'sector'])[['past_twenty_month_return_zscore']].apply(clip_outliers)
df['past_twentyone_month_return_zscore'] = df.groupby(['year-month', 'sector'])[['past_twentyone_month_return_zscore']].apply(clip_outliers)
df['past_twentytwo_month_return_zscore'] = df.groupby(['year-month', 'sector'])[['past_twentytwo_month_return_zscore']].apply(clip_outliers)
df['past_twentythree_month_return_zscore'] = df.groupby(['year-month', 'sector'])[['past_twentythree_month_return_zscore']].apply(clip_outliers)
df['past_twentyfour_month_return_zscore'] = df.groupby(['year-month', 'sector'])[['past_twentyfour_month_return_zscore']].apply(clip_outliers)
df['past_twentyfive_month_return_zscore'] = df.groupby(['year-month', 'sector'])[['past_twentyfive_month_return_zscore']].apply(clip_outliers)
df['past_twentysix_month_return_zscore'] = df.groupby(['year-month', 'sector'])[['past_twentysix_month_return_zscore']].apply(clip_outliers)
df['past_twentyseven_month_return_zscore'] = df.groupby(['year-month', 'sector'])[['past_twentyseven_month_return_zscore']].apply(clip_outliers)
df['past_twentyeight_month_return_zscore'] = df.groupby(['year-month', 'sector'])[['past_twentyeight_month_return_zscore']].apply(clip_outliers)
df['past_twentynine_month_return_zscore'] = df.groupby(['year-month', 'sector'])[['past_twentynine_month_return_zscore']].apply(clip_outliers)
df['past_thirty_month_return_zscore'] = df.groupby(['year-month', 'sector'])[['past_thirty_month_return_zscore']].apply(clip_outliers)
df['past_thirtyone_month_return_zscore'] = df.groupby(['year-month', 'sector'])[['past_thirtyone_month_return_zscore']].apply(clip_outliers)
df['past_thirtytwo_month_return_zscore'] = df.groupby(['year-month', 'sector'])[['past_thirtytwo_month_return_zscore']].apply(clip_outliers)
df['past_thirtythree_month_return_zscore'] = df.groupby(['year-month', 'sector'])[['past_thirtythree_month_return_zscore']].apply(clip_outliers)
df['past_thirtyfour_month_return_zscore'] = df.groupby(['year-month', 'sector'])[['past_thirtyfour_month_return_zscore']].apply(clip_outliers)
df['past_thirtyfive_month_return_zscore'] = df.groupby(['year-month', 'sector'])[['past_thirtyfive_month_return_zscore']].apply(clip_outliers)
df['past_thirtysix_month_return_zscore'] = df.groupby(['year-month', 'sector'])[['past_thirtysix_month_return_zscore']].apply(clip_outliers)
df['accrual_zscore'] = df.groupby(['year-month', 'sector'])[['accrual_zscore']].apply(clip_outliers)
df['adv_sale_zscore'] = df.groupby(['year-month', 'sector'])[['adv_sale_zscore']].apply(clip_outliers)
df['aftret_eq_zscore'] = df.groupby(['year-month', 'sector'])[['aftret_eq_zscore']].apply(clip_outliers)
df['aftret_equity_zscore'] = df.groupby(['year-month', 'sector'])[['aftret_equity_zscore']].apply(clip_outliers)
df['aftret_invcapx_zscore'] = df.groupby(['year-month', 'sector'])[['aftret_invcapx_zscore']].apply(clip_outliers)
df['at_turn_zscore'] = df.groupby(['year-month', 'sector'])[['at_turn_zscore']].apply(clip_outliers)
df['bm_zscore'] = df.groupby(['year-month', 'sector'])[['bm_zscore']].apply(clip_outliers)
df['CAPEI_zscore'] = df.groupby(['year-month', 'sector'])[['CAPEI_zscore']].apply(clip_outliers)
df['capital_ratio_zscore'] = df.groupby(['year-month', 'sector'])[['capital_ratio_zscore']].apply(clip_outliers)
df['cash_conversion_zscore'] = df.groupby(['year-month', 'sector'])[['cash_conversion_zscore']].apply(clip_outliers)
df['cash_debt_zscore'] = df.groupby(['year-month', 'sector'])[['cash_debt_zscore']].apply(clip_outliers)
df['cash_lt_zscore'] = df.groupby(['year-month', 'sector'])[['cash_lt_zscore']].apply(clip_outliers)
df['cash_ratio_zscore'] = df.groupby(['year-month', 'sector'])[['cash_ratio_zscore']].apply(clip_outliers)
df['cfm_zscore'] = df.groupby(['year-month', 'sector'])[['cfm_zscore']].apply(clip_outliers)
df['curr_debt_zscore'] = df.groupby(['year-month', 'sector'])[['curr_debt_zscore']].apply(clip_outliers)
df['curr_ratio_zscore'] = df.groupby(['year-month', 'sector'])[['curr_ratio_zscore']].apply(clip_outliers)
df['de_ratio_zscore'] = df.groupby(['year-month', 'sector'])[['de_ratio_zscore']].apply(clip_outliers)
df['debt_assets_zscore'] = df.groupby(['year-month', 'sector'])[['debt_assets_zscore']].apply(clip_outliers)
df['debt_at_zscore'] = df.groupby(['year-month', 'sector'])[['debt_at_zscore']].apply(clip_outliers)
df['debt_capital_zscore'] = df.groupby(['year-month', 'sector'])[['debt_capital_zscore']].apply(clip_outliers)
df['debt_ebitda_zscore'] = df.groupby(['year-month', 'sector'])[['debt_ebitda_zscore']].apply(clip_outliers)
df['debt_invcap_zscore'] = df.groupby(['year-month', 'sector'])[['debt_invcap_zscore']].apply(clip_outliers)
df['DIVYIELD_zscore'] = df.groupby(['year-month', 'sector'])[['DIVYIELD_zscore']].apply(clip_outliers)
df['dltt_be_zscore'] = df.groupby(['year-month', 'sector'])[['dltt_be_zscore']].apply(clip_outliers)
df['dpr_zscore'] = df.groupby(['year-month', 'sector'])[['dpr_zscore']].apply(clip_outliers)
df['efftax_zscore'] = df.groupby(['year-month', 'sector'])[['efftax_zscore']].apply(clip_outliers)
df['equity_invcap_zscore'] = df.groupby(['year-month', 'sector'])[['equity_invcap_zscore']].apply(clip_outliers)
df['evm_zscore'] = df.groupby(['year-month', 'sector'])[['evm_zscore']].apply(clip_outliers)
df['fcf_ocf_zscore'] = df.groupby(['year-month', 'sector'])[['fcf_ocf_zscore']].apply(clip_outliers)
df['gpm_zscore'] = df.groupby(['year-month', 'sector'])[['gpm_zscore']].apply(clip_outliers)
df['GProf_zscore'] = df.groupby(['year-month', 'sector'])[['GProf_zscore']].apply(clip_outliers)
df['int_debt_zscore'] = df.groupby(['year-month', 'sector'])[['int_debt_zscore']].apply(clip_outliers)
df['int_totdebt_zscore'] = df.groupby(['year-month', 'sector'])[['int_totdebt_zscore']].apply(clip_outliers)
df['intcov_zscore'] = df.groupby(['year-month', 'sector'])[['intcov_zscore']].apply(clip_outliers)
df['intcov_ratio_zscore'] = df.groupby(['year-month', 'sector'])[['intcov_ratio_zscore']].apply(clip_outliers)
df['inv_turn_zscore'] = df.groupby(['year-month', 'sector'])[['inv_turn_zscore']].apply(clip_outliers)
df['invt_act_zscore'] = df.groupby(['year-month', 'sector'])[['invt_act_zscore']].apply(clip_outliers)
df['lt_debt_zscore'] = df.groupby(['year-month', 'sector'])[['lt_debt_zscore']].apply(clip_outliers)
df['lt_ppent_zscore'] = df.groupby(['year-month', 'sector'])[['lt_ppent_zscore']].apply(clip_outliers)
df['npm_zscore'] = df.groupby(['year-month', 'sector'])[['npm_zscore']].apply(clip_outliers)
df['ocf_lct_zscore'] = df.groupby(['year-month', 'sector'])[['ocf_lct_zscore']].apply(clip_outliers)
df['opmad_zscore'] = df.groupby(['year-month', 'sector'])[['opmad_zscore']].apply(clip_outliers)
df['opmbd_zscore'] = df.groupby(['year-month', 'sector'])[['opmbd_zscore']].apply(clip_outliers)
df['pay_turn_zscore'] = df.groupby(['year-month', 'sector'])[['pay_turn_zscore']].apply(clip_outliers)
df['pcf_zscore'] = df.groupby(['year-month', 'sector'])[['pcf_zscore']].apply(clip_outliers)
df['pe_exi_zscore'] = df.groupby(['year-month', 'sector'])[['pe_exi_zscore']].apply(clip_outliers)
df['pe_inc_zscore'] = df.groupby(['year-month', 'sector'])[['pe_inc_zscore']].apply(clip_outliers)
df['pe_op_basic_zscore'] = df.groupby(['year-month', 'sector'])[['pe_op_basic_zscore']].apply(clip_outliers)
df['pe_op_dil_zscore'] = df.groupby(['year-month', 'sector'])[['pe_op_dil_zscore']].apply(clip_outliers)
df['PEG_1yrforward_zscore'] = df.groupby(['year-month', 'sector'])[['PEG_1yrforward_zscore']].apply(clip_outliers)
df['PEG_ltgforward_zscore'] = df.groupby(['year-month', 'sector'])[['PEG_ltgforward_zscore']].apply(clip_outliers)
df['PEG_trailing_zscore'] = df.groupby(['year-month', 'sector'])[['PEG_trailing_zscore']].apply(clip_outliers)
df['pretret_earnat_zscore'] = df.groupby(['year-month', 'sector'])[['pretret_earnat_zscore']].apply(clip_outliers)
df['pretret_noa_zscore'] = df.groupby(['year-month', 'sector'])[['pretret_noa_zscore']].apply(clip_outliers)
df['profit_lct_zscore'] = df.groupby(['year-month', 'sector'])[['profit_lct_zscore']].apply(clip_outliers)
df['ps_zscore'] = df.groupby(['year-month', 'sector'])[['ps_zscore']].apply(clip_outliers)
df['ptb_zscore'] = df.groupby(['year-month', 'sector'])[['ptb_zscore']].apply(clip_outliers)
df['ptpm_zscore'] = df.groupby(['year-month', 'sector'])[['ptpm_zscore']].apply(clip_outliers)
df['quick_ratio_zscore'] = df.groupby(['year-month', 'sector'])[['quick_ratio_zscore']].apply(clip_outliers)
df['rd_sale_zscore'] = df.groupby(['year-month', 'sector'])[['rd_sale_zscore']].apply(clip_outliers)
df['rect_act_zscore'] = df.groupby(['year-month', 'sector'])[['rect_act_zscore']].apply(clip_outliers)
df['rect_turn_zscore'] = df.groupby(['year-month', 'sector'])[['rect_turn_zscore']].apply(clip_outliers)
df['roa_zscore'] = df.groupby(['year-month', 'sector'])[['roa_zscore']].apply(clip_outliers)
df['roce_zscore'] = df.groupby(['year-month', 'sector'])[['roce_zscore']].apply(clip_outliers)
df['roe_zscore'] = df.groupby(['year-month', 'sector'])[['roe_zscore']].apply(clip_outliers)
df['sale_equity_zscore'] = df.groupby(['year-month', 'sector'])[['sale_equity_zscore']].apply(clip_outliers)
df['sale_invcap_zscore'] = df.groupby(['year-month', 'sector'])[['sale_invcap_zscore']].apply(clip_outliers)
df['sale_nwc_zscore'] = df.groupby(['year-month', 'sector'])[['sale_nwc_zscore']].apply(clip_outliers)
df['short_debt_zscore'] = df.groupby(['year-month', 'sector'])[['short_debt_zscore']].apply(clip_outliers)
df['staff_sale_zscore'] = df.groupby(['year-month', 'sector'])[['staff_sale_zscore']].apply(clip_outliers)
df['totdebt_invcap_zscore'] = df.groupby(['year-month', 'sector'])[['totdebt_invcap_zscore']].apply(clip_outliers)
df['dvpspm_zscore'] = df.groupby(['year-month', 'sector'])[['dvpspm_zscore']].apply(clip_outliers)
df['dvpsxm_zscore'] = df.groupby(['year-month', 'sector'])[['dvpsxm_zscore']].apply(clip_outliers)
df['dvrate_zscore'] = df.groupby(['year-month', 'sector'])[['dvrate_zscore']].apply(clip_outliers)
df['spcsrc_zscore'] = df.groupby(['year-month', 'sector'])[['spcsrc_zscore']].apply(clip_outliers)
df['alpha_zscore'] = df.groupby(['year-month', 'sector'])[['alpha_zscore']].apply(clip_outliers)
df['b_hml_zscore'] = df.groupby(['year-month', 'sector'])[['b_hml_zscore']].apply(clip_outliers)
df['b_mkt_zscore'] = df.groupby(['year-month', 'sector'])[['b_mkt_zscore']].apply(clip_outliers)
df['b_smb_zscore'] = df.groupby(['year-month', 'sector'])[['b_smb_zscore']].apply(clip_outliers)
df['b_umd_zscore'] = df.groupby(['year-month', 'sector'])[['b_umd_zscore']].apply(clip_outliers)
df['exret_zscore'] = df.groupby(['year-month', 'sector'])[['exret_zscore']].apply(clip_outliers)
df['ivol_zscore'] = df.groupby(['year-month', 'sector'])[['ivol_zscore']].apply(clip_outliers)
df['n_zscore'] = df.groupby(['year-month', 'sector'])[['n_zscore']].apply(clip_outliers)
df['R2_zscore'] = df.groupby(['year-month', 'sector'])[['R2_zscore']].apply(clip_outliers)
df['tvol_zscore'] = df.groupby(['year-month', 'sector'])[['tvol_zscore']].apply(clip_outliers)
df['BUYPCT_zscore'] = df.groupby(['year-month', 'sector'])[['BUYPCT_zscore']].apply(clip_outliers)
df['HOLDPCT_zscore'] = df.groupby(['year-month', 'sector'])[['HOLDPCT_zscore']].apply(clip_outliers)
df['MEANREC_zscore'] = df.groupby(['year-month', 'sector'])[['MEANREC_zscore']].apply(clip_outliers)
df['MEDREC_zscore'] = df.groupby(['year-month', 'sector'])[['MEDREC_zscore']].apply(clip_outliers)
df['recup_zscore'] = df.groupby(['year-month', 'sector'])[['recup_zscore']].apply(clip_outliers)
df['recdown_zscore'] = df.groupby(['year-month', 'sector'])[['recdown_zscore']].apply(clip_outliers)
df['SELLPCT_zscore'] = df.groupby(['year-month', 'sector'])[['SELLPCT_zscore']].apply(clip_outliers)
df['STDEV_zscore'] = df.groupby(['year-month', 'sector'])[['STDEV_zscore']].apply(clip_outliers)
df['past_one_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_one_month_return_sector_zscore']].apply(clip_outliers)
df['past_two_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_two_month_return_sector_zscore']].apply(clip_outliers)
df['past_three_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_three_month_return_sector_zscore']].apply(clip_outliers)
df['past_four_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_four_month_return_sector_zscore']].apply(clip_outliers)
df['past_five_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_five_month_return_sector_zscore']].apply(clip_outliers)
df['past_six_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_six_month_return_sector_zscore']].apply(clip_outliers)
df['past_seven_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_seven_month_return_sector_zscore']].apply(clip_outliers)
df['past_eight_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_eight_month_return_sector_zscore']].apply(clip_outliers)
df['past_nine_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_nine_month_return_sector_zscore']].apply(clip_outliers)
df['past_ten_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_ten_month_return_sector_zscore']].apply(clip_outliers)
df['past_eleven_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_eleven_month_return_sector_zscore']].apply(clip_outliers)
df['past_twelve_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_twelve_month_return_sector_zscore']].apply(clip_outliers)
df['past_thirteen_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_thirteen_month_return_sector_zscore']].apply(clip_outliers)
df['past_fourteen_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_fourteen_month_return_sector_zscore']].apply(clip_outliers)
df['past_fifteen_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_fifteen_month_return_sector_zscore']].apply(clip_outliers)
df['past_sixteen_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_sixteen_month_return_sector_zscore']].apply(clip_outliers)
df['past_seventeen_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_seventeen_month_return_sector_zscore']].apply(clip_outliers)
df['past_eighteen_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_eighteen_month_return_sector_zscore']].apply(clip_outliers)
df['past_nineteen_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_nineteen_month_return_sector_zscore']].apply(clip_outliers)
df['past_twenty_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_twenty_month_return_sector_zscore']].apply(clip_outliers)
df['past_twentyone_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_twentyone_month_return_sector_zscore']].apply(clip_outliers)
df['past_twentytwo_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_twentytwo_month_return_sector_zscore']].apply(clip_outliers)
df['past_twentythree_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_twentythree_month_return_sector_zscore']].apply(clip_outliers)
df['past_twentyfour_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_twentyfour_month_return_sector_zscore']].apply(clip_outliers)
df['past_twentyfive_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_twentyfive_month_return_sector_zscore']].apply(clip_outliers)
df['past_twentysix_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_twentysix_month_return_sector_zscore']].apply(clip_outliers)
df['past_twentyseven_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_twentyseven_month_return_sector_zscore']].apply(clip_outliers)
df['past_twentyeight_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_twentyeight_month_return_sector_zscore']].apply(clip_outliers)
df['past_twentynine_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_twentynine_month_return_sector_zscore']].apply(clip_outliers)
df['past_thirty_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_thirty_month_return_sector_zscore']].apply(clip_outliers)
df['past_thirtyone_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_thirtyone_month_return_sector_zscore']].apply(clip_outliers)
df['past_thirtytwo_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_thirtytwo_month_return_sector_zscore']].apply(clip_outliers)
df['past_thirtythree_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_thirtythree_month_return_sector_zscore']].apply(clip_outliers)
df['past_thirtyfour_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_thirtyfour_month_return_sector_zscore']].apply(clip_outliers)
df['past_thirtyfive_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_thirtyfive_month_return_sector_zscore']].apply(clip_outliers)
df['past_thirtysix_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_thirtysix_month_return_sector_zscore']].apply(clip_outliers)
df['accrual_sector_zscore'] = df.groupby(['year-month', 'sector'])[['accrual_sector_zscore']].apply(clip_outliers)
df['adv_sale_sector_zscore'] = df.groupby(['year-month', 'sector'])[['adv_sale_sector_zscore']].apply(clip_outliers)
df['aftret_eq_sector_zscore'] = df.groupby(['year-month', 'sector'])[['aftret_eq_sector_zscore']].apply(clip_outliers)
df['aftret_equity_sector_zscore'] = df.groupby(['year-month', 'sector'])[['aftret_equity_sector_zscore']].apply(clip_outliers)
df['aftret_invcapx_sector_zscore'] = df.groupby(['year-month', 'sector'])[['aftret_invcapx_sector_zscore']].apply(clip_outliers)
df['at_turn_sector_zscore'] = df.groupby(['year-month', 'sector'])[['at_turn_sector_zscore']].apply(clip_outliers)
df['bm_sector_zscore'] = df.groupby(['year-month', 'sector'])[['bm_sector_zscore']].apply(clip_outliers)
df['CAPEI_sector_zscore'] = df.groupby(['year-month', 'sector'])[['CAPEI_sector_zscore']].apply(clip_outliers)
df['capital_ratio_sector_zscore'] = df.groupby(['year-month', 'sector'])[['capital_ratio_sector_zscore']].apply(clip_outliers)
df['cash_conversion_sector_zscore'] = df.groupby(['year-month', 'sector'])[['cash_conversion_sector_zscore']].apply(clip_outliers)
df['cash_debt_sector_zscore'] = df.groupby(['year-month', 'sector'])[['cash_debt_sector_zscore']].apply(clip_outliers)
df['cash_lt_sector_zscore'] = df.groupby(['year-month', 'sector'])[['cash_lt_sector_zscore']].apply(clip_outliers)
df['cash_ratio_sector_zscore'] = df.groupby(['year-month', 'sector'])[['cash_ratio_sector_zscore']].apply(clip_outliers)
df['cfm_sector_zscore'] = df.groupby(['year-month', 'sector'])[['cfm_sector_zscore']].apply(clip_outliers)
df['curr_debt_sector_zscore'] = df.groupby(['year-month', 'sector'])[['curr_debt_sector_zscore']].apply(clip_outliers)
df['curr_ratio_sector_zscore'] = df.groupby(['year-month', 'sector'])[['curr_ratio_sector_zscore']].apply(clip_outliers)
df['de_ratio_sector_zscore'] = df.groupby(['year-month', 'sector'])[['de_ratio_sector_zscore']].apply(clip_outliers)
df['debt_assets_sector_zscore'] = df.groupby(['year-month', 'sector'])[['debt_assets_sector_zscore']].apply(clip_outliers)
df['debt_at_sector_zscore'] = df.groupby(['year-month', 'sector'])[['debt_at_sector_zscore']].apply(clip_outliers)
df['debt_capital_sector_zscore'] = df.groupby(['year-month', 'sector'])[['debt_capital_sector_zscore']].apply(clip_outliers)
df['debt_ebitda_sector_zscore'] = df.groupby(['year-month', 'sector'])[['debt_ebitda_sector_zscore']].apply(clip_outliers)
df['debt_invcap_sector_zscore'] = df.groupby(['year-month', 'sector'])[['debt_invcap_sector_zscore']].apply(clip_outliers)
df['DIVYIELD_sector_zscore'] = df.groupby(['year-month', 'sector'])[['DIVYIELD_sector_zscore']].apply(clip_outliers)
df['dltt_be_sector_zscore'] = df.groupby(['year-month', 'sector'])[['dltt_be_sector_zscore']].apply(clip_outliers)
df['dpr_sector_zscore'] = df.groupby(['year-month', 'sector'])[['dpr_sector_zscore']].apply(clip_outliers)
df['efftax_sector_zscore'] = df.groupby(['year-month', 'sector'])[['efftax_sector_zscore']].apply(clip_outliers)
df['equity_invcap_sector_zscore'] = df.groupby(['year-month', 'sector'])[['equity_invcap_sector_zscore']].apply(clip_outliers)
df['evm_sector_zscore'] = df.groupby(['year-month', 'sector'])[['evm_sector_zscore']].apply(clip_outliers)
df['fcf_ocf_sector_zscore'] = df.groupby(['year-month', 'sector'])[['fcf_ocf_sector_zscore']].apply(clip_outliers)
df['gpm_sector_zscore'] = df.groupby(['year-month', 'sector'])[['gpm_sector_zscore']].apply(clip_outliers)
df['GProf_sector_zscore'] = df.groupby(['year-month', 'sector'])[['GProf_sector_zscore']].apply(clip_outliers)
df['int_debt_sector_zscore'] = df.groupby(['year-month', 'sector'])[['int_debt_sector_zscore']].apply(clip_outliers)
df['int_totdebt_sector_zscore'] = df.groupby(['year-month', 'sector'])[['int_totdebt_sector_zscore']].apply(clip_outliers)
df['intcov_sector_zscore'] = df.groupby(['year-month', 'sector'])[['intcov_sector_zscore']].apply(clip_outliers)
df['intcov_ratio_sector_zscore'] = df.groupby(['year-month', 'sector'])[['intcov_ratio_sector_zscore']].apply(clip_outliers)
df['inv_turn_sector_zscore'] = df.groupby(['year-month', 'sector'])[['inv_turn_sector_zscore']].apply(clip_outliers)
df['invt_act_sector_zscore'] = df.groupby(['year-month', 'sector'])[['invt_act_sector_zscore']].apply(clip_outliers)
df['lt_debt_sector_zscore'] = df.groupby(['year-month', 'sector'])[['lt_debt_sector_zscore']].apply(clip_outliers)
df['lt_ppent_sector_zscore'] = df.groupby(['year-month', 'sector'])[['lt_ppent_sector_zscore']].apply(clip_outliers)
df['npm_sector_zscore'] = df.groupby(['year-month', 'sector'])[['npm_sector_zscore']].apply(clip_outliers)
df['ocf_lct_sector_zscore'] = df.groupby(['year-month', 'sector'])[['ocf_lct_sector_zscore']].apply(clip_outliers)
df['opmad_sector_zscore'] = df.groupby(['year-month', 'sector'])[['opmad_sector_zscore']].apply(clip_outliers)
df['opmbd_sector_zscore'] = df.groupby(['year-month', 'sector'])[['opmbd_sector_zscore']].apply(clip_outliers)
df['pay_turn_sector_zscore'] = df.groupby(['year-month', 'sector'])[['pay_turn_sector_zscore']].apply(clip_outliers)
df['pcf_sector_zscore'] = df.groupby(['year-month', 'sector'])[['pcf_sector_zscore']].apply(clip_outliers)
df['pe_exi_sector_zscore'] = df.groupby(['year-month', 'sector'])[['pe_exi_sector_zscore']].apply(clip_outliers)
df['pe_inc_sector_zscore'] = df.groupby(['year-month', 'sector'])[['pe_inc_sector_zscore']].apply(clip_outliers)
df['pe_op_basic_sector_zscore'] = df.groupby(['year-month', 'sector'])[['pe_op_basic_sector_zscore']].apply(clip_outliers)
df['pe_op_dil_sector_zscore'] = df.groupby(['year-month', 'sector'])[['pe_op_dil_sector_zscore']].apply(clip_outliers)
df['PEG_1yrforward_sector_zscore'] = df.groupby(['year-month', 'sector'])[['PEG_1yrforward_sector_zscore']].apply(clip_outliers)
df['PEG_ltgforward_sector_zscore'] = df.groupby(['year-month', 'sector'])[['PEG_ltgforward_sector_zscore']].apply(clip_outliers)
df['PEG_trailing_sector_zscore'] = df.groupby(['year-month', 'sector'])[['PEG_trailing_sector_zscore']].apply(clip_outliers)
df['pretret_earnat_sector_zscore'] = df.groupby(['year-month', 'sector'])[['pretret_earnat_sector_zscore']].apply(clip_outliers)
df['pretret_noa_sector_zscore'] = df.groupby(['year-month', 'sector'])[['pretret_noa_sector_zscore']].apply(clip_outliers)
df['profit_lct_sector_zscore'] = df.groupby(['year-month', 'sector'])[['profit_lct_sector_zscore']].apply(clip_outliers)
df['ps_sector_zscore'] = df.groupby(['year-month', 'sector'])[['ps_sector_zscore']].apply(clip_outliers)
df['ptb_sector_zscore'] = df.groupby(['year-month', 'sector'])[['ptb_sector_zscore']].apply(clip_outliers)
df['ptpm_sector_zscore'] = df.groupby(['year-month', 'sector'])[['ptpm_sector_zscore']].apply(clip_outliers)
df['quick_ratio_sector_zscore'] = df.groupby(['year-month', 'sector'])[['quick_ratio_sector_zscore']].apply(clip_outliers)
df['rd_sale_sector_zscore'] = df.groupby(['year-month', 'sector'])[['rd_sale_sector_zscore']].apply(clip_outliers)
df['rect_act_sector_zscore'] = df.groupby(['year-month', 'sector'])[['rect_act_sector_zscore']].apply(clip_outliers)
df['rect_turn_sector_zscore'] = df.groupby(['year-month', 'sector'])[['rect_turn_sector_zscore']].apply(clip_outliers)
df['roa_sector_zscore'] = df.groupby(['year-month', 'sector'])[['roa_sector_zscore']].apply(clip_outliers)
df['roce_sector_zscore'] = df.groupby(['year-month', 'sector'])[['roce_sector_zscore']].apply(clip_outliers)
df['roe_sector_zscore'] = df.groupby(['year-month', 'sector'])[['roe_sector_zscore']].apply(clip_outliers)
df['sale_equity_sector_zscore'] = df.groupby(['year-month', 'sector'])[['sale_equity_sector_zscore']].apply(clip_outliers)
df['sale_invcap_sector_zscore'] = df.groupby(['year-month', 'sector'])[['sale_invcap_sector_zscore']].apply(clip_outliers)
df['sale_nwc_sector_zscore'] = df.groupby(['year-month', 'sector'])[['sale_nwc_sector_zscore']].apply(clip_outliers)
df['short_debt_sector_zscore'] = df.groupby(['year-month', 'sector'])[['short_debt_sector_zscore']].apply(clip_outliers)
df['staff_sale_sector_zscore'] = df.groupby(['year-month', 'sector'])[['staff_sale_sector_zscore']].apply(clip_outliers)
df['totdebt_invcap_sector_zscore'] = df.groupby(['year-month', 'sector'])[['totdebt_invcap_sector_zscore']].apply(clip_outliers)
df['dvpspm_sector_zscore'] = df.groupby(['year-month', 'sector'])[['dvpspm_sector_zscore']].apply(clip_outliers)
df['dvpsxm_sector_zscore'] = df.groupby(['year-month', 'sector'])[['dvpsxm_sector_zscore']].apply(clip_outliers)
df['dvrate_sector_zscore'] = df.groupby(['year-month', 'sector'])[['dvrate_sector_zscore']].apply(clip_outliers)
df['spcsrc_sector_zscore'] = df.groupby(['year-month', 'sector'])[['spcsrc_sector_zscore']].apply(clip_outliers)
df['alpha_sector_zscore'] = df.groupby(['year-month', 'sector'])[['alpha_sector_zscore']].apply(clip_outliers)
df['b_hml_sector_zscore'] = df.groupby(['year-month', 'sector'])[['b_hml_sector_zscore']].apply(clip_outliers)
df['b_mkt_sector_zscore'] = df.groupby(['year-month', 'sector'])[['b_mkt_sector_zscore']].apply(clip_outliers)
df['b_smb_sector_zscore'] = df.groupby(['year-month', 'sector'])[['b_smb_sector_zscore']].apply(clip_outliers)
df['b_umd_sector_zscore'] = df.groupby(['year-month', 'sector'])[['b_umd_sector_zscore']].apply(clip_outliers)
df['exret_sector_zscore'] = df.groupby(['year-month', 'sector'])[['exret_sector_zscore']].apply(clip_outliers)
df['ivol_sector_zscore'] = df.groupby(['year-month', 'sector'])[['ivol_sector_zscore']].apply(clip_outliers)
df['n_sector_zscore'] = df.groupby(['year-month', 'sector'])[['n_sector_zscore']].apply(clip_outliers)
df['R2_sector_zscore'] = df.groupby(['year-month', 'sector'])[['R2_sector_zscore']].apply(clip_outliers)
df['tvol_sector_zscore'] = df.groupby(['year-month', 'sector'])[['tvol_sector_zscore']].apply(clip_outliers)
df['BUYPCT_sector_zscore'] = df.groupby(['year-month', 'sector'])[['BUYPCT_sector_zscore']].apply(clip_outliers)
df['HOLDPCT_sector_zscore'] = df.groupby(['year-month', 'sector'])[['HOLDPCT_sector_zscore']].apply(clip_outliers)
df['MEANREC_sector_zscore'] = df.groupby(['year-month', 'sector'])[['MEANREC_sector_zscore']].apply(clip_outliers)
df['MEDREC_sector_zscore'] = df.groupby(['year-month', 'sector'])[['MEDREC_sector_zscore']].apply(clip_outliers)
df['recup_sector_zscore'] = df.groupby(['year-month', 'sector'])[['recup_sector_zscore']].apply(clip_outliers)
df['recdown_sector_zscore'] = df.groupby(['year-month', 'sector'])[['recdown_sector_zscore']].apply(clip_outliers)
df['SELLPCT_sector_zscore'] = df.groupby(['year-month', 'sector'])[['SELLPCT_sector_zscore']].apply(clip_outliers)
df['STDEV_sector_zscore'] = df.groupby(['year-month', 'sector'])[['STDEV_sector_zscore']].apply(clip_outliers)

# By Month

# Dependent Variables
df['forward_one_month_return'] = df.groupby(['year-month'])[['forward_one_month_return']].apply(clip_outliers)
df['forward_two_month_return'] = df.groupby(['year-month'])[['forward_two_month_return']].apply(clip_outliers)
df['forward_three_month_return'] = df.groupby(['year-month'])[['forward_three_month_return']].apply(clip_outliers)
df['forward_four_month_return'] = df.groupby(['year-month'])[['forward_four_month_return']].apply(clip_outliers)
df['forward_five_month_return'] = df.groupby(['year-month'])[['forward_five_month_return']].apply(clip_outliers)
df['forward_six_month_return'] = df.groupby(['year-month'])[['forward_six_month_return']].apply(clip_outliers)
df['forward_seven_month_return'] = df.groupby(['year-month'])[['forward_seven_month_return']].apply(clip_outliers)
df['forward_eight_month_return'] = df.groupby(['year-month'])[['forward_eight_month_return']].apply(clip_outliers)
df['forward_nine_month_return'] = df.groupby(['year-month'])[['forward_nine_month_return']].apply(clip_outliers)
df['forward_ten_month_return'] = df.groupby(['year-month'])[['forward_ten_month_return']].apply(clip_outliers)
df['forward_eleven_month_return'] = df.groupby(['year-month'])[['forward_eleven_month_return']].apply(clip_outliers)
df['forward_twelve_month_return'] = df.groupby(['year-month'])[['forward_twelve_month_return']].apply(clip_outliers)
df['forward_thirteen_month_return'] = df.groupby(['year-month'])[['forward_thirteen_month_return']].apply(clip_outliers)
df['forward_fourteen_month_return'] = df.groupby(['year-month'])[['forward_fourteen_month_return']].apply(clip_outliers)
df['forward_fifteen_month_return'] = df.groupby(['year-month'])[['forward_fifteen_month_return']].apply(clip_outliers)
df['forward_sixteen_month_return'] = df.groupby(['year-month'])[['forward_sixteen_month_return']].apply(clip_outliers)
df['forward_seventeen_month_return'] = df.groupby(['year-month'])[['forward_seventeen_month_return']].apply(clip_outliers)
df['forward_eighteen_month_return'] = df.groupby(['year-month'])[['forward_eighteen_month_return']].apply(clip_outliers)
df['forward_nineteen_month_return'] = df.groupby(['year-month'])[['forward_nineteen_month_return']].apply(clip_outliers)
df['forward_twenty_month_return'] = df.groupby(['year-month'])[['forward_twenty_month_return']].apply(clip_outliers)
df['forward_twentyone_month_return'] = df.groupby(['year-month'])[['forward_twentyone_month_return']].apply(clip_outliers)
df['forward_twentytwo_month_return'] = df.groupby(['year-month'])[['forward_twentytwo_month_return']].apply(clip_outliers)
df['forward_twentythree_month_return'] = df.groupby(['year-month'])[['forward_twentythree_month_return']].apply(clip_outliers)
df['forward_twentyfour_month_return'] = df.groupby(['year-month'])[['forward_twentyfour_month_return']].apply(clip_outliers)
df['forward_twentyfive_month_return'] = df.groupby(['year-month'])[['forward_twentyfive_month_return']].apply(clip_outliers)
df['forward_twentysix_month_return'] = df.groupby(['year-month'])[['forward_twentysix_month_return']].apply(clip_outliers)
df['forward_twentyseven_month_return'] = df.groupby(['year-month'])[['forward_twentyseven_month_return']].apply(clip_outliers)
df['forward_twentyeight_month_return'] = df.groupby(['year-month'])[['forward_twentyeight_month_return']].apply(clip_outliers)
df['forward_twentynine_month_return'] = df.groupby(['year-month'])[['forward_twentynine_month_return']].apply(clip_outliers)
df['forward_thirty_month_return'] = df.groupby(['year-month'])[['forward_thirty_month_return']].apply(clip_outliers)
df['forward_thirtyone_month_return'] = df.groupby(['year-month'])[['forward_thirtyone_month_return']].apply(clip_outliers)
df['forward_thirtytwo_month_return'] = df.groupby(['year-month'])[['forward_thirtytwo_month_return']].apply(clip_outliers)
df['forward_thirtythree_month_return'] = df.groupby(['year-month'])[['forward_thirtythree_month_return']].apply(clip_outliers)
df['forward_thirtyfour_month_return'] = df.groupby(['year-month'])[['forward_thirtyfour_month_return']].apply(clip_outliers)
df['forward_thirtyfive_month_return'] = df.groupby(['year-month'])[['forward_thirtyfive_month_return']].apply(clip_outliers)
df['forward_thirtysix_month_return'] = df.groupby(['year-month'])[['forward_thirtysix_month_return']].apply(clip_outliers)

# Independent Variables
df['past_one_month_return'] = df.groupby(['year-month'])[['past_one_month_return']].apply(clip_outliers)
df['past_two_month_return'] = df.groupby(['year-month'])[['past_two_month_return']].apply(clip_outliers)
df['past_three_month_return'] = df.groupby(['year-month'])[['past_three_month_return']].apply(clip_outliers)
df['past_four_month_return'] = df.groupby(['year-month'])[['past_four_month_return']].apply(clip_outliers)
df['past_five_month_return'] = df.groupby(['year-month'])[['past_five_month_return']].apply(clip_outliers)
df['past_six_month_return'] = df.groupby(['year-month'])[['past_six_month_return']].apply(clip_outliers)
df['past_seven_month_return'] = df.groupby(['year-month'])[['past_seven_month_return']].apply(clip_outliers)
df['past_eight_month_return'] = df.groupby(['year-month'])[['past_eight_month_return']].apply(clip_outliers)
df['past_nine_month_return'] = df.groupby(['year-month'])[['past_nine_month_return']].apply(clip_outliers)
df['past_ten_month_return'] = df.groupby(['year-month'])[['past_ten_month_return']].apply(clip_outliers)
df['past_eleven_month_return'] = df.groupby(['year-month'])[['past_eleven_month_return']].apply(clip_outliers)
df['past_twelve_month_return'] = df.groupby(['year-month'])[['past_twelve_month_return']].apply(clip_outliers)
df['past_thirteen_month_return'] = df.groupby(['year-month'])[['past_thirteen_month_return']].apply(clip_outliers)
df['past_fourteen_month_return'] = df.groupby(['year-month'])[['past_fourteen_month_return']].apply(clip_outliers)
df['past_fifteen_month_return'] = df.groupby(['year-month'])[['past_fifteen_month_return']].apply(clip_outliers)
df['past_sixteen_month_return'] = df.groupby(['year-month'])[['past_sixteen_month_return']].apply(clip_outliers)
df['past_seventeen_month_return'] = df.groupby(['year-month'])[['past_seventeen_month_return']].apply(clip_outliers)
df['past_eighteen_month_return'] = df.groupby(['year-month'])[['past_eighteen_month_return']].apply(clip_outliers)
df['past_nineteen_month_return'] = df.groupby(['year-month'])[['past_nineteen_month_return']].apply(clip_outliers)
df['past_twenty_month_return'] = df.groupby(['year-month'])[['past_twenty_month_return']].apply(clip_outliers)
df['past_twentyone_month_return'] = df.groupby(['year-month'])[['past_twentyone_month_return']].apply(clip_outliers)
df['past_twentytwo_month_return'] = df.groupby(['year-month'])[['past_twentytwo_month_return']].apply(clip_outliers)
df['past_twentythree_month_return'] = df.groupby(['year-month'])[['past_twentythree_month_return']].apply(clip_outliers)
df['past_twentyfour_month_return'] = df.groupby(['year-month'])[['past_twentyfour_month_return']].apply(clip_outliers)
df['past_twentyfive_month_return'] = df.groupby(['year-month'])[['past_twentyfive_month_return']].apply(clip_outliers)
df['past_twentysix_month_return'] = df.groupby(['year-month'])[['past_twentysix_month_return']].apply(clip_outliers)
df['past_twentyseven_month_return'] = df.groupby(['year-month'])[['past_twentyseven_month_return']].apply(clip_outliers)
df['past_twentyeight_month_return'] = df.groupby(['year-month'])[['past_twentyeight_month_return']].apply(clip_outliers)
df['past_twentynine_month_return'] = df.groupby(['year-month'])[['past_twentynine_month_return']].apply(clip_outliers)
df['past_thirty_month_return'] = df.groupby(['year-month'])[['past_thirty_month_return']].apply(clip_outliers)
df['past_thirtyone_month_return'] = df.groupby(['year-month'])[['past_thirtyone_month_return']].apply(clip_outliers)
df['past_thirtytwo_month_return'] = df.groupby(['year-month'])[['past_thirtytwo_month_return']].apply(clip_outliers)
df['past_thirtythree_month_return'] = df.groupby(['year-month'])[['past_thirtythree_month_return']].apply(clip_outliers)
df['past_thirtyfour_month_return'] = df.groupby(['year-month'])[['past_thirtyfour_month_return']].apply(clip_outliers)
df['past_thirtyfive_month_return'] = df.groupby(['year-month'])[['past_thirtyfive_month_return']].apply(clip_outliers)
df['past_thirtysix_month_return'] = df.groupby(['year-month'])[['past_thirtysix_month_return']].apply(clip_outliers)
df['accrual'] = df.groupby(['year-month'])[['accrual']].apply(clip_outliers)
df['adv_sale'] = df.groupby(['year-month'])[['adv_sale']].apply(clip_outliers)
df['aftret_eq'] = df.groupby(['year-month'])[['aftret_eq']].apply(clip_outliers)
df['aftret_equity'] = df.groupby(['year-month'])[['aftret_equity']].apply(clip_outliers)
df['aftret_invcapx'] = df.groupby(['year-month'])[['aftret_invcapx']].apply(clip_outliers)
df['at_turn'] = df.groupby(['year-month'])[['at_turn']].apply(clip_outliers)
df['bm'] = df.groupby(['year-month'])[['bm']].apply(clip_outliers)
df['CAPEI'] = df.groupby(['year-month'])[['CAPEI']].apply(clip_outliers)
df['capital_ratio'] = df.groupby(['year-month'])[['capital_ratio']].apply(clip_outliers)
df['cash_conversion'] = df.groupby(['year-month'])[['cash_conversion']].apply(clip_outliers)
df['cash_debt'] = df.groupby(['year-month'])[['cash_debt']].apply(clip_outliers)
df['cash_lt'] = df.groupby(['year-month'])[['cash_lt']].apply(clip_outliers)
df['cash_ratio'] = df.groupby(['year-month'])[['cash_ratio']].apply(clip_outliers)
df['cfm'] = df.groupby(['year-month'])[['cfm']].apply(clip_outliers)
df['curr_debt'] = df.groupby(['year-month'])[['curr_debt']].apply(clip_outliers)
df['curr_ratio'] = df.groupby(['year-month'])[['curr_ratio']].apply(clip_outliers)
df['de_ratio'] = df.groupby(['year-month'])[['de_ratio']].apply(clip_outliers)
df['debt_assets'] = df.groupby(['year-month'])[['debt_assets']].apply(clip_outliers)
df['debt_at'] = df.groupby(['year-month'])[['debt_at']].apply(clip_outliers)
df['debt_capital'] = df.groupby(['year-month'])[['debt_capital']].apply(clip_outliers)
df['debt_ebitda'] = df.groupby(['year-month'])[['debt_ebitda']].apply(clip_outliers)
df['debt_invcap'] = df.groupby(['year-month'])[['debt_invcap']].apply(clip_outliers)
df['DIVYIELD'] = df.groupby(['year-month'])[['DIVYIELD']].apply(clip_outliers)
df['dltt_be'] = df.groupby(['year-month'])[['dltt_be']].apply(clip_outliers)
df['dpr'] = df.groupby(['year-month'])[['dpr']].apply(clip_outliers)
df['efftax'] = df.groupby(['year-month'])[['efftax']].apply(clip_outliers)
df['equity_invcap'] = df.groupby(['year-month'])[['equity_invcap']].apply(clip_outliers)
df['evm'] = df.groupby(['year-month'])[['evm']].apply(clip_outliers)
df['fcf_ocf'] = df.groupby(['year-month'])[['fcf_ocf']].apply(clip_outliers)
df['gpm'] = df.groupby(['year-month'])[['gpm']].apply(clip_outliers)
df['GProf'] = df.groupby(['year-month'])[['GProf']].apply(clip_outliers)
df['int_debt'] = df.groupby(['year-month'])[['int_debt']].apply(clip_outliers)
df['int_totdebt'] = df.groupby(['year-month'])[['int_totdebt']].apply(clip_outliers)
df['intcov'] = df.groupby(['year-month'])[['intcov']].apply(clip_outliers)
df['intcov_ratio'] = df.groupby(['year-month'])[['intcov_ratio']].apply(clip_outliers)
df['inv_turn'] = df.groupby(['year-month'])[['inv_turn']].apply(clip_outliers)
df['invt_act'] = df.groupby(['year-month'])[['invt_act']].apply(clip_outliers)
df['lt_debt'] = df.groupby(['year-month'])[['lt_debt']].apply(clip_outliers)
df['lt_ppent'] = df.groupby(['year-month'])[['lt_ppent']].apply(clip_outliers)
df['npm'] = df.groupby(['year-month'])[['npm']].apply(clip_outliers)
df['ocf_lct'] = df.groupby(['year-month'])[['ocf_lct']].apply(clip_outliers)
df['opmad'] = df.groupby(['year-month'])[['opmad']].apply(clip_outliers)
df['opmbd'] = df.groupby(['year-month'])[['opmbd']].apply(clip_outliers)
df['pay_turn'] = df.groupby(['year-month'])[['pay_turn']].apply(clip_outliers)
df['pcf'] = df.groupby(['year-month'])[['pcf']].apply(clip_outliers)
df['pe_exi'] = df.groupby(['year-month'])[['pe_exi']].apply(clip_outliers)
df['pe_inc'] = df.groupby(['year-month'])[['pe_inc']].apply(clip_outliers)
df['pe_op_basic'] = df.groupby(['year-month'])[['pe_op_basic']].apply(clip_outliers)
df['pe_op_dil'] = df.groupby(['year-month'])[['pe_op_dil']].apply(clip_outliers)
df['PEG_1yrforward'] = df.groupby(['year-month'])[['PEG_1yrforward']].apply(clip_outliers)
df['PEG_ltgforward'] = df.groupby(['year-month'])[['PEG_ltgforward']].apply(clip_outliers)
df['PEG_trailing'] = df.groupby(['year-month'])[['PEG_trailing']].apply(clip_outliers)
df['pretret_earnat'] = df.groupby(['year-month'])[['pretret_earnat']].apply(clip_outliers)
df['pretret_noa'] = df.groupby(['year-month'])[['pretret_noa']].apply(clip_outliers)
df['profit_lct'] = df.groupby(['year-month'])[['profit_lct']].apply(clip_outliers)
df['ps'] = df.groupby(['year-month'])[['ps']].apply(clip_outliers)
df['ptb'] = df.groupby(['year-month'])[['ptb']].apply(clip_outliers)
df['ptpm'] = df.groupby(['year-month'])[['ptpm']].apply(clip_outliers)
df['quick_ratio'] = df.groupby(['year-month'])[['quick_ratio']].apply(clip_outliers)
df['rd_sale'] = df.groupby(['year-month'])[['rd_sale']].apply(clip_outliers)
df['rect_act'] = df.groupby(['year-month'])[['rect_act']].apply(clip_outliers)
df['rect_turn'] = df.groupby(['year-month'])[['rect_turn']].apply(clip_outliers)
df['roa'] = df.groupby(['year-month'])[['roa']].apply(clip_outliers)
df['roce'] = df.groupby(['year-month'])[['roce']].apply(clip_outliers)
df['roe'] = df.groupby(['year-month'])[['roe']].apply(clip_outliers)
df['sale_equity'] = df.groupby(['year-month'])[['sale_equity']].apply(clip_outliers)
df['sale_invcap'] = df.groupby(['year-month'])[['sale_invcap']].apply(clip_outliers)
df['sale_nwc'] = df.groupby(['year-month'])[['sale_nwc']].apply(clip_outliers)
df['short_debt'] = df.groupby(['year-month'])[['short_debt']].apply(clip_outliers)
df['staff_sale'] = df.groupby(['year-month'])[['staff_sale']].apply(clip_outliers)
df['totdebt_invcap'] = df.groupby(['year-month'])[['totdebt_invcap']].apply(clip_outliers)
df['dvpspm'] = df.groupby(['year-month'])[['dvpspm']].apply(clip_outliers)
df['dvpsxm'] = df.groupby(['year-month'])[['dvpsxm']].apply(clip_outliers)
df['dvrate'] = df.groupby(['year-month'])[['dvrate']].apply(clip_outliers)
df['spcsrc'] = df.groupby(['year-month'])[['spcsrc']].apply(clip_outliers)
df['alpha'] = df.groupby(['year-month'])[['alpha']].apply(clip_outliers)
df['b_hml'] = df.groupby(['year-month'])[['b_hml']].apply(clip_outliers)
df['b_mkt'] = df.groupby(['year-month'])[['b_mkt']].apply(clip_outliers)
df['b_smb'] = df.groupby(['year-month'])[['b_smb']].apply(clip_outliers)
df['b_umd'] = df.groupby(['year-month'])[['b_umd']].apply(clip_outliers)
df['exret'] = df.groupby(['year-month'])[['exret']].apply(clip_outliers)
df['ivol'] = df.groupby(['year-month'])[['ivol']].apply(clip_outliers)
df['n'] = df.groupby(['year-month'])[['n']].apply(clip_outliers)
df['R2'] = df.groupby(['year-month'])[['R2']].apply(clip_outliers)
df['tvol'] = df.groupby(['year-month'])[['tvol']].apply(clip_outliers)
df['BUYPCT'] = df.groupby(['year-month'])[['BUYPCT']].apply(clip_outliers)
df['HOLDPCT'] = df.groupby(['year-month'])[['HOLDPCT']].apply(clip_outliers)
df['SELLPCT'] = df.groupby(['year-month'])[['SELLPCT']].apply(clip_outliers)
df['MEANREC'] = df.groupby(['year-month'])[['MEANREC']].apply(clip_outliers)
df['MEDREC'] = df.groupby(['year-month'])[['MEDREC']].apply(clip_outliers)
df['recup'] = df.groupby(['year-month'])[['recup']].apply(clip_outliers)
df['recdown'] = df.groupby(['year-month'])[['recdown']].apply(clip_outliers)
df['STDEV'] = df.groupby(['year-month'])[['STDEV']].apply(clip_outliers)
df['past_one_month_return_zscore'] = df.groupby(['year-month'])[['past_one_month_return_zscore']].apply(clip_outliers)
df['past_two_month_return_zscore'] = df.groupby(['year-month'])[['past_two_month_return_zscore']].apply(clip_outliers)
df['past_three_month_return_zscore'] = df.groupby(['year-month'])[['past_three_month_return_zscore']].apply(clip_outliers)
df['past_four_month_return_zscore'] = df.groupby(['year-month'])[['past_four_month_return_zscore']].apply(clip_outliers)
df['past_five_month_return_zscore'] = df.groupby(['year-month'])[['past_five_month_return_zscore']].apply(clip_outliers)
df['past_six_month_return_zscore'] = df.groupby(['year-month'])[['past_six_month_return_zscore']].apply(clip_outliers)
df['past_seven_month_return_zscore'] = df.groupby(['year-month'])[['past_seven_month_return_zscore']].apply(clip_outliers)
df['past_eight_month_return_zscore'] = df.groupby(['year-month'])[['past_eight_month_return_zscore']].apply(clip_outliers)
df['past_nine_month_return_zscore'] = df.groupby(['year-month'])[['past_nine_month_return_zscore']].apply(clip_outliers)
df['past_ten_month_return_zscore'] = df.groupby(['year-month'])[['past_ten_month_return_zscore']].apply(clip_outliers)
df['past_eleven_month_return_zscore'] = df.groupby(['year-month'])[['past_eleven_month_return_zscore']].apply(clip_outliers)
df['past_twelve_month_return_zscore'] = df.groupby(['year-month'])[['past_twelve_month_return_zscore']].apply(clip_outliers)
df['past_thirteen_month_return_zscore'] = df.groupby(['year-month'])[['past_thirteen_month_return_zscore']].apply(clip_outliers)
df['past_fourteen_month_return_zscore'] = df.groupby(['year-month'])[['past_fourteen_month_return_zscore']].apply(clip_outliers)
df['past_fifteen_month_return_zscore'] = df.groupby(['year-month'])[['past_fifteen_month_return_zscore']].apply(clip_outliers)
df['past_sixteen_month_return_zscore'] = df.groupby(['year-month'])[['past_sixteen_month_return_zscore']].apply(clip_outliers)
df['past_seventeen_month_return_zscore'] = df.groupby(['year-month'])[['past_seventeen_month_return_zscore']].apply(clip_outliers)
df['past_eighteen_month_return_zscore'] = df.groupby(['year-month'])[['past_eighteen_month_return_zscore']].apply(clip_outliers)
df['past_nineteen_month_return_zscore'] = df.groupby(['year-month'])[['past_nineteen_month_return_zscore']].apply(clip_outliers)
df['past_twenty_month_return_zscore'] = df.groupby(['year-month'])[['past_twenty_month_return_zscore']].apply(clip_outliers)
df['past_twentyone_month_return_zscore'] = df.groupby(['year-month'])[['past_twentyone_month_return_zscore']].apply(clip_outliers)
df['past_twentytwo_month_return_zscore'] = df.groupby(['year-month'])[['past_twentytwo_month_return_zscore']].apply(clip_outliers)
df['past_twentythree_month_return_zscore'] = df.groupby(['year-month'])[['past_twentythree_month_return_zscore']].apply(clip_outliers)
df['past_twentyfour_month_return_zscore'] = df.groupby(['year-month'])[['past_twentyfour_month_return_zscore']].apply(clip_outliers)
df['past_twentyfive_month_return_zscore'] = df.groupby(['year-month'])[['past_twentyfive_month_return_zscore']].apply(clip_outliers)
df['past_twentysix_month_return_zscore'] = df.groupby(['year-month'])[['past_twentysix_month_return_zscore']].apply(clip_outliers)
df['past_twentyseven_month_return_zscore'] = df.groupby(['year-month'])[['past_twentyseven_month_return_zscore']].apply(clip_outliers)
df['past_twentyeight_month_return_zscore'] = df.groupby(['year-month'])[['past_twentyeight_month_return_zscore']].apply(clip_outliers)
df['past_twentynine_month_return_zscore'] = df.groupby(['year-month'])[['past_twentynine_month_return_zscore']].apply(clip_outliers)
df['past_thirty_month_return_zscore'] = df.groupby(['year-month'])[['past_thirty_month_return_zscore']].apply(clip_outliers)
df['past_thirtyone_month_return_zscore'] = df.groupby(['year-month'])[['past_thirtyone_month_return_zscore']].apply(clip_outliers)
df['past_thirtytwo_month_return_zscore'] = df.groupby(['year-month'])[['past_thirtytwo_month_return_zscore']].apply(clip_outliers)
df['past_thirtythree_month_return_zscore'] = df.groupby(['year-month'])[['past_thirtythree_month_return_zscore']].apply(clip_outliers)
df['past_thirtyfour_month_return_zscore'] = df.groupby(['year-month'])[['past_thirtyfour_month_return_zscore']].apply(clip_outliers)
df['past_thirtyfive_month_return_zscore'] = df.groupby(['year-month'])[['past_thirtyfive_month_return_zscore']].apply(clip_outliers)
df['past_thirtysix_month_return_zscore'] = df.groupby(['year-month'])[['past_thirtysix_month_return_zscore']].apply(clip_outliers)
df['accrual_zscore'] = df.groupby(['year-month'])[['accrual_zscore']].apply(clip_outliers)
df['adv_sale_zscore'] = df.groupby(['year-month'])[['adv_sale_zscore']].apply(clip_outliers)
df['aftret_eq_zscore'] = df.groupby(['year-month'])[['aftret_eq_zscore']].apply(clip_outliers)
df['aftret_equity_zscore'] = df.groupby(['year-month'])[['aftret_equity_zscore']].apply(clip_outliers)
df['aftret_invcapx_zscore'] = df.groupby(['year-month'])[['aftret_invcapx_zscore']].apply(clip_outliers)
df['at_turn_zscore'] = df.groupby(['year-month'])[['at_turn_zscore']].apply(clip_outliers)
df['bm_zscore'] = df.groupby(['year-month'])[['bm_zscore']].apply(clip_outliers)
df['CAPEI_zscore'] = df.groupby(['year-month'])[['CAPEI_zscore']].apply(clip_outliers)
df['capital_ratio_zscore'] = df.groupby(['year-month'])[['capital_ratio_zscore']].apply(clip_outliers)
df['cash_conversion_zscore'] = df.groupby(['year-month'])[['cash_conversion_zscore']].apply(clip_outliers)
df['cash_debt_zscore'] = df.groupby(['year-month'])[['cash_debt_zscore']].apply(clip_outliers)
df['cash_lt_zscore'] = df.groupby(['year-month'])[['cash_lt_zscore']].apply(clip_outliers)
df['cash_ratio_zscore'] = df.groupby(['year-month'])[['cash_ratio_zscore']].apply(clip_outliers)
df['cfm_zscore'] = df.groupby(['year-month'])[['cfm_zscore']].apply(clip_outliers)
df['curr_debt_zscore'] = df.groupby(['year-month'])[['curr_debt_zscore']].apply(clip_outliers)
df['curr_ratio_zscore'] = df.groupby(['year-month'])[['curr_ratio_zscore']].apply(clip_outliers)
df['de_ratio_zscore'] = df.groupby(['year-month'])[['de_ratio_zscore']].apply(clip_outliers)
df['debt_assets_zscore'] = df.groupby(['year-month'])[['debt_assets_zscore']].apply(clip_outliers)
df['debt_at_zscore'] = df.groupby(['year-month'])[['debt_at_zscore']].apply(clip_outliers)
df['debt_capital_zscore'] = df.groupby(['year-month'])[['debt_capital_zscore']].apply(clip_outliers)
df['debt_ebitda_zscore'] = df.groupby(['year-month'])[['debt_ebitda_zscore']].apply(clip_outliers)
df['debt_invcap_zscore'] = df.groupby(['year-month'])[['debt_invcap_zscore']].apply(clip_outliers)
df['DIVYIELD_zscore'] = df.groupby(['year-month'])[['DIVYIELD_zscore']].apply(clip_outliers)
df['dltt_be_zscore'] = df.groupby(['year-month'])[['dltt_be_zscore']].apply(clip_outliers)
df['dpr_zscore'] = df.groupby(['year-month'])[['dpr_zscore']].apply(clip_outliers)
df['efftax_zscore'] = df.groupby(['year-month'])[['efftax_zscore']].apply(clip_outliers)
df['equity_invcap_zscore'] = df.groupby(['year-month'])[['equity_invcap_zscore']].apply(clip_outliers)
df['evm_zscore'] = df.groupby(['year-month'])[['evm_zscore']].apply(clip_outliers)
df['fcf_ocf_zscore'] = df.groupby(['year-month'])[['fcf_ocf_zscore']].apply(clip_outliers)
df['gpm_zscore'] = df.groupby(['year-month'])[['gpm_zscore']].apply(clip_outliers)
df['GProf_zscore'] = df.groupby(['year-month'])[['GProf_zscore']].apply(clip_outliers)
df['int_debt_zscore'] = df.groupby(['year-month'])[['int_debt_zscore']].apply(clip_outliers)
df['int_totdebt_zscore'] = df.groupby(['year-month'])[['int_totdebt_zscore']].apply(clip_outliers)
df['intcov_zscore'] = df.groupby(['year-month'])[['intcov_zscore']].apply(clip_outliers)
df['intcov_ratio_zscore'] = df.groupby(['year-month'])[['intcov_ratio_zscore']].apply(clip_outliers)
df['inv_turn_zscore'] = df.groupby(['year-month'])[['inv_turn_zscore']].apply(clip_outliers)
df['invt_act_zscore'] = df.groupby(['year-month'])[['invt_act_zscore']].apply(clip_outliers)
df['lt_debt_zscore'] = df.groupby(['year-month'])[['lt_debt_zscore']].apply(clip_outliers)
df['lt_ppent_zscore'] = df.groupby(['year-month'])[['lt_ppent_zscore']].apply(clip_outliers)
df['npm_zscore'] = df.groupby(['year-month'])[['npm_zscore']].apply(clip_outliers)
df['ocf_lct_zscore'] = df.groupby(['year-month'])[['ocf_lct_zscore']].apply(clip_outliers)
df['opmad_zscore'] = df.groupby(['year-month'])[['opmad_zscore']].apply(clip_outliers)
df['opmbd_zscore'] = df.groupby(['year-month'])[['opmbd_zscore']].apply(clip_outliers)
df['pay_turn_zscore'] = df.groupby(['year-month'])[['pay_turn_zscore']].apply(clip_outliers)
df['pcf_zscore'] = df.groupby(['year-month'])[['pcf_zscore']].apply(clip_outliers)
df['pe_exi_zscore'] = df.groupby(['year-month'])[['pe_exi_zscore']].apply(clip_outliers)
df['pe_inc_zscore'] = df.groupby(['year-month'])[['pe_inc_zscore']].apply(clip_outliers)
df['pe_op_basic_zscore'] = df.groupby(['year-month'])[['pe_op_basic_zscore']].apply(clip_outliers)
df['pe_op_dil_zscore'] = df.groupby(['year-month'])[['pe_op_dil_zscore']].apply(clip_outliers)
df['PEG_1yrforward_zscore'] = df.groupby(['year-month'])[['PEG_1yrforward_zscore']].apply(clip_outliers)
df['PEG_ltgforward_zscore'] = df.groupby(['year-month'])[['PEG_ltgforward_zscore']].apply(clip_outliers)
df['PEG_trailing_zscore'] = df.groupby(['year-month'])[['PEG_trailing_zscore']].apply(clip_outliers)
df['pretret_earnat_zscore'] = df.groupby(['year-month'])[['pretret_earnat_zscore']].apply(clip_outliers)
df['pretret_noa_zscore'] = df.groupby(['year-month'])[['pretret_noa_zscore']].apply(clip_outliers)
df['profit_lct_zscore'] = df.groupby(['year-month'])[['profit_lct_zscore']].apply(clip_outliers)
df['ps_zscore'] = df.groupby(['year-month'])[['ps_zscore']].apply(clip_outliers)
df['ptb_zscore'] = df.groupby(['year-month'])[['ptb_zscore']].apply(clip_outliers)
df['ptpm_zscore'] = df.groupby(['year-month'])[['ptpm_zscore']].apply(clip_outliers)
df['quick_ratio_zscore'] = df.groupby(['year-month'])[['quick_ratio_zscore']].apply(clip_outliers)
df['rd_sale_zscore'] = df.groupby(['year-month'])[['rd_sale_zscore']].apply(clip_outliers)
df['rect_act_zscore'] = df.groupby(['year-month'])[['rect_act_zscore']].apply(clip_outliers)
df['rect_turn_zscore'] = df.groupby(['year-month'])[['rect_turn_zscore']].apply(clip_outliers)
df['roa_zscore'] = df.groupby(['year-month'])[['roa_zscore']].apply(clip_outliers)
df['roce_zscore'] = df.groupby(['year-month'])[['roce_zscore']].apply(clip_outliers)
df['roe_zscore'] = df.groupby(['year-month'])[['roe_zscore']].apply(clip_outliers)
df['sale_equity_zscore'] = df.groupby(['year-month'])[['sale_equity_zscore']].apply(clip_outliers)
df['sale_invcap_zscore'] = df.groupby(['year-month'])[['sale_invcap_zscore']].apply(clip_outliers)
df['sale_nwc_zscore'] = df.groupby(['year-month'])[['sale_nwc_zscore']].apply(clip_outliers)
df['short_debt_zscore'] = df.groupby(['year-month'])[['short_debt_zscore']].apply(clip_outliers)
df['staff_sale_zscore'] = df.groupby(['year-month'])[['staff_sale_zscore']].apply(clip_outliers)
df['totdebt_invcap_zscore'] = df.groupby(['year-month'])[['totdebt_invcap_zscore']].apply(clip_outliers)
df['dvpspm_zscore'] = df.groupby(['year-month'])[['dvpspm_zscore']].apply(clip_outliers)
df['dvpsxm_zscore'] = df.groupby(['year-month'])[['dvpsxm_zscore']].apply(clip_outliers)
df['dvrate_zscore'] = df.groupby(['year-month'])[['dvrate_zscore']].apply(clip_outliers)
df['spcsrc_zscore'] = df.groupby(['year-month'])[['spcsrc_zscore']].apply(clip_outliers)
df['alpha_zscore'] = df.groupby(['year-month'])[['alpha_zscore']].apply(clip_outliers)
df['b_hml_zscore'] = df.groupby(['year-month'])[['b_hml_zscore']].apply(clip_outliers)
df['b_mkt_zscore'] = df.groupby(['year-month'])[['b_mkt_zscore']].apply(clip_outliers)
df['b_smb_zscore'] = df.groupby(['year-month'])[['b_smb_zscore']].apply(clip_outliers)
df['b_umd_zscore'] = df.groupby(['year-month'])[['b_umd_zscore']].apply(clip_outliers)
df['exret_zscore'] = df.groupby(['year-month'])[['exret_zscore']].apply(clip_outliers)
df['ivol_zscore'] = df.groupby(['year-month'])[['ivol_zscore']].apply(clip_outliers)
df['n_zscore'] = df.groupby(['year-month'])[['n_zscore']].apply(clip_outliers)
df['R2_zscore'] = df.groupby(['year-month'])[['R2_zscore']].apply(clip_outliers)
df['tvol_zscore'] = df.groupby(['year-month'])[['tvol_zscore']].apply(clip_outliers)
df['BUYPCT_zscore'] = df.groupby(['year-month'])[['BUYPCT_zscore']].apply(clip_outliers)
df['HOLDPCT_zscore'] = df.groupby(['year-month'])[['HOLDPCT_zscore']].apply(clip_outliers)
df['MEANREC_zscore'] = df.groupby(['year-month'])[['MEANREC_zscore']].apply(clip_outliers)
df['MEDREC_zscore'] = df.groupby(['year-month'])[['MEDREC_zscore']].apply(clip_outliers)
df['recup_zscore'] = df.groupby(['year-month'])[['recup_zscore']].apply(clip_outliers)
df['recdown_zscore'] = df.groupby(['year-month'])[['recdown_zscore']].apply(clip_outliers)
df['SELLPCT_zscore'] = df.groupby(['year-month'])[['SELLPCT_zscore']].apply(clip_outliers)
df['STDEV_zscore'] = df.groupby(['year-month'])[['STDEV_zscore']].apply(clip_outliers)
df['past_one_month_return_sector_zscore'] = df.groupby(['year-month'])[['past_one_month_return_sector_zscore']].apply(clip_outliers)
df['past_two_month_return_sector_zscore'] = df.groupby(['year-month'])[['past_two_month_return_sector_zscore']].apply(clip_outliers)
df['past_three_month_return_sector_zscore'] = df.groupby(['year-month'])[['past_three_month_return_sector_zscore']].apply(clip_outliers)
df['past_four_month_return_sector_zscore'] = df.groupby(['year-month'])[['past_four_month_return_sector_zscore']].apply(clip_outliers)
df['past_five_month_return_sector_zscore'] = df.groupby(['year-month'])[['past_five_month_return_sector_zscore']].apply(clip_outliers)
df['past_six_month_return_sector_zscore'] = df.groupby(['year-month'])[['past_six_month_return_sector_zscore']].apply(clip_outliers)
df['past_seven_month_return_sector_zscore'] = df.groupby(['year-month'])[['past_seven_month_return_sector_zscore']].apply(clip_outliers)
df['past_eight_month_return_sector_zscore'] = df.groupby(['year-month'])[['past_eight_month_return_sector_zscore']].apply(clip_outliers)
df['past_nine_month_return_sector_zscore'] = df.groupby(['year-month'])[['past_nine_month_return_sector_zscore']].apply(clip_outliers)
df['past_ten_month_return_sector_zscore'] = df.groupby(['year-month'])[['past_ten_month_return_sector_zscore']].apply(clip_outliers)
df['past_eleven_month_return_sector_zscore'] = df.groupby(['year-month'])[['past_eleven_month_return_sector_zscore']].apply(clip_outliers)
df['past_twelve_month_return_sector_zscore'] = df.groupby(['year-month'])[['past_twelve_month_return_sector_zscore']].apply(clip_outliers)
df['past_thirteen_month_return_sector_zscore'] = df.groupby(['year-month'])[['past_thirteen_month_return_sector_zscore']].apply(clip_outliers)
df['past_fourteen_month_return_sector_zscore'] = df.groupby(['year-month'])[['past_fourteen_month_return_sector_zscore']].apply(clip_outliers)
df['past_fifteen_month_return_sector_zscore'] = df.groupby(['year-month'])[['past_fifteen_month_return_sector_zscore']].apply(clip_outliers)
df['past_sixteen_month_return_sector_zscore'] = df.groupby(['year-month'])[['past_sixteen_month_return_sector_zscore']].apply(clip_outliers)
df['past_seventeen_month_return_sector_zscore'] = df.groupby(['year-month'])[['past_seventeen_month_return_sector_zscore']].apply(clip_outliers)
df['past_eighteen_month_return_sector_zscore'] = df.groupby(['year-month'])[['past_eighteen_month_return_sector_zscore']].apply(clip_outliers)
df['past_nineteen_month_return_sector_zscore'] = df.groupby(['year-month'])[['past_nineteen_month_return_sector_zscore']].apply(clip_outliers)
df['past_twenty_month_return_sector_zscore'] = df.groupby(['year-month'])[['past_twenty_month_return_sector_zscore']].apply(clip_outliers)
df['past_twentyone_month_return_sector_zscore'] = df.groupby(['year-month'])[['past_twentyone_month_return_sector_zscore']].apply(clip_outliers)
df['past_twentytwo_month_return_sector_zscore'] = df.groupby(['year-month'])[['past_twentytwo_month_return_sector_zscore']].apply(clip_outliers)
df['past_twentythree_month_return_sector_zscore'] = df.groupby(['year-month'])[['past_twentythree_month_return_sector_zscore']].apply(clip_outliers)
df['past_twentyfour_month_return_sector_zscore'] = df.groupby(['year-month'])[['past_twentyfour_month_return_sector_zscore']].apply(clip_outliers)
df['past_twentyfive_month_return_sector_zscore'] = df.groupby(['year-month'])[['past_twentyfive_month_return_sector_zscore']].apply(clip_outliers)
df['past_twentysix_month_return_sector_zscore'] = df.groupby(['year-month'])[['past_twentysix_month_return_sector_zscore']].apply(clip_outliers)
df['past_twentyseven_month_return_sector_zscore'] = df.groupby(['year-month'])[['past_twentyseven_month_return_sector_zscore']].apply(clip_outliers)
df['past_twentyeight_month_return_sector_zscore'] = df.groupby(['year-month'])[['past_twentyeight_month_return_sector_zscore']].apply(clip_outliers)
df['past_twentynine_month_return_sector_zscore'] = df.groupby(['year-month'])[['past_twentynine_month_return_sector_zscore']].apply(clip_outliers)
df['past_thirty_month_return_sector_zscore'] = df.groupby(['year-month'])[['past_thirty_month_return_sector_zscore']].apply(clip_outliers)
df['past_thirtyone_month_return_sector_zscore'] = df.groupby(['year-month'])[['past_thirtyone_month_return_sector_zscore']].apply(clip_outliers)
df['past_thirtytwo_month_return_sector_zscore'] = df.groupby(['year-month'])[['past_thirtytwo_month_return_sector_zscore']].apply(clip_outliers)
df['past_thirtythree_month_return_sector_zscore'] = df.groupby(['year-month'])[['past_thirtythree_month_return_sector_zscore']].apply(clip_outliers)
df['past_thirtyfour_month_return_sector_zscore'] = df.groupby(['year-month'])[['past_thirtyfour_month_return_sector_zscore']].apply(clip_outliers)
df['past_thirtyfive_month_return_sector_zscore'] = df.groupby(['year-month'])[['past_thirtyfive_month_return_sector_zscore']].apply(clip_outliers)
df['past_thirtysix_month_return_sector_zscore'] = df.groupby(['year-month'])[['past_thirtysix_month_return_sector_zscore']].apply(clip_outliers)
df['accrual_sector_zscore'] = df.groupby(['year-month'])[['accrual_sector_zscore']].apply(clip_outliers)
df['adv_sale_sector_zscore'] = df.groupby(['year-month'])[['adv_sale_sector_zscore']].apply(clip_outliers)
df['aftret_eq_sector_zscore'] = df.groupby(['year-month'])[['aftret_eq_sector_zscore']].apply(clip_outliers)
df['aftret_equity_sector_zscore'] = df.groupby(['year-month'])[['aftret_equity_sector_zscore']].apply(clip_outliers)
df['aftret_invcapx_sector_zscore'] = df.groupby(['year-month'])[['aftret_invcapx_sector_zscore']].apply(clip_outliers)
df['at_turn_sector_zscore'] = df.groupby(['year-month'])[['at_turn_sector_zscore']].apply(clip_outliers)
df['bm_sector_zscore'] = df.groupby(['year-month'])[['bm_sector_zscore']].apply(clip_outliers)
df['CAPEI_sector_zscore'] = df.groupby(['year-month'])[['CAPEI_sector_zscore']].apply(clip_outliers)
df['capital_ratio_sector_zscore'] = df.groupby(['year-month'])[['capital_ratio_sector_zscore']].apply(clip_outliers)
df['cash_conversion_sector_zscore'] = df.groupby(['year-month'])[['cash_conversion_sector_zscore']].apply(clip_outliers)
df['cash_debt_sector_zscore'] = df.groupby(['year-month'])[['cash_debt_sector_zscore']].apply(clip_outliers)
df['cash_lt_sector_zscore'] = df.groupby(['year-month'])[['cash_lt_sector_zscore']].apply(clip_outliers)
df['cash_ratio_sector_zscore'] = df.groupby(['year-month'])[['cash_ratio_sector_zscore']].apply(clip_outliers)
df['cfm_sector_zscore'] = df.groupby(['year-month'])[['cfm_sector_zscore']].apply(clip_outliers)
df['curr_debt_sector_zscore'] = df.groupby(['year-month'])[['curr_debt_sector_zscore']].apply(clip_outliers)
df['curr_ratio_sector_zscore'] = df.groupby(['year-month'])[['curr_ratio_sector_zscore']].apply(clip_outliers)
df['de_ratio_sector_zscore'] = df.groupby(['year-month'])[['de_ratio_sector_zscore']].apply(clip_outliers)
df['debt_assets_sector_zscore'] = df.groupby(['year-month'])[['debt_assets_sector_zscore']].apply(clip_outliers)
df['debt_at_sector_zscore'] = df.groupby(['year-month'])[['debt_at_sector_zscore']].apply(clip_outliers)
df['debt_capital_sector_zscore'] = df.groupby(['year-month'])[['debt_capital_sector_zscore']].apply(clip_outliers)
df['debt_ebitda_sector_zscore'] = df.groupby(['year-month'])[['debt_ebitda_sector_zscore']].apply(clip_outliers)
df['debt_invcap_sector_zscore'] = df.groupby(['year-month'])[['debt_invcap_sector_zscore']].apply(clip_outliers)
df['DIVYIELD_sector_zscore'] = df.groupby(['year-month'])[['DIVYIELD_sector_zscore']].apply(clip_outliers)
df['dltt_be_sector_zscore'] = df.groupby(['year-month'])[['dltt_be_sector_zscore']].apply(clip_outliers)
df['dpr_sector_zscore'] = df.groupby(['year-month'])[['dpr_sector_zscore']].apply(clip_outliers)
df['efftax_sector_zscore'] = df.groupby(['year-month'])[['efftax_sector_zscore']].apply(clip_outliers)
df['equity_invcap_sector_zscore'] = df.groupby(['year-month'])[['equity_invcap_sector_zscore']].apply(clip_outliers)
df['evm_sector_zscore'] = df.groupby(['year-month'])[['evm_sector_zscore']].apply(clip_outliers)
df['fcf_ocf_sector_zscore'] = df.groupby(['year-month'])[['fcf_ocf_sector_zscore']].apply(clip_outliers)
df['gpm_sector_zscore'] = df.groupby(['year-month'])[['gpm_sector_zscore']].apply(clip_outliers)
df['GProf_sector_zscore'] = df.groupby(['year-month'])[['GProf_sector_zscore']].apply(clip_outliers)
df['int_debt_sector_zscore'] = df.groupby(['year-month'])[['int_debt_sector_zscore']].apply(clip_outliers)
df['int_totdebt_sector_zscore'] = df.groupby(['year-month'])[['int_totdebt_sector_zscore']].apply(clip_outliers)
df['intcov_sector_zscore'] = df.groupby(['year-month'])[['intcov_sector_zscore']].apply(clip_outliers)
df['intcov_ratio_sector_zscore'] = df.groupby(['year-month'])[['intcov_ratio_sector_zscore']].apply(clip_outliers)
df['inv_turn_sector_zscore'] = df.groupby(['year-month'])[['inv_turn_sector_zscore']].apply(clip_outliers)
df['invt_act_sector_zscore'] = df.groupby(['year-month'])[['invt_act_sector_zscore']].apply(clip_outliers)
df['lt_debt_sector_zscore'] = df.groupby(['year-month'])[['lt_debt_sector_zscore']].apply(clip_outliers)
df['lt_ppent_sector_zscore'] = df.groupby(['year-month'])[['lt_ppent_sector_zscore']].apply(clip_outliers)
df['npm_sector_zscore'] = df.groupby(['year-month'])[['npm_sector_zscore']].apply(clip_outliers)
df['ocf_lct_sector_zscore'] = df.groupby(['year-month'])[['ocf_lct_sector_zscore']].apply(clip_outliers)
df['opmad_sector_zscore'] = df.groupby(['year-month'])[['opmad_sector_zscore']].apply(clip_outliers)
df['opmbd_sector_zscore'] = df.groupby(['year-month'])[['opmbd_sector_zscore']].apply(clip_outliers)
df['pay_turn_sector_zscore'] = df.groupby(['year-month'])[['pay_turn_sector_zscore']].apply(clip_outliers)
df['pcf_sector_zscore'] = df.groupby(['year-month'])[['pcf_sector_zscore']].apply(clip_outliers)
df['pe_exi_sector_zscore'] = df.groupby(['year-month'])[['pe_exi_sector_zscore']].apply(clip_outliers)
df['pe_inc_sector_zscore'] = df.groupby(['year-month'])[['pe_inc_sector_zscore']].apply(clip_outliers)
df['pe_op_basic_sector_zscore'] = df.groupby(['year-month'])[['pe_op_basic_sector_zscore']].apply(clip_outliers)
df['pe_op_dil_sector_zscore'] = df.groupby(['year-month'])[['pe_op_dil_sector_zscore']].apply(clip_outliers)
df['PEG_1yrforward_sector_zscore'] = df.groupby(['year-month'])[['PEG_1yrforward_sector_zscore']].apply(clip_outliers)
df['PEG_ltgforward_sector_zscore'] = df.groupby(['year-month'])[['PEG_ltgforward_sector_zscore']].apply(clip_outliers)
df['PEG_trailing_sector_zscore'] = df.groupby(['year-month'])[['PEG_trailing_sector_zscore']].apply(clip_outliers)
df['pretret_earnat_sector_zscore'] = df.groupby(['year-month'])[['pretret_earnat_sector_zscore']].apply(clip_outliers)
df['pretret_noa_sector_zscore'] = df.groupby(['year-month'])[['pretret_noa_sector_zscore']].apply(clip_outliers)
df['profit_lct_sector_zscore'] = df.groupby(['year-month'])[['profit_lct_sector_zscore']].apply(clip_outliers)
df['ps_sector_zscore'] = df.groupby(['year-month'])[['ps_sector_zscore']].apply(clip_outliers)
df['ptb_sector_zscore'] = df.groupby(['year-month'])[['ptb_sector_zscore']].apply(clip_outliers)
df['ptpm_sector_zscore'] = df.groupby(['year-month'])[['ptpm_sector_zscore']].apply(clip_outliers)
df['quick_ratio_sector_zscore'] = df.groupby(['year-month'])[['quick_ratio_sector_zscore']].apply(clip_outliers)
df['rd_sale_sector_zscore'] = df.groupby(['year-month'])[['rd_sale_sector_zscore']].apply(clip_outliers)
df['rect_act_sector_zscore'] = df.groupby(['year-month'])[['rect_act_sector_zscore']].apply(clip_outliers)
df['rect_turn_sector_zscore'] = df.groupby(['year-month'])[['rect_turn_sector_zscore']].apply(clip_outliers)
df['roa_sector_zscore'] = df.groupby(['year-month'])[['roa_sector_zscore']].apply(clip_outliers)
df['roce_sector_zscore'] = df.groupby(['year-month'])[['roce_sector_zscore']].apply(clip_outliers)
df['roe_sector_zscore'] = df.groupby(['year-month'])[['roe_sector_zscore']].apply(clip_outliers)
df['sale_equity_sector_zscore'] = df.groupby(['year-month'])[['sale_equity_sector_zscore']].apply(clip_outliers)
df['sale_invcap_sector_zscore'] = df.groupby(['year-month'])[['sale_invcap_sector_zscore']].apply(clip_outliers)
df['sale_nwc_sector_zscore'] = df.groupby(['year-month'])[['sale_nwc_sector_zscore']].apply(clip_outliers)
df['short_debt_sector_zscore'] = df.groupby(['year-month'])[['short_debt_sector_zscore']].apply(clip_outliers)
df['staff_sale_sector_zscore'] = df.groupby(['year-month'])[['staff_sale_sector_zscore']].apply(clip_outliers)
df['totdebt_invcap_sector_zscore'] = df.groupby(['year-month'])[['totdebt_invcap_sector_zscore']].apply(clip_outliers)
df['dvpspm_sector_zscore'] = df.groupby(['year-month'])[['dvpspm_sector_zscore']].apply(clip_outliers)
df['dvpsxm_sector_zscore'] = df.groupby(['year-month'])[['dvpsxm_sector_zscore']].apply(clip_outliers)
df['dvrate_sector_zscore'] = df.groupby(['year-month'])[['dvrate_sector_zscore']].apply(clip_outliers)
df['spcsrc_sector_zscore'] = df.groupby(['year-month'])[['spcsrc_sector_zscore']].apply(clip_outliers)
df['alpha_sector_zscore'] = df.groupby(['year-month'])[['alpha_sector_zscore']].apply(clip_outliers)
df['b_hml_sector_zscore'] = df.groupby(['year-month'])[['b_hml_sector_zscore']].apply(clip_outliers)
df['b_mkt_sector_zscore'] = df.groupby(['year-month'])[['b_mkt_sector_zscore']].apply(clip_outliers)
df['b_smb_sector_zscore'] = df.groupby(['year-month'])[['b_smb_sector_zscore']].apply(clip_outliers)
df['b_umd_sector_zscore'] = df.groupby(['year-month'])[['b_umd_sector_zscore']].apply(clip_outliers)
df['exret_sector_zscore'] = df.groupby(['year-month'])[['exret_sector_zscore']].apply(clip_outliers)
df['ivol_sector_zscore'] = df.groupby(['year-month'])[['ivol_sector_zscore']].apply(clip_outliers)
df['n_sector_zscore'] = df.groupby(['year-month'])[['n_sector_zscore']].apply(clip_outliers)
df['R2_sector_zscore'] = df.groupby(['year-month'])[['R2_sector_zscore']].apply(clip_outliers)
df['tvol_sector_zscore'] = df.groupby(['year-month'])[['tvol_sector_zscore']].apply(clip_outliers)
df['BUYPCT_sector_zscore'] = df.groupby(['year-month'])[['BUYPCT_sector_zscore']].apply(clip_outliers)
df['HOLDPCT_sector_zscore'] = df.groupby(['year-month'])[['HOLDPCT_sector_zscore']].apply(clip_outliers)
df['MEANREC_sector_zscore'] = df.groupby(['year-month'])[['MEANREC_sector_zscore']].apply(clip_outliers)
df['MEDREC_sector_zscore'] = df.groupby(['year-month'])[['MEDREC_sector_zscore']].apply(clip_outliers)
df['recup_sector_zscore'] = df.groupby(['year-month'])[['recup_sector_zscore']].apply(clip_outliers)
df['recdown_sector_zscore'] = df.groupby(['year-month'])[['recdown_sector_zscore']].apply(clip_outliers)
df['SELLPCT_sector_zscore'] = df.groupby(['year-month'])[['SELLPCT_sector_zscore']].apply(clip_outliers)
df['STDEV_sector_zscore'] = df.groupby(['year-month'])[['STDEV_sector_zscore']].apply(clip_outliers)

# %%
# # df - Clean - Further standardize Z-scores (~0 mean and ~-3 to +3 deviation range)

# # Market by month
# df['past_one_month_return_zscore'] = df.groupby(['year-month'])[['past_one_month_return_zscore']].apply(modified_z)
# df['past_two_month_return_zscore'] = df.groupby(['year-month'])[['past_two_month_return_zscore']].apply(modified_z)
# df['past_three_month_return_zscore'] = df.groupby(['year-month'])[['past_three_month_return_zscore']].apply(modified_z)
# df['past_four_month_return_zscore'] = df.groupby(['year-month'])[['past_four_month_return_zscore']].apply(modified_z)
# df['past_five_month_return_zscore'] = df.groupby(['year-month'])[['past_five_month_return_zscore']].apply(modified_z)
# df['past_six_month_return_zscore'] = df.groupby(['year-month'])[['past_six_month_return_zscore']].apply(modified_z)
# df['past_seven_month_return_zscore'] = df.groupby(['year-month'])[['past_seven_month_return_zscore']].apply(modified_z)
# df['past_eight_month_return_zscore'] = df.groupby(['year-month'])[['past_eight_month_return_zscore']].apply(modified_z)
# df['past_nine_month_return_zscore'] = df.groupby(['year-month'])[['past_nine_month_return_zscore']].apply(modified_z)
# df['past_ten_month_return_zscore'] = df.groupby(['year-month'])[['past_ten_month_return_zscore']].apply(modified_z)
# df['past_eleven_month_return_zscore'] = df.groupby(['year-month'])[['past_eleven_month_return_zscore']].apply(modified_z)
# df['past_twelve_month_return_zscore'] = df.groupby(['year-month'])[['past_twelve_month_return_zscore']].apply(modified_z)
# df['past_thirteen_month_return_zscore'] = df.groupby(['year-month'])[['past_thirteen_month_return_zscore']].apply(modified_z)
# df['past_fourteen_month_return_zscore'] = df.groupby(['year-month'])[['past_fourteen_month_return_zscore']].apply(modified_z)
# df['past_fifteen_month_return_zscore'] = df.groupby(['year-month'])[['past_fifteen_month_return_zscore']].apply(modified_z)
# df['past_sixteen_month_return_zscore'] = df.groupby(['year-month'])[['past_sixteen_month_return_zscore']].apply(modified_z)
# df['past_seventeen_month_return_zscore'] = df.groupby(['year-month'])[['past_seventeen_month_return_zscore']].apply(modified_z)
# df['past_eighteen_month_return_zscore'] = df.groupby(['year-month'])[['past_eighteen_month_return_zscore']].apply(modified_z)
# df['past_nineteen_month_return_zscore'] = df.groupby(['year-month'])[['past_nineteen_month_return_zscore']].apply(modified_z)
# df['past_twenty_month_return_zscore'] = df.groupby(['year-month'])[['past_twenty_month_return_zscore']].apply(modified_z)
# df['past_twentyone_month_return_zscore'] = df.groupby(['year-month'])[['past_twentyone_month_return_zscore']].apply(modified_z)
# df['past_twentytwo_month_return_zscore'] = df.groupby(['year-month'])[['past_twentytwo_month_return_zscore']].apply(modified_z)
# df['past_twentythree_month_return_zscore'] = df.groupby(['year-month'])[['past_twentythree_month_return_zscore']].apply(modified_z)
# df['past_twentyfour_month_return_zscore'] = df.groupby(['year-month'])[['past_twentyfour_month_return_zscore']].apply(modified_z)
# df['past_twentyfive_month_return_zscore'] = df.groupby(['year-month'])[['past_twentyfive_month_return_zscore']].apply(modified_z)
# df['past_twentysix_month_return_zscore'] = df.groupby(['year-month'])[['past_twentysix_month_return_zscore']].apply(modified_z)
# df['past_twentyseven_month_return_zscore'] = df.groupby(['year-month'])[['past_twentyseven_month_return_zscore']].apply(modified_z)
# df['past_twentyeight_month_return_zscore'] = df.groupby(['year-month'])[['past_twentyeight_month_return_zscore']].apply(modified_z)
# df['past_twentynine_month_return_zscore'] = df.groupby(['year-month'])[['past_twentynine_month_return_zscore']].apply(modified_z)
# df['past_thirty_month_return_zscore'] = df.groupby(['year-month'])[['past_thirty_month_return_zscore']].apply(modified_z)
# df['past_thirtyone_month_return_zscore'] = df.groupby(['year-month'])[['past_thirtyone_month_return_zscore']].apply(modified_z)
# df['past_thirtytwo_month_return_zscore'] = df.groupby(['year-month'])[['past_thirtytwo_month_return_zscore']].apply(modified_z)
# df['past_thirtythree_month_return_zscore'] = df.groupby(['year-month'])[['past_thirtythree_month_return_zscore']].apply(modified_z)
# df['past_thirtyfour_month_return_zscore'] = df.groupby(['year-month'])[['past_thirtyfour_month_return_zscore']].apply(modified_z)
# df['past_thirtyfive_month_return_zscore'] = df.groupby(['year-month'])[['past_thirtyfive_month_return_zscore']].apply(modified_z)
# df['past_thirtysix_month_return_zscore'] = df.groupby(['year-month'])[['past_thirtysix_month_return_zscore']].apply(modified_z)
# df['accrual_zscore'] = df.groupby(['year-month'])[['accrual_zscore']].apply(modified_z)
# df['adv_sale_zscore'] = df.groupby(['year-month'])[['adv_sale_zscore']].apply(modified_z)
# df['aftret_eq_zscore'] = df.groupby(['year-month'])[['aftret_eq_zscore']].apply(modified_z)
# df['aftret_equity_zscore'] = df.groupby(['year-month'])[['aftret_equity_zscore']].apply(modified_z)
# df['aftret_invcapx_zscore'] = df.groupby(['year-month'])[['aftret_invcapx_zscore']].apply(modified_z)
# df['at_turn_zscore'] = df.groupby(['year-month'])[['at_turn_zscore']].apply(modified_z)
# df['bm_zscore'] = df.groupby(['year-month'])[['bm_zscore']].apply(modified_z)
# df['CAPEI_zscore'] = df.groupby(['year-month'])[['CAPEI_zscore']].apply(modified_z)
# df['capital_ratio_zscore'] = df.groupby(['year-month'])[['capital_ratio_zscore']].apply(modified_z)
# df['cash_conversion_zscore'] = df.groupby(['year-month'])[['cash_conversion_zscore']].apply(modified_z)
# df['cash_debt_zscore'] = df.groupby(['year-month'])[['cash_debt_zscore']].apply(modified_z)
# df['cash_lt_zscore'] = df.groupby(['year-month'])[['cash_lt_zscore']].apply(modified_z)
# df['cash_ratio_zscore'] = df.groupby(['year-month'])[['cash_ratio_zscore']].apply(modified_z)
# df['cfm_zscore'] = df.groupby(['year-month'])[['cfm_zscore']].apply(modified_z)
# df['curr_debt_zscore'] = df.groupby(['year-month'])[['curr_debt_zscore']].apply(modified_z)
# df['curr_ratio_zscore'] = df.groupby(['year-month'])[['curr_ratio_zscore']].apply(modified_z)
# df['de_ratio_zscore'] = df.groupby(['year-month'])[['de_ratio_zscore']].apply(modified_z)
# df['debt_assets_zscore'] = df.groupby(['year-month'])[['debt_assets_zscore']].apply(modified_z)
# df['debt_at_zscore'] = df.groupby(['year-month'])[['debt_at_zscore']].apply(modified_z)
# df['debt_capital_zscore'] = df.groupby(['year-month'])[['debt_capital_zscore']].apply(modified_z)
# df['debt_ebitda_zscore'] = df.groupby(['year-month'])[['debt_ebitda_zscore']].apply(modified_z)
# df['debt_invcap_zscore'] = df.groupby(['year-month'])[['debt_invcap_zscore']].apply(modified_z)
# df['DIVYIELD_zscore'] = df.groupby(['year-month'])[['DIVYIELD_zscore']].apply(modified_z)
# df['dltt_be_zscore'] = df.groupby(['year-month'])[['dltt_be_zscore']].apply(modified_z)
# df['dpr_zscore'] = df.groupby(['year-month'])[['dpr_zscore']].apply(modified_z)
# df['efftax_zscore'] = df.groupby(['year-month'])[['efftax_zscore']].apply(modified_z)
# df['equity_invcap_zscore'] = df.groupby(['year-month'])[['equity_invcap_zscore']].apply(modified_z)
# df['evm_zscore'] = df.groupby(['year-month'])[['evm_zscore']].apply(modified_z)
# df['fcf_ocf_zscore'] = df.groupby(['year-month'])[['fcf_ocf_zscore']].apply(modified_z)
# df['gpm_zscore'] = df.groupby(['year-month'])[['gpm_zscore']].apply(modified_z)
# df['GProf_zscore'] = df.groupby(['year-month'])[['GProf_zscore']].apply(modified_z)
# df['int_debt_zscore'] = df.groupby(['year-month'])[['int_debt_zscore']].apply(modified_z)
# df['int_totdebt_zscore'] = df.groupby(['year-month'])[['int_totdebt_zscore']].apply(modified_z)
# df['intcov_zscore'] = df.groupby(['year-month'])[['intcov_zscore']].apply(modified_z)
# df['intcov_ratio_zscore'] = df.groupby(['year-month'])[['intcov_ratio_zscore']].apply(modified_z)
# df['inv_turn_zscore'] = df.groupby(['year-month'])[['inv_turn_zscore']].apply(modified_z)
# df['invt_act_zscore'] = df.groupby(['year-month'])[['invt_act_zscore']].apply(modified_z)
# df['lt_debt_zscore'] = df.groupby(['year-month'])[['lt_debt_zscore']].apply(modified_z)
# df['lt_ppent_zscore'] = df.groupby(['year-month'])[['lt_ppent_zscore']].apply(modified_z)
# df['npm_zscore'] = df.groupby(['year-month'])[['npm_zscore']].apply(modified_z)
# df['ocf_lct_zscore'] = df.groupby(['year-month'])[['ocf_lct_zscore']].apply(modified_z)
# df['opmad_zscore'] = df.groupby(['year-month'])[['opmad_zscore']].apply(modified_z)
# df['opmbd_zscore'] = df.groupby(['year-month'])[['opmbd_zscore']].apply(modified_z)
# df['pay_turn_zscore'] = df.groupby(['year-month'])[['pay_turn_zscore']].apply(modified_z)
# df['pcf_zscore'] = df.groupby(['year-month'])[['pcf_zscore']].apply(modified_z)
# df['pe_exi_zscore'] = df.groupby(['year-month'])[['pe_exi_zscore']].apply(modified_z)
# df['pe_inc_zscore'] = df.groupby(['year-month'])[['pe_inc_zscore']].apply(modified_z)
# df['pe_op_basic_zscore'] = df.groupby(['year-month'])[['pe_op_basic_zscore']].apply(modified_z)
# df['pe_op_dil_zscore'] = df.groupby(['year-month'])[['pe_op_dil_zscore']].apply(modified_z)
# df['PEG_1yrforward_zscore'] = df.groupby(['year-month'])[['PEG_1yrforward_zscore']].apply(modified_z)
# df['PEG_ltgforward_zscore'] = df.groupby(['year-month'])[['PEG_ltgforward_zscore']].apply(modified_z)
# df['PEG_trailing_zscore'] = df.groupby(['year-month'])[['PEG_trailing_zscore']].apply(modified_z)
# df['pretret_earnat_zscore'] = df.groupby(['year-month'])[['pretret_earnat_zscore']].apply(modified_z)
# df['pretret_noa_zscore'] = df.groupby(['year-month'])[['pretret_noa_zscore']].apply(modified_z)
# df['profit_lct_zscore'] = df.groupby(['year-month'])[['profit_lct_zscore']].apply(modified_z)
# df['ps_zscore'] = df.groupby(['year-month'])[['ps_zscore']].apply(modified_z)
# df['ptb_zscore'] = df.groupby(['year-month'])[['ptb_zscore']].apply(modified_z)
# df['ptpm_zscore'] = df.groupby(['year-month'])[['ptpm_zscore']].apply(modified_z)
# df['quick_ratio_zscore'] = df.groupby(['year-month'])[['quick_ratio_zscore']].apply(modified_z)
# df['rd_sale_zscore'] = df.groupby(['year-month'])[['rd_sale_zscore']].apply(modified_z)
# df['rect_act_zscore'] = df.groupby(['year-month'])[['rect_act_zscore']].apply(modified_z)
# df['rect_turn_zscore'] = df.groupby(['year-month'])[['rect_turn_zscore']].apply(modified_z)
# df['roa_zscore'] = df.groupby(['year-month'])[['roa_zscore']].apply(modified_z)
# df['roce_zscore'] = df.groupby(['year-month'])[['roce_zscore']].apply(modified_z)
# df['roe_zscore'] = df.groupby(['year-month'])[['roe_zscore']].apply(modified_z)
# df['sale_equity_zscore'] = df.groupby(['year-month'])[['sale_equity_zscore']].apply(modified_z)
# df['sale_invcap_zscore'] = df.groupby(['year-month'])[['sale_invcap_zscore']].apply(modified_z)
# df['sale_nwc_zscore'] = df.groupby(['year-month'])[['sale_nwc_zscore']].apply(modified_z)
# df['short_debt_zscore'] = df.groupby(['year-month'])[['short_debt_zscore']].apply(modified_z)
# df['staff_sale_zscore'] = df.groupby(['year-month'])[['staff_sale_zscore']].apply(modified_z)
# df['totdebt_invcap_zscore'] = df.groupby(['year-month'])[['totdebt_invcap_zscore']].apply(modified_z)
# df['dvpspm_zscore'] = df.groupby(['year-month'])[['dvpspm_zscore']].apply(modified_z)
# df['dvpsxm_zscore'] = df.groupby(['year-month'])[['dvpsxm_zscore']].apply(modified_z)
# df['dvrate_zscore'] = df.groupby(['year-month'])[['dvrate_zscore']].apply(modified_z)
# df['spcsrc_zscore'] = df.groupby(['year-month'])[['spcsrc_zscore']].apply(modified_z)
# df['alpha_zscore'] = df.groupby(['year-month'])[['alpha_zscore']].apply(modified_z)
# df['b_hml_zscore'] = df.groupby(['year-month'])[['b_hml_zscore']].apply(modified_z)
# df['b_mkt_zscore'] = df.groupby(['year-month'])[['b_mkt_zscore']].apply(modified_z)
# df['b_smb_zscore'] = df.groupby(['year-month'])[['b_smb_zscore']].apply(modified_z)
# df['b_umd_zscore'] = df.groupby(['year-month'])[['b_umd_zscore']].apply(modified_z)
# df['exret_zscore'] = df.groupby(['year-month'])[['exret_zscore']].apply(modified_z)
# df['ivol_zscore'] = df.groupby(['year-month'])[['ivol_zscore']].apply(modified_z)
# df['n_zscore'] = df.groupby(['year-month'])[['n_zscore']].apply(modified_z)
# df['R2_zscore'] = df.groupby(['year-month'])[['R2_zscore']].apply(modified_z)
# df['tvol_zscore'] = df.groupby(['year-month'])[['tvol_zscore']].apply(modified_z)
# df['BUYPCT_zscore'] = df.groupby(['year-month'])[['BUYPCT_zscore']].apply(modified_z)
# df['HOLDPCT_zscore'] = df.groupby(['year-month'])[['HOLDPCT_zscore']].apply(modified_z)
# df['MEANREC_zscore'] = df.groupby(['year-month'])[['MEANREC_zscore']].apply(modified_z)
# df['MEDREC_zscore'] = df.groupby(['year-month'])[['MEDREC_zscore']].apply(modified_z)
# df['recup_zscore'] = df.groupby(['year-month'])[['recup_zscore']].apply(modified_z)
# df['recdown_zscore'] = df.groupby(['year-month'])[['recdown_zscore']].apply(modified_z)
# df['SELLPCT_zscore'] = df.groupby(['year-month'])[['SELLPCT_zscore']].apply(modified_z)
# df['STDEV_zscore'] = df.groupby(['year-month'])[['STDEV_zscore']].apply(modified_z)

# # By Sector
# df['past_one_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_one_month_return_sector_zscore']].apply(modified_z)
# df['past_two_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_two_month_return_sector_zscore']].apply(modified_z)
# df['past_three_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_three_month_return_sector_zscore']].apply(modified_z)
# df['past_four_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_four_month_return_sector_zscore']].apply(modified_z)
# df['past_five_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_five_month_return_sector_zscore']].apply(modified_z)
# df['past_six_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_six_month_return_sector_zscore']].apply(modified_z)
# df['past_seven_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_seven_month_return_sector_zscore']].apply(modified_z)
# df['past_eight_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_eight_month_return_sector_zscore']].apply(modified_z)
# df['past_nine_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_nine_month_return_sector_zscore']].apply(modified_z)
# df['past_ten_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_ten_month_return_sector_zscore']].apply(modified_z)
# df['past_eleven_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_eleven_month_return_sector_zscore']].apply(modified_z)
# df['past_twelve_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_twelve_month_return_sector_zscore']].apply(modified_z)
# df['past_thirteen_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_thirteen_month_return_sector_zscore']].apply(modified_z)
# df['past_fourteen_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_fourteen_month_return_sector_zscore']].apply(modified_z)
# df['past_fifteen_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_fifteen_month_return_sector_zscore']].apply(modified_z)
# df['past_sixteen_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_sixteen_month_return_sector_zscore']].apply(modified_z)
# df['past_seventeen_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_seventeen_month_return_sector_zscore']].apply(modified_z)
# df['past_eighteen_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_eighteen_month_return_sector_zscore']].apply(modified_z)
# df['past_nineteen_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_nineteen_month_return_sector_zscore']].apply(modified_z)
# df['past_twenty_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_twenty_month_return_sector_zscore']].apply(modified_z)
# df['past_twentyone_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_twentyone_month_return_sector_zscore']].apply(modified_z)
# df['past_twentytwo_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_twentytwo_month_return_sector_zscore']].apply(modified_z)
# df['past_twentythree_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_twentythree_month_return_sector_zscore']].apply(modified_z)
# df['past_twentyfour_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_twentyfour_month_return_sector_zscore']].apply(modified_z)
# df['past_twentyfive_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_twentyfive_month_return_sector_zscore']].apply(modified_z)
# df['past_twentysix_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_twentysix_month_return_sector_zscore']].apply(modified_z)
# df['past_twentyseven_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_twentyseven_month_return_sector_zscore']].apply(modified_z)
# df['past_twentyeight_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_twentyeight_month_return_sector_zscore']].apply(modified_z)
# df['past_twentynine_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_twentynine_month_return_sector_zscore']].apply(modified_z)
# df['past_thirty_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_thirty_month_return_sector_zscore']].apply(modified_z)
# df['past_thirtyone_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_thirtyone_month_return_sector_zscore']].apply(modified_z)
# df['past_thirtytwo_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_thirtytwo_month_return_sector_zscore']].apply(modified_z)
# df['past_thirtythree_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_thirtythree_month_return_sector_zscore']].apply(modified_z)
# df['past_thirtyfour_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_thirtyfour_month_return_sector_zscore']].apply(modified_z)
# df['past_thirtyfive_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_thirtyfive_month_return_sector_zscore']].apply(modified_z)
# df['past_thirtysix_month_return_sector_zscore'] = df.groupby(['year-month', 'sector'])[['past_thirtysix_month_return_sector_zscore']].apply(modified_z)
# df['accrual_sector_zscore'] = df.groupby(['year-month', 'sector'])[['accrual_sector_zscore']].apply(modified_z)
# df['adv_sale_sector_zscore'] = df.groupby(['year-month', 'sector'])[['adv_sale_sector_zscore']].apply(modified_z)
# df['aftret_eq_sector_zscore'] = df.groupby(['year-month', 'sector'])[['aftret_eq_sector_zscore']].apply(modified_z)
# df['aftret_equity_sector_zscore'] = df.groupby(['year-month', 'sector'])[['aftret_equity_sector_zscore']].apply(modified_z)
# df['aftret_invcapx_sector_zscore'] = df.groupby(['year-month', 'sector'])[['aftret_invcapx_sector_zscore']].apply(modified_z)
# df['at_turn_sector_zscore'] = df.groupby(['year-month', 'sector'])[['at_turn_sector_zscore']].apply(modified_z)
# df['bm_sector_zscore'] = df.groupby(['year-month', 'sector'])[['bm_sector_zscore']].apply(modified_z)
# df['CAPEI_sector_zscore'] = df.groupby(['year-month', 'sector'])[['CAPEI_sector_zscore']].apply(modified_z)
# df['capital_ratio_sector_zscore'] = df.groupby(['year-month', 'sector'])[['capital_ratio_sector_zscore']].apply(modified_z)
# df['cash_conversion_sector_zscore'] = df.groupby(['year-month', 'sector'])[['cash_conversion_sector_zscore']].apply(modified_z)
# df['cash_debt_sector_zscore'] = df.groupby(['year-month', 'sector'])[['cash_debt_sector_zscore']].apply(modified_z)
# df['cash_lt_sector_zscore'] = df.groupby(['year-month', 'sector'])[['cash_lt_sector_zscore']].apply(modified_z)
# df['cash_ratio_sector_zscore'] = df.groupby(['year-month', 'sector'])[['cash_ratio_sector_zscore']].apply(modified_z)
# df['cfm_sector_zscore'] = df.groupby(['year-month', 'sector'])[['cfm_sector_zscore']].apply(modified_z)
# df['curr_debt_sector_zscore'] = df.groupby(['year-month', 'sector'])[['curr_debt_sector_zscore']].apply(modified_z)
# df['curr_ratio_sector_zscore'] = df.groupby(['year-month', 'sector'])[['curr_ratio_sector_zscore']].apply(modified_z)
# df['de_ratio_sector_zscore'] = df.groupby(['year-month', 'sector'])[['de_ratio_sector_zscore']].apply(modified_z)
# df['debt_assets_sector_zscore'] = df.groupby(['year-month', 'sector'])[['debt_assets_sector_zscore']].apply(modified_z)
# df['debt_at_sector_zscore'] = df.groupby(['year-month', 'sector'])[['debt_at_sector_zscore']].apply(modified_z)
# df['debt_capital_sector_zscore'] = df.groupby(['year-month', 'sector'])[['debt_capital_sector_zscore']].apply(modified_z)
# df['debt_ebitda_sector_zscore'] = df.groupby(['year-month', 'sector'])[['debt_ebitda_sector_zscore']].apply(modified_z)
# df['debt_invcap_sector_zscore'] = df.groupby(['year-month', 'sector'])[['debt_invcap_sector_zscore']].apply(modified_z)
# df['DIVYIELD_sector_zscore'] = df.groupby(['year-month', 'sector'])[['DIVYIELD_sector_zscore']].apply(modified_z)
# df['dltt_be_sector_zscore'] = df.groupby(['year-month', 'sector'])[['dltt_be_sector_zscore']].apply(modified_z)
# df['dpr_sector_zscore'] = df.groupby(['year-month', 'sector'])[['dpr_sector_zscore']].apply(modified_z)
# df['efftax_sector_zscore'] = df.groupby(['year-month', 'sector'])[['efftax_sector_zscore']].apply(modified_z)
# df['equity_invcap_sector_zscore'] = df.groupby(['year-month', 'sector'])[['equity_invcap_sector_zscore']].apply(modified_z)
# df['evm_sector_zscore'] = df.groupby(['year-month', 'sector'])[['evm_sector_zscore']].apply(modified_z)
# df['fcf_ocf_sector_zscore'] = df.groupby(['year-month', 'sector'])[['fcf_ocf_sector_zscore']].apply(modified_z)
# df['gpm_sector_zscore'] = df.groupby(['year-month', 'sector'])[['gpm_sector_zscore']].apply(modified_z)
# df['GProf_sector_zscore'] = df.groupby(['year-month', 'sector'])[['GProf_sector_zscore']].apply(modified_z)
# df['int_debt_sector_zscore'] = df.groupby(['year-month', 'sector'])[['int_debt_sector_zscore']].apply(modified_z)
# df['int_totdebt_sector_zscore'] = df.groupby(['year-month', 'sector'])[['int_totdebt_sector_zscore']].apply(modified_z)
# df['intcov_sector_zscore'] = df.groupby(['year-month', 'sector'])[['intcov_sector_zscore']].apply(modified_z)
# df['intcov_ratio_sector_zscore'] = df.groupby(['year-month', 'sector'])[['intcov_ratio_sector_zscore']].apply(modified_z)
# df['inv_turn_sector_zscore'] = df.groupby(['year-month', 'sector'])[['inv_turn_sector_zscore']].apply(modified_z)
# df['invt_act_sector_zscore'] = df.groupby(['year-month', 'sector'])[['invt_act_sector_zscore']].apply(modified_z)
# df['lt_debt_sector_zscore'] = df.groupby(['year-month', 'sector'])[['lt_debt_sector_zscore']].apply(modified_z)
# df['lt_ppent_sector_zscore'] = df.groupby(['year-month', 'sector'])[['lt_ppent_sector_zscore']].apply(modified_z)
# df['npm_sector_zscore'] = df.groupby(['year-month', 'sector'])[['npm_sector_zscore']].apply(modified_z)
# df['ocf_lct_sector_zscore'] = df.groupby(['year-month', 'sector'])[['ocf_lct_sector_zscore']].apply(modified_z)
# df['opmad_sector_zscore'] = df.groupby(['year-month', 'sector'])[['opmad_sector_zscore']].apply(modified_z)
# df['opmbd_sector_zscore'] = df.groupby(['year-month', 'sector'])[['opmbd_sector_zscore']].apply(modified_z)
# df['pay_turn_sector_zscore'] = df.groupby(['year-month', 'sector'])[['pay_turn_sector_zscore']].apply(modified_z)
# df['pcf_sector_zscore'] = df.groupby(['year-month', 'sector'])[['pcf_sector_zscore']].apply(modified_z)
# df['pe_exi_sector_zscore'] = df.groupby(['year-month', 'sector'])[['pe_exi_sector_zscore']].apply(modified_z)
# df['pe_inc_sector_zscore'] = df.groupby(['year-month', 'sector'])[['pe_inc_sector_zscore']].apply(modified_z)
# df['pe_op_basic_sector_zscore'] = df.groupby(['year-month', 'sector'])[['pe_op_basic_sector_zscore']].apply(modified_z)
# df['pe_op_dil_sector_zscore'] = df.groupby(['year-month', 'sector'])[['pe_op_dil_sector_zscore']].apply(modified_z)
# df['PEG_1yrforward_sector_zscore'] = df.groupby(['year-month', 'sector'])[['PEG_1yrforward_sector_zscore']].apply(modified_z)
# df['PEG_ltgforward_sector_zscore'] = df.groupby(['year-month', 'sector'])[['PEG_ltgforward_sector_zscore']].apply(modified_z)
# df['PEG_trailing_sector_zscore'] = df.groupby(['year-month', 'sector'])[['PEG_trailing_sector_zscore']].apply(modified_z)
# df['pretret_earnat_sector_zscore'] = df.groupby(['year-month', 'sector'])[['pretret_earnat_sector_zscore']].apply(modified_z)
# df['pretret_noa_sector_zscore'] = df.groupby(['year-month', 'sector'])[['pretret_noa_sector_zscore']].apply(modified_z)
# df['profit_lct_sector_zscore'] = df.groupby(['year-month', 'sector'])[['profit_lct_sector_zscore']].apply(modified_z)
# df['ps_sector_zscore'] = df.groupby(['year-month', 'sector'])[['ps_sector_zscore']].apply(modified_z)
# df['ptb_sector_zscore'] = df.groupby(['year-month', 'sector'])[['ptb_sector_zscore']].apply(modified_z)
# df['ptpm_sector_zscore'] = df.groupby(['year-month', 'sector'])[['ptpm_sector_zscore']].apply(modified_z)
# df['quick_ratio_sector_zscore'] = df.groupby(['year-month', 'sector'])[['quick_ratio_sector_zscore']].apply(modified_z)
# df['rd_sale_sector_zscore'] = df.groupby(['year-month', 'sector'])[['rd_sale_sector_zscore']].apply(modified_z)
# df['rect_act_sector_zscore'] = df.groupby(['year-month', 'sector'])[['rect_act_sector_zscore']].apply(modified_z)
# df['rect_turn_sector_zscore'] = df.groupby(['year-month', 'sector'])[['rect_turn_sector_zscore']].apply(modified_z)
# df['roa_sector_zscore'] = df.groupby(['year-month', 'sector'])[['roa_sector_zscore']].apply(modified_z)
# df['roce_sector_zscore'] = df.groupby(['year-month', 'sector'])[['roce_sector_zscore']].apply(modified_z)
# df['roe_sector_zscore'] = df.groupby(['year-month', 'sector'])[['roe_sector_zscore']].apply(modified_z)
# df['sale_equity_sector_zscore'] = df.groupby(['year-month', 'sector'])[['sale_equity_sector_zscore']].apply(modified_z)
# df['sale_invcap_sector_zscore'] = df.groupby(['year-month', 'sector'])[['sale_invcap_sector_zscore']].apply(modified_z)
# df['sale_nwc_sector_zscore'] = df.groupby(['year-month', 'sector'])[['sale_nwc_sector_zscore']].apply(modified_z)
# df['short_debt_sector_zscore'] = df.groupby(['year-month', 'sector'])[['short_debt_sector_zscore']].apply(modified_z)
# df['staff_sale_sector_zscore'] = df.groupby(['year-month', 'sector'])[['staff_sale_sector_zscore']].apply(modified_z)
# df['totdebt_invcap_sector_zscore'] = df.groupby(['year-month', 'sector'])[['totdebt_invcap_sector_zscore']].apply(modified_z)
# df['dvpspm_sector_zscore'] = df.groupby(['year-month', 'sector'])[['dvpspm_sector_zscore']].apply(modified_z)
# df['dvpsxm_sector_zscore'] = df.groupby(['year-month', 'sector'])[['dvpsxm_sector_zscore']].apply(modified_z)
# df['dvrate_sector_zscore'] = df.groupby(['year-month', 'sector'])[['dvrate_sector_zscore']].apply(modified_z)
# df['spcsrc_sector_zscore'] = df.groupby(['year-month', 'sector'])[['spcsrc_sector_zscore']].apply(modified_z)
# df['alpha_sector_zscore'] = df.groupby(['year-month', 'sector'])[['alpha_sector_zscore']].apply(modified_z)
# df['b_hml_sector_zscore'] = df.groupby(['year-month', 'sector'])[['b_hml_sector_zscore']].apply(modified_z)
# df['b_mkt_sector_zscore'] = df.groupby(['year-month', 'sector'])[['b_mkt_sector_zscore']].apply(modified_z)
# df['b_smb_sector_zscore'] = df.groupby(['year-month', 'sector'])[['b_smb_sector_zscore']].apply(modified_z)
# df['b_umd_sector_zscore'] = df.groupby(['year-month', 'sector'])[['b_umd_sector_zscore']].apply(modified_z)
# df['exret_sector_zscore'] = df.groupby(['year-month', 'sector'])[['exret_sector_zscore']].apply(modified_z)
# df['ivol_sector_zscore'] = df.groupby(['year-month', 'sector'])[['ivol_sector_zscore']].apply(modified_z)
# df['n_sector_zscore'] = df.groupby(['year-month', 'sector'])[['n_sector_zscore']].apply(modified_z)
# df['R2_sector_zscore'] = df.groupby(['year-month', 'sector'])[['R2_sector_zscore']].apply(modified_z)
# df['tvol_sector_zscore'] = df.groupby(['year-month', 'sector'])[['tvol_sector_zscore']].apply(modified_z)
# df['BUYPCT_sector_zscore'] = df.groupby(['year-month', 'sector'])[['BUYPCT_sector_zscore']].apply(modified_z)
# df['HOLDPCT_sector_zscore'] = df.groupby(['year-month', 'sector'])[['HOLDPCT_sector_zscore']].apply(modified_z)
# df['MEANREC_sector_zscore'] = df.groupby(['year-month', 'sector'])[['MEANREC_sector_zscore']].apply(modified_z)
# df['MEDREC_sector_zscore'] = df.groupby(['year-month', 'sector'])[['MEDREC_sector_zscore']].apply(modified_z)
# df['recup_sector_zscore'] = df.groupby(['year-month', 'sector'])[['recup_sector_zscore']].apply(modified_z)
# df['recdown_sector_zscore'] = df.groupby(['year-month', 'sector'])[['recdown_sector_zscore']].apply(modified_z)
# df['SELLPCT_sector_zscore'] = df.groupby(['year-month', 'sector'])[['SELLPCT_sector_zscore']].apply(modified_z)
# df['STDEV_sector_zscore'] = df.groupby(['year-month', 'sector'])[['STDEV_sector_zscore']].apply(modified_z)

# %%
# df - Enrich - Add Up/Down binary Dependents
# Dependent
df['forward_one_month_return_up'] = np.where(df['forward_one_month_return'] >= 0, 1, 0)
df['forward_two_month_return_up'] = np.where(df['forward_two_month_return'] >= 0, 1, 0)
df['forward_three_month_return_up'] = np.where(df['forward_three_month_return'] >= 0, 1, 0)
df['forward_four_month_return_up'] = np.where(df['forward_four_month_return'] >= 0, 1, 0)
df['forward_five_month_return_up'] = np.where(df['forward_five_month_return'] >= 0, 1, 0)
df['forward_six_month_return_up'] = np.where(df['forward_six_month_return'] >= 0, 1, 0)
df['forward_seven_month_return_up'] = np.where(df['forward_seven_month_return'] >= 0, 1, 0)
df['forward_eight_month_return_up'] = np.where(df['forward_eight_month_return'] >= 0, 1, 0)
df['forward_nine_month_return_up'] = np.where(df['forward_nine_month_return'] >= 0, 1, 0)
df['forward_ten_month_return_up'] = np.where(df['forward_ten_month_return'] >= 0, 1, 0)
df['forward_eleven_month_return_up'] = np.where(df['forward_eleven_month_return'] >= 0, 1, 0)
df['forward_twelve_month_return_up'] = np.where(df['forward_twelve_month_return'] >= 0, 1, 0)
df['forward_thirteen_month_return_up'] = np.where(df['forward_thirteen_month_return'] >= 0, 1, 0)
df['forward_fourteen_month_return_up'] = np.where(df['forward_fourteen_month_return'] >= 0, 1, 0)
df['forward_fifteen_month_return_up'] = np.where(df['forward_fifteen_month_return'] >= 0, 1, 0)
df['forward_sixteen_month_return_up'] = np.where(df['forward_sixteen_month_return'] >= 0, 1, 0)
df['forward_seventeen_month_return_up'] = np.where(df['forward_seventeen_month_return'] >= 0, 1, 0)
df['forward_eighteen_month_return_up'] = np.where(df['forward_eighteen_month_return'] >= 0, 1, 0)
df['forward_nineteen_month_return_up'] = np.where(df['forward_nineteen_month_return'] >= 0, 1, 0)
df['forward_twenty_month_return_up'] = np.where(df['forward_twenty_month_return'] >= 0, 1, 0)
df['forward_twentyone_month_return_up'] = np.where(df['forward_twentyone_month_return'] >= 0, 1, 0)
df['forward_twentytwo_month_return_up'] = np.where(df['forward_twentytwo_month_return'] >= 0, 1, 0)
df['forward_twentythree_month_return_up'] = np.where(df['forward_twentythree_month_return'] >= 0, 1, 0)
df['forward_twentyfour_month_return_up'] = np.where(df['forward_twentyfour_month_return'] >= 0, 1, 0)
df['forward_twentyfive_month_return_up'] = np.where(df['forward_twentyfive_month_return'] >= 0, 1, 0)
df['forward_twentysix_month_return_up'] = np.where(df['forward_twentysix_month_return'] >= 0, 1, 0)
df['forward_twentyseven_month_return_up'] = np.where(df['forward_twentyseven_month_return'] >= 0, 1, 0)
df['forward_twentyeight_month_return_up'] = np.where(df['forward_twentyeight_month_return'] >= 0, 1, 0)
df['forward_twentynine_month_return_up'] = np.where(df['forward_twentynine_month_return'] >= 0, 1, 0)
df['forward_thirty_month_return_up'] = np.where(df['forward_thirty_month_return'] >= 0, 1, 0)
df['forward_thirtyone_month_return_up'] = np.where(df['forward_thirtyone_month_return'] >= 0, 1, 0)
df['forward_thirtytwo_month_return_up'] = np.where(df['forward_thirtytwo_month_return'] >= 0, 1, 0)
df['forward_thirtythree_month_return_up'] = np.where(df['forward_thirtythree_month_return'] >= 0, 1, 0)
df['forward_thirtyfour_month_return_up'] = np.where(df['forward_thirtyfour_month_return'] >= 0, 1, 0)
df['forward_thirtyfive_month_return_up'] = np.where(df['forward_thirtyfive_month_return'] >= 0, 1, 0)
df['forward_thirtysix_month_return_up'] = np.where(df['forward_thirtysix_month_return'] >= 0, 1, 0)

# Features
df['past_one_month_return_up'] = np.where(df['past_one_month_return'] >= 0, 1, 0)
df['past_two_month_return_up'] = np.where(df['past_two_month_return'] >= 0, 1, 0)
df['past_three_month_return_up'] = np.where(df['past_three_month_return'] >= 0, 1, 0)
df['past_four_month_return_up'] = np.where(df['past_four_month_return'] >= 0, 1, 0)
df['past_five_month_return_up'] = np.where(df['past_five_month_return'] >= 0, 1, 0)
df['past_six_month_return_up'] = np.where(df['past_six_month_return'] >= 0, 1, 0)
df['past_seven_month_return_up'] = np.where(df['past_seven_month_return'] >= 0, 1, 0)
df['past_eight_month_return_up'] = np.where(df['past_eight_month_return'] >= 0, 1, 0)
df['past_nine_month_return_up'] = np.where(df['past_nine_month_return'] >= 0, 1, 0)
df['past_ten_month_return_up'] = np.where(df['past_ten_month_return'] >= 0, 1, 0)
df['past_eleven_month_return_up'] = np.where(df['past_eleven_month_return'] >= 0, 1, 0)
df['past_twelve_month_return_up'] = np.where(df['past_twelve_month_return'] >= 0, 1, 0)
df['past_thirteen_month_return_up'] = np.where(df['past_thirteen_month_return'] >= 0, 1, 0)
df['past_fourteen_month_return_up'] = np.where(df['past_fourteen_month_return'] >= 0, 1, 0)
df['past_fifteen_month_return_up'] = np.where(df['past_fifteen_month_return'] >= 0, 1, 0)
df['past_sixteen_month_return_up'] = np.where(df['past_sixteen_month_return'] >= 0, 1, 0)
df['past_seventeen_month_return_up'] = np.where(df['past_seventeen_month_return'] >= 0, 1, 0)
df['past_eighteen_month_return_up'] = np.where(df['past_eighteen_month_return'] >= 0, 1, 0)
df['past_nineteen_month_return_up'] = np.where(df['past_nineteen_month_return'] >= 0, 1, 0)
df['past_twenty_month_return_up'] = np.where(df['past_twenty_month_return'] >= 0, 1, 0)
df['past_twentyone_month_return_up'] = np.where(df['past_twentyone_month_return'] >= 0, 1, 0)
df['past_twentytwo_month_return_up'] = np.where(df['past_twentytwo_month_return'] >= 0, 1, 0)
df['past_twentythree_month_return_up'] = np.where(df['past_twentythree_month_return'] >= 0, 1, 0)
df['past_twentyfour_month_return_up'] = np.where(df['past_twentyfour_month_return'] >= 0, 1, 0)
df['past_twentyfive_month_return_up'] = np.where(df['past_twentyfive_month_return'] >= 0, 1, 0)
df['past_twentysix_month_return_up'] = np.where(df['past_twentysix_month_return'] >= 0, 1, 0)
df['past_twentyseven_month_return_up'] = np.where(df['past_twentyseven_month_return'] >= 0, 1, 0)
df['past_twentyeight_month_return_up'] = np.where(df['past_twentyeight_month_return'] >= 0, 1, 0)
df['past_twentynine_month_return_up'] = np.where(df['past_twentynine_month_return'] >= 0, 1, 0)
df['past_thirty_month_return_up'] = np.where(df['past_thirty_month_return'] >= 0, 1, 0)
df['past_thirtyone_month_return_up'] = np.where(df['past_thirtyone_month_return'] >= 0, 1, 0)
df['past_thirtytwo_month_return_up'] = np.where(df['past_thirtytwo_month_return'] >= 0, 1, 0)
df['past_thirtythree_month_return_up'] = np.where(df['past_thirtythree_month_return'] >= 0, 1, 0)
df['past_thirtyfour_month_return_up'] = np.where(df['past_thirtyfour_month_return'] >= 0, 1, 0)
df['past_thirtyfive_month_return_up'] = np.where(df['past_thirtyfive_month_return'] >= 0, 1, 0)
df['past_thirtysix_month_return_up'] = np.where(df['past_thirtysix_month_return'] >= 0, 1, 0)

# %%
# df - Enrich - Sector Dummy Variablees

sectors =  pd.get_dummies(df.sector, prefix="sector_").astype(int32)
df  = pd.concat([df, sectors], axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-76-6198b5bf79f9> in <module>()
#       1 # df - Enrich - Sector Dummy Variablees
#       2
# ----> 3 sectors =  pd.get_dummies(df.sector, prefix="sector_").astype(int32)
#       4 df  = pd.concat([df, sectors], axis=1)
#
# NameError: name 'int32' is not defined

# %%
# df - Clean - All - Fill N/A's
df = df.groupby(['GVKEY'], as_index=False).apply(lambda group: group.ffill())
df = df.groupby(['GVKEY'], as_index=False).apply(lambda group: group.bfill())
df = df.groupby(['sector'], as_index=False).apply(lambda group: group.ffill())
df = df.groupby(['sector'], as_index=False).apply(lambda group: group.bfill())
df = df.fillna(method='ffill')
df = df.fillna(method='bfill')

# %%
# df - Subset - Numeric Columns
numeric = df.select_dtypes(include=[np.float]).columns

# %%
# df - Subset - Int Columns
integer = df.select_dtypes(['integer']).columns

# %%
return_all_rows(df.dtypes)
# Out:
# GVKEY                                          float64
# GVKEY-year-month                                object
# sector                                          object
# year-month                                      object
# forward_one_month_return                       float64
# forward_two_month_return                       float64
# forward_three_month_return                     float64
# forward_four_month_return                      float64
# forward_five_month_return                      float64
# forward_six_month_return                       float64
# forward_seven_month_return                     float64
# forward_eight_month_return                     float64
# forward_nine_month_return                      float64
# forward_ten_month_return                       float64
# forward_eleven_month_return                    float64
# forward_twelve_month_return                    float64
# forward_thirteen_month_return                  float64
# forward_fourteen_month_return                  float64
# forward_fifteen_month_return                   float64
# forward_sixteen_month_return                   float64
# forward_seventeen_month_return                 float64
# forward_eighteen_month_return                  float64
# forward_nineteen_month_return                  float64
# forward_twenty_month_return                    float64
# forward_twentyone_month_return                 float64
# forward_twentytwo_month_return                 float64
# forward_twentythree_month_return               float64
# forward_twentyfour_month_return                float64
# forward_twentyfive_month_return                float64
# forward_twentysix_month_return                 float64
# forward_twentyseven_month_return               float64
# forward_twentyeight_month_return               float64
# forward_twentynine_month_return                float64
# forward_thirty_month_return                    float64
# forward_thirtyone_month_return                 float64
# forward_thirtytwo_month_return                 float64
# forward_thirtythree_month_return               float64
# forward_thirtyfour_month_return                float64
# forward_thirtyfive_month_return                float64
# forward_thirtysix_month_return                 float64
# past_one_month_return                          float64
# past_two_month_return                          float64
# past_three_month_return                        float64
# past_four_month_return                         float64
# past_five_month_return                         float64
# past_six_month_return                          float64
# past_seven_month_return                        float64
# past_eight_month_return                        float64
# past_nine_month_return                         float64
# past_ten_month_return                          float64
# past_eleven_month_return                       float64
# past_twelve_month_return                       float64
# past_thirteen_month_return                     float64
# past_fourteen_month_return                     float64
# past_fifteen_month_return                      float64
# past_sixteen_month_return                      float64
# past_seventeen_month_return                    float64
# past_eighteen_month_return                     float64
# past_nineteen_month_return                     float64
# past_twenty_month_return                       float64
# past_twentyone_month_return                    float64
# past_twentytwo_month_return                    float64
# past_twentythree_month_return                  float64
# past_twentyfour_month_return                   float64
# past_twentyfive_month_return                   float64
# past_twentysix_month_return                    float64
# past_twentyseven_month_return                  float64
# past_twentyeight_month_return                  float64
# past_twentynine_month_return                   float64
# past_thirty_month_return                       float64
# past_thirtyone_month_return                    float64
# past_thirtytwo_month_return                    float64
# past_thirtythree_month_return                  float64
# past_thirtyfour_month_return                   float64
# past_thirtyfive_month_return                   float64
# past_thirtysix_month_return                    float64
# accrual                                        float64
# adv_sale                                       float64
# aftret_eq                                      float64
# aftret_equity                                  float64
# aftret_invcapx                                 float64
# at_turn                                        float64
# bm                                             float64
# CAPEI                                          float64
# capital_ratio                                  float64
# cash_conversion                                float64
# cash_debt                                      float64
# cash_lt                                        float64
# cash_ratio                                     float64
# cfm                                            float64
# curr_debt                                      float64
# curr_ratio                                     float64
# de_ratio                                       float64
# debt_assets                                    float64
# debt_at                                        float64
# debt_capital                                   float64
# debt_ebitda                                    float64
# debt_invcap                                    float64
# DIVYIELD                                       float64
# dltt_be                                        float64
# dpr                                            float64
# efftax                                         float64
# equity_invcap                                  float64
# evm                                            float64
# fcf_ocf                                        float64
# gpm                                            float64
# GProf                                          float64
# int_debt                                       float64
# int_totdebt                                    float64
# intcov                                         float64
# intcov_ratio                                   float64
# inv_turn                                       float64
# invt_act                                       float64
# lt_debt                                        float64
# lt_ppent                                       float64
# npm                                            float64
# ocf_lct                                        float64
# opmad                                          float64
# opmbd                                          float64
# pay_turn                                       float64
# pcf                                            float64
# pe_exi                                         float64
# pe_inc                                         float64
# pe_op_basic                                    float64
# pe_op_dil                                      float64
# PEG_1yrforward                                 float64
# PEG_ltgforward                                 float64
# PEG_trailing                                   float64
# pretret_earnat                                 float64
# pretret_noa                                    float64
# profit_lct                                     float64
# ps                                             float64
# ptb                                            float64
# ptpm                                           float64
# quick_ratio                                    float64
# rd_sale                                        float64
# rect_act                                       float64
# rect_turn                                      float64
# roa                                            float64
# roce                                           float64
# roe                                            float64
# sale_equity                                    float64
# sale_invcap                                    float64
# sale_nwc                                       float64
# short_debt                                     float64
# staff_sale                                     float64
# totdebt_invcap                                 float64
# dvpspm                                         float64
# dvpsxm                                         float64
# dvrate                                         float64
# spcsrc                                         float64
# alpha                                          float64
# b_hml                                          float64
# b_mkt                                          float64
# b_smb                                          float64
# b_umd                                          float64
# exret                                          float64
# ivol                                           float64
# n                                              float64
# R2                                             float64
# tvol                                           float64
# BUYPCT                                         float64
# HOLDPCT                                        float64
# SELLPCT                                        float64
# MEANREC                                        float64
# MEDREC                                         float64
# recup                                          float64
# recdown                                        float64
# STDEV                                          float64
# january                                        float64
# february                                       float64
# march                                          float64
# april                                          float64
# may                                            float64
# june                                           float64
# july                                           float64
# august                                         float64
# september                                      float64
# october                                        float64
# november                                       float64
# december                                       float64
# past_one_month_return_zscore                   float64
# past_two_month_return_zscore                   float64
# past_three_month_return_zscore                 float64
# past_four_month_return_zscore                  float64
# past_five_month_return_zscore                  float64
# past_six_month_return_zscore                   float64
# past_seven_month_return_zscore                 float64
# past_eight_month_return_zscore                 float64
# past_nine_month_return_zscore                  float64
# past_ten_month_return_zscore                   float64
# past_eleven_month_return_zscore                float64
# past_twelve_month_return_zscore                float64
# past_thirteen_month_return_zscore              float64
# past_fourteen_month_return_zscore              float64
# past_fifteen_month_return_zscore               float64
# past_sixteen_month_return_zscore               float64
# past_seventeen_month_return_zscore             float64
# past_eighteen_month_return_zscore              float64
# past_nineteen_month_return_zscore              float64
# past_twenty_month_return_zscore                float64
# past_twentyone_month_return_zscore             float64
# past_twentytwo_month_return_zscore             float64
# past_twentythree_month_return_zscore           float64
# past_twentyfour_month_return_zscore            float64
# past_twentyfive_month_return_zscore            float64
# past_twentysix_month_return_zscore             float64
# past_twentyseven_month_return_zscore           float64
# past_twentyeight_month_return_zscore           float64
# past_twentynine_month_return_zscore            float64
# past_thirty_month_return_zscore                float64
# past_thirtyone_month_return_zscore             float64
# past_thirtytwo_month_return_zscore             float64
# past_thirtythree_month_return_zscore           float64
# past_thirtyfour_month_return_zscore            float64
# past_thirtyfive_month_return_zscore            float64
# past_thirtysix_month_return_zscore             float64
# accrual_zscore                                 float64
# adv_sale_zscore                                float64
# aftret_eq_zscore                               float64
# aftret_equity_zscore                           float64
# aftret_invcapx_zscore                          float64
# at_turn_zscore                                 float64
# bm_zscore                                      float64
# CAPEI_zscore                                   float64
# capital_ratio_zscore                           float64
# cash_conversion_zscore                         float64
# cash_debt_zscore                               float64
# cash_lt_zscore                                 float64
# cash_ratio_zscore                              float64
# cfm_zscore                                     float64
# curr_debt_zscore                               float64
# curr_ratio_zscore                              float64
# de_ratio_zscore                                float64
# debt_assets_zscore                             float64
# debt_at_zscore                                 float64
# debt_capital_zscore                            float64
# debt_ebitda_zscore                             float64
# debt_invcap_zscore                             float64
# DIVYIELD_zscore                                float64
# dltt_be_zscore                                 float64
# dpr_zscore                                     float64
# efftax_zscore                                  float64
# equity_invcap_zscore                           float64
# evm_zscore                                     float64
# fcf_ocf_zscore                                 float64
# gpm_zscore                                     float64
# GProf_zscore                                   float64
# int_debt_zscore                                float64
# int_totdebt_zscore                             float64
# intcov_zscore                                  float64
# intcov_ratio_zscore                            float64
# inv_turn_zscore                                float64
# invt_act_zscore                                float64
# lt_debt_zscore                                 float64
# lt_ppent_zscore                                float64
# npm_zscore                                     float64
# ocf_lct_zscore                                 float64
# opmad_zscore                                   float64
# opmbd_zscore                                   float64
# pay_turn_zscore                                float64
# pcf_zscore                                     float64
# pe_exi_zscore                                  float64
# pe_inc_zscore                                  float64
# pe_op_basic_zscore                             float64
# pe_op_dil_zscore                               float64
# PEG_1yrforward_zscore                          float64
# PEG_ltgforward_zscore                          float64
# PEG_trailing_zscore                            float64
# pretret_earnat_zscore                          float64
# pretret_noa_zscore                             float64
# profit_lct_zscore                              float64
# ps_zscore                                      float64
# ptb_zscore                                     float64
# ptpm_zscore                                    float64
# quick_ratio_zscore                             float64
# rd_sale_zscore                                 float64
# rect_act_zscore                                float64
# rect_turn_zscore                               float64
# roa_zscore                                     float64
# roce_zscore                                    float64
# roe_zscore                                     float64
# sale_equity_zscore                             float64
# sale_invcap_zscore                             float64
# sale_nwc_zscore                                float64
# short_debt_zscore                              float64
# staff_sale_zscore                              float64
# totdebt_invcap_zscore                          float64
# dvpspm_zscore                                  float64
# dvpsxm_zscore                                  float64
# dvrate_zscore                                  float64
# spcsrc_zscore                                  float64
# alpha_zscore                                   float64
# b_hml_zscore                                   float64
# b_mkt_zscore                                   float64
# b_smb_zscore                                   float64
# b_umd_zscore                                   float64
# exret_zscore                                   float64
# ivol_zscore                                    float64
# n_zscore                                       float64
# R2_zscore                                      float64
# tvol_zscore                                    float64
# BUYPCT_zscore                                  float64
# HOLDPCT_zscore                                 float64
# MEANREC_zscore                                 float64
# MEDREC_zscore                                  float64
# recup_zscore                                   float64
# recdown_zscore                                 float64
# SELLPCT_zscore                                 float64
# STDEV_zscore                                   float64
# past_one_month_return_sector_zscore            float64
# past_two_month_return_sector_zscore            float64
# past_three_month_return_sector_zscore          float64
# past_four_month_return_sector_zscore           float64
# past_five_month_return_sector_zscore           float64
# past_six_month_return_sector_zscore            float64
# past_seven_month_return_sector_zscore          float64
# past_eight_month_return_sector_zscore          float64
# past_nine_month_return_sector_zscore           float64
# past_ten_month_return_sector_zscore            float64
# past_eleven_month_return_sector_zscore         float64
# past_twelve_month_return_sector_zscore         float64
# past_thirteen_month_return_sector_zscore       float64
# past_fourteen_month_return_sector_zscore       float64
# past_fifteen_month_return_sector_zscore        float64
# past_sixteen_month_return_sector_zscore        float64
# past_seventeen_month_return_sector_zscore      float64
# past_eighteen_month_return_sector_zscore       float64
# past_nineteen_month_return_sector_zscore       float64
# past_twenty_month_return_sector_zscore         float64
# past_twentyone_month_return_sector_zscore      float64
# past_twentytwo_month_return_sector_zscore      float64
# past_twentythree_month_return_sector_zscore    float64
# past_twentyfour_month_return_sector_zscore     float64
# past_twentyfive_month_return_sector_zscore     float64
# past_twentysix_month_return_sector_zscore      float64
# past_twentyseven_month_return_sector_zscore    float64
# past_twentyeight_month_return_sector_zscore    float64
# past_twentynine_month_return_sector_zscore     float64
# past_thirty_month_return_sector_zscore         float64
# past_thirtyone_month_return_sector_zscore      float64
# past_thirtytwo_month_return_sector_zscore      float64
# past_thirtythree_month_return_sector_zscore    float64
# past_thirtyfour_month_return_sector_zscore     float64
# past_thirtyfive_month_return_sector_zscore     float64
# past_thirtysix_month_return_sector_zscore      float64
# accrual_sector_zscore                          float64
# adv_sale_sector_zscore                         float64
# aftret_eq_sector_zscore                        float64
# aftret_equity_sector_zscore                    float64
# aftret_invcapx_sector_zscore                   float64
# at_turn_sector_zscore                          float64
# bm_sector_zscore                               float64
# CAPEI_sector_zscore                            float64
# capital_ratio_sector_zscore                    float64
# cash_conversion_sector_zscore                  float64
# cash_debt_sector_zscore                        float64
# cash_lt_sector_zscore                          float64
# cash_ratio_sector_zscore                       float64
# cfm_sector_zscore                              float64
# curr_debt_sector_zscore                        float64
# curr_ratio_sector_zscore                       float64
# de_ratio_sector_zscore                         float64
# debt_assets_sector_zscore                      float64
# debt_at_sector_zscore                          float64
# debt_capital_sector_zscore                     float64
# debt_ebitda_sector_zscore                      float64
# debt_invcap_sector_zscore                      float64
# DIVYIELD_sector_zscore                         float64
# dltt_be_sector_zscore                          float64
# dpr_sector_zscore                              float64
# efftax_sector_zscore                           float64
# equity_invcap_sector_zscore                    float64
# evm_sector_zscore                              float64
# fcf_ocf_sector_zscore                          float64
# gpm_sector_zscore                              float64
# GProf_sector_zscore                            float64
# int_debt_sector_zscore                         float64
# int_totdebt_sector_zscore                      float64
# intcov_sector_zscore                           float64
# intcov_ratio_sector_zscore                     float64
# inv_turn_sector_zscore                         float64
# invt_act_sector_zscore                         float64
# lt_debt_sector_zscore                          float64
# lt_ppent_sector_zscore                         float64
# npm_sector_zscore                              float64
# ocf_lct_sector_zscore                          float64
# opmad_sector_zscore                            float64
# opmbd_sector_zscore                            float64
# pay_turn_sector_zscore                         float64
# pcf_sector_zscore                              float64
# pe_exi_sector_zscore                           float64
# pe_inc_sector_zscore                           float64
# pe_op_basic_sector_zscore                      float64
# pe_op_dil_sector_zscore                        float64
# PEG_1yrforward_sector_zscore                   float64
# PEG_ltgforward_sector_zscore                   float64
# PEG_trailing_sector_zscore                     float64
# pretret_earnat_sector_zscore                   float64
# pretret_noa_sector_zscore                      float64
# profit_lct_sector_zscore                       float64
# ps_sector_zscore                               float64
# ptb_sector_zscore                              float64
# ptpm_sector_zscore                             float64
# quick_ratio_sector_zscore                      float64
# rd_sale_sector_zscore                          float64
# rect_act_sector_zscore                         float64
# rect_turn_sector_zscore                        float64
# roa_sector_zscore                              float64
# roce_sector_zscore                             float64
# roe_sector_zscore                              float64
# sale_equity_sector_zscore                      float64
# sale_invcap_sector_zscore                      float64
# sale_nwc_sector_zscore                         float64
# short_debt_sector_zscore                       float64
# staff_sale_sector_zscore                       float64
# totdebt_invcap_sector_zscore                   float64
# dvpspm_sector_zscore                           float64
# dvpsxm_sector_zscore                           float64
# dvrate_sector_zscore                           float64
# spcsrc_sector_zscore                           float64
# alpha_sector_zscore                            float64
# b_hml_sector_zscore                            float64
# b_mkt_sector_zscore                            float64
# b_smb_sector_zscore                            float64
# b_umd_sector_zscore                            float64
# exret_sector_zscore                            float64
# ivol_sector_zscore                             float64
# n_sector_zscore                                float64
# R2_sector_zscore                               float64
# tvol_sector_zscore                             float64
# BUYPCT_sector_zscore                           float64
# HOLDPCT_sector_zscore                          float64
# MEANREC_sector_zscore                          float64
# MEDREC_sector_zscore                           float64
# recup_sector_zscore                            float64
# recdown_sector_zscore                          float64
# SELLPCT_sector_zscore                          float64
# STDEV_sector_zscore                            float64
# forward_one_month_return_up                      int32
# forward_two_month_return_up                      int32
# forward_three_month_return_up                    int32
# forward_four_month_return_up                     int32
# forward_five_month_return_up                     int32
# forward_six_month_return_up                      int32
# forward_seven_month_return_up                    int32
# forward_eight_month_return_up                    int32
# forward_nine_month_return_up                     int32
# forward_ten_month_return_up                      int32
# forward_eleven_month_return_up                   int32
# forward_twelve_month_return_up                   int32
# forward_thirteen_month_return_up                 int32
# forward_fourteen_month_return_up                 int32
# forward_fifteen_month_return_up                  int32
# forward_sixteen_month_return_up                  int32
# forward_seventeen_month_return_up                int32
# forward_eighteen_month_return_up                 int32
# forward_nineteen_month_return_up                 int32
# forward_twenty_month_return_up                   int32
# forward_twentyone_month_return_up                int32
# forward_twentytwo_month_return_up                int32
# forward_twentythree_month_return_up              int32
# forward_twentyfour_month_return_up               int32
# forward_twentyfive_month_return_up               int32
# forward_twentysix_month_return_up                int32
# forward_twentyseven_month_return_up              int32
# forward_twentyeight_month_return_up              int32
# forward_twentynine_month_return_up               int32
# forward_thirty_month_return_up                   int32
# forward_thirtyone_month_return_up                int32
# forward_thirtytwo_month_return_up                int32
# forward_thirtythree_month_return_up              int32
# forward_thirtyfour_month_return_up               int32
# forward_thirtyfive_month_return_up               int32
# forward_thirtysix_month_return_up                int32
# past_one_month_return_up                         int32
# past_two_month_return_up                         int32
# past_three_month_return_up                       int32
# past_four_month_return_up                        int32
# past_five_month_return_up                        int32
# past_six_month_return_up                         int32
# past_seven_month_return_up                       int32
# past_eight_month_return_up                       int32
# past_nine_month_return_up                        int32
# past_ten_month_return_up                         int32
# past_eleven_month_return_up                      int32
# past_twelve_month_return_up                      int32
# past_thirteen_month_return_up                    int32
# past_fourteen_month_return_up                    int32
# past_fifteen_month_return_up                     int32
# past_sixteen_month_return_up                     int32
# past_seventeen_month_return_up                   int32
# past_eighteen_month_return_up                    int32
# past_nineteen_month_return_up                    int32
# past_twenty_month_return_up                      int32
# past_twentyone_month_return_up                   int32
# past_twentytwo_month_return_up                   int32
# past_twentythree_month_return_up                 int32
# past_twentyfour_month_return_up                  int32
# past_twentyfive_month_return_up                  int32
# past_twentysix_month_return_up                   int32
# past_twentyseven_month_return_up                 int32
# past_twentyeight_month_return_up                 int32
# past_twentynine_month_return_up                  int32
# past_thirty_month_return_up                      int32
# past_thirtyone_month_return_up                   int32
# past_thirtytwo_month_return_up                   int32
# past_thirtythree_month_return_up                 int32
# past_thirtyfour_month_return_up                  int32
# past_thirtyfive_month_return_up                  int32
# past_thirtysix_month_return_up                   int32
# sector__Consumer Discretionary                   uint8
# sector__Consumer Staples                         uint8
# sector__Energy                                   uint8
# sector__Financials                               uint8
# sector__Health Care                              uint8
# sector__Industrials                              uint8
# sector__Information Technology                   uint8
# sector__Materials                                uint8
# sector__Real Estate                              uint8
# sector__Telecommunication Services               uint8
# sector__Utilities                                uint8
# dtype: object

# %%
feature = []
correlation = []
correlation_direction = []
significance = []

for column in df[numeric]:
    try:
        pair = pearsonr(df['forward_twelve_month_return_up'], df[column])
        feature.append(column)
        correlation.append(abs(pair[0]))
        correlation_direction.append(pair[0])
        significance.append(pair[1])
    except:
        feature.append(column)
        correlation.append(np.np.nan)
        correlation_direction.append(np.np.nan)
        significance.append(np.np.nan)
        
for column in df[integer]:
    try:
        pair = pearsonr(df['forward_twelve_month_return_up'], df[column])
        feature.append(column)
        correlation.append(abs(pair[0]))
        correlation_direction.append(pair[0])
        significance.append(pair[1])
    except:
        feature.append(column)
        correlation.append(np.np.nan)
        correlation_direction.append(np.np.nan)
        significance.append(np.np.nan)
    
review = pd.DataFrame()
review['feature'] = feature
review['correlation'] = correlation
review['correlation_direction'] = correlation_direction
review['significance'] = significance

# review - Sort - Correlation
review = review.sort_values(by=['correlation'], ascending=0)

# %%
review.to_csv('correlation.csv')

# %%
df.to_csv('df.csv')

# %%
review
# Out:
#                                          feature  correlation  \
# 447               forward_twelve_month_return_up     1.000000
# 448             forward_thirteen_month_return_up     0.847069
# 446               forward_eleven_month_return_up     0.837559
# 449             forward_fourteen_month_return_up     0.793295
# 445                  forward_ten_month_return_up     0.771552
# 450              forward_fifteen_month_return_up     0.745942
# 451              forward_sixteen_month_return_up     0.715170
# 444                 forward_nine_month_return_up     0.708995
# 452            forward_seventeen_month_return_up     0.683009
# 453             forward_eighteen_month_return_up     0.662097
# 443                forward_eight_month_return_up     0.656448
# 454             forward_nineteen_month_return_up     0.637594
# 455               forward_twenty_month_return_up     0.619063
# 442                forward_seven_month_return_up     0.600902
# 456            forward_twentyone_month_return_up     0.597622
# 457            forward_twentytwo_month_return_up     0.581850
# 458          forward_twentythree_month_return_up     0.564056
# 441                  forward_six_month_return_up     0.551509
# 459           forward_twentyfour_month_return_up     0.551408
# 460           forward_twentyfive_month_return_up     0.533716
# 461            forward_twentysix_month_return_up     0.522743
# 462          forward_twentyseven_month_return_up     0.508154
# 463          forward_twentyeight_month_return_up     0.497595
# 440                 forward_five_month_return_up     0.496054
# 464           forward_twentynine_month_return_up     0.485163
# 465               forward_thirty_month_return_up     0.474992
# 466            forward_thirtyone_month_return_up     0.463192
# 467            forward_thirtytwo_month_return_up     0.454421
# 468          forward_thirtythree_month_return_up     0.445331
# 439                 forward_four_month_return_up     0.441640
# 469           forward_thirtyfour_month_return_up     0.437472
# 470           forward_thirtyfive_month_return_up     0.427740
# 471            forward_thirtysix_month_return_up     0.421334
# 438                forward_three_month_return_up     0.373991
# 437                  forward_two_month_return_up     0.302647
# 436                  forward_one_month_return_up     0.210406
# 147                                       spcsrc     0.182455
# 288                                spcsrc_zscore     0.182455
# 487                 past_sixteen_month_return_up     0.149004
# 157                                         tvol     0.148870
# 486                 past_fifteen_month_return_up     0.148383
# 488               past_seventeen_month_return_up     0.148031
# 490                past_nineteen_month_return_up     0.148021
# 154                                         ivol     0.147452
# 489                past_eighteen_month_return_up     0.147345
# 495              past_twentyfour_month_return_up     0.147120
# 485                past_fourteen_month_return_up     0.147114
# 492               past_twentyone_month_return_up     0.146891
# 494             past_twentythree_month_return_up     0.146797
# 491                  past_twenty_month_return_up     0.146597
# 496              past_twentyfive_month_return_up     0.146341
# 493               past_twentytwo_month_return_up     0.146305
# 298                                  tvol_zscore     0.145814
# 507               past_thirtysix_month_return_up     0.145729
# 497               past_twentysix_month_return_up     0.145421
# 499             past_twentyeight_month_return_up     0.145203
# 505              past_thirtyfour_month_return_up     0.145022
# 483                  past_twelve_month_return_up     0.144902
# 506              past_thirtyfive_month_return_up     0.144891
# 498             past_twentyseven_month_return_up     0.144612
# 504             past_thirtythree_month_return_up     0.144498
# 503               past_thirtytwo_month_return_up     0.143875
# 484                past_thirteen_month_return_up     0.143845
# 502               past_thirtyone_month_return_up     0.143738
# 501                  past_thirty_month_return_up     0.143145
# 500              past_twentynine_month_return_up     0.142849
# 295                                  ivol_zscore     0.142837
# 482                  past_eleven_month_return_up     0.142785
# 481                     past_ten_month_return_up     0.139924
# 480                    past_nine_month_return_up     0.137568
# 479                   past_eight_month_return_up     0.133648
# 478                   past_seven_month_return_up     0.128107
# 287                                dvrate_zscore     0.127007
# 146                                       dvrate     0.121878
# 477                     past_six_month_return_up     0.121195
# 476                    past_five_month_return_up     0.111981
# 95                                      DIVYIELD     0.111531
# 236                              DIVYIELD_zscore     0.107266
# 511                           sector__Financials     0.103488
# 475                    past_four_month_return_up     0.102013
# 151                                        b_smb     0.101347
# 292                                 b_smb_zscore     0.100249
# 417                         spcsrc_sector_zscore     0.091537
# 474                   past_three_month_return_up     0.088334
# 155                                            n     0.082614
# 427                           tvol_sector_zscore     0.074179
# 129                                          ptb     0.073782
# 473                     past_two_month_return_up     0.073750
# 269                                    ps_zscore     0.073119
# 424                           ivol_sector_zscore     0.071649
# 128                                           ps     0.070924
# 113                                      ocf_lct     0.070147
# 254                               ocf_lct_zscore     0.067632
# 0                                          GVKEY     0.064884
# 149                                        b_hml     0.064105
# 87                                     curr_debt     0.062928
# 290                                 b_hml_zscore     0.062527
# 270                                   ptb_zscore     0.060025
# 398                             ps_sector_zscore     0.059610
# 514               sector__Information Technology     0.059237
# 228                             curr_debt_zscore     0.058721
# 150                                        b_mkt     0.057594
# 383                        ocf_lct_sector_zscore     0.055487
# 518                            sector__Utilities     0.054939
# 472                     past_one_month_return_up     0.054515
# 291                                 b_mkt_zscore     0.052424
# 268                            profit_lct_zscore     0.050751
# 397                     profit_lct_sector_zscore     0.050375
# 421                          b_smb_sector_zscore     0.050355
# 127                                   profit_lct     0.048924
# 435                          STDEV_sector_zscore     0.048350
# 426                             R2_sector_zscore     0.044469
# 120                                  pe_op_basic     0.043810
# 261                           pe_op_basic_zscore     0.043275
# 296                                     n_zscore     0.043074
# 32                forward_thirtytwo_month_return     0.042020
# 35               forward_thirtyfive_month_return     0.041301
# 29               forward_twentynine_month_return     0.041000
# 83                                     cash_debt     0.040973
# 259                                pe_exi_zscore     0.040738
# 122                               PEG_1yrforward     0.040084
# 260                                pe_inc_zscore     0.040017
# 118                                       pe_exi     0.039863
# 416                         dvrate_sector_zscore     0.039798
# 33              forward_thirtythree_month_return     0.039595
# 263                        PEG_1yrforward_zscore     0.039421
# 119                                       pe_inc     0.038934
# 286                                dvpsxm_zscore     0.038709
# 152                                        b_umd     0.038651
# 508               sector__Consumer Discretionary     0.038343
# 224                             cash_debt_zscore     0.038105
# 34               forward_thirtyfour_month_return     0.037939
# 285                                dvpspm_zscore     0.037758
# 27              forward_twentyseven_month_return     0.037317
# 30                   forward_thirty_month_return     0.037113
# 158                                       BUYPCT     0.037044
# 399                            ptb_sector_zscore     0.036651
# 28              forward_twentyeight_month_return     0.036544
# 293                                 b_umd_zscore     0.036335
# 31                forward_thirtyone_month_return     0.036278
# 365                       DIVYIELD_sector_zscore     0.036216
# 265                          PEG_trailing_zscore     0.036043
# 162                                       MEDREC     0.035831
# 411                     short_debt_sector_zscore     0.035554
# 390                    pe_op_basic_sector_zscore     0.035231
# 161                                      MEANREC     0.034861
# 264                        PEG_ltgforward_zscore     0.034737
# 123                               PEG_ltgforward     0.033863
# 24               forward_twentyfour_month_return     0.033320
# 388                         pe_exi_sector_zscore     0.032301
# 25               forward_twentyfive_month_return     0.032238
# 392                 PEG_1yrforward_sector_zscore     0.032225
# 26                forward_twentysix_month_return     0.032213
# 159                                      HOLDPCT     0.031730
# 36                forward_thirtysix_month_return     0.031699
# 389                         pe_inc_sector_zscore     0.031589
# 512                          sector__Health Care     0.030959
# 124                                 PEG_trailing     0.030581
# 414                         dvpspm_sector_zscore     0.030469
# 415                         dvpsxm_sector_zscore     0.029202
# 145                                       dvpsxm     0.027997
# 258                                   pcf_zscore     0.027644
# 156                                           R2     0.027538
# 373                          GProf_sector_zscore     0.026915
# 23              forward_twentythree_month_return     0.026769
# 144                                       dvpspm     0.026681
# 419                          b_hml_sector_zscore     0.026158
# 361                        debt_at_sector_zscore     0.026003
# 357                      curr_debt_sector_zscore     0.025318
# 225                               cash_lt_zscore     0.025228
# 387                            pcf_sector_zscore     0.024910
# 297                                    R2_zscore     0.024697
# 262                             pe_op_dil_zscore     0.024493
# 117                                          pcf     0.023930
# 274                              rect_act_zscore     0.023923
# 133                                     rect_act     0.023918
# 121                                    pe_op_dil     0.023739
# 18                 forward_eighteen_month_return     0.023571
# 393                 PEG_ltgforward_sector_zscore     0.022903
# 141                                   short_debt     0.022827
# 21                forward_twentyone_month_return     0.022735
# 22                forward_twentytwo_month_return     0.022603
# 394                   PEG_trailing_sector_zscore     0.021513
# 90                                   debt_assets     0.020959
# 84                                       cash_lt     0.020613
# 17                forward_seventeen_month_return     0.020179
# 231                           debt_assets_zscore     0.020087
# 78                                       at_turn     0.019572
# 418                          alpha_sector_zscore     0.019348
# 20                   forward_twenty_month_return     0.018322
# 16                  forward_sixteen_month_return     0.017904
# 219                               at_turn_zscore     0.017650
# 422                          b_umd_sector_zscore     0.017513
# 403                       rect_act_sector_zscore     0.017087
# 15                  forward_fifteen_month_return     0.016265
# 301                               MEANREC_zscore     0.015668
# 431                         MEDREC_sector_zscore     0.015664
# 282                            short_debt_zscore     0.015563
# 244                                 GProf_zscore     0.015515
# 103                                        GProf     0.015485
# 214                               accrual_zscore     0.015240
# 8                     forward_eight_month_return     0.015215
# 14                 forward_fourteen_month_return     0.015061
# 9                      forward_nine_month_return     0.015008
# 299                                BUYPCT_zscore     0.014974
# 160                                      SELLPCT     0.014844
# 19                 forward_nineteen_month_return     0.014813
# 428                         BUYPCT_sector_zscore     0.014373
# 294                                 exret_zscore     0.014299
# 391                      pe_op_dil_sector_zscore     0.013981
# 10                      forward_ten_month_return     0.013699
# 13                 forward_thirteen_month_return     0.013596
# 12                   forward_twelve_month_return     0.013445
# 82                               cash_conversion     0.013389
# 223                       cash_conversion_zscore     0.013201
# 85                                    cash_ratio     0.013191
# 509                     sector__Consumer Staples     0.013087
# 300                               HOLDPCT_zscore     0.013027
# 352                cash_conversion_sector_zscore     0.012816
# 91                                       debt_at     0.012788
# 11                   forward_eleven_month_return     0.012697
# 372                            gpm_sector_zscore     0.012436
# 355                     cash_ratio_sector_zscore     0.012351
# 273                               rd_sale_zscore     0.012326
# 73                                       accrual     0.012314
# 7                     forward_seven_month_return     0.012205
# 148                                        alpha     0.011959
# 153                                        exret     0.011518
# 344                       adv_sale_sector_zscore     0.011474
# 306                                 STDEV_zscore     0.011399
# 102                                          gpm     0.011259
# 226                            cash_ratio_zscore     0.011240
# 243                                   gpm_zscore     0.011197
# 516                          sector__Real Estate     0.010879
# 348                        at_turn_sector_zscore     0.010819
# 6                       forward_six_month_return     0.010656
# 423                          exret_sector_zscore     0.010005
# 380                        lt_debt_sector_zscore     0.009920
# 412                     staff_sale_sector_zscore     0.009691
# 354                        cash_lt_sector_zscore     0.009627
# 232                               debt_at_zscore     0.009510
# 517           sector__Telecommunication Services     0.009483
# 135                                          roa     0.009287
# 215                              adv_sale_zscore     0.008991
# 430                        MEANREC_sector_zscore     0.008928
# 266                        pretret_earnat_zscore     0.008822
# 125                               pretret_earnat     0.008663
# 5                      forward_five_month_return     0.008613
# 276                                   roa_zscore     0.008558
# 429                        HOLDPCT_sector_zscore     0.008410
# 343                        accrual_sector_zscore     0.008358
# 425                              n_sector_zscore     0.008317
# 245                              int_debt_zscore     0.008137
# 289                                 alpha_zscore     0.007711
# 104                                     int_debt     0.007701
# 4                      forward_four_month_return     0.007524
# 420                          b_mkt_sector_zscore     0.007042
# 405                            roa_sector_zscore     0.007038
# 70                  past_thirtyfour_month_return     0.006995
# 338    past_thirtytwo_month_return_sector_zscore     0.006758
# 211          past_thirtyfour_month_return_zscore     0.006557
# 110                                      lt_debt     0.006509
# 209           past_thirtytwo_month_return_zscore     0.006253
# 72                   past_thirtysix_month_return     0.006235
# 250                              invt_act_zscore     0.006122
# 432                          recup_sector_zscore     0.006023
# 165                                        STDEV     0.005932
# 402                        rd_sale_sector_zscore     0.005825
# 68                   past_thirtytwo_month_return     0.005752
# 163                                        recup     0.005709
# 340   past_thirtyfour_month_return_sector_zscore     0.005641
# 109                                     invt_act     0.005582
# 132                                      rd_sale     0.005570
# 3                     forward_three_month_return     0.005448
# 66                      past_thirty_month_return     0.005281
# 207              past_thirty_month_return_zscore     0.005158
# 74                                      adv_sale     0.005100
# 213           past_thirtysix_month_return_zscore     0.005052
# 305                               SELLPCT_zscore     0.004989
# 375                    int_totdebt_sector_zscore     0.004979
# 515                            sector__Materials     0.004926
# 2                       forward_two_month_return     0.004569
# 105                                  int_totdebt     0.004509
# 246                           int_totdebt_zscore     0.004504
# 353                      cash_debt_sector_zscore     0.004463
# 336       past_thirty_month_return_sector_zscore     0.004415
# 360                    debt_assets_sector_zscore     0.004223
# 374                       int_debt_sector_zscore     0.004114
# 275                             rect_turn_zscore     0.003865
# 134                                    rect_turn     0.003768
# 304                               recdown_zscore     0.003745
# 206          past_twentynine_month_return_zscore     0.003663
# 175                                      october     0.003580
# 303                                 recup_zscore     0.003539
# 71                  past_thirtyfive_month_return     0.003471
# 65                  past_twentynine_month_return     0.003470
# 342    past_thirtysix_month_return_sector_zscore     0.003419
# 395                 pretret_earnat_sector_zscore     0.003392
# 69                 past_thirtythree_month_return     0.003335
# 88                                    curr_ratio     0.003246
# 210         past_thirtythree_month_return_zscore     0.003220
# 166                                      january     0.003219
# 280                           sale_invcap_zscore     0.003197
# 335   past_twentynine_month_return_sector_zscore     0.003176
# 212          past_thirtyfive_month_return_zscore     0.003175
# 378                       inv_turn_sector_zscore     0.003141
# 327    past_twentyone_month_return_sector_zscore     0.003102
# 139                                  sale_invcap     0.003094
# 349                             bm_sector_zscore     0.003026
# 67                   past_thirtyone_month_return     0.003016
# 379                       invt_act_sector_zscore     0.002970
# 409                    sale_invcap_sector_zscore     0.002953
# 358                     curr_ratio_sector_zscore     0.002912
# 510                               sector__Energy     0.002899
# 131                                  quick_ratio     0.002886
# 347                 aftret_invcapx_sector_zscore     0.002840
# 208           past_thirtyone_month_return_zscore     0.002814
# 396                    pretret_noa_sector_zscore     0.002757
# 267                           pretret_noa_zscore     0.002727
# 77                                aftret_invcapx     0.002710
# 218                        aftret_invcapx_zscore     0.002671
# 279                           sale_equity_zscore     0.002598
# 332    past_twentysix_month_return_sector_zscore     0.002564
# 126                                  pretret_noa     0.002555
# 339  past_thirtythree_month_return_sector_zscore     0.002521
# 143                               totdebt_invcap     0.002489
# 99                                 equity_invcap     0.002483
# 284                        totdebt_invcap_zscore     0.002471
# 177                                     december     0.002453
# 142                                   staff_sale     0.002418
# 94                                   debt_invcap     0.002405
# 330   past_twentyfour_month_return_sector_zscore     0.002382
# 240                         equity_invcap_zscore     0.002378
# 408                    sale_equity_sector_zscore     0.002364
# 326       past_twenty_month_return_sector_zscore     0.002349
# 138                                  sale_equity     0.002343
# 203           past_twentysix_month_return_zscore     0.002342
# 341   past_thirtyfive_month_return_sector_zscore     0.002333
# 513                          sector__Industrials     0.002328
# 198           past_twentyone_month_return_zscore     0.002325
# 216                             aftret_eq_zscore     0.002308
# 350                          CAPEI_sector_zscore     0.002302
# 167                                     february     0.002286
# 1                       forward_one_month_return     0.002278
# 345                      aftret_eq_sector_zscore     0.002263
# 172                                         july     0.002243
# 197              past_twenty_month_return_zscore     0.002236
# 80                                         CAPEI     0.002223
# 235                           debt_invcap_zscore     0.002190
# 62                   past_twentysix_month_return     0.002187
# 221                                 CAPEI_zscore     0.002184
# 75                                     aftret_eq     0.002151
# 337    past_thirtyone_month_return_sector_zscore     0.002133
# 56                      past_twenty_month_return     0.002129
# 57                   past_twentyone_month_return     0.002088
# 204         past_twentyseven_month_return_zscore     0.002078
# 173                                       august     0.002004
# 229                            curr_ratio_zscore     0.001974
# 220                                    bm_zscore     0.001930
# 333  past_twentyseven_month_return_sector_zscore     0.001917
# 64                 past_twentyeight_month_return     0.001887
# 413                 totdebt_invcap_sector_zscore     0.001879
# 189              past_twelve_month_return_zscore     0.001869
# 63                 past_twentyseven_month_return     0.001857
# 171                                         june     0.001837
# 108                                     inv_turn     0.001817
# 310         past_four_month_return_sector_zscore     0.001813
# 302                                MEDREC_zscore     0.001806
# 367                            dpr_sector_zscore     0.001802
# 48                      past_twelve_month_return     0.001793
# 230                              de_ratio_zscore     0.001770
# 89                                      de_ratio     0.001767
# 328    past_twentytwo_month_return_sector_zscore     0.001743
# 329  past_twentythree_month_return_sector_zscore     0.001725
# 205         past_twentyeight_month_return_zscore     0.001724
# 318       past_twelve_month_return_sector_zscore     0.001724
# 249                              inv_turn_zscore     0.001708
# 181                past_four_month_return_zscore     0.001697
# 381                       lt_ppent_sector_zscore     0.001680
# 331   past_twentyfive_month_return_sector_zscore     0.001645
# 40                        past_four_month_return     0.001643
# 107                                 intcov_ratio     0.001629
# 106                                       intcov     0.001629
# 376                         intcov_sector_zscore     0.001629
# 248                          intcov_ratio_zscore     0.001629
# 247                                intcov_zscore     0.001629
# 377                   intcov_ratio_sector_zscore     0.001629
# 369                  equity_invcap_sector_zscore     0.001624
# 201          past_twentyfour_month_return_zscore     0.001535
# 251                               lt_debt_zscore     0.001503
# 272                           quick_ratio_zscore     0.001478
# 98                                        efftax     0.001473
# 359                       de_ratio_sector_zscore     0.001471
# 202          past_twentyfive_month_return_zscore     0.001471
# 192             past_fifteen_month_return_zscore     0.001437
# 52                     past_sixteen_month_return     0.001434
# 351                  capital_ratio_sector_zscore     0.001421
# 193             past_sixteen_month_return_zscore     0.001397
# 60                  past_twentyfour_month_return     0.001390
# 222                         capital_ratio_zscore     0.001380
# 86                                           cfm     0.001350
# 115                                        opmbd     0.001350
# 112                                          npm     0.001350
# 130                                         ptpm     0.001350
# 114                                        opmad     0.001350
# 382                            npm_sector_zscore     0.001350
# 385                          opmbd_sector_zscore     0.001350
# 256                                 opmbd_zscore     0.001350
# 271                                  ptpm_zscore     0.001350
# 255                                 opmad_zscore     0.001350
# 384                          opmad_sector_zscore     0.001350
# 227                                   cfm_zscore     0.001350
# 400                           ptpm_sector_zscore     0.001350
# 253                                   npm_zscore     0.001350
# 356                            cfm_sector_zscore     0.001350
# 61                  past_twentyfive_month_return     0.001327
# 50                    past_fourteen_month_return     0.001308
# 277                                  roce_zscore     0.001304
# 136                                         roce     0.001293
# 81                                 capital_ratio     0.001291
# 191            past_fourteen_month_return_zscore     0.001290
# 346                  aftret_equity_sector_zscore     0.001284
# 366                        dltt_be_sector_zscore     0.001277
# 200         past_twentythree_month_return_zscore     0.001271
# 137                                          roe     0.001267
# 79                                            bm     0.001263
# 278                                   roe_zscore     0.001262
# 401                    quick_ratio_sector_zscore     0.001253
# 140                                     sale_nwc     0.001242
# 51                     past_fifteen_month_return     0.001238
# 239                                efftax_zscore     0.001220
# 334  past_twentyeight_month_return_sector_zscore     0.001213
# 281                              sale_nwc_zscore     0.001207
# 410                       sale_nwc_sector_zscore     0.001201
# 97                                           dpr     0.001193
# 371                        fcf_ocf_sector_zscore     0.001167
# 185               past_eight_month_return_zscore     0.001163
# 100                                          evm     0.001162
# 368                         efftax_sector_zscore     0.001160
# 54                    past_eighteen_month_return     0.001155
# 386                       pay_turn_sector_zscore     0.001149
# 241                                   evm_zscore     0.001140
# 96                                       dltt_be     0.001119
# 188              past_eleven_month_return_zscore     0.001105
# 237                               dltt_be_zscore     0.001101
# 169                                        april     0.001095
# 59                 past_twentythree_month_return     0.001085
# 187                 past_ten_month_return_zscore     0.001078
# 195            past_eighteen_month_return_zscore     0.000990
# 184               past_seven_month_return_zscore     0.000980
# 199           past_twentytwo_month_return_zscore     0.000977
# 44                       past_eight_month_return     0.000977
# 46                         past_ten_month_return     0.000970
# 370                            evm_sector_zscore     0.000955
# 194           past_seventeen_month_return_zscore     0.000954
# 217                         aftret_equity_zscore     0.000900
# 364                    debt_invcap_sector_zscore     0.000885
# 238                                   dpr_zscore     0.000864
# 47                      past_eleven_month_return     0.000862
# 183                 past_six_month_return_zscore     0.000857
# 283                            staff_sale_zscore     0.000854
# 242                               fcf_ocf_zscore     0.000853
# 58                   past_twentytwo_month_return     0.000845
# 101                                      fcf_ocf     0.000838
# 311         past_five_month_return_sector_zscore     0.000835
# 190            past_thirteen_month_return_zscore     0.000832
# 53                   past_seventeen_month_return     0.000827
# 76                                 aftret_equity     0.000784
# 307          past_one_month_return_sector_zscore     0.000773
# 42                         past_six_month_return     0.000759
# 116                                     pay_turn     0.000740
# 180               past_three_month_return_zscore     0.000732
# 433                        recdown_sector_zscore     0.000730
# 257                              pay_turn_zscore     0.000727
# 186                past_nine_month_return_zscore     0.000719
# 174                                    september     0.000706
# 434                        SELLPCT_sector_zscore     0.000704
# 49                    past_thirteen_month_return     0.000686
# 233                          debt_capital_zscore     0.000682
# 168                                        march     0.000657
# 325     past_nineteen_month_return_sector_zscore     0.000657
# 92                                  debt_capital     0.000628
# 170                                          may     0.000625
# 43                       past_seven_month_return     0.000609
# 322      past_sixteen_month_return_sector_zscore     0.000598
# 406                           roce_sector_zscore     0.000589
# 179                 past_two_month_return_zscore     0.000563
# 38                         past_two_month_return     0.000553
# 321      past_fifteen_month_return_sector_zscore     0.000541
# 362                   debt_capital_sector_zscore     0.000528
# 320     past_fourteen_month_return_sector_zscore     0.000493
# 363                    debt_ebitda_sector_zscore     0.000447
# 93                                   debt_ebitda     0.000444
# 39                       past_three_month_return     0.000430
# 314        past_eight_month_return_sector_zscore     0.000421
# 234                           debt_ebitda_zscore     0.000391
# 319     past_thirteen_month_return_sector_zscore     0.000382
# 45                        past_nine_month_return     0.000376
# 196            past_nineteen_month_return_zscore     0.000316
# 37                         past_one_month_return     0.000304
# 55                    past_nineteen_month_return     0.000232
# 317       past_eleven_month_return_sector_zscore     0.000221
# 316          past_ten_month_return_sector_zscore     0.000211
# 182                past_five_month_return_zscore     0.000207
# 176                                     november     0.000204
# 315         past_nine_month_return_sector_zscore     0.000199
# 313        past_seven_month_return_sector_zscore     0.000198
# 309        past_three_month_return_sector_zscore     0.000125
# 404                      rect_turn_sector_zscore     0.000120
# 178                 past_one_month_return_zscore     0.000112
# 111                                     lt_ppent     0.000101
# 324     past_eighteen_month_return_sector_zscore     0.000095
# 41                        past_five_month_return     0.000090
# 312          past_six_month_return_sector_zscore     0.000082
# 252                              lt_ppent_zscore     0.000079
# 323    past_seventeen_month_return_sector_zscore     0.000063
# 164                                      recdown     0.000040
# 407                            roe_sector_zscore     0.000024
# 308          past_two_month_return_sector_zscore     0.000023
#
#      correlation_direction   significance
# 447               1.000000   0.000000e+00
# 448               0.847069   0.000000e+00
# 446               0.837559   0.000000e+00
# 449               0.793295   0.000000e+00
# 445               0.771552   0.000000e+00
# 450               0.745942   0.000000e+00
# 451               0.715170   0.000000e+00
# 444               0.708995   0.000000e+00
# 452               0.683009   0.000000e+00
# 453               0.662097   0.000000e+00
# 443               0.656448   0.000000e+00
# 454               0.637594   0.000000e+00
# 455               0.619063   0.000000e+00
# 442               0.600902   0.000000e+00
# 456               0.597622   0.000000e+00
# 457               0.581850   0.000000e+00
# 458               0.564056   0.000000e+00
# 441               0.551509   0.000000e+00
# 459               0.551408   0.000000e+00
# 460               0.533716   0.000000e+00
# 461               0.522743   0.000000e+00
# 462               0.508154   0.000000e+00
# 463               0.497595   0.000000e+00
# 440               0.496054   0.000000e+00
# 464               0.485163   0.000000e+00
# 465               0.474992   0.000000e+00
# 466               0.463192   0.000000e+00
# 467               0.454421   0.000000e+00
# 468               0.445331   0.000000e+00
# 439               0.441640   0.000000e+00
# 469               0.437472   0.000000e+00
# 470               0.427740   0.000000e+00
# 471               0.421334   0.000000e+00
# 438               0.373991   0.000000e+00
# 437               0.302647   0.000000e+00
# 436               0.210406   0.000000e+00
# 147               0.182455   0.000000e+00
# 288               0.182455   0.000000e+00
# 487               0.149004   0.000000e+00
# 157              -0.148870   0.000000e+00
# 486               0.148383   0.000000e+00
# 488               0.148031   0.000000e+00
# 490               0.148021   0.000000e+00
# 154              -0.147452   0.000000e+00
# 489               0.147345   0.000000e+00
# 495               0.147120   0.000000e+00
# 485               0.147114   0.000000e+00
# 492               0.146891   0.000000e+00
# 494               0.146797   0.000000e+00
# 491               0.146597   0.000000e+00
# 496               0.146341   0.000000e+00
# 493               0.146305   0.000000e+00
# 298              -0.145814   0.000000e+00
# 507               0.145729   0.000000e+00
# 497               0.145421   0.000000e+00
# 499               0.145203   0.000000e+00
# 505               0.145022   0.000000e+00
# 483               0.144902   0.000000e+00
# 506               0.144891   0.000000e+00
# 498               0.144612   0.000000e+00
# 504               0.144498   0.000000e+00
# 503               0.143875   0.000000e+00
# 484               0.143845   0.000000e+00
# 502               0.143738   0.000000e+00
# 501               0.143145   0.000000e+00
# 500               0.142849   0.000000e+00
# 295              -0.142837   0.000000e+00
# 482               0.142785   0.000000e+00
# 481               0.139924   0.000000e+00
# 480               0.137568   0.000000e+00
# 479               0.133648   0.000000e+00
# 478               0.128107   0.000000e+00
# 287               0.127007   0.000000e+00
# 146               0.121878   0.000000e+00
# 477               0.121195   0.000000e+00
# 476               0.111981   0.000000e+00
# 95                0.111531   0.000000e+00
# 236               0.107266   0.000000e+00
# 511               0.103488   0.000000e+00
# 475               0.102013   0.000000e+00
# 151              -0.101347   0.000000e+00
# 292              -0.100249   0.000000e+00
# 417               0.091537   0.000000e+00
# 474               0.088334   0.000000e+00
# 155               0.082614   0.000000e+00
# 427              -0.074179   0.000000e+00
# 129              -0.073782   0.000000e+00
# 473               0.073750   0.000000e+00
# 269              -0.073119   0.000000e+00
# 424              -0.071649   0.000000e+00
# 128              -0.070924   0.000000e+00
# 113               0.070147   0.000000e+00
# 254               0.067632   0.000000e+00
# 0                -0.064884   0.000000e+00
# 149               0.064105   0.000000e+00
# 87               -0.062928   0.000000e+00
# 290               0.062527   0.000000e+00
# 270              -0.060025   0.000000e+00
# 398              -0.059610   0.000000e+00
# 514              -0.059237   0.000000e+00
# 228              -0.058721   0.000000e+00
# 150              -0.057594   0.000000e+00
# 383               0.055487   0.000000e+00
# 518               0.054939   0.000000e+00
# 472               0.054515   0.000000e+00
# 291              -0.052424   0.000000e+00
# 268               0.050751   0.000000e+00
# 397               0.050375   0.000000e+00
# 421              -0.050355   0.000000e+00
# 127               0.048924   0.000000e+00
# 435               0.048350   0.000000e+00
# 426               0.044469   0.000000e+00
# 120               0.043810   0.000000e+00
# 261               0.043275   0.000000e+00
# 296               0.043074   0.000000e+00
# 32                0.042020   0.000000e+00
# 35                0.041301   0.000000e+00
# 29                0.041000   0.000000e+00
# 83                0.040973   0.000000e+00
# 259               0.040738   0.000000e+00
# 122               0.040084   0.000000e+00
# 260               0.040017   0.000000e+00
# 118               0.039863   0.000000e+00
# 416               0.039798   0.000000e+00
# 33                0.039595   0.000000e+00
# 263               0.039421   0.000000e+00
# 119               0.038934   0.000000e+00
# 286               0.038709   0.000000e+00
# 152               0.038651   0.000000e+00
# 508              -0.038343   0.000000e+00
# 224               0.038105   0.000000e+00
# 34                0.037939   0.000000e+00
# 285               0.037758   0.000000e+00
# 27                0.037317   0.000000e+00
# 30                0.037113   0.000000e+00
# 158              -0.037044   0.000000e+00
# 399              -0.036651   0.000000e+00
# 28                0.036544   0.000000e+00
# 293               0.036335   0.000000e+00
# 31                0.036278   0.000000e+00
# 365               0.036216   0.000000e+00
# 265               0.036043   0.000000e+00
# 162               0.035831   0.000000e+00
# 411              -0.035554   0.000000e+00
# 390               0.035231   0.000000e+00
# 161               0.034861   0.000000e+00
# 264               0.034737   0.000000e+00
# 123               0.033863   0.000000e+00
# 24                0.033320   0.000000e+00
# 388               0.032301  1.326282e-311
# 25                0.032238  2.141363e-310
# 392               0.032225  3.766234e-310
# 26                0.032213  6.354935e-310
# 159               0.031730  9.532728e-301
# 36                0.031699  3.542725e-300
# 389               0.031589  4.223345e-298
# 512              -0.030959  2.076943e-286
# 124               0.030581  1.646329e-279
# 414               0.030469  1.740583e-277
# 415               0.029202  4.812178e-255
# 145               0.027997  1.323533e-234
# 258               0.027644  8.856981e-229
# 156               0.027538  4.875020e-227
# 373               0.026915  5.754869e-217
# 23                0.026769  1.201802e-214
# 144               0.026681  3.042756e-213
# 419               0.026158  4.794928e-205
# 361              -0.026003  1.207489e-202
# 357              -0.025318  3.176932e-192
# 225              -0.025228  7.258953e-191
# 387               0.024910  3.910159e-186
# 297               0.024697  5.279403e-183
# 262               0.024493  5.025167e-180
# 117               0.023930  6.222210e-172
# 274               0.023923  7.832431e-172
# 133               0.023918  9.222854e-172
# 121               0.023739  3.105197e-169
# 18                0.023571  7.109031e-167
# 393               0.022903  1.160988e-157
# 141              -0.022827  1.245088e-156
# 21                0.022735  2.168917e-155
# 22                0.022603  1.301163e-153
# 394               0.021513  2.401169e-139
# 90                0.020959  2.342491e-132
# 84               -0.020613  4.371686e-128
# 17                0.020179  7.791368e-123
# 231               0.020087  9.903403e-122
# 78               -0.019572  1.153990e-115
# 418               0.019348  4.397787e-113
# 20                0.018322  1.308638e-101
# 16                0.017904   4.197774e-97
# 219              -0.017650   2.009630e-94
# 422               0.017513   5.384608e-93
# 403               0.017087   1.289512e-88
# 15                0.016265   1.783033e-80
# 301               0.015668   8.290371e-75
# 431              -0.015664   9.011516e-75
# 282              -0.015563   7.710468e-74
# 244               0.015515   2.165393e-73
# 103               0.015485   4.047590e-73
# 214              -0.015240   7.016436e-71
# 8                 0.015215   1.192779e-70
# 14                0.015061   2.865684e-69
# 9                 0.015008   8.546910e-69
# 299              -0.014974   1.719383e-68
# 160               0.014844   2.436606e-67
# 19                0.014813   4.596463e-67
# 428               0.014373   3.011250e-63
# 294               0.014299   1.301744e-62
# 391               0.013981   6.054397e-60
# 10                0.013699   1.266474e-57
# 13                0.013596   8.820128e-57
# 12                0.013445   1.443742e-55
# 82                0.013389   4.037528e-55
# 223               0.013201   1.238010e-53
# 85               -0.013191   1.477967e-53
# 509               0.013087   9.643415e-53
# 300               0.013027   2.809092e-52
# 352               0.012816   1.180274e-50
# 91               -0.012788   1.922480e-50
# 11                0.012697   9.350109e-50
# 372               0.012436   8.367595e-48
# 355              -0.012351   3.571830e-47
# 273              -0.012326   5.437085e-47
# 73               -0.012314   6.629410e-47
# 7                 0.012205   4.156290e-46
# 148              -0.011959   2.466289e-44
# 153               0.011518   2.984282e-41
# 344              -0.011474   5.997595e-41
# 306               0.011399   1.925815e-40
# 102               0.011259   1.713503e-39
# 226              -0.011240   2.281562e-39
# 243               0.011197   4.408417e-39
# 516               0.010879   5.464417e-37
# 348               0.010819   1.344210e-36
# 6                 0.010656   1.465674e-35
# 423               0.010005   1.508792e-31
# 380              -0.009920   4.853199e-31
# 412              -0.009691   1.058364e-29
# 354              -0.009627   2.473630e-29
# 232              -0.009510   1.160246e-28
# 517              -0.009483   1.657246e-28
# 135               0.009287   2.079583e-27
# 215              -0.008991   8.534606e-26
# 430               0.008928   1.861734e-25
# 266               0.008822   6.760451e-25
# 125               0.008663   4.600215e-24
# 5                 0.008613   8.354928e-24
# 276               0.008558   1.593389e-23
# 429              -0.008410   8.999397e-23
# 343              -0.008358   1.646917e-22
# 425               0.008317   2.623344e-22
# 245              -0.008137   2.033527e-21
# 289              -0.007711   2.145393e-19
# 104              -0.007701   2.385003e-19
# 4                 0.007524   1.533882e-18
# 420              -0.007042   1.953507e-16
# 405               0.007038   2.030800e-16
# 70                0.006995   3.081771e-16
# 338               0.006758   2.951395e-15
# 211               0.006557   1.880022e-14
# 110              -0.006509   2.909982e-14
# 209               0.006253   2.800539e-13
# 72                0.006235   3.293480e-13
# 250              -0.006122   8.649140e-13
# 432               0.006023   2.007835e-12
# 165               0.005932   4.261849e-12
# 402              -0.005825   1.020445e-11
# 68                0.005752   1.839973e-11
# 163               0.005709   2.598667e-11
# 340               0.005641   4.455574e-11
# 109              -0.005582   7.038691e-11
# 132              -0.005570   7.720635e-11
# 3                 0.005448   1.979190e-10
# 66                0.005281   6.939911e-10
# 207               0.005158   1.693681e-09
# 74               -0.005100   2.582531e-09
# 213               0.005052   3.616935e-09
# 305               0.004989   5.649147e-09
# 375              -0.004979   6.039751e-09
# 515              -0.004926   8.769799e-09
# 2                 0.004569   9.479117e-08
# 105              -0.004509   1.395315e-07
# 246              -0.004504   1.442250e-07
# 353               0.004463   1.861742e-07
# 336               0.004415   2.524468e-07
# 360              -0.004223   8.118363e-07
# 374              -0.004114   1.553080e-06
# 275              -0.003865   6.377331e-06
# 134              -0.003768   1.080106e-05
# 304              -0.003745   1.219376e-05
# 206               0.003663   1.884349e-05
# 175               0.003580   2.897799e-05
# 303               0.003539   3.568678e-05
# 71                0.003471   5.029837e-05
# 65                0.003470   5.056433e-05
# 342               0.003419   6.506350e-05
# 395               0.003392   7.436666e-05
# 69                0.003335   9.821489e-05
# 88               -0.003246   1.501396e-04
# 210               0.003220   1.695741e-04
# 166              -0.003219   1.698921e-04
# 280              -0.003197   1.883470e-04
# 335               0.003176   2.074341e-04
# 212               0.003175   2.083080e-04
# 378              -0.003141   2.438966e-04
# 327               0.003102   2.911230e-04
# 139              -0.003094   3.023696e-04
# 349              -0.003026   4.091999e-04
# 67                0.003016   4.283245e-04
# 379              -0.002970   5.230910e-04
# 409              -0.002953   5.627489e-04
# 358               0.002912   6.722538e-04
# 510              -0.002899   7.087119e-04
# 131              -0.002886   7.510390e-04
# 347               0.002840   9.113968e-04
# 208               0.002814   1.016204e-03
# 396               0.002757   1.281426e-03
# 267               0.002727   1.446780e-03
# 77                0.002710   1.548772e-03
# 218               0.002671   1.812661e-03
# 279              -0.002598   2.411097e-03
# 332               0.002564   2.747012e-03
# 126               0.002555   2.842981e-03
# 339               0.002521   3.235534e-03
# 143              -0.002489   3.647462e-03
# 99                0.002483   3.733855e-03
# 284              -0.002471   3.904897e-03
# 177              -0.002453   4.167733e-03
# 142               0.002418   4.750329e-03
# 94               -0.002405   4.968409e-03
# 330               0.002382   5.395711e-03
# 240               0.002378   5.473325e-03
# 408              -0.002364   5.753030e-03
# 326              -0.002349   6.072844e-03
# 138              -0.002343   6.201761e-03
# 203               0.002342   6.229818e-03
# 341               0.002333   6.426547e-03
# 513              -0.002328   6.545129e-03
# 198               0.002325   6.623629e-03
# 216               0.002308   7.020748e-03
# 350               0.002302   7.183645e-03
# 167              -0.002286   7.598462e-03
# 1                 0.002278   7.792733e-03
# 345               0.002263   8.206852e-03
# 172               0.002243   8.802702e-03
# 197              -0.002236   9.015412e-03
# 80                0.002223   9.417236e-03
# 235              -0.002190   1.054338e-02
# 62                0.002187   1.063255e-02
# 221               0.002184   1.074115e-02
# 75                0.002151   1.201383e-02
# 337               0.002133   1.272350e-02
# 56               -0.002129   1.290378e-02
# 57                0.002088   1.473341e-02
# 204               0.002078   1.524582e-02
# 173               0.002004   1.923609e-02
# 229              -0.001974   2.113917e-02
# 220              -0.001930   2.421497e-02
# 333               0.001917   2.515336e-02
# 64                0.001887   2.757341e-02
# 413              -0.001879   2.820286e-02
# 189              -0.001869   2.905143e-02
# 63                0.001857   3.013479e-02
# 171               0.001837   3.188150e-02
# 108              -0.001817   3.383198e-02
# 310              -0.001813   3.420319e-02
# 302               0.001806   3.495407e-02
# 367               0.001802   3.535118e-02
# 48               -0.001793   3.626154e-02
# 230               0.001770   3.868907e-02
# 89                0.001767   3.902469e-02
# 328               0.001743   4.182358e-02
# 329               0.001725   4.390415e-02
# 205               0.001724   4.402198e-02
# 318              -0.001724   4.408544e-02
# 249              -0.001708   4.604729e-02
# 181              -0.001697   4.747661e-02
# 381               0.001680   4.980824e-02
# 331               0.001645   5.468610e-02
# 40               -0.001643   5.493101e-02
# 107               0.001629   5.709213e-02
# 106               0.001629   5.709213e-02
# 376               0.001629   5.711352e-02
# 248               0.001629   5.712006e-02
# 247               0.001629   5.712416e-02
# 377               0.001629   5.716903e-02
# 369               0.001624   5.792051e-02
# 201               0.001535   7.300606e-02
# 251               0.001503   7.917069e-02
# 272              -0.001478   8.428287e-02
# 98               -0.001473   8.539598e-02
# 359               0.001471   8.572641e-02
# 202               0.001471   8.574680e-02
# 192              -0.001437   9.320067e-02
# 52               -0.001434   9.393795e-02
# 351              -0.001421   9.687598e-02
# 193              -0.001397   1.027979e-01
# 60                0.001390   1.045002e-01
# 222               0.001380   1.069756e-01
# 86               -0.001350   1.148443e-01
# 115              -0.001350   1.148443e-01
# 112              -0.001350   1.148443e-01
# 130              -0.001350   1.148443e-01
# 114              -0.001350   1.148443e-01
# 382              -0.001350   1.148443e-01
# 385              -0.001350   1.148455e-01
# 256              -0.001350   1.148531e-01
# 271              -0.001350   1.148540e-01
# 255              -0.001350   1.148543e-01
# 384              -0.001350   1.148585e-01
# 227              -0.001350   1.148611e-01
# 400              -0.001350   1.148837e-01
# 253              -0.001350   1.148882e-01
# 356              -0.001350   1.148983e-01
# 61                0.001327   1.211322e-01
# 50               -0.001308   1.265711e-01
# 277              -0.001304   1.278420e-01
# 136              -0.001293   1.309061e-01
# 81                0.001291   1.315764e-01
# 191              -0.001290   1.318493e-01
# 346               0.001284   1.338318e-01
# 366               0.001277   1.358355e-01
# 200               0.001271   1.376273e-01
# 137               0.001267   1.388152e-01
# 79               -0.001263   1.403419e-01
# 278               0.001262   1.405614e-01
# 401               0.001253   1.434261e-01
# 140               0.001242   1.467513e-01
# 51               -0.001238   1.480782e-01
# 239              -0.001220   1.543554e-01
# 334               0.001213   1.565599e-01
# 281               0.001207   1.585087e-01
# 410               0.001201   1.605516e-01
# 97                0.001193   1.635697e-01
# 371              -0.001167   1.730375e-01
# 185              -0.001163   1.745416e-01
# 100              -0.001162   1.748844e-01
# 368              -0.001160   1.754516e-01
# 54               -0.001155   1.774218e-01
# 386               0.001149   1.794639e-01
# 241              -0.001140   1.831931e-01
# 96                0.001119   1.911739e-01
# 188              -0.001105   1.968476e-01
# 237               0.001101   1.985898e-01
# 169              -0.001095   2.007537e-01
# 59                0.001085   2.052321e-01
# 187              -0.001078   2.078349e-01
# 195              -0.000990   2.477658e-01
# 184              -0.000980   2.523074e-01
# 199               0.000977   2.537467e-01
# 44               -0.000977   2.537560e-01
# 46               -0.000970   2.572879e-01
# 370              -0.000955   2.646881e-01
# 194              -0.000954   2.653246e-01
# 217               0.000900   2.933375e-01
# 364              -0.000885   3.015779e-01
# 238               0.000864   3.130781e-01
# 47               -0.000862   3.140851e-01
# 183              -0.000857   3.169299e-01
# 283              -0.000854   3.184198e-01
# 242              -0.000853   3.192704e-01
# 58                0.000845   3.234853e-01
# 101              -0.000838   3.276222e-01
# 311               0.000835   3.297357e-01
# 190              -0.000832   3.312454e-01
# 53               -0.000827   3.338531e-01
# 76                0.000784   3.597750e-01
# 307               0.000773   3.667206e-01
# 42               -0.000759   3.756702e-01
# 116              -0.000740   3.872754e-01
# 180              -0.000732   3.926503e-01
# 433               0.000730   3.937644e-01
# 257              -0.000727   3.960680e-01
# 186              -0.000719   4.011608e-01
# 174              -0.000706   4.096808e-01
# 434               0.000704   4.112553e-01
# 49               -0.000686   4.230400e-01
# 233               0.000682   4.258110e-01
# 168              -0.000657   4.426869e-01
# 325               0.000657   4.430604e-01
# 92                0.000628   4.634410e-01
# 170               0.000625   4.652242e-01
# 43               -0.000609   4.768078e-01
# 322              -0.000598   4.849848e-01
# 406              -0.000589   4.912095e-01
# 179              -0.000563   5.107917e-01
# 38               -0.000553   5.180552e-01
# 321              -0.000541   5.275028e-01
# 362               0.000528   5.372708e-01
# 320              -0.000493   5.649653e-01
# 363               0.000447   6.012802e-01
# 93                0.000444   6.044639e-01
# 39               -0.000430   6.157865e-01
# 314              -0.000421   6.233135e-01
# 234               0.000391   6.478892e-01
# 319               0.000382   6.553306e-01
# 45               -0.000376   6.605838e-01
# 196              -0.000316   7.118132e-01
# 37                0.000304   7.228040e-01
# 55               -0.000232   7.860397e-01
# 317              -0.000221   7.965692e-01
# 316              -0.000211   8.055005e-01
# 182              -0.000207   8.092880e-01
# 176               0.000204   8.115534e-01
# 315               0.000199   8.163949e-01
# 313              -0.000198   8.175064e-01
# 309              -0.000125   8.836805e-01
# 404              -0.000120   8.881470e-01
# 178               0.000112   8.956956e-01
# 111               0.000101   9.059571e-01
# 324              -0.000095   9.116036e-01
# 41                0.000090   9.165596e-01
# 312              -0.000082   9.241650e-01
# 252              -0.000079   9.267269e-01
# 323              -0.000063   9.415178e-01
# 164               0.000040   9.625568e-01
# 407              -0.000024   9.775590e-01
# 308              -0.000023   9.784763e-01
